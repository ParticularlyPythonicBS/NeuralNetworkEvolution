# %%
# %env "WANDB_NOTEBOOK_NAME" "13_homo_poly_loss_strat.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="13_homo_poly_loss_strat.ipynb"
# env: WANDB_SILENT=True
# env: XLA_PYTHON_CLIENT_MEM_FRACTION=0.3

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

import os
import sys
import logging
from tqdm.notebook import trange
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='viridis', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
input_size = 1
hidden_sizes = [10, 10] 
output_size = 1
initial_activation_list = [sin]
activation_list = [sin]
bias = False
num_epochs = 3000
add_node_every = 50
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
n_samples = 2000
learning_rate = 0.01

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)
# Out:
# 2024-06-04 13:02:46.863329: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.4.131). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'add_node_every': add_node_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
jax.config.update('jax_platform_name', 'cpu')
Description = f"Homo_poly_loss_strat__no_bias_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{add_node_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 4
# Description: Homo_poly_loss_strat__no_bias_10_10_3000_50_0.0001_0
# jax backend: cpu
# jax devices: [cuda(id=0), cuda(id=1), cuda(id=2), cuda(id=3)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %%
def initialize_optimizer_state(mlp, optimizer):
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
mlp = CustomMLP(config)

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
def poly(x):
    return (x - 3)*(x - 2)*(x - 1)*x*(x + 1)*(x + 2)*(x + 3)

# %%
x = jnp.linspace(-3, 3, n_samples).reshape(-1, 1)
y = poly(x)

# %%
plt.plot(x,y)

# %%
opt = optax.adabelief(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
plt.matshow(initial_adjacency_matrix, cmap=plt.cm.viridis)
plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %%
Loss_history = []
Node_history = []
graph_history = []
Update_history = []

# %%
for epoch in range(num_epochs):
    loss, mlp, opt_state = train_step(mlp, x, y, opt_state, opt.update)

    key, add_key, sub_key = jax.random.split(key,3)
    n_neurons = sum(mlp.get_shape())
    logging.info(f"Epoch {epoch :03d}, Loss: {loss.item()}, Neurons: {n_neurons}")
    wandb.log({"loss": loss.item(), "neurons": n_neurons})
    Loss_history.append(loss)
    Node_history.append(n_neurons)


    # Dynamically add or remove neurons
    if (epoch + 1) % add_node_every == 0:

        #add criterion
        if len(Update_history) == 0 or Update_history[-1][2] > loss or (Update_history[-1][3] == "removed" and Update_history[-2][3] == "removed" ):
            # if no previous addition or last addition was rejected, add a neuron
            # if last addition was accepted, add a neuron
            # if two removals in a row, add a neuron
            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0]
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            Update_history.append((epoch, n_neurons, loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
        
        # remove criteria
        elif (Update_history[-1][3] == "removed" and Update_history[-2][2] < loss) or \
            (Update_history[-1][3] != "removed" and Update_history[-1][2] < loss):
            # if last addition was removed check loss against value before that
            # if last addition was accepted, check loss against it
            # if loss doesn't improve, reject it
            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            layer = Update_history[-1][4]
            neuron_idx = len(mlp.layers[layer]) -1

            if len(mlp.layers[layer]) <= 1:
                logging.info(f"Cannot remove neuron from layer {layer+1}, only one neuron left")
                Update_history.append((epoch, n_neurons, loss, "single_node_layer", layer))
                continue

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            Update_history.append((epoch, n_neurons, loss, "removed", layer))

            logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
            wandb.log({"removed neuron": neuron_idx})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
        
        
    if loss < threshold:
        # if loss is below threshold, stop training
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break
# Out:
# Epoch 000, Loss: 1512.1080430202317, Neurons: 21
# Epoch 001, Loss: 1507.64402298578, Neurons: 21
# Epoch 002, Loss: 1502.9602775063718, Neurons: 21
# Epoch 003, Loss: 1497.997891767339, Neurons: 21
# Epoch 004, Loss: 1492.7360276621664, Neurons: 21
# Epoch 005, Loss: 1487.1664690813172, Neurons: 21
# Epoch 006, Loss: 1481.3004222276109, Neurons: 21
# Epoch 007, Loss: 1475.1897244954712, Neurons: 21
# Epoch 008, Loss: 1468.9316896921443, Neurons: 21
# Epoch 009, Loss: 1462.6567799500976, Neurons: 21
# Epoch 010, Loss: 1456.511846462762, Neurons: 21
# Epoch 011, Loss: 1450.6285030355439, Neurons: 21
# Epoch 012, Loss: 1445.0723447654857, Neurons: 21
# Epoch 013, Loss: 1439.8294235280785, Neurons: 21
# Epoch 014, Loss: 1434.834645514762, Neurons: 21
# Epoch 015, Loss: 1430.000629198534, Neurons: 21
# Epoch 016, Loss: 1425.2340596377794, Neurons: 21
# Epoch 017, Loss: 1420.4460961875743, Neurons: 21
# Epoch 018, Loss: 1415.5621529668504, Neurons: 21
# Epoch 019, Loss: 1410.5295839088276, Neurons: 21
# Epoch 020, Loss: 1405.3257255065953, Neurons: 21
# Epoch 021, Loss: 1399.961712122439, Neurons: 21
# Epoch 022, Loss: 1394.4716359350336, Neurons: 21
# Epoch 023, Loss: 1388.8880228216694, Neurons: 21
# Epoch 024, Loss: 1383.2232208441378, Neurons: 21
# Epoch 025, Loss: 1377.4684041539472, Neurons: 21
# Epoch 026, Loss: 1371.602365053119, Neurons: 21
# Epoch 027, Loss: 1365.6097957349066, Neurons: 21
# Epoch 028, Loss: 1359.502858989613, Neurons: 21
# Epoch 029, Loss: 1353.3192567116118, Neurons: 21
# Epoch 030, Loss: 1347.0896503856957, Neurons: 21
# Epoch 031, Loss: 1340.800947143534, Neurons: 21
# Epoch 032, Loss: 1334.3874576207027, Neurons: 21
# Epoch 033, Loss: 1327.7575213826194, Neurons: 21
# Epoch 034, Loss: 1320.831246718224, Neurons: 21
# Epoch 035, Loss: 1313.5612900964832, Neurons: 21
# Epoch 036, Loss: 1305.9313195020588, Neurons: 21
# Epoch 037, Loss: 1297.9367680164187, Neurons: 21
# Epoch 038, Loss: 1289.5544082214835, Neurons: 21
# Epoch 039, Loss: 1280.7186389274434, Neurons: 21
# Epoch 040, Loss: 1271.3247089518923, Neurons: 21
# Epoch 041, Loss: 1261.252478501715, Neurons: 21
# Epoch 042, Loss: 1250.3900025986538, Neurons: 21
# Epoch 043, Loss: 1238.6542948743374, Neurons: 21
# Epoch 044, Loss: 1226.0130562149593, Neurons: 21
# Epoch 045, Loss: 1212.4994075558234, Neurons: 21
# Epoch 046, Loss: 1198.211426080295, Neurons: 21
# Epoch 047, Loss: 1183.3009963977643, Neurons: 21
# Epoch 048, Loss: 1167.9649796281267, Neurons: 21
# Epoch 049, Loss: 1152.4492531964747, Neurons: 21
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[10, 11, 1]
# Epoch 050, Loss: 1141.814900120247, Neurons: 22
# Epoch 051, Loss: 1134.58617570927, Neurons: 22
# Epoch 052, Loss: 1127.3670045006413, Neurons: 22
# Epoch 053, Loss: 1120.0606188406005, Neurons: 22
# Epoch 054, Loss: 1112.5546508721134, Neurons: 22
# Epoch 055, Loss: 1104.8616689143978, Neurons: 22
# Epoch 056, Loss: 1097.0339953620103, Neurons: 22
# Epoch 057, Loss: 1089.1106402200762, Neurons: 22
# Epoch 058, Loss: 1081.1391562114181, Neurons: 22
# Epoch 059, Loss: 1073.1800864761035, Neurons: 22
# Epoch 060, Loss: 1065.311603066431, Neurons: 22
# Epoch 061, Loss: 1057.6223390219673, Neurons: 22
# Epoch 062, Loss: 1050.1792341337507, Neurons: 22
# Epoch 063, Loss: 1043.0289853435715, Neurons: 22
# Epoch 064, Loss: 1036.2127192688947, Neurons: 22
# Epoch 065, Loss: 1029.7263013674365, Neurons: 22
# Epoch 066, Loss: 1023.5040860940977, Neurons: 22
# Epoch 067, Loss: 1017.4505844372438, Neurons: 22
# Epoch 068, Loss: 1011.4772165186298, Neurons: 22
# Epoch 069, Loss: 1005.5018204670804, Neurons: 22
# Epoch 070, Loss: 999.4473741428018, Neurons: 22
# Epoch 071, Loss: 993.2635359245924, Neurons: 22
# Epoch 072, Loss: 986.9247145095097, Neurons: 22
# Epoch 073, Loss: 980.4216781750929, Neurons: 22
# Epoch 074, Loss: 973.7506670504879, Neurons: 22
# Epoch 075, Loss: 966.9177294994535, Neurons: 22
# Epoch 076, Loss: 959.9446483753612, Neurons: 22
# Epoch 077, Loss: 952.8622458637324, Neurons: 22
# Epoch 078, Loss: 945.7013669796023, Neurons: 22
# Epoch 079, Loss: 938.4922632750261, Neurons: 22
# Epoch 080, Loss: 931.2627956405278, Neurons: 22
# Epoch 081, Loss: 924.0318974447365, Neurons: 22
# Epoch 082, Loss: 916.8084787735427, Neurons: 22
# Epoch 083, Loss: 909.5935945559922, Neurons: 22
# Epoch 084, Loss: 902.3830482533375, Neurons: 22
# Epoch 085, Loss: 895.1643827460384, Neurons: 22
# Epoch 086, Loss: 887.9163004396928, Neurons: 22
# Epoch 087, Loss: 880.6175002768447, Neurons: 22
# Epoch 088, Loss: 873.2546303558986, Neurons: 22
# Epoch 089, Loss: 865.821032477977, Neurons: 22
# Epoch 090, Loss: 858.3132459955851, Neurons: 22
# Epoch 091, Loss: 850.7317147075322, Neurons: 22
# Epoch 092, Loss: 843.082027091574, Neurons: 22
# Epoch 093, Loss: 835.3736012472928, Neurons: 22
# Epoch 094, Loss: 827.6178053689296, Neurons: 22
# Epoch 095, Loss: 819.8261146430457, Neurons: 22
# Epoch 096, Loss: 812.0068656193712, Neurons: 22
# Epoch 097, Loss: 804.1626494841555, Neurons: 22
# Epoch 098, Loss: 796.2909613469922, Neurons: 22
# Epoch 099, Loss: 788.3857978056011, Neurons: 22
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[10, 12, 1]
# Epoch 100, Loss: 780.7108826405557, Neurons: 23
# Epoch 101, Loss: 777.1577131520359, Neurons: 23
# Epoch 102, Loss: 773.5557345116686, Neurons: 23
# Epoch 103, Loss: 768.9598886406495, Neurons: 23
# Epoch 104, Loss: 764.7664922856022, Neurons: 23
# Epoch 105, Loss: 760.1551287746781, Neurons: 23
# Epoch 106, Loss: 755.2978090644165, Neurons: 23
# Epoch 107, Loss: 750.4199934253255, Neurons: 23
# Epoch 108, Loss: 745.1380926577165, Neurons: 23
# Epoch 109, Loss: 739.5274103182165, Neurons: 23
# Epoch 110, Loss: 733.8677972436175, Neurons: 23
# Epoch 111, Loss: 728.011409930581, Neurons: 23
# Epoch 112, Loss: 721.8969724008372, Neurons: 23
# Epoch 113, Loss: 715.6734270521398, Neurons: 23
# Epoch 114, Loss: 709.3136384344622, Neurons: 23
# Epoch 115, Loss: 702.7208472117181, Neurons: 23
# Epoch 116, Loss: 695.9811637233843, Neurons: 23
# Epoch 117, Loss: 689.1434144173824, Neurons: 23
# Epoch 118, Loss: 682.0969659168995, Neurons: 23
# Epoch 119, Loss: 674.8193576227914, Neurons: 23
# Epoch 120, Loss: 667.3846799363542, Neurons: 23
# Epoch 121, Loss: 659.7564384685281, Neurons: 23
# Epoch 122, Loss: 651.8718079964634, Neurons: 23
# Epoch 123, Loss: 643.7850387968386, Neurons: 23
# Epoch 124, Loss: 635.5339305060464, Neurons: 23
# Epoch 125, Loss: 627.1031551956029, Neurons: 23
# Epoch 126, Loss: 618.5439311206809, Neurons: 23
# Epoch 127, Loss: 609.9206783024159, Neurons: 23
# Epoch 128, Loss: 601.2445004868651, Neurons: 23
# Epoch 129, Loss: 592.5758474678404, Neurons: 23
# Epoch 130, Loss: 584.010020040629, Neurons: 23
# Epoch 131, Loss: 575.5765950188278, Neurons: 23
# Epoch 132, Loss: 567.315105668485, Neurons: 23
# Epoch 133, Loss: 559.2685008195253, Neurons: 23
# Epoch 134, Loss: 551.422171546523, Neurons: 23
# Epoch 135, Loss: 543.7984941822189, Neurons: 23
# Epoch 136, Loss: 536.3900431241298, Neurons: 23
# Epoch 137, Loss: 529.1623389740286, Neurons: 23
# Epoch 138, Loss: 522.1180599552831, Neurons: 23
# Epoch 139, Loss: 515.2160395412953, Neurons: 23
# Epoch 140, Loss: 508.4491808080898, Neurons: 23
# Epoch 141, Loss: 501.8067321688477, Neurons: 23
# Epoch 142, Loss: 495.27517360517635, Neurons: 23
# Epoch 143, Loss: 488.8612872373875, Neurons: 23
# Epoch 144, Loss: 482.54307387064665, Neurons: 23
# Epoch 145, Loss: 476.3230443420746, Neurons: 23
# Epoch 146, Loss: 470.18049011511454, Neurons: 23
# Epoch 147, Loss: 464.1072036467625, Neurons: 23
# Epoch 148, Loss: 458.0865749208742, Neurons: 23
# Epoch 149, Loss: 452.09961302448625, Neurons: 23
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[11, 12, 1]
# Epoch 150, Loss: 446.6684290312169, Neurons: 24
# Epoch 151, Loss: 449.1877167519416, Neurons: 24
# Epoch 152, Loss: 442.2664934989922, Neurons: 24
# Epoch 153, Loss: 440.57406699665313, Neurons: 24
# Epoch 154, Loss: 438.51134346060843, Neurons: 24
# Epoch 155, Loss: 434.7249946962127, Neurons: 24
# Epoch 156, Loss: 431.24192210377936, Neurons: 24
# Epoch 157, Loss: 428.63553368284374, Neurons: 24
# Epoch 158, Loss: 425.81181645762996, Neurons: 24
# Epoch 159, Loss: 422.2642108161352, Neurons: 24
# Epoch 160, Loss: 418.6425706924268, Neurons: 24
# Epoch 161, Loss: 415.4617041315439, Neurons: 24
# Epoch 162, Loss: 412.4368758451789, Neurons: 24
# Epoch 163, Loss: 409.0235413694453, Neurons: 24
# Epoch 164, Loss: 405.17862876025293, Neurons: 24
# Epoch 165, Loss: 401.3503617940148, Neurons: 24
# Epoch 166, Loss: 397.8519367576435, Neurons: 24
# Epoch 167, Loss: 394.4741463834064, Neurons: 24
# Epoch 168, Loss: 390.8365764018792, Neurons: 24
# Epoch 169, Loss: 386.9095882035918, Neurons: 24
# Epoch 170, Loss: 382.9700224023229, Neurons: 24
# Epoch 171, Loss: 379.18806710355403, Neurons: 24
# Epoch 172, Loss: 375.44987611786974, Neurons: 24
# Epoch 173, Loss: 371.5958309068227, Neurons: 24
# Epoch 174, Loss: 367.65680618837183, Neurons: 24
# Epoch 175, Loss: 363.76626380515285, Neurons: 24
# Epoch 176, Loss: 359.939198937474, Neurons: 24
# Epoch 177, Loss: 356.06099463015516, Neurons: 24
# Epoch 178, Loss: 352.0877747264442, Neurons: 24
# Epoch 179, Loss: 348.12321182511374, Neurons: 24
# Epoch 180, Loss: 344.25861091307866, Neurons: 24
# Epoch 181, Loss: 340.4441443951559, Neurons: 24
# Epoch 182, Loss: 336.58499935097194, Neurons: 24
# Epoch 183, Loss: 332.6895505709246, Neurons: 24
# Epoch 184, Loss: 328.83860596202743, Neurons: 24
# Epoch 185, Loss: 325.05214795327095, Neurons: 24
# Epoch 186, Loss: 321.2768537451712, Neurons: 24
# Epoch 187, Loss: 317.49539078937767, Neurons: 24
# Epoch 188, Loss: 313.75445334476746, Neurons: 24
# Epoch 189, Loss: 310.0752161488818, Neurons: 24
# Epoch 190, Loss: 306.4200078698525, Neurons: 24
# Epoch 191, Loss: 302.7694044344976, Neurons: 24
# Epoch 192, Loss: 299.1601811067016, Neurons: 24
# Epoch 193, Loss: 295.61742419702836, Neurons: 24
# Epoch 194, Loss: 292.11195854411426, Neurons: 24
# Epoch 195, Loss: 288.62004209642055, Neurons: 24
# Epoch 196, Loss: 285.1667003255909, Neurons: 24
# Epoch 197, Loss: 281.7754682070524, Neurons: 24
# Epoch 198, Loss: 278.42984226444264, Neurons: 24
# Epoch 199, Loss: 275.11442819576945, Neurons: 24
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[11, 13, 1]
# Epoch 200, Loss: 284.9697628013325, Neurons: 25
# Epoch 201, Loss: 289.7181690704883, Neurons: 25
# Epoch 202, Loss: 281.5139260175829, Neurons: 25
# Epoch 203, Loss: 281.3594102687252, Neurons: 25
# Epoch 204, Loss: 280.0487437430764, Neurons: 25
# Epoch 205, Loss: 275.39330549697763, Neurons: 25
# Epoch 206, Loss: 271.6636905393362, Neurons: 25
# Epoch 207, Loss: 270.02402166438776, Neurons: 25
# Epoch 208, Loss: 268.0413413194397, Neurons: 25
# Epoch 209, Loss: 264.3532776467273, Neurons: 25
# Epoch 210, Loss: 259.9541256841478, Neurons: 25
# Epoch 211, Loss: 256.26400452484825, Neurons: 25
# Epoch 212, Loss: 253.45541801019803, Neurons: 25
# Epoch 213, Loss: 250.46333688885878, Neurons: 25
# Epoch 214, Loss: 246.66137188704752, Neurons: 25
# Epoch 215, Loss: 242.57607386757522, Neurons: 25
# Epoch 216, Loss: 238.97557314542559, Neurons: 25
# Epoch 217, Loss: 235.92894282674203, Neurons: 25
# Epoch 218, Loss: 232.92313902573096, Neurons: 25
# Epoch 219, Loss: 229.68906362514687, Neurons: 25
# Epoch 220, Loss: 226.5244544609526, Neurons: 25
# Epoch 221, Loss: 223.8472359473545, Neurons: 25
# Epoch 222, Loss: 221.6490621473799, Neurons: 25
# Epoch 223, Loss: 219.53028455909603, Neurons: 25
# Epoch 224, Loss: 217.2500501886664, Neurons: 25
# Epoch 225, Loss: 214.98182344232737, Neurons: 25
# Epoch 226, Loss: 212.9721015017468, Neurons: 25
# Epoch 227, Loss: 211.1512696109135, Neurons: 25
# Epoch 228, Loss: 209.23450513929933, Neurons: 25
# Epoch 229, Loss: 207.1205102075443, Neurons: 25
# Epoch 230, Loss: 204.98733958324138, Neurons: 25
# Epoch 231, Loss: 202.9975426489556, Neurons: 25
# Epoch 232, Loss: 201.0640518844767, Neurons: 25
# Epoch 233, Loss: 199.0080295842397, Neurons: 25
# Epoch 234, Loss: 196.83975007445028, Neurons: 25
# Epoch 235, Loss: 194.72111050470937, Neurons: 25
# Epoch 236, Loss: 192.71010189811076, Neurons: 25
# Epoch 237, Loss: 190.70016740138246, Neurons: 25
# Epoch 238, Loss: 188.62021112346545, Neurons: 25
# Epoch 239, Loss: 186.54941724120914, Neurons: 25
# Epoch 240, Loss: 184.57746408934668, Neurons: 25
# Epoch 241, Loss: 182.6647507382252, Neurons: 25
# Epoch 242, Loss: 180.73302590145877, Neurons: 25
# Epoch 243, Loss: 178.81005687115425, Neurons: 25
# Epoch 244, Loss: 176.97308128349007, Neurons: 25
# Epoch 245, Loss: 175.21202504493587, Neurons: 25
# Epoch 246, Loss: 173.45958613017456, Neurons: 25
# Epoch 247, Loss: 171.71630730119196, Neurons: 25
# Epoch 248, Loss: 170.0390164003003, Neurons: 25
# Epoch 249, Loss: 168.42890291268958, Neurons: 25
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[12, 13, 1]
# Epoch 250, Loss: 1399.599086885356, Neurons: 26
# Epoch 251, Loss: 1124.867029059629, Neurons: 26
# Epoch 252, Loss: 883.7729813617268, Neurons: 26
# Epoch 253, Loss: 684.4498106889997, Neurons: 26
# Epoch 254, Loss: 530.0901387950458, Neurons: 26
# Epoch 255, Loss: 418.31577724942844, Neurons: 26
# Epoch 256, Loss: 341.7470893080848, Neurons: 26
# Epoch 257, Loss: 290.82348389468444, Neurons: 26
# Epoch 258, Loss: 257.07253201093624, Neurons: 26
# Epoch 259, Loss: 234.1145568210723, Neurons: 26
# Epoch 260, Loss: 217.53607163256802, Neurons: 26
# Epoch 261, Loss: 204.66035734460334, Neurons: 26
# Epoch 262, Loss: 194.271999214925, Neurons: 26
# Epoch 263, Loss: 186.20731291280194, Neurons: 26
# Epoch 264, Loss: 180.83744828033022, Neurons: 26
# Epoch 265, Loss: 178.54896335229952, Neurons: 26
# Epoch 266, Loss: 179.3426737822077, Neurons: 26
# Epoch 267, Loss: 182.6634468114456, Neurons: 26
# Epoch 268, Loss: 187.50563565159962, Neurons: 26
# Epoch 269, Loss: 192.6985296206099, Neurons: 26
# Epoch 270, Loss: 197.1906319557473, Neurons: 26
# Epoch 271, Loss: 200.2144574162236, Neurons: 26
# Epoch 272, Loss: 201.32844233959946, Neurons: 26
# Epoch 273, Loss: 200.3873681996272, Neurons: 26
# Epoch 274, Loss: 197.48731350703616, Neurons: 26
# Epoch 275, Loss: 192.9084478366322, Neurons: 26
# Epoch 276, Loss: 187.06201100173445, Neurons: 26
# Epoch 277, Loss: 180.43985786428814, Neurons: 26
# Epoch 278, Loss: 173.5632052607509, Neurons: 26
# Epoch 279, Loss: 166.92902072118406, Neurons: 26
# Epoch 280, Loss: 160.95619726581523, Neurons: 26
# Epoch 281, Loss: 155.93798227341347, Neurons: 26
# Epoch 282, Loss: 152.010414635841, Neurons: 26
# Epoch 283, Loss: 149.14660194540198, Neurons: 26
# Epoch 284, Loss: 147.18182492111438, Neurons: 26
# Epoch 285, Loss: 145.86529396582173, Neurons: 26
# Epoch 286, Loss: 144.92482283653598, Neurons: 26
# Epoch 287, Loss: 144.1260535961135, Neurons: 26
# Epoch 288, Loss: 143.31090858895243, Neurons: 26
# Epoch 289, Loss: 142.40866898964066, Neurons: 26
# Epoch 290, Loss: 141.4226700577046, Neurons: 26
# Epoch 291, Loss: 140.4020241369979, Neurons: 26
# Epoch 292, Loss: 139.40965052125318, Neurons: 26
# Epoch 293, Loss: 138.49601497669934, Neurons: 26
# Epoch 294, Loss: 137.68405982486195, Neurons: 26
# Epoch 295, Loss: 136.96648459037672, Neurons: 26
# Epoch 296, Loss: 136.31301646744052, Neurons: 26
# Epoch 297, Loss: 135.6832493507264, Neurons: 26
# Epoch 298, Loss: 135.04017615140526, Neurons: 26
# Epoch 299, Loss: 134.36041827137782, Neurons: 26
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[12, 14, 1]
# Epoch 300, Loss: 130.11669771563558, Neurons: 27
# Epoch 301, Loss: 130.31362028490722, Neurons: 27
# Epoch 302, Loss: 125.3128600277165, Neurons: 27
# Epoch 303, Loss: 122.69219705549665, Neurons: 27
# Epoch 304, Loss: 122.26055949101571, Neurons: 27
# Epoch 305, Loss: 120.36045486823268, Neurons: 27
# Epoch 306, Loss: 117.51855409949947, Neurons: 27
# Epoch 307, Loss: 115.60043064810168, Neurons: 27
# Epoch 308, Loss: 114.39710045606105, Neurons: 27
# Epoch 309, Loss: 112.6596546628973, Neurons: 27
# Epoch 310, Loss: 110.47784777099159, Neurons: 27
# Epoch 311, Loss: 108.48855195494447, Neurons: 27
# Epoch 312, Loss: 106.73067092857254, Neurons: 27
# Epoch 313, Loss: 104.90437109493254, Neurons: 27
# Epoch 314, Loss: 102.93028811150475, Neurons: 27
# Epoch 315, Loss: 100.94917957979342, Neurons: 27
# Epoch 316, Loss: 99.0178682100274, Neurons: 27
# Epoch 317, Loss: 97.06234246104502, Neurons: 27
# Epoch 318, Loss: 95.12846785034506, Neurons: 27
# Epoch 319, Loss: 93.26616023371662, Neurons: 27
# Epoch 320, Loss: 91.29789773490678, Neurons: 27
# Epoch 321, Loss: 89.21359996320238, Neurons: 27
# Epoch 322, Loss: 87.28198270893009, Neurons: 27
# Epoch 323, Loss: 85.54455180224558, Neurons: 27
# Epoch 324, Loss: 83.71778981613053, Neurons: 27
# Epoch 325, Loss: 81.71092928908976, Neurons: 27
# Epoch 326, Loss: 79.77697190624983, Neurons: 27
# Epoch 327, Loss: 78.04598181970422, Neurons: 27
# Epoch 328, Loss: 76.28380354097136, Neurons: 27
# Epoch 329, Loss: 74.37625699484099, Neurons: 27
# Epoch 330, Loss: 72.51193610047387, Neurons: 27
# Epoch 331, Loss: 70.76267436561898, Neurons: 27
# Epoch 332, Loss: 68.9990484455588, Neurons: 27
# Epoch 333, Loss: 67.18634729021791, Neurons: 27
# Epoch 334, Loss: 65.40988258714715, Neurons: 27
# Epoch 335, Loss: 63.70091154290334, Neurons: 27
# Epoch 336, Loss: 62.039967919243864, Neurons: 27
# Epoch 337, Loss: 60.406973658877526, Neurons: 27
# Epoch 338, Loss: 58.7745276527816, Neurons: 27
# Epoch 339, Loss: 57.1864441715895, Neurons: 27
# Epoch 340, Loss: 55.68962362280095, Neurons: 27
# Epoch 341, Loss: 54.20574155582804, Neurons: 27
# Epoch 342, Loss: 52.70623018344064, Neurons: 27
# Epoch 343, Loss: 51.284429252292014, Neurons: 27
# Epoch 344, Loss: 49.92672443875003, Neurons: 27
# Epoch 345, Loss: 48.561394733098865, Neurons: 27
# Epoch 346, Loss: 47.2375623488254, Neurons: 27
# Epoch 347, Loss: 45.98101757522754, Neurons: 27
# Epoch 348, Loss: 44.744649306461184, Neurons: 27
# Epoch 349, Loss: 43.53051039478292, Neurons: 27
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[13, 14, 1]
# Epoch 350, Loss: 42.486939403263094, Neurons: 28
# Epoch 351, Loss: 67.79131112550458, Neurons: 28
# Epoch 352, Loss: 43.526714523467874, Neurons: 28
# Epoch 353, Loss: 47.52425556076547, Neurons: 28
# Epoch 354, Loss: 55.61424213548248, Neurons: 28
# Epoch 355, Loss: 50.630654646031324, Neurons: 28
# Epoch 356, Loss: 42.55643695410999, Neurons: 28
# Epoch 357, Loss: 40.35054477067715, Neurons: 28
# Epoch 358, Loss: 43.82961961410032, Neurons: 28
# Epoch 359, Loss: 46.519461606387566, Neurons: 28
# Epoch 360, Loss: 44.90548350165624, Neurons: 28
# Epoch 361, Loss: 40.900428869837846, Neurons: 28
# Epoch 362, Loss: 38.19343887176143, Neurons: 28
# Epoch 363, Loss: 38.52660068000115, Neurons: 28
# Epoch 364, Loss: 40.30974845168686, Neurons: 28
# Epoch 365, Loss: 40.79085622476252, Neurons: 28
# Epoch 366, Loss: 39.14738916160316, Neurons: 28
# Epoch 367, Loss: 36.81093111371722, Neurons: 28
# Epoch 368, Loss: 35.59764883806932, Neurons: 28
# Epoch 369, Loss: 35.925624220373386, Neurons: 28
# Epoch 370, Loss: 36.62963416010427, Neurons: 28
# Epoch 371, Loss: 36.38585936666996, Neurons: 28
# Epoch 372, Loss: 35.06561793414835, Neurons: 28
# Epoch 373, Loss: 33.64317605677824, Neurons: 28
# Epoch 374, Loss: 33.049951098775544, Neurons: 28
# Epoch 375, Loss: 33.23376917072107, Neurons: 28
# Epoch 376, Loss: 33.342698054462545, Neurons: 28
# Epoch 377, Loss: 32.75223622247194, Neurons: 28
# Epoch 378, Loss: 31.694194925847317, Neurons: 28
# Epoch 379, Loss: 30.86793143762087, Neurons: 28
# Epoch 380, Loss: 30.622304614142568, Neurons: 28
# Epoch 381, Loss: 30.62574943591387, Neurons: 28
# Epoch 382, Loss: 30.32765548822277, Neurons: 28
# Epoch 383, Loss: 29.611316394521705, Neurons: 28
# Epoch 384, Loss: 28.86432010718708, Neurons: 28
# Epoch 385, Loss: 28.458925654202314, Neurons: 28
# Epoch 386, Loss: 28.31793444851607, Neurons: 28
# Epoch 387, Loss: 28.07055496548162, Neurons: 28
# Epoch 388, Loss: 27.54223333375637, Neurons: 28
# Epoch 389, Loss: 26.934696144659284, Neurons: 28
# Epoch 390, Loss: 26.523011765122195, Neurons: 28
# Epoch 391, Loss: 26.305828891286385, Neurons: 28
# Epoch 392, Loss: 26.043604610051357, Neurons: 28
# Epoch 393, Loss: 25.598050918402805, Neurons: 28
# Epoch 394, Loss: 25.09968072829205, Neurons: 28
# Epoch 395, Loss: 24.737266562075227, Neurons: 28
# Epoch 396, Loss: 24.496962545187376, Neurons: 28
# Epoch 397, Loss: 24.210773137638554, Neurons: 28
# Epoch 398, Loss: 23.808035800297688, Neurons: 28
# Epoch 399, Loss: 23.396924473867834, Neurons: 28
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[14, 14, 1]
# Epoch 400, Loss: 54.02073173850611, Neurons: 29
# Epoch 401, Loss: 29.787318192291355, Neurons: 29
# Epoch 402, Loss: 38.32309186381764, Neurons: 29
# Epoch 403, Loss: 32.80666185842727, Neurons: 29
# Epoch 404, Loss: 26.13991150790307, Neurons: 29
# Epoch 405, Loss: 27.24598881952088, Neurons: 29
# Epoch 406, Loss: 29.819512199509308, Neurons: 29
# Epoch 407, Loss: 28.806188118542167, Neurons: 29
# Epoch 408, Loss: 25.97164421715435, Neurons: 29
# Epoch 409, Loss: 24.612606110236076, Neurons: 29
# Epoch 410, Loss: 25.303732916137232, Neurons: 29
# Epoch 411, Loss: 26.023836547958002, Neurons: 29
# Epoch 412, Loss: 25.176905335410726, Neurons: 29
# Epoch 413, Loss: 23.304057587561445, Neurons: 29
# Epoch 414, Loss: 22.20460616613217, Neurons: 29
# Epoch 415, Loss: 22.78618272617671, Neurons: 29
# Epoch 416, Loss: 23.92978458711822, Neurons: 29
# Epoch 417, Loss: 23.944730724972906, Neurons: 29
# Epoch 418, Loss: 22.608021439665524, Neurons: 29
# Epoch 419, Loss: 21.160531937764958, Neurons: 29
# Epoch 420, Loss: 20.770327525061933, Neurons: 29
# Epoch 421, Loss: 21.31831170312514, Neurons: 29
# Epoch 422, Loss: 21.732549656421305, Neurons: 29
# Epoch 423, Loss: 21.332617172228055, Neurons: 29
# Epoch 424, Loss: 20.47834013565155, Neurons: 29
# Epoch 425, Loss: 19.97048145636882, Neurons: 29
# Epoch 426, Loss: 20.091953122543458, Neurons: 29
# Epoch 427, Loss: 20.358249484395223, Neurons: 29
# Epoch 428, Loss: 20.206188266612187, Neurons: 29
# Epoch 429, Loss: 19.675655543715525, Neurons: 29
# Epoch 430, Loss: 19.22366045027841, Neurons: 29
# Epoch 431, Loss: 19.076911375728663, Neurons: 29
# Epoch 432, Loss: 19.032215757380534, Neurons: 29
# Epoch 433, Loss: 18.851700979023363, Neurons: 29
# Epoch 434, Loss: 18.58523337748841, Neurons: 29
# Epoch 435, Loss: 18.405994816725173, Neurons: 29
# Epoch 436, Loss: 18.31321245085694, Neurons: 29
# Epoch 437, Loss: 18.159111157037195, Neurons: 29
# Epoch 438, Loss: 17.906016524447875, Neurons: 29
# Epoch 439, Loss: 17.685449184600877, Neurons: 29
# Epoch 440, Loss: 17.572963220565892, Neurons: 29
# Epoch 441, Loss: 17.459547579230765, Neurons: 29
# Epoch 442, Loss: 17.235610382090876, Neurons: 29
# Epoch 443, Loss: 16.97614681692956, Neurons: 29
# Epoch 444, Loss: 16.821316810638265, Neurons: 29
# Epoch 445, Loss: 16.752724141500536, Neurons: 29
# Epoch 446, Loss: 16.623805644341026, Neurons: 29
# Epoch 447, Loss: 16.38629573683242, Neurons: 29
# Epoch 448, Loss: 16.154817433180696, Neurons: 29
# Epoch 449, Loss: 16.02297640122125, Neurons: 29
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[14, 15, 1]
# Epoch 450, Loss: 15.919046490283941, Neurons: 30
# Epoch 451, Loss: 38.46062450667944, Neurons: 30
# Epoch 452, Loss: 18.26068675208028, Neurons: 30
# Epoch 453, Loss: 25.60362703909744, Neurons: 30
# Epoch 454, Loss: 25.5003533990333, Neurons: 30
# Epoch 455, Loss: 20.342841511980776, Neurons: 30
# Epoch 456, Loss: 19.8873157652623, Neurons: 30
# Epoch 457, Loss: 20.40164624271547, Neurons: 30
# Epoch 458, Loss: 18.79145934814747, Neurons: 30
# Epoch 459, Loss: 17.240186087688105, Neurons: 30
# Epoch 460, Loss: 17.85474555746022, Neurons: 30
# Epoch 461, Loss: 19.080516736377664, Neurons: 30
# Epoch 462, Loss: 18.534951660236178, Neurons: 30
# Epoch 463, Loss: 16.44148174902092, Neurons: 30
# Epoch 464, Loss: 14.926837943413222, Neurons: 30
# Epoch 465, Loss: 15.468978698502635, Neurons: 30
# Epoch 466, Loss: 16.93667690964208, Neurons: 30
# Epoch 467, Loss: 17.086852353715443, Neurons: 30
# Epoch 468, Loss: 15.625267539297303, Neurons: 30
# Epoch 469, Loss: 14.206793975525082, Neurons: 30
# Epoch 470, Loss: 14.176701032697917, Neurons: 30
# Epoch 471, Loss: 15.069170404294805, Neurons: 30
# Epoch 472, Loss: 15.471852597441712, Neurons: 30
# Epoch 473, Loss: 14.85848701616304, Neurons: 30
# Epoch 474, Loss: 13.93991684148608, Neurons: 30
# Epoch 475, Loss: 13.584851178585835, Neurons: 30
# Epoch 476, Loss: 13.829402410243198, Neurons: 30
# Epoch 477, Loss: 14.04283509126837, Neurons: 30
# Epoch 478, Loss: 13.851225487170531, Neurons: 30
# Epoch 479, Loss: 13.465130693871203, Neurons: 30
# Epoch 480, Loss: 13.19518430630308, Neurons: 30
# Epoch 481, Loss: 13.071771210453237, Neurons: 30
# Epoch 482, Loss: 12.985627845510884, Neurons: 30
# Epoch 483, Loss: 12.905656071952858, Neurons: 30
# Epoch 484, Loss: 12.823737076843607, Neurons: 30
# Epoch 485, Loss: 12.67045950083509, Neurons: 30
# Epoch 486, Loss: 12.42384232995204, Neurons: 30
# Epoch 487, Loss: 12.207841024613257, Neurons: 30
# Epoch 488, Loss: 12.147254120703598, Neurons: 30
# Epoch 489, Loss: 12.153689702798568, Neurons: 30
# Epoch 490, Loss: 12.022326813897225, Neurons: 30
# Epoch 491, Loss: 11.745338408460531, Neurons: 30
# Epoch 492, Loss: 11.536146913923616, Neurons: 30
# Epoch 493, Loss: 11.502716876807572, Neurons: 30
# Epoch 494, Loss: 11.484575129554186, Neurons: 30
# Epoch 495, Loss: 11.312954471097688, Neurons: 30
# Epoch 496, Loss: 11.066949302004653, Neurons: 30
# Epoch 497, Loss: 10.9263769304582, Neurons: 30
# Epoch 498, Loss: 10.886268224023047, Neurons: 30
# Epoch 499, Loss: 10.791377558511003, Neurons: 30
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[15, 15, 1]
# Epoch 500, Loss: 2881.245972665911, Neurons: 31
# Epoch 501, Loss: 2258.0889025374295, Neurons: 31
# Epoch 502, Loss: 1686.6495640051457, Neurons: 31
# Epoch 503, Loss: 1197.6361181579118, Neurons: 31
# Epoch 504, Loss: 810.1359268795361, Neurons: 31
# Epoch 505, Loss: 533.3493287607517, Neurons: 31
# Epoch 506, Loss: 365.699818927889, Neurons: 31
# Epoch 507, Loss: 290.1401597940394, Neurons: 31
# Epoch 508, Loss: 274.7276585186208, Neurons: 31
# Epoch 509, Loss: 284.9413563797692, Neurons: 31
# Epoch 510, Loss: 295.9151299786696, Neurons: 31
# Epoch 511, Loss: 295.1785975781535, Neurons: 31
# Epoch 512, Loss: 279.5086694884542, Neurons: 31
# Epoch 513, Loss: 251.0868949640983, Neurons: 31
# Epoch 514, Loss: 214.70141129763428, Neurons: 31
# Epoch 515, Loss: 175.89370391672844, Neurons: 31
# Epoch 516, Loss: 139.75771005814707, Neurons: 31
# Epoch 517, Loss: 110.21124701053233, Neurons: 31
# Epoch 518, Loss: 89.56540347044223, Neurons: 31
# Epoch 519, Loss: 78.30652730936016, Neurons: 31
# Epoch 520, Loss: 75.17494363598142, Neurons: 31
# Epoch 521, Loss: 77.63407390031813, Neurons: 31
# Epoch 522, Loss: 82.6092625211406, Neurons: 31
# Epoch 523, Loss: 87.23062751437206, Neurons: 31
# Epoch 524, Loss: 89.3826679140721, Neurons: 31
# Epoch 525, Loss: 87.9863736605468, Neurons: 31
# Epoch 526, Loss: 83.0218513506471, Neurons: 31
# Epoch 527, Loss: 75.34611534311959, Neurons: 31
# Epoch 528, Loss: 66.37700085763139, Neurons: 31
# Epoch 529, Loss: 57.710125154674984, Neurons: 31
# Epoch 530, Loss: 50.72999974712936, Neurons: 31
# Epoch 531, Loss: 46.281440316023385, Neurons: 31
# Epoch 532, Loss: 44.48018742005175, Neurons: 31
# Epoch 533, Loss: 44.736226722109606, Neurons: 31
# Epoch 534, Loss: 46.00201934204469, Neurons: 31
# Epoch 535, Loss: 47.151021504164035, Neurons: 31
# Epoch 536, Loss: 47.32773308403042, Neurons: 31
# Epoch 537, Loss: 46.14743614900852, Neurons: 31
# Epoch 538, Loss: 43.71322320803075, Neurons: 31
# Epoch 539, Loss: 40.48882174943664, Neurons: 31
# Epoch 540, Loss: 37.09649769245596, Neurons: 31
# Epoch 541, Loss: 34.11090830107866, Neurons: 31
# Epoch 542, Loss: 31.905413532499765, Neurons: 31
# Epoch 543, Loss: 30.583864718536038, Neurons: 31
# Epoch 544, Loss: 30.00252056407695, Neurons: 31
# Epoch 545, Loss: 29.859898556233023, Neurons: 31
# Epoch 546, Loss: 29.815347129031068, Neurons: 31
# Epoch 547, Loss: 29.59527312747014, Neurons: 31
# Epoch 548, Loss: 29.057763763622482, Neurons: 31
# Epoch 549, Loss: 28.20481664837966, Neurons: 31
# Removed neuron to hidden layer 1 at index 14
# network shape updated to :[14, 15, 1]
# Epoch 550, Loss: 2933.7164865336817, Neurons: 30
# Epoch 551, Loss: 2395.2655231816816, Neurons: 30
# Epoch 552, Loss: 1850.5881567606093, Neurons: 30
# Epoch 553, Loss: 1335.1768336064822, Neurons: 30
# Epoch 554, Loss: 887.9175756700486, Neurons: 30
# Epoch 555, Loss: 541.507461168893, Neurons: 30
# Epoch 556, Loss: 310.55801462048754, Neurons: 30
# Epoch 557, Loss: 184.95727764646605, Neurons: 30
# Epoch 558, Loss: 136.60754840211322, Neurons: 30
# Epoch 559, Loss: 134.12381062217622, Neurons: 30
# Epoch 560, Loss: 152.32576104069759, Neurons: 30
# Epoch 561, Loss: 174.3297192149979, Neurons: 30
# Epoch 562, Loss: 190.63788417672274, Neurons: 30
# Epoch 563, Loss: 197.22736084619473, Neurons: 30
# Epoch 564, Loss: 193.7108529005443, Neurons: 30
# Epoch 565, Loss: 181.95163640469113, Neurons: 30
# Epoch 566, Loss: 165.01413784804336, Neurons: 30
# Epoch 567, Loss: 146.29933480492758, Neurons: 30
# Epoch 568, Loss: 128.81161294112357, Neurons: 30
# Epoch 569, Loss: 114.59657516824362, Neurons: 30
# Epoch 570, Loss: 104.46441720272261, Neurons: 30
# Epoch 571, Loss: 98.1087188544521, Neurons: 30
# Epoch 572, Loss: 94.54764567530256, Neurons: 30
# Epoch 573, Loss: 92.61004054141564, Neurons: 30
# Epoch 574, Loss: 91.24951802659324, Neurons: 30
# Epoch 575, Loss: 89.67286582433881, Neurons: 30
# Epoch 576, Loss: 87.363249212753, Neurons: 30
# Epoch 577, Loss: 84.06463319894904, Neurons: 30
# Epoch 578, Loss: 79.75705596698573, Neurons: 30
# Epoch 579, Loss: 74.62813556687192, Neurons: 30
# Epoch 580, Loss: 69.03559110849807, Neurons: 30
# Epoch 581, Loss: 63.45315762897545, Neurons: 30
# Epoch 582, Loss: 58.3945777780396, Neurons: 30
# Epoch 583, Loss: 54.316679373704986, Neurons: 30
# Epoch 584, Loss: 51.51437650463013, Neurons: 30
# Epoch 585, Loss: 50.03745877896111, Neurons: 30
# Epoch 586, Loss: 49.66864552473444, Neurons: 30
# Epoch 587, Loss: 49.98345336957831, Neurons: 30
# Epoch 588, Loss: 50.47258594397321, Neurons: 30
# Epoch 589, Loss: 50.681568890699374, Neurons: 30
# Epoch 590, Loss: 50.321434504753796, Neurons: 30
# Epoch 591, Loss: 49.31916830367551, Neurons: 30
# Epoch 592, Loss: 47.79987681608743, Neurons: 30
# Epoch 593, Loss: 46.015796337169675, Neurons: 30
# Epoch 594, Loss: 44.25178704851503, Neurons: 30
# Epoch 595, Loss: 42.73925740359254, Neurons: 30
# Epoch 596, Loss: 41.6021987134171, Neurons: 30
# Epoch 597, Loss: 40.844798703437455, Neurons: 30
# Epoch 598, Loss: 40.37556011296832, Neurons: 30
# Epoch 599, Loss: 40.052892031594716, Neurons: 30
# Removed neuron to hidden layer 1 at index 13
# network shape updated to :[13, 15, 1]
# Epoch 600, Loss: 78.50273565436187, Neurons: 29
# Epoch 601, Loss: 48.10308278848278, Neurons: 29
# Epoch 602, Loss: 42.14077456473395, Neurons: 29
# Epoch 603, Loss: 45.17212367607293, Neurons: 29
# Epoch 604, Loss: 46.34922493046137, Neurons: 29
# Epoch 605, Loss: 45.68144199958825, Neurons: 29
# Epoch 606, Loss: 44.338359153785596, Neurons: 29
# Epoch 607, Loss: 42.08425008234554, Neurons: 29
# Epoch 608, Loss: 39.15972191288245, Neurons: 29
# Epoch 609, Loss: 36.37660110912626, Neurons: 29
# Epoch 610, Loss: 34.08560768316864, Neurons: 29
# Epoch 611, Loss: 32.283069198987064, Neurons: 29
# Epoch 612, Loss: 30.980799574858633, Neurons: 29
# Epoch 613, Loss: 30.071344130978293, Neurons: 29
# Epoch 614, Loss: 29.273439610009813, Neurons: 29
# Epoch 615, Loss: 28.50717572625112, Neurons: 29
# Epoch 616, Loss: 27.727370677299188, Neurons: 29
# Epoch 617, Loss: 26.688461495205352, Neurons: 29
# Epoch 618, Loss: 25.441241557943357, Neurons: 29
# Epoch 619, Loss: 24.35466304447451, Neurons: 29
# Epoch 620, Loss: 23.524423856100643, Neurons: 29
# Epoch 621, Loss: 22.801343778277587, Neurons: 29
# Epoch 622, Loss: 22.2124139521525, Neurons: 29
# Epoch 623, Loss: 21.807968467036606, Neurons: 29
# Epoch 624, Loss: 21.39556825820476, Neurons: 29
# Epoch 625, Loss: 20.802658817469553, Neurons: 29
# Epoch 626, Loss: 20.088766318034164, Neurons: 29
# Epoch 627, Loss: 19.324252911296327, Neurons: 29
# Epoch 628, Loss: 18.521492152536407, Neurons: 29
# Epoch 629, Loss: 17.752321890190796, Neurons: 29
# Epoch 630, Loss: 17.078961087577103, Neurons: 29
# Epoch 631, Loss: 16.51432027290535, Neurons: 29
# Epoch 632, Loss: 16.08870592408275, Neurons: 29
# Epoch 633, Loss: 15.761144948000041, Neurons: 29
# Epoch 634, Loss: 15.41418024562821, Neurons: 29
# Epoch 635, Loss: 15.038023909547839, Neurons: 29
# Epoch 636, Loss: 14.65299748541724, Neurons: 29
# Epoch 637, Loss: 14.19959578326347, Neurons: 29
# Epoch 638, Loss: 13.704605396379215, Neurons: 29
# Epoch 639, Loss: 13.252837606234122, Neurons: 29
# Epoch 640, Loss: 12.835487270855898, Neurons: 29
# Epoch 641, Loss: 12.451681459859433, Neurons: 29
# Epoch 642, Loss: 12.132585907214212, Neurons: 29
# Epoch 643, Loss: 11.853938062717905, Neurons: 29
# Epoch 644, Loss: 11.581526794875225, Neurons: 29
# Epoch 645, Loss: 11.303460107102913, Neurons: 29
# Epoch 646, Loss: 11.019315903139317, Neurons: 29
# Epoch 647, Loss: 10.723902773635691, Neurons: 29
# Epoch 648, Loss: 10.414907970040769, Neurons: 29
# Epoch 649, Loss: 10.123753599484175, Neurons: 29
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[14, 15, 1]
# Epoch 650, Loss: 24.943281153885255, Neurons: 30
# Epoch 651, Loss: 23.0048461036204, Neurons: 30
# Epoch 652, Loss: 18.81521013904911, Neurons: 30
# Epoch 653, Loss: 11.100064817142469, Neurons: 30
# Epoch 654, Loss: 14.584359225840219, Neurons: 30
# Epoch 655, Loss: 17.077026301074046, Neurons: 30
# Epoch 656, Loss: 13.627749773938474, Neurons: 30
# Epoch 657, Loss: 11.002225466709813, Neurons: 30
# Epoch 658, Loss: 12.281795803023037, Neurons: 30
# Epoch 659, Loss: 13.653524089292112, Neurons: 30
# Epoch 660, Loss: 12.22758465378243, Neurons: 30
# Epoch 661, Loss: 10.056776117215843, Neurons: 30
# Epoch 662, Loss: 9.965763608543345, Neurons: 30
# Epoch 663, Loss: 11.285058602717637, Neurons: 30
# Epoch 664, Loss: 11.483384187034066, Neurons: 30
# Epoch 665, Loss: 10.3251395441926, Neurons: 30
# Epoch 666, Loss: 9.591685154512398, Neurons: 30
# Epoch 667, Loss: 10.0299914141209, Neurons: 30
# Epoch 668, Loss: 10.465811062425564, Neurons: 30
# Epoch 669, Loss: 9.91394612512662, Neurons: 30
# Epoch 670, Loss: 9.01409373092915, Neurons: 30
# Epoch 671, Loss: 8.827106990184177, Neurons: 30
# Epoch 672, Loss: 9.217496661646988, Neurons: 30
# Epoch 673, Loss: 9.258674187781551, Neurons: 30
# Epoch 674, Loss: 8.758195418280701, Neurons: 30
# Epoch 675, Loss: 8.391224722742354, Neurons: 30
# Epoch 676, Loss: 8.515311698330047, Neurons: 30
# Epoch 677, Loss: 8.664453191095243, Neurons: 30
# Epoch 678, Loss: 8.383662970186014, Neurons: 30
# Epoch 679, Loss: 7.931768014229661, Neurons: 30
# Epoch 680, Loss: 7.789755959941911, Neurons: 30
# Epoch 681, Loss: 7.890150172402244, Neurons: 30
# Epoch 682, Loss: 7.811621432944616, Neurons: 30
# Epoch 683, Loss: 7.515562166956459, Neurons: 30
# Epoch 684, Loss: 7.34572833441249, Neurons: 30
# Epoch 685, Loss: 7.392399363310502, Neurons: 30
# Epoch 686, Loss: 7.366719934115075, Neurons: 30
# Epoch 687, Loss: 7.136350047731648, Neurons: 30
# Epoch 688, Loss: 6.924598663805188, Neurons: 30
# Epoch 689, Loss: 6.881947736262302, Neurons: 30
# Epoch 690, Loss: 6.850796633835307, Neurons: 30
# Epoch 691, Loss: 6.696612182499947, Neurons: 30
# Epoch 692, Loss: 6.539766943994596, Neurons: 30
# Epoch 693, Loss: 6.49758677791678, Neurons: 30
# Epoch 694, Loss: 6.474791655474377, Neurons: 30
# Epoch 695, Loss: 6.367495181408657, Neurons: 30
# Epoch 696, Loss: 6.244484947570423, Neurons: 30
# Epoch 697, Loss: 6.186185208097609, Neurons: 30
# Epoch 698, Loss: 6.1382924236146215, Neurons: 30
# Epoch 699, Loss: 6.044538874899632, Neurons: 30
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[15, 15, 1]
# Epoch 700, Loss: 5.985810406378571, Neurons: 31
# Epoch 701, Loss: 42.54618942538745, Neurons: 31
# Epoch 702, Loss: 7.357303510487338, Neurons: 31
# Epoch 703, Loss: 18.658851315181554, Neurons: 31
# Epoch 704, Loss: 27.735224071281927, Neurons: 31
# Epoch 705, Loss: 18.218308151049126, Neurons: 31
# Epoch 706, Loss: 7.821426428432045, Neurons: 31
# Epoch 707, Loss: 7.806642505369652, Neurons: 31
# Epoch 708, Loss: 13.924925366617568, Neurons: 31
# Epoch 709, Loss: 16.360800662198244, Neurons: 31
# Epoch 710, Loss: 13.045485959138722, Neurons: 31
# Epoch 711, Loss: 8.335168636795986, Neurons: 31
# Epoch 712, Loss: 6.551003569469904, Neurons: 31
# Epoch 713, Loss: 8.170639246631572, Neurons: 31
# Epoch 714, Loss: 10.361957268244007, Neurons: 31
# Epoch 715, Loss: 10.484427476752572, Neurons: 31
# Epoch 716, Loss: 8.59468852684284, Neurons: 31
# Epoch 717, Loss: 6.738122635134313, Neurons: 31
# Epoch 718, Loss: 6.463582606179807, Neurons: 31
# Epoch 719, Loss: 7.361916211978151, Neurons: 31
# Epoch 720, Loss: 7.976550054911766, Neurons: 31
# Epoch 721, Loss: 7.57613245584511, Neurons: 31
# Epoch 722, Loss: 6.659841764105175, Neurons: 31
# Epoch 723, Loss: 6.102142355984751, Neurons: 31
# Epoch 724, Loss: 6.200338764920946, Neurons: 31
# Epoch 725, Loss: 6.542749110091364, Neurons: 31
# Epoch 726, Loss: 6.585925237550299, Neurons: 31
# Epoch 727, Loss: 6.233669172761741, Neurons: 31
# Epoch 728, Loss: 5.855190610399836, Neurons: 31
# Epoch 729, Loss: 5.782490947579693, Neurons: 31
# Epoch 730, Loss: 5.911388529792112, Neurons: 31
# Epoch 731, Loss: 5.904020761653341, Neurons: 31
# Epoch 732, Loss: 5.665317199971921, Neurons: 31
# Epoch 733, Loss: 5.433011899790815, Neurons: 31
# Epoch 734, Loss: 5.422283874165669, Neurons: 31
# Epoch 735, Loss: 5.548225897028108, Neurons: 31
# Epoch 736, Loss: 5.5656573132335545, Neurons: 31
# Epoch 737, Loss: 5.386305003428681, Neurons: 31
# Epoch 738, Loss: 5.173220576519644, Neurons: 31
# Epoch 739, Loss: 5.128271589036197, Neurons: 31
# Epoch 740, Loss: 5.236267430557254, Neurons: 31
# Epoch 741, Loss: 5.288872442663418, Neurons: 31
# Epoch 742, Loss: 5.1628330384952195, Neurons: 31
# Epoch 743, Loss: 4.975731313309479, Neurons: 31
# Epoch 744, Loss: 4.918332303278227, Neurons: 31
# Epoch 745, Loss: 5.0042892287827785, Neurons: 31
# Epoch 746, Loss: 5.067969928833361, Neurons: 31
# Epoch 747, Loss: 4.990280447656014, Neurons: 31
# Epoch 748, Loss: 4.841130305556482, Neurons: 31
# Epoch 749, Loss: 4.771378969735126, Neurons: 31
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[15, 16, 1]
# Epoch 750, Loss: 4.817442897729022, Neurons: 32
# Epoch 751, Loss: 26.167961448294562, Neurons: 32
# Epoch 752, Loss: 6.12548035931899, Neurons: 32
# Epoch 753, Loss: 10.069755088120022, Neurons: 32
# Epoch 754, Loss: 16.677916443522307, Neurons: 32
# Epoch 755, Loss: 12.255571482324054, Neurons: 32
# Epoch 756, Loss: 6.0177229432832355, Neurons: 32
# Epoch 757, Loss: 5.039561373875273, Neurons: 32
# Epoch 758, Loss: 8.322557956100923, Neurons: 32
# Epoch 759, Loss: 10.507579955279628, Neurons: 32
# Epoch 760, Loss: 9.211062672231913, Neurons: 32
# Epoch 761, Loss: 6.199393075956521, Neurons: 32
# Epoch 762, Loss: 4.505189157057835, Neurons: 32
# Epoch 763, Loss: 5.3559626567671765, Neurons: 32
# Epoch 764, Loss: 7.092540679579097, Neurons: 32
# Epoch 765, Loss: 7.526276591047168, Neurons: 32
# Epoch 766, Loss: 6.331451207158951, Neurons: 32
# Epoch 767, Loss: 4.802940782379682, Neurons: 32
# Epoch 768, Loss: 4.330239050730641, Neurons: 32
# Epoch 769, Loss: 5.061119690064655, Neurons: 32
# Epoch 770, Loss: 5.911784426785755, Neurons: 32
# Epoch 771, Loss: 5.91168993249195, Neurons: 32
# Epoch 772, Loss: 5.123710220537892, Neurons: 32
# Epoch 773, Loss: 4.334416668656968, Neurons: 32
# Epoch 774, Loss: 4.2149309906726415, Neurons: 32
# Epoch 775, Loss: 4.688472445377379, Neurons: 32
# Epoch 776, Loss: 5.058870356723941, Neurons: 32
# Epoch 777, Loss: 4.864375456023082, Neurons: 32
# Epoch 778, Loss: 4.350063008826555, Neurons: 32
# Epoch 779, Loss: 4.0441115389586155, Neurons: 32
# Epoch 780, Loss: 4.159518864669342, Neurons: 32
# Epoch 781, Loss: 4.419076265512591, Neurons: 32
# Epoch 782, Loss: 4.423868490840427, Neurons: 32
# Epoch 783, Loss: 4.1537091073466526, Neurons: 32
# Epoch 784, Loss: 3.926764507106918, Neurons: 32
# Epoch 785, Loss: 3.9415312152080197, Neurons: 32
# Epoch 786, Loss: 4.070802275754364, Neurons: 32
# Epoch 787, Loss: 4.070617479993111, Neurons: 32
# Epoch 788, Loss: 3.8889526134570014, Neurons: 32
# Epoch 789, Loss: 3.7262584085106503, Neurons: 32
# Epoch 790, Loss: 3.7415976015746693, Neurons: 32
# Epoch 791, Loss: 3.834275621993635, Neurons: 32
# Epoch 792, Loss: 3.8165314004099886, Neurons: 32
# Epoch 793, Loss: 3.669355325841096, Neurons: 32
# Epoch 794, Loss: 3.549636260510792, Neurons: 32
# Epoch 795, Loss: 3.564893312276663, Neurons: 32
# Epoch 796, Loss: 3.620157547912131, Neurons: 32
# Epoch 797, Loss: 3.5788446771661224, Neurons: 32
# Epoch 798, Loss: 3.4653000469772968, Neurons: 32
# Epoch 799, Loss: 3.3996229636123116, Neurons: 32
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[16, 16, 1]
# Epoch 800, Loss: 133.65651389218664, Neurons: 33
# Epoch 801, Loss: 43.84062604716206, Neurons: 33
# Epoch 802, Loss: 24.747912562788414, Neurons: 33
# Epoch 803, Loss: 33.48740532153833, Neurons: 33
# Epoch 804, Loss: 32.172986355366554, Neurons: 33
# Epoch 805, Loss: 18.463285710600168, Neurons: 33
# Epoch 806, Loss: 6.313958674804621, Neurons: 33
# Epoch 807, Loss: 6.389160868155723, Neurons: 33
# Epoch 808, Loss: 14.81517363152628, Neurons: 33
# Epoch 809, Loss: 19.67950344440551, Neurons: 33
# Epoch 810, Loss: 17.117385976540973, Neurons: 33
# Epoch 811, Loss: 11.292467500661605, Neurons: 33
# Epoch 812, Loss: 7.647729065507113, Neurons: 33
# Epoch 813, Loss: 8.229943445025398, Neurons: 33
# Epoch 814, Loss: 10.86314038858803, Neurons: 33
# Epoch 815, Loss: 12.09472401870661, Neurons: 33
# Epoch 816, Loss: 10.510352492215123, Neurons: 33
# Epoch 817, Loss: 7.393436526845522, Neurons: 33
# Epoch 818, Loss: 5.141258955037718, Neurons: 33
# Epoch 819, Loss: 5.171326626008722, Neurons: 33
# Epoch 820, Loss: 6.851424100611548, Neurons: 33
# Epoch 821, Loss: 8.310023578315631, Neurons: 33
# Epoch 822, Loss: 8.258318152944806, Neurons: 33
# Epoch 823, Loss: 6.921921679766905, Neurons: 33
# Epoch 824, Loss: 5.499173348863349, Neurons: 33
# Epoch 825, Loss: 4.999788003326275, Neurons: 33
# Epoch 826, Loss: 5.472795950862265, Neurons: 33
# Epoch 827, Loss: 6.131852684380084, Neurons: 33
# Epoch 828, Loss: 6.1580849860020095, Neurons: 33
# Epoch 829, Loss: 5.4184507701720195, Neurons: 33
# Epoch 830, Loss: 4.494283870145135, Neurons: 33
# Epoch 831, Loss: 4.085036453661524, Neurons: 33
# Epoch 832, Loss: 4.36652613338011, Neurons: 33
# Epoch 833, Loss: 4.8836290543070335, Neurons: 33
# Epoch 834, Loss: 5.0457274980289135, Neurons: 33
# Epoch 835, Loss: 4.690293029025993, Neurons: 33
# Epoch 836, Loss: 4.1584056519399635, Neurons: 33
# Epoch 837, Loss: 3.887007634347379, Neurons: 33
# Epoch 838, Loss: 3.982914957377419, Neurons: 33
# Epoch 839, Loss: 4.18296286708654, Neurons: 33
# Epoch 840, Loss: 4.175137991138624, Neurons: 33
# Epoch 841, Loss: 3.9124777585365043, Neurons: 33
# Epoch 842, Loss: 3.617868011581615, Neurons: 33
# Epoch 843, Loss: 3.5220864562266527, Neurons: 33
# Epoch 844, Loss: 3.629106824212979, Neurons: 33
# Epoch 845, Loss: 3.742983309875859, Neurons: 33
# Epoch 846, Loss: 3.6975908059590434, Neurons: 33
# Epoch 847, Loss: 3.5207575634262156, Neurons: 33
# Epoch 848, Loss: 3.3695844818617453, Neurons: 33
# Epoch 849, Loss: 3.3430158382973603, Neurons: 33
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[16, 17, 1]
# Epoch 850, Loss: 3.4909781441700054, Neurons: 34
# Epoch 851, Loss: 30.5169234170945, Neurons: 34
# Epoch 852, Loss: 5.939689221931069, Neurons: 34
# Epoch 853, Loss: 9.315090966862353, Neurons: 34
# Epoch 854, Loss: 17.720259374897434, Neurons: 34
# Epoch 855, Loss: 14.38772215701673, Neurons: 34
# Epoch 856, Loss: 6.622962485907004, Neurons: 34
# Epoch 857, Loss: 3.4465498165254527, Neurons: 34
# Epoch 858, Loss: 6.577940440461995, Neurons: 34
# Epoch 859, Loss: 10.266792991782738, Neurons: 34
# Epoch 860, Loss: 9.957496496167758, Neurons: 34
# Epoch 861, Loss: 6.5959148589491425, Neurons: 34
# Epoch 862, Loss: 3.643589102242935, Neurons: 34
# Epoch 863, Loss: 3.435603274274467, Neurons: 34
# Epoch 864, Loss: 5.354380744545024, Neurons: 34
# Epoch 865, Loss: 6.929624631325149, Neurons: 34
# Epoch 866, Loss: 6.578229561349597, Neurons: 34
# Epoch 867, Loss: 4.843500595891109, Neurons: 34
# Epoch 868, Loss: 3.409587432386749, Neurons: 34
# Epoch 869, Loss: 3.3747087073609214, Neurons: 34
# Epoch 870, Loss: 4.3373741026757795, Neurons: 34
# Epoch 871, Loss: 5.044038046166344, Neurons: 34
# Epoch 872, Loss: 4.7525388273978715, Neurons: 34
# Epoch 873, Loss: 3.8117832582154563, Neurons: 34
# Epoch 874, Loss: 3.1270894116886665, Neurons: 34
# Epoch 875, Loss: 3.230119722739249, Neurons: 34
# Epoch 876, Loss: 3.811297877116171, Neurons: 34
# Epoch 877, Loss: 4.130673819331584, Neurons: 34
# Epoch 878, Loss: 3.827020710101497, Neurons: 34
# Epoch 879, Loss: 3.2199125097563566, Neurons: 34
# Epoch 880, Loss: 2.886698368050275, Neurons: 34
# Epoch 881, Loss: 3.0504517688846984, Neurons: 34
# Epoch 882, Loss: 3.3998757188399025, Neurons: 34
# Epoch 883, Loss: 3.482159190005495, Neurons: 34
# Epoch 884, Loss: 3.201221266883147, Neurons: 34
# Epoch 885, Loss: 2.8695556109881246, Neurons: 34
# Epoch 886, Loss: 2.804419106374071, Neurons: 34
# Epoch 887, Loss: 2.973243107542052, Neurons: 34
# Epoch 888, Loss: 3.0882526203837686, Neurons: 34
# Epoch 889, Loss: 2.979753611498228, Neurons: 34
# Epoch 890, Loss: 2.7715548189814245, Neurons: 34
# Epoch 891, Loss: 2.6885487712192004, Neurons: 34
# Epoch 892, Loss: 2.773494696697239, Neurons: 34
# Epoch 893, Loss: 2.856448840326928, Neurons: 34
# Epoch 894, Loss: 2.7913487030632873, Neurons: 34
# Epoch 895, Loss: 2.640010128871432, Neurons: 34
# Epoch 896, Loss: 2.5698970859061303, Neurons: 34
# Epoch 897, Loss: 2.625050337866722, Neurons: 34
# Epoch 898, Loss: 2.683025271932367, Neurons: 34
# Epoch 899, Loss: 2.636709029940276, Neurons: 34
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[17, 17, 1]
# Epoch 900, Loss: 25.874697542012456, Neurons: 35
# Epoch 901, Loss: 13.56374960606201, Neurons: 35
# Epoch 902, Loss: 14.552411956792414, Neurons: 35
# Epoch 903, Loss: 4.803448369986459, Neurons: 35
# Epoch 904, Loss: 5.940911974849965, Neurons: 35
# Epoch 905, Loss: 10.829864674346094, Neurons: 35
# Epoch 906, Loss: 8.991215364347477, Neurons: 35
# Epoch 907, Loss: 5.099041830881717, Neurons: 35
# Epoch 908, Loss: 4.580417063216505, Neurons: 35
# Epoch 909, Loss: 6.232036428621697, Neurons: 35
# Epoch 910, Loss: 6.474866660582868, Neurons: 35
# Epoch 911, Loss: 4.9153439796290295, Neurons: 35
# Epoch 912, Loss: 3.6814994965056824, Neurons: 35
# Epoch 913, Loss: 3.8046754411223183, Neurons: 35
# Epoch 914, Loss: 4.258340714730537, Neurons: 35
# Epoch 915, Loss: 4.124160037421598, Neurons: 35
# Epoch 916, Loss: 3.618007486376971, Neurons: 35
# Epoch 917, Loss: 3.2675357443000776, Neurons: 35
# Epoch 918, Loss: 3.3108106568871234, Neurons: 35
# Epoch 919, Loss: 3.5794827915559835, Neurons: 35
# Epoch 920, Loss: 3.6846490486429095, Neurons: 35
# Epoch 921, Loss: 3.4331283643661847, Neurons: 35
# Epoch 922, Loss: 2.9781818424147484, Neurons: 35
# Epoch 923, Loss: 2.6493045241007676, Neurons: 35
# Epoch 924, Loss: 2.6778407116644005, Neurons: 35
# Epoch 925, Loss: 2.900236936948836, Neurons: 35
# Epoch 926, Loss: 2.9102070384173295, Neurons: 35
# Epoch 927, Loss: 2.6496610143257113, Neurons: 35
# Epoch 928, Loss: 2.4982463844904825, Neurons: 35
# Epoch 929, Loss: 2.6651017577929528, Neurons: 35
# Epoch 930, Loss: 2.8441665273809, Neurons: 35
# Epoch 931, Loss: 2.702979600577501, Neurons: 35
# Epoch 932, Loss: 2.3972880071109826, Neurons: 35
# Epoch 933, Loss: 2.318733917558723, Neurons: 35
# Epoch 934, Loss: 2.4879862731509306, Neurons: 35
# Epoch 935, Loss: 2.543507814932036, Neurons: 35
# Epoch 936, Loss: 2.3598135694347833, Neurons: 35
# Epoch 937, Loss: 2.220725304445703, Neurons: 35
# Epoch 938, Loss: 2.3021586083975896, Neurons: 35
# Epoch 939, Loss: 2.4023113113820043, Neurons: 35
# Epoch 940, Loss: 2.329509374350407, Neurons: 35
# Epoch 941, Loss: 2.2103648762069494, Neurons: 35
# Epoch 942, Loss: 2.223810480378671, Neurons: 35
# Epoch 943, Loss: 2.2946435550530486, Neurons: 35
# Epoch 944, Loss: 2.2645310137083143, Neurons: 35
# Epoch 945, Loss: 2.1712369324650513, Neurons: 35
# Epoch 946, Loss: 2.142931126880448, Neurons: 35
# Epoch 947, Loss: 2.1708877588989073, Neurons: 35
# Epoch 948, Loss: 2.1644361487823756, Neurons: 35
# Epoch 949, Loss: 2.1220314252547188, Neurons: 35
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[17, 18, 1]
# Epoch 950, Loss: 2.394647727625389, Neurons: 36
# Epoch 951, Loss: 31.235610263637987, Neurons: 36
# Epoch 952, Loss: 3.7135227879896537, Neurons: 36
# Epoch 953, Loss: 17.28268433270193, Neurons: 36
# Epoch 954, Loss: 18.788309607630683, Neurons: 36
# Epoch 955, Loss: 7.937087515767977, Neurons: 36
# Epoch 956, Loss: 3.7067150445490022, Neurons: 36
# ...
# Epoch 2690, Loss: 2.443939970409744, Neurons: 48
# Epoch 2691, Loss: 2.616899032412134, Neurons: 48
# Epoch 2692, Loss: 2.683697179970817, Neurons: 48
# Epoch 2693, Loss: 2.5431030148853124, Neurons: 48
# Epoch 2694, Loss: 2.3360459091357235, Neurons: 48
# Epoch 2695, Loss: 2.2726406975402615, Neurons: 48
# Epoch 2696, Loss: 2.3787864506206415, Neurons: 48
# Epoch 2697, Loss: 2.484641910004653, Neurons: 48
# Epoch 2698, Loss: 2.449240066842378, Neurons: 48
# Epoch 2699, Loss: 2.3186787056832254, Neurons: 48
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[19, 29, 1]
# Epoch 2700, Loss: 2.238520418207926, Neurons: 49
# Epoch 2701, Loss: 53.66338567464159, Neurons: 49
# Epoch 2702, Loss: 5.4428105247515, Neurons: 49
# Epoch 2703, Loss: 19.228317438773853, Neurons: 49
# Epoch 2704, Loss: 29.524337227115662, Neurons: 49
# Epoch 2705, Loss: 18.311807904141148, Neurons: 49
# Epoch 2706, Loss: 7.7384357200221485, Neurons: 49
# Epoch 2707, Loss: 7.790963383982281, Neurons: 49
# Epoch 2708, Loss: 12.400662450504436, Neurons: 49
# Epoch 2709, Loss: 13.29105446264026, Neurons: 49
# Epoch 2710, Loss: 9.64719897654468, Neurons: 49
# Epoch 2711, Loss: 6.194910809856839, Neurons: 49
# Epoch 2712, Loss: 6.173317539550444, Neurons: 49
# Epoch 2713, Loss: 7.8242802185863844, Neurons: 49
# Epoch 2714, Loss: 7.892407392377101, Neurons: 49
# Epoch 2715, Loss: 5.9475428922509, Neurons: 49
# Epoch 2716, Loss: 4.166913763560615, Neurons: 49
# Epoch 2717, Loss: 4.314921974250184, Neurons: 49
# Epoch 2718, Loss: 5.698621806135974, Neurons: 49
# Epoch 2719, Loss: 6.289491486900151, Neurons: 49
# Epoch 2720, Loss: 5.1802949756148955, Neurons: 49
# Epoch 2721, Loss: 3.348763635300661, Neurons: 49
# Epoch 2722, Loss: 2.4811180819177454, Neurons: 49
# Epoch 2723, Loss: 3.2231069062621778, Neurons: 49
# Epoch 2724, Loss: 4.4901441381838705, Neurons: 49
# Epoch 2725, Loss: 4.730731272014487, Neurons: 49
# Epoch 2726, Loss: 3.6702492893613514, Neurons: 49
# Epoch 2727, Loss: 2.425398083060378, Neurons: 49
# Epoch 2728, Loss: 2.143402041781156, Neurons: 49
# Epoch 2729, Loss: 2.828851486736572, Neurons: 49
# Epoch 2730, Loss: 3.525987228700298, Neurons: 49
# Epoch 2731, Loss: 3.461648811746788, Neurons: 49
# Epoch 2732, Loss: 2.7804232750325486, Neurons: 49
# Epoch 2733, Loss: 2.215912718074771, Neurons: 49
# Epoch 2734, Loss: 2.2374855250319015, Neurons: 49
# Epoch 2735, Loss: 2.6106788989961487, Neurons: 49
# Epoch 2736, Loss: 2.7882771669138955, Neurons: 49
# Epoch 2737, Loss: 2.578997834709338, Neurons: 49
# Epoch 2738, Loss: 2.2718023098703637, Neurons: 49
# Epoch 2739, Loss: 2.188048093636519, Neurons: 49
# Epoch 2740, Loss: 2.3084780541706946, Neurons: 49
# Epoch 2741, Loss: 2.3871005722222574, Neurons: 49
# Epoch 2742, Loss: 2.3028506607866985, Neurons: 49
# Epoch 2743, Loss: 2.173888347444769, Neurons: 49
# Epoch 2744, Loss: 2.1480087190739803, Neurons: 49
# Epoch 2745, Loss: 2.1972340798429766, Neurons: 49
# Epoch 2746, Loss: 2.1884280219391594, Neurons: 49
# Epoch 2747, Loss: 2.096249990373715, Neurons: 49
# Epoch 2748, Loss: 2.0338949029251974, Neurons: 49
# Epoch 2749, Loss: 2.07205537985866, Neurons: 49
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[19, 30, 1]
# Epoch 2750, Loss: 2.158454890869899, Neurons: 50
# Epoch 2751, Loss: 53.720407330227275, Neurons: 50
# Epoch 2752, Loss: 5.759817909989606, Neurons: 50
# Epoch 2753, Loss: 14.945275915819561, Neurons: 50
# Epoch 2754, Loss: 29.75820857575874, Neurons: 50
# Epoch 2755, Loss: 21.895380690444703, Neurons: 50
# Epoch 2756, Loss: 7.931680623415097, Neurons: 50
# Epoch 2757, Loss: 3.4687597114014883, Neurons: 50
# Epoch 2758, Loss: 9.332027269282973, Neurons: 50
# Epoch 2759, Loss: 14.880959077232497, Neurons: 50
# Epoch 2760, Loss: 13.309941224952146, Neurons: 50
# Epoch 2761, Loss: 7.4108324601225855, Neurons: 50
# Epoch 2762, Loss: 3.3096891213238986, Neurons: 50
# Epoch 2763, Loss: 3.927376244862527, Neurons: 50
# Epoch 2764, Loss: 7.088801900130984, Neurons: 50
# Epoch 2765, Loss: 8.63102132423509, Neurons: 50
# Epoch 2766, Loss: 6.994895751137323, Neurons: 50
# Epoch 2767, Loss: 4.054677701344107, Neurons: 50
# Epoch 2768, Loss: 2.5383987153668586, Neurons: 50
# Epoch 2769, Loss: 3.2824752782745166, Neurons: 50
# Epoch 2770, Loss: 4.789907816239905, Neurons: 50
# Epoch 2771, Loss: 5.22575097373429, Neurons: 50
# Epoch 2772, Loss: 4.300276816890788, Neurons: 50
# Epoch 2773, Loss: 3.1208942907612154, Neurons: 50
# Epoch 2774, Loss: 2.7432866866458356, Neurons: 50
# Epoch 2775, Loss: 3.178649847431377, Neurons: 50
# Epoch 2776, Loss: 3.6601970276292413, Neurons: 50
# Epoch 2777, Loss: 3.5590033356997903, Neurons: 50
# Epoch 2778, Loss: 2.9434655222063486, Neurons: 50
# Epoch 2779, Loss: 2.3815645985298, Neurons: 50
# Epoch 2780, Loss: 2.300637920605019, Neurons: 50
# Epoch 2781, Loss: 2.583059469033381, Neurons: 50
# Epoch 2782, Loss: 2.8012076810118742, Neurons: 50
# Epoch 2783, Loss: 2.730152678699487, Neurons: 50
# Epoch 2784, Loss: 2.501419269213566, Neurons: 50
# Epoch 2785, Loss: 2.3366821173387438, Neurons: 50
# Epoch 2786, Loss: 2.298705484029193, Neurons: 50
# Epoch 2787, Loss: 2.3095855350875256, Neurons: 50
# Epoch 2788, Loss: 2.291865019314468, Neurons: 50
# Epoch 2789, Loss: 2.2361412681740305, Neurons: 50
# Epoch 2790, Loss: 2.1734850101474903, Neurons: 50
# Epoch 2791, Loss: 2.12564214472508, Neurons: 50
# Epoch 2792, Loss: 2.089625345046473, Neurons: 50
# Epoch 2793, Loss: 2.0620339824852474, Neurons: 50
# Epoch 2794, Loss: 2.052558362256385, Neurons: 50
# Epoch 2795, Loss: 2.0552448049213963, Neurons: 50
# Epoch 2796, Loss: 2.035440734137551, Neurons: 50
# Epoch 2797, Loss: 1.9781486488405269, Neurons: 50
# Epoch 2798, Loss: 1.9242576372338787, Neurons: 50
# Epoch 2799, Loss: 1.9215084990994091, Neurons: 50
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[19, 31, 1]
# Epoch 2800, Loss: 1.954088288062814, Neurons: 51
# Epoch 2801, Loss: 36.19415730330025, Neurons: 51
# Epoch 2802, Loss: 4.203395222204125, Neurons: 51
# Epoch 2803, Loss: 11.308888004878215, Neurons: 51
# Epoch 2804, Loss: 19.81859627120029, Neurons: 51
# Epoch 2805, Loss: 15.295067121217574, Neurons: 51
# Epoch 2806, Loss: 6.978277118915296, Neurons: 51
# Epoch 2807, Loss: 2.7436444619656917, Neurons: 51
# Epoch 2808, Loss: 4.495168436297277, Neurons: 51
# Epoch 2809, Loss: 8.616073408208791, Neurons: 51
# Epoch 2810, Loss: 9.822852829558338, Neurons: 51
# Epoch 2811, Loss: 7.247734466111728, Neurons: 51
# Epoch 2812, Loss: 3.6974159954860855, Neurons: 51
# Epoch 2813, Loss: 2.2144808722646543, Neurons: 51
# Epoch 2814, Loss: 3.435561727693203, Neurons: 51
# Epoch 2815, Loss: 5.200290632020293, Neurons: 51
# Epoch 2816, Loss: 5.575247909311559, Neurons: 51
# Epoch 2817, Loss: 4.557090884362062, Neurons: 51
# Epoch 2818, Loss: 3.150518367622085, Neurons: 51
# Epoch 2819, Loss: 2.305933470344922, Neurons: 51
# Epoch 2820, Loss: 2.4221943143513163, Neurons: 51
# Epoch 2821, Loss: 3.1664690060387364, Neurons: 51
# Epoch 2822, Loss: 3.717291820762868, Neurons: 51
# Epoch 2823, Loss: 3.50637373770245, Neurons: 51
# Epoch 2824, Loss: 2.7608538634689075, Neurons: 51
# Epoch 2825, Loss: 2.179838674827404, Neurons: 51
# Epoch 2826, Loss: 2.1483218323065127, Neurons: 51
# Epoch 2827, Loss: 2.4616223717449643, Neurons: 51
# Epoch 2828, Loss: 2.740235343222471, Neurons: 51
# Epoch 2829, Loss: 2.7628782483144834, Neurons: 51
# Epoch 2830, Loss: 2.489753398258777, Neurons: 51
# Epoch 2831, Loss: 2.0985946072643364, Neurons: 51
# Epoch 2832, Loss: 1.9093798507858997, Neurons: 51
# Epoch 2833, Loss: 2.049723755356112, Neurons: 51
# Epoch 2834, Loss: 2.2891313095293064, Neurons: 51
# Epoch 2835, Loss: 2.3446865866874833, Neurons: 51
# Epoch 2836, Loss: 2.1927513659576214, Neurons: 51
# Epoch 2837, Loss: 1.9831044237341722, Neurons: 51
# Epoch 2838, Loss: 1.844046750433061, Neurons: 51
# Epoch 2839, Loss: 1.8441300236775326, Neurons: 51
# Epoch 2840, Loss: 1.9652993489958293, Neurons: 51
# Epoch 2841, Loss: 2.067392231519277, Neurons: 51
# Epoch 2842, Loss: 2.0302457470927076, Neurons: 51
# Epoch 2843, Loss: 1.9102379936002543, Neurons: 51
# Epoch 2844, Loss: 1.8325338416907526, Neurons: 51
# Epoch 2845, Loss: 1.8253233414328998, Neurons: 51
# Epoch 2846, Loss: 1.8491201094937233, Neurons: 51
# Epoch 2847, Loss: 1.8689423344958183, Neurons: 51
# Epoch 2848, Loss: 1.852755269811452, Neurons: 51
# Epoch 2849, Loss: 1.800589822934046, Neurons: 51
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[19, 32, 1]
# Epoch 2850, Loss: 1.7681606872702564, Neurons: 52
# Epoch 2851, Loss: 10.357441055508708, Neurons: 52
# Epoch 2852, Loss: 5.471433675324714, Neurons: 52
# Epoch 2853, Loss: 3.9815147958282897, Neurons: 52
# Epoch 2854, Loss: 4.560265004590383, Neurons: 52
# Epoch 2855, Loss: 5.0524538356009305, Neurons: 52
# Epoch 2856, Loss: 5.320493297742129, Neurons: 52
# Epoch 2857, Loss: 3.277755093420721, Neurons: 52
# Epoch 2858, Loss: 2.3659758628572636, Neurons: 52
# Epoch 2859, Loss: 2.669276184844103, Neurons: 52
# Epoch 2860, Loss: 2.6664797366332866, Neurons: 52
# Epoch 2861, Loss: 2.891011099000679, Neurons: 52
# Epoch 2862, Loss: 3.001197187235908, Neurons: 52
# Epoch 2863, Loss: 2.9579543879224754, Neurons: 52
# Epoch 2864, Loss: 2.6421113868765933, Neurons: 52
# Epoch 2865, Loss: 2.0626354355166128, Neurons: 52
# Epoch 2866, Loss: 2.0687125473672374, Neurons: 52
# Epoch 2867, Loss: 2.2525546368630476, Neurons: 52
# Epoch 2868, Loss: 2.06828195726527, Neurons: 52
# Epoch 2869, Loss: 2.1499880471489567, Neurons: 52
# Epoch 2870, Loss: 2.32224024841755, Neurons: 52
# Epoch 2871, Loss: 2.1888080681144904, Neurons: 52
# Epoch 2872, Loss: 2.0230504457426397, Neurons: 52
# Epoch 2873, Loss: 1.8477014010063628, Neurons: 52
# Epoch 2874, Loss: 1.8109595513931749, Neurons: 52
# Epoch 2875, Loss: 1.8489644278420423, Neurons: 52
# Epoch 2876, Loss: 1.7990279949135375, Neurons: 52
# Epoch 2877, Loss: 1.912421284352672, Neurons: 52
# Epoch 2878, Loss: 1.9713719489111032, Neurons: 52
# Epoch 2879, Loss: 1.8080325676919378, Neurons: 52
# Epoch 2880, Loss: 1.7236323939245062, Neurons: 52
# Epoch 2881, Loss: 1.6880421239939642, Neurons: 52
# Epoch 2882, Loss: 1.6691377647332775, Neurons: 52
# Epoch 2883, Loss: 1.6951566760526884, Neurons: 52
# Epoch 2884, Loss: 1.7172922479189523, Neurons: 52
# Epoch 2885, Loss: 1.750834051899372, Neurons: 52
# Epoch 2886, Loss: 1.6808822271619261, Neurons: 52
# Epoch 2887, Loss: 1.605192897730837, Neurons: 52
# Epoch 2888, Loss: 1.6156998078772182, Neurons: 52
# Epoch 2889, Loss: 1.5945550203325785, Neurons: 52
# Epoch 2890, Loss: 1.5988803387245363, Neurons: 52
# Epoch 2891, Loss: 1.6176360383928132, Neurons: 52
# Epoch 2892, Loss: 1.6050350476971988, Neurons: 52
# Epoch 2893, Loss: 1.5728023968890092, Neurons: 52
# Epoch 2894, Loss: 1.5426059403020163, Neurons: 52
# Epoch 2895, Loss: 1.5477379566961553, Neurons: 52
# Epoch 2896, Loss: 1.5284913330461485, Neurons: 52
# Epoch 2897, Loss: 1.524862762710728, Neurons: 52
# Epoch 2898, Loss: 1.5318177350560123, Neurons: 52
# Epoch 2899, Loss: 1.5097214866106115, Neurons: 52
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[19, 33, 1]
# Epoch 2900, Loss: 1.4989364416088597, Neurons: 53
# Epoch 2901, Loss: 49.59612262270078, Neurons: 53
# Epoch 2902, Loss: 3.947851170006198, Neurons: 53
# Epoch 2903, Loss: 16.05503835486991, Neurons: 53
# Epoch 2904, Loss: 28.153203833947433, Neurons: 53
# Epoch 2905, Loss: 19.416096335851595, Neurons: 53
# Epoch 2906, Loss: 7.179391451010519, Neurons: 53
# Epoch 2907, Loss: 4.633919564408383, Neurons: 53
# Epoch 2908, Loss: 10.634183430640922, Neurons: 53
# Epoch 2909, Loss: 14.68870721350795, Neurons: 53
# Epoch 2910, Loss: 11.790391509943223, Neurons: 53
# Epoch 2911, Loss: 5.7443788555069, Neurons: 53
# Epoch 2912, Loss: 2.416684679722227, Neurons: 53
# Epoch 2913, Loss: 3.8223241658604747, Neurons: 53
# Epoch 2914, Loss: 7.088908469196884, Neurons: 53
# Epoch 2915, Loss: 8.324028292950855, Neurons: 53
# Epoch 2916, Loss: 6.4940228601401095, Neurons: 53
# Epoch 2917, Loss: 3.533488869235931, Neurons: 53
# Epoch 2918, Loss: 2.0321810657757657, Neurons: 53
# Epoch 2919, Loss: 2.845180844212615, Neurons: 53
# Epoch 2920, Loss: 4.46955388957605, Neurons: 53
# Epoch 2921, Loss: 4.884007963986421, Neurons: 53
# Epoch 2922, Loss: 3.7182575141013094, Neurons: 53
# Epoch 2923, Loss: 2.264140797287285, Neurons: 53
# Epoch 2924, Loss: 1.8451320563331226, Neurons: 53
# Epoch 2925, Loss: 2.535084101508952, Neurons: 53
# Epoch 2926, Loss: 3.3423208395663457, Neurons: 53
# Epoch 2927, Loss: 3.3682329972778144, Neurons: 53
# Epoch 2928, Loss: 2.635293798357892, Neurons: 53
# Epoch 2929, Loss: 1.8995234038999484, Neurons: 53
# Epoch 2930, Loss: 1.804710771616607, Neurons: 53
# Epoch 2931, Loss: 2.241011151138748, Neurons: 53
# Epoch 2932, Loss: 2.5439326734329772, Neurons: 53
# Epoch 2933, Loss: 2.2921798646048224, Neurons: 53
# Epoch 2934, Loss: 1.7562664932181355, Neurons: 53
# Epoch 2935, Loss: 1.5046261484173178, Neurons: 53
# Epoch 2936, Loss: 1.7170394217837053, Neurons: 53
# Epoch 2937, Loss: 2.0374133464027966, Neurons: 53
# Epoch 2938, Loss: 2.060167256687888, Neurons: 53
# Epoch 2939, Loss: 1.781482908739503, Neurons: 53
# Epoch 2940, Loss: 1.52002673168132, Neurons: 53
# Epoch 2941, Loss: 1.5092245404907085, Neurons: 53
# Epoch 2942, Loss: 1.6652703753924372, Neurons: 53
# Epoch 2943, Loss: 1.7449490810099528, Neurons: 53
# Epoch 2944, Loss: 1.6471438717699884, Neurons: 53
# Epoch 2945, Loss: 1.4981720286216635, Neurons: 53
# Epoch 2946, Loss: 1.4650197116770012, Neurons: 53
# Epoch 2947, Loss: 1.55021231640692, Neurons: 53
# Epoch 2948, Loss: 1.6061855800668585, Neurons: 53
# Epoch 2949, Loss: 1.5330578857013464, Neurons: 53
# Removed neuron to hidden layer 2 at index 32
# network shape updated to :[19, 32, 1]
# Epoch 2950, Loss: 1.4036012070642474, Neurons: 52
# Epoch 2951, Loss: 53.90922509199588, Neurons: 52
# Epoch 2952, Loss: 5.115832087129975, Neurons: 52
# Epoch 2953, Loss: 12.719856643364652, Neurons: 52
# Epoch 2954, Loss: 29.76614143519543, Neurons: 52
# Epoch 2955, Loss: 24.889714007117483, Neurons: 52
# Epoch 2956, Loss: 10.32933811089238, Neurons: 52
# Epoch 2957, Loss: 2.0378611654553205, Neurons: 52
# Epoch 2958, Loss: 5.893790759881939, Neurons: 52
# Epoch 2959, Loss: 13.776937649430545, Neurons: 52
# Epoch 2960, Loss: 15.315903533823498, Neurons: 52
# Epoch 2961, Loss: 9.903973782000026, Neurons: 52
# Epoch 2962, Loss: 3.613785788622496, Neurons: 52
# Epoch 2963, Loss: 1.740739025018826, Neurons: 52
# Epoch 2964, Loss: 4.472578238989842, Neurons: 52
# Epoch 2965, Loss: 7.9258091524411896, Neurons: 52
# Epoch 2966, Loss: 8.64384985752816, Neurons: 52
# Epoch 2967, Loss: 6.318789288284589, Neurons: 52
# Epoch 2968, Loss: 3.151645717473053, Neurons: 52
# Epoch 2969, Loss: 1.6477703810753423, Neurons: 52
# Epoch 2970, Loss: 2.5741361028104532, Neurons: 52
# Epoch 2971, Loss: 4.463811081712374, Neurons: 52
# Epoch 2972, Loss: 5.201365005968687, Neurons: 52
# Epoch 2973, Loss: 4.108762032540888, Neurons: 52
# Epoch 2974, Loss: 2.347799255743078, Neurons: 52
# Epoch 2975, Loss: 1.5163372175479568, Neurons: 52
# Epoch 2976, Loss: 2.075251596179438, Neurons: 52
# Epoch 2977, Loss: 3.1229078209627508, Neurons: 52
# Epoch 2978, Loss: 3.5048116504787017, Neurons: 52
# Epoch 2979, Loss: 2.9011609232551474, Neurons: 52
# Epoch 2980, Loss: 1.9275880953654767, Neurons: 52
# Epoch 2981, Loss: 1.4433041465532306, Neurons: 52
# Epoch 2982, Loss: 1.7578553415296159, Neurons: 52
# Epoch 2983, Loss: 2.3795676543136364, Neurons: 52
# Epoch 2984, Loss: 2.5649508025083168, Neurons: 52
# Epoch 2985, Loss: 2.1254563904767556, Neurons: 52
# Epoch 2986, Loss: 1.5594423395644745, Neurons: 52
# Epoch 2987, Loss: 1.4137929457042167, Neurons: 52
# Epoch 2988, Loss: 1.6998910660512663, Neurons: 52
# Epoch 2989, Loss: 1.9910675679468277, Neurons: 52
# Epoch 2990, Loss: 1.9487147404302396, Neurons: 52
# Epoch 2991, Loss: 1.6382288836309415, Neurons: 52
# Epoch 2992, Loss: 1.3886675794901562, Neurons: 52
# Epoch 2993, Loss: 1.421244864817213, Neurons: 52
# Epoch 2994, Loss: 1.6287904933997748, Neurons: 52
# Epoch 2995, Loss: 1.7249581041903048, Neurons: 52
# Epoch 2996, Loss: 1.5876768870759517, Neurons: 52
# Epoch 2997, Loss: 1.381900695263401, Neurons: 52
# Epoch 2998, Loss: 1.3272121879734373, Neurons: 52
# Epoch 2999, Loss: 1.4329338382909633, Neurons: 52
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[19, 33, 1]

# %%
np.savetxt(f"{out_folder}/neurons.txt", Node_history)
np.savetxt(f"{out_folder}/loss.txt", Loss_history)

# %%
x_test = jnp.linspace(-3, 3, 100).reshape(-1, 1)
y_test = poly(x_test)
y_pred = jax.vmap(mlp)(x_test)

plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, label="True Poly Function")
plt.plot(x_test, y_pred, label="MLP Predictions")
plt.legend()
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("MLP Approximation of polynomial Function")
plt.savefig(f"{fig_folder}/polynomial_approximation.png")
wandb.log({"polynomial approximation": wandb.Image(plt, caption="polynomial approximation")})

# %%
Update_history
# Out:
# [(49, 21, Array(1152.4492532, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (99, 22, Array(788.38579781, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (149, 23, Array(452.09961302, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (199, 24, Array(275.1144282, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (249, 25, Array(168.42890291, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (299, 26, Array(134.36041827, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (349, 27, Array(43.53051039, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (399, 28, Array(23.39692447, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (449, 29, Array(16.0229764, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (499, 30, Array(10.79137756, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (549,
#   31,
#   Array(28.20481665, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (599,
#   30,
#   Array(40.05289203, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (649, 29, Array(10.1237536, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (699, 30, Array(6.04453887, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (749, 31, Array(4.77137897, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (799, 32, Array(3.39962296, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (849, 33, Array(3.34301584, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (899, 34, Array(2.63670903, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (949, 35, Array(2.12203143, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (999, 36, Array(1.91541713, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1049, 37, Array(1.81640054, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (1099, 38, Array(1.80728648, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (1149,
#   39,
#   Array(6.30493546, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (1199, 38, Array(4.04064916, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (1249,
#   39,
#   Array(19.31993899, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (1299, 38, Array(5.27382746, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1349, 39, Array(2.58632416, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1399, 40, Array(2.37842999, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1449, 41, Array(2.11893086, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1499,
#   42,
#   Array(2.14404246, dtype=float64),
#   'removed',
#   Array(1, dtype=int64)),
#  (1549, 41, Array(1.80011678, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1599,
#   42,
#   Array(1.82389291, dtype=float64),
#   'removed',
#   Array(1, dtype=int64)),
#  (1649, 41, Array(1.69939459, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1699,
#   42,
#   Array(1.71045401, dtype=float64),
#   'removed',
#   Array(1, dtype=int64)),
#  (1749, 41, Array(1.66517182, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (1799, 42, Array(1.50222884, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (1849, 43, Array(1.49915724, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (1899,
#   44,
#   Array(2.25723775, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (1949, 43, Array(2.07978667, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (1999, 44, Array(7.4950591, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (2049, 43, Array(6.51299248, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2099, 44, Array(1.96558535, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (2149, 45, Array(1.60366219, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2199, 46, Array(1.59035172, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (2249,
#   47,
#   Array(4.21035002, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (2299,
#   46,
#   Array(4.45720011, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (2349, 45, Array(2.55049541, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (2399,
#   46,
#   Array(3.16685215, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (2449, 45, Array(2.66007941, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (2499,
#   46,
#   Array(18.91485205, dtype=float64),
#   'removed',
#   Array(0, dtype=int64)),
#  (2549, 45, Array(17.26394575, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2599, 46, Array(2.81047041, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2649, 47, Array(2.73877311, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2699, 48, Array(2.31867871, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2749, 49, Array(2.07205538, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2799, 50, Array(1.9215085, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2849, 51, Array(1.80058982, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2899, 52, Array(1.50972149, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (2949,
#   53,
#   Array(1.53305789, dtype=float64),
#   'removed',
#   Array(1, dtype=int64)),
#  (2999, 52, Array(1.43293384, dtype=float64), 'sin', Array(1, dtype=int64))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
plt.matshow(final_adjacency_matrix, cmap=plt.cm.viridis)
plt.colorbar()
plt.title("Final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(np.arange(0,len(Loss_history)), Loss_history, ".", color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(np.arange(0,len(Node_history)), Node_history, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.suptitle("Homogenous Neural Network with Loss strategic Node Addition and Removal")
fig.tight_layout()

plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()
