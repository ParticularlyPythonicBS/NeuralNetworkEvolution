# %% [markdown]
# # Probabilistic strategy for 1d mnist classification with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "30_hetero_1dmnist_probabilistic.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="30_hetero_1dmnist_probabilistic.ipynb"
# env: WANDB_SILENT=True
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

from mnist1d.data import make_dataset, get_dataset_args, get_templates

import os
import sys
import time
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %%
def plot_1dmnist(xs, t, labels=None, ratio=2.6, dark_mode=False, zoom=1):
    rows, cols = 1, 10
    fig = plt.figure(figsize=[cols*1.5,rows*1.5*ratio], dpi=60)
    for r in range(rows):
        for c in range(cols):
            ix = r*cols + c
            x, t = xs[ix], t
            ax = plt.subplot(rows,cols,ix+1)

            if dark_mode:
                plt.plot(x, t, 'wo', linewidth=6)
                ax.set_facecolor('k')
            else:
                plt.plot(x, t, 'k-', linewidth=2)
            if labels is not None:
                plt.title("label=" + str(labels[ix]), fontsize=22)

            plt.xlim(-zoom,zoom) ; plt.ylim(-zoom,zoom)
            plt.gca().invert_yaxis() ; plt.xticks([], []), plt.yticks([], [])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.tight_layout() ; plt.show()
    return fig

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 40
hidden_sizes = [10, 10] 
min_neurons = 20
output_size = 10
initial_activation_list = [jax.nn.relu]
activation_list = [jax.nn.relu]
optimizer = optax.adabelief
bias = False
num_epochs = 3000
intervene_every = 50
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
input_size = 40
hidden_sizes = [10, 10] 
min_neurons = 20
output_size = 10
initial_activation_list = [jax.nn.relu, jax.nn.tanh, sin]
activation_list = [jax.nn.relu, jax.nn.tanh, sin]
optimizer = optax.adabelief
bias = False
num_epochs = 3000
intervene_every = 50
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"Hetero_{act_string}_1dmnist_probabilistic_strat_{optimizer.__name__}_no_bias_min_{min_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: Hetero_relu_tanh_sin_1dmnist_probabilistic_strat_adabelief_no_bias_min_20_10_10_3000_50_0.0001_0
# Description: Hetero_relu_tanh_sin_1dmnist_probabilistic_strat_adabelief_no_bias_min_20_10_10_3000_50_0.0001_0
# jax backend: cpu
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
data_config = get_dataset_args()

# %%
data_config.num_samples = n_samples
data_config.shuffle_seq = True

# %%
data = make_dataset(data_config)

# %%
x_train, y_train = data["x"], data["y"]
x_test, y_test = data["x_test"], data["y_test"]
template = data["t"]

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape, template.shape
# Out:
# ((16000, 40), (16000,), (4000, 40), (4000,), (40,))

# %%
plt.hist(y_train)
# Out:
# (array([1613., 1598., 1597., 1614., 1571., 1589., 1597., 1602., 1600.,
#         1619.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_1dmnist(x, t, labels=y, ratio=1.33, dark_mode=False)
# Out:
# Templates for the MNIST-1D dataset:

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@jax.jit
def cross_entropy(y, pred_y):
    # y are the true targets, and should be integers 0-9.
    # pred_y are the log-softmax'd predictions.
    pred_y = jnp.take_along_axis(pred_y, jnp.expand_dims(y, 1), axis=1)
    return -jnp.mean(pred_y)

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred_y = jax.nn.log_softmax(jax.vmap(mlp)(x))
    loss = cross_entropy(y, pred_y)
    return loss

# %%
@eqx.filter_jit()
def accuracy(mlp, x, y):
    logits = jax.vmap(mlp)(x)
    return jnp.mean(jnp.argmax(logits, axis=-1) == y)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0], accuracy(mlp, x, y)

# %%
@eqx.filter_jit()
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 30
# Number of neurons at start: 30

# %%
# logits = jax.nn.log_softmax(jax.vmap(mlp)(x_train))
# logits.shape
# one_hot_labels = jax.nn.one_hot(y_train, 10)
# one_hot_labels.shape
# plt.plot(optax.softmax_cross_entropy(logits=logits, labels=one_hot_labels))

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
accuracy_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity
check_accuracy = 0 # initialize check accuracy to 0

# %%
def p_add(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to add a neuron
    """
    return test_loss / (test_loss + n_neurons / min_neurons)

def p_remove(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to remove a neuron
    """
    return test_loss / (test_loss + min_neurons / n_neurons)

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss, test_accuracy = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}, Test accuracy: {test_accuracy}")
        wandb.log({"test_loss": test_loss.item(), "test_accuracy": test_accuracy})
        test_loss_history.append((epoch,test_loss))
        accuracy_history.append((epoch, test_accuracy))
        # if relative difference in test loss is positive and high, stop training
        if (test_loss - check_loss)/check_loss > 0.1 and epoch > 0:
            logging.info(f"Test loss increased by more than 0.1, stopping training at epoch {epoch}")
            wandb.log({"test_loss_increased": epoch})
            break

        # Neuron Addition criteria
        if ((len(update_history) == 0    # if no previous addition
            or check_loss > test_loss) # if last addition was accepted
            and jax.random.uniform(prob_key, minval = 0, maxval = 1)< p_add(test_loss, n_neurons, min_neurons)): # addition probability

            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0] # randomly select a layer to add neuron to
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            update_history.append((epoch, n_neurons, train_loss, test_loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
            check_loss = test_loss
            logging.info(f"Check loss updated to {check_loss}")
        
        # Neuron Removal criteria
        elif ((check_loss < test_loss) # check current loss against last accepted addition
            and n_neurons>min_neurons # neuron floor
            and jax.random.uniform(prob_key, minval = 0, maxval = 1)<p_remove(test_loss, n_neurons, min_neurons)): # removal probability 

            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            layer = update_history[-1][-1] # get the layer of last addition
            neuron_idx = len(mlp.layers[layer]) -1

            if len(mlp.layers[layer]) <= 1:
                logging.info(f"Cannot remove neuron from layer {layer+1}, only one neuron left")
                update_history.append((epoch, n_neurons, train_loss, test_loss, "single_node_layer", layer))
                continue

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            update_history.append((epoch, n_neurons, train_loss, test_loss, "removed", layer))

            logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
            wandb.log({"removed neuron": neuron_idx})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 2.3025851249694824, Neurons: 30, Grad norm: 2.825e-02
# Epoch 000, Loss: 2.3025851249694824, Neurons: 30, Grad norm: 2.825e-02
# Epoch 001, Loss: 2.302525758743286, Neurons: 30, Grad norm: 2.891e-02
# Epoch 001, Loss: 2.302525758743286, Neurons: 30, Grad norm: 2.891e-02
# Epoch 002, Loss: 2.302459955215454, Neurons: 30, Grad norm: 2.971e-02
# Epoch 002, Loss: 2.302459955215454, Neurons: 30, Grad norm: 2.971e-02
# Epoch 003, Loss: 2.302387237548828, Neurons: 30, Grad norm: 3.062e-02
# Epoch 003, Loss: 2.302387237548828, Neurons: 30, Grad norm: 3.062e-02
# Epoch 004, Loss: 2.302306652069092, Neurons: 30, Grad norm: 3.163e-02
# Epoch 004, Loss: 2.302306652069092, Neurons: 30, Grad norm: 3.163e-02
# Epoch 005, Loss: 2.302217483520508, Neurons: 30, Grad norm: 3.275e-02
# Epoch 005, Loss: 2.302217483520508, Neurons: 30, Grad norm: 3.275e-02
# Epoch 006, Loss: 2.3021185398101807, Neurons: 30, Grad norm: 3.396e-02
# Epoch 006, Loss: 2.3021185398101807, Neurons: 30, Grad norm: 3.396e-02
# Epoch 007, Loss: 2.302008628845215, Neurons: 30, Grad norm: 3.529e-02
# Epoch 007, Loss: 2.302008628845215, Neurons: 30, Grad norm: 3.529e-02
# Epoch 008, Loss: 2.301886796951294, Neurons: 30, Grad norm: 3.672e-02
# Epoch 008, Loss: 2.301886796951294, Neurons: 30, Grad norm: 3.672e-02
# Epoch 009, Loss: 2.3017516136169434, Neurons: 30, Grad norm: 3.826e-02
# Epoch 009, Loss: 2.3017516136169434, Neurons: 30, Grad norm: 3.826e-02
# Epoch 010, Loss: 2.3016014099121094, Neurons: 30, Grad norm: 3.992e-02
# Epoch 010, Loss: 2.3016014099121094, Neurons: 30, Grad norm: 3.992e-02
# Epoch 029, Loss: 2.2930338382720947, Neurons: 30, Grad norm: 9.633e-02
# Epoch 029, Loss: 2.2930338382720947, Neurons: 30, Grad norm: 9.633e-02
# Epoch 030, Loss: 2.2920777797698975, Neurons: 30, Grad norm: 1.007e-01
# Epoch 030, Loss: 2.2920777797698975, Neurons: 30, Grad norm: 1.007e-01
# Epoch 031, Loss: 2.2910454273223877, Neurons: 30, Grad norm: 1.052e-01
# Epoch 031, Loss: 2.2910454273223877, Neurons: 30, Grad norm: 1.052e-01
# Epoch 032, Loss: 2.2899327278137207, Neurons: 30, Grad norm: 1.098e-01
# Epoch 032, Loss: 2.2899327278137207, Neurons: 30, Grad norm: 1.098e-01
# Epoch 033, Loss: 2.2887344360351562, Neurons: 30, Grad norm: 1.145e-01
# Epoch 033, Loss: 2.2887344360351562, Neurons: 30, Grad norm: 1.145e-01
# Epoch 034, Loss: 2.2874467372894287, Neurons: 30, Grad norm: 1.193e-01
# Epoch 034, Loss: 2.2874467372894287, Neurons: 30, Grad norm: 1.193e-01
# Epoch 035, Loss: 2.2860641479492188, Neurons: 30, Grad norm: 1.243e-01
# Epoch 035, Loss: 2.2860641479492188, Neurons: 30, Grad norm: 1.243e-01
# Epoch 036, Loss: 2.2845821380615234, Neurons: 30, Grad norm: 1.293e-01
# Epoch 036, Loss: 2.2845821380615234, Neurons: 30, Grad norm: 1.293e-01
# Epoch 037, Loss: 2.28299617767334, Neurons: 30, Grad norm: 1.345e-01
# Epoch 037, Loss: 2.28299617767334, Neurons: 30, Grad norm: 1.345e-01
# Epoch 038, Loss: 2.2812998294830322, Neurons: 30, Grad norm: 1.398e-01
# Epoch 038, Loss: 2.2812998294830322, Neurons: 30, Grad norm: 1.398e-01
# Epoch 039, Loss: 2.2794883251190186, Neurons: 30, Grad norm: 1.451e-01
# Epoch 039, Loss: 2.2794883251190186, Neurons: 30, Grad norm: 1.451e-01
# Epoch 040, Loss: 2.2775561809539795, Neurons: 30, Grad norm: 1.506e-01
# Epoch 040, Loss: 2.2775561809539795, Neurons: 30, Grad norm: 1.506e-01
# Epoch 041, Loss: 2.275498151779175, Neurons: 30, Grad norm: 1.561e-01
# Epoch 041, Loss: 2.275498151779175, Neurons: 30, Grad norm: 1.561e-01
# Epoch 042, Loss: 2.2733089923858643, Neurons: 30, Grad norm: 1.617e-01
# Epoch 042, Loss: 2.2733089923858643, Neurons: 30, Grad norm: 1.617e-01
# Epoch 043, Loss: 2.2709832191467285, Neurons: 30, Grad norm: 1.673e-01
# Epoch 043, Loss: 2.2709832191467285, Neurons: 30, Grad norm: 1.673e-01
# Epoch 044, Loss: 2.2685153484344482, Neurons: 30, Grad norm: 1.730e-01
# Epoch 044, Loss: 2.2685153484344482, Neurons: 30, Grad norm: 1.730e-01
# Epoch 045, Loss: 2.265900135040283, Neurons: 30, Grad norm: 1.787e-01
# Epoch 045, Loss: 2.265900135040283, Neurons: 30, Grad norm: 1.787e-01
# Epoch 046, Loss: 2.263134241104126, Neurons: 30, Grad norm: 1.845e-01
# Epoch 046, Loss: 2.263134241104126, Neurons: 30, Grad norm: 1.845e-01
# Epoch 047, Loss: 2.2602128982543945, Neurons: 30, Grad norm: 1.902e-01
# Epoch 047, Loss: 2.2602128982543945, Neurons: 30, Grad norm: 1.902e-01
# Epoch 048, Loss: 2.2571330070495605, Neurons: 30, Grad norm: 1.959e-01
# Epoch 048, Loss: 2.2571330070495605, Neurons: 30, Grad norm: 1.959e-01
# Epoch 049, Loss: 2.253889560699463, Neurons: 30, Grad norm: 2.015e-01
# Epoch 049, Loss: 2.253889560699463, Neurons: 30, Grad norm: 2.015e-01
# Epoch 049, Test loss: 2.251248598098755, Test accuracy: 0.1720000058412552
# Epoch 049, Test loss: 2.251248598098755, Test accuracy: 0.1720000058412552
# Epoch 050, Loss: 2.2504796981811523, Neurons: 30, Grad norm: 2.071e-01
# Epoch 050, Loss: 2.2504796981811523, Neurons: 30, Grad norm: 2.071e-01
# Epoch 051, Loss: 2.246900796890259, Neurons: 30, Grad norm: 2.127e-01
# Epoch 051, Loss: 2.246900796890259, Neurons: 30, Grad norm: 2.127e-01
# Epoch 052, Loss: 2.2431507110595703, Neurons: 30, Grad norm: 2.181e-01
# Epoch 052, Loss: 2.2431507110595703, Neurons: 30, Grad norm: 2.181e-01
# Epoch 053, Loss: 2.239227294921875, Neurons: 30, Grad norm: 2.235e-01
# Epoch 053, Loss: 2.239227294921875, Neurons: 30, Grad norm: 2.235e-01
# Epoch 054, Loss: 2.2351303100585938, Neurons: 30, Grad norm: 2.287e-01
# Epoch 054, Loss: 2.2351303100585938, Neurons: 30, Grad norm: 2.287e-01
# Epoch 055, Loss: 2.23085880279541, Neurons: 30, Grad norm: 2.338e-01
# Epoch 055, Loss: 2.23085880279541, Neurons: 30, Grad norm: 2.338e-01
# Epoch 056, Loss: 2.2264113426208496, Neurons: 30, Grad norm: 2.387e-01
# Epoch 056, Loss: 2.2264113426208496, Neurons: 30, Grad norm: 2.387e-01
# Epoch 057, Loss: 2.221790313720703, Neurons: 30, Grad norm: 2.435e-01
# Epoch 057, Loss: 2.221790313720703, Neurons: 30, Grad norm: 2.435e-01
# Epoch 058, Loss: 2.216996192932129, Neurons: 30, Grad norm: 2.481e-01
# Epoch 058, Loss: 2.216996192932129, Neurons: 30, Grad norm: 2.481e-01
# Epoch 059, Loss: 2.212031841278076, Neurons: 30, Grad norm: 2.525e-01
# Epoch 059, Loss: 2.212031841278076, Neurons: 30, Grad norm: 2.525e-01
# Epoch 060, Loss: 2.2068989276885986, Neurons: 30, Grad norm: 2.567e-01
# Epoch 060, Loss: 2.2068989276885986, Neurons: 30, Grad norm: 2.567e-01
# Epoch 061, Loss: 2.20160174369812, Neurons: 30, Grad norm: 2.606e-01
# Epoch 061, Loss: 2.20160174369812, Neurons: 30, Grad norm: 2.606e-01
# Epoch 062, Loss: 2.19614315032959, Neurons: 30, Grad norm: 2.643e-01
# Epoch 062, Loss: 2.19614315032959, Neurons: 30, Grad norm: 2.643e-01
# Epoch 063, Loss: 2.1905298233032227, Neurons: 30, Grad norm: 2.678e-01
# Epoch 063, Loss: 2.1905298233032227, Neurons: 30, Grad norm: 2.678e-01
# Epoch 064, Loss: 2.1847662925720215, Neurons: 30, Grad norm: 2.710e-01
# Epoch 064, Loss: 2.1847662925720215, Neurons: 30, Grad norm: 2.710e-01
# Epoch 065, Loss: 2.1788580417633057, Neurons: 30, Grad norm: 2.740e-01
# Epoch 065, Loss: 2.1788580417633057, Neurons: 30, Grad norm: 2.740e-01
# Epoch 066, Loss: 2.17280912399292, Neurons: 30, Grad norm: 2.767e-01
# Epoch 066, Loss: 2.17280912399292, Neurons: 30, Grad norm: 2.767e-01
# Epoch 067, Loss: 2.166628122329712, Neurons: 30, Grad norm: 2.791e-01
# Epoch 067, Loss: 2.166628122329712, Neurons: 30, Grad norm: 2.791e-01
# Epoch 068, Loss: 2.160320520401001, Neurons: 30, Grad norm: 2.813e-01
# Epoch 068, Loss: 2.160320520401001, Neurons: 30, Grad norm: 2.813e-01
# Epoch 069, Loss: 2.1538946628570557, Neurons: 30, Grad norm: 2.831e-01
# Epoch 069, Loss: 2.1538946628570557, Neurons: 30, Grad norm: 2.831e-01
# Epoch 070, Loss: 2.1473584175109863, Neurons: 30, Grad norm: 2.847e-01
# Epoch 070, Loss: 2.1473584175109863, Neurons: 30, Grad norm: 2.847e-01
# Epoch 071, Loss: 2.1407196521759033, Neurons: 30, Grad norm: 2.860e-01
# Epoch 071, Loss: 2.1407196521759033, Neurons: 30, Grad norm: 2.860e-01
# Epoch 072, Loss: 2.1339874267578125, Neurons: 30, Grad norm: 2.870e-01
# Epoch 072, Loss: 2.1339874267578125, Neurons: 30, Grad norm: 2.870e-01
# Epoch 073, Loss: 2.1271719932556152, Neurons: 30, Grad norm: 2.876e-01
# Epoch 073, Loss: 2.1271719932556152, Neurons: 30, Grad norm: 2.876e-01
# Epoch 074, Loss: 2.12028431892395, Neurons: 30, Grad norm: 2.879e-01
# Epoch 074, Loss: 2.12028431892395, Neurons: 30, Grad norm: 2.879e-01
# Epoch 075, Loss: 2.113335132598877, Neurons: 30, Grad norm: 2.879e-01
# Epoch 075, Loss: 2.113335132598877, Neurons: 30, Grad norm: 2.879e-01
# Epoch 076, Loss: 2.1063358783721924, Neurons: 30, Grad norm: 2.876e-01
# Epoch 076, Loss: 2.1063358783721924, Neurons: 30, Grad norm: 2.876e-01
# Epoch 077, Loss: 2.0992989540100098, Neurons: 30, Grad norm: 2.869e-01
# Epoch 077, Loss: 2.0992989540100098, Neurons: 30, Grad norm: 2.869e-01
# Epoch 078, Loss: 2.0922374725341797, Neurons: 30, Grad norm: 2.859e-01
# Epoch 078, Loss: 2.0922374725341797, Neurons: 30, Grad norm: 2.859e-01
# Epoch 079, Loss: 2.085167169570923, Neurons: 30, Grad norm: 2.845e-01
# Epoch 079, Loss: 2.085167169570923, Neurons: 30, Grad norm: 2.845e-01
# Epoch 080, Loss: 2.0781002044677734, Neurons: 30, Grad norm: 2.828e-01
# Epoch 080, Loss: 2.0781002044677734, Neurons: 30, Grad norm: 2.828e-01
# Epoch 081, Loss: 2.0710513591766357, Neurons: 30, Grad norm: 2.808e-01
# Epoch 081, Loss: 2.0710513591766357, Neurons: 30, Grad norm: 2.808e-01
# Epoch 082, Loss: 2.064035654067993, Neurons: 30, Grad norm: 2.784e-01
# Epoch 082, Loss: 2.064035654067993, Neurons: 30, Grad norm: 2.784e-01
# Epoch 083, Loss: 2.0570693016052246, Neurons: 30, Grad norm: 2.757e-01
# Epoch 083, Loss: 2.0570693016052246, Neurons: 30, Grad norm: 2.757e-01
# Epoch 084, Loss: 2.0501673221588135, Neurons: 30, Grad norm: 2.727e-01
# Epoch 084, Loss: 2.0501673221588135, Neurons: 30, Grad norm: 2.727e-01
# Epoch 085, Loss: 2.043346405029297, Neurons: 30, Grad norm: 2.693e-01
# Epoch 085, Loss: 2.043346405029297, Neurons: 30, Grad norm: 2.693e-01
# Epoch 086, Loss: 2.0366218090057373, Neurons: 30, Grad norm: 2.657e-01
# Epoch 086, Loss: 2.0366218090057373, Neurons: 30, Grad norm: 2.657e-01
# Epoch 087, Loss: 2.030008554458618, Neurons: 30, Grad norm: 2.618e-01
# Epoch 087, Loss: 2.030008554458618, Neurons: 30, Grad norm: 2.618e-01
# Epoch 088, Loss: 2.02352237701416, Neurons: 30, Grad norm: 2.576e-01
# Epoch 088, Loss: 2.02352237701416, Neurons: 30, Grad norm: 2.576e-01
# Epoch 089, Loss: 2.0171773433685303, Neurons: 30, Grad norm: 2.532e-01
# Epoch 089, Loss: 2.0171773433685303, Neurons: 30, Grad norm: 2.532e-01
# Epoch 090, Loss: 2.0109877586364746, Neurons: 30, Grad norm: 2.485e-01
# Epoch 090, Loss: 2.0109877586364746, Neurons: 30, Grad norm: 2.485e-01
# Epoch 091, Loss: 2.0049638748168945, Neurons: 30, Grad norm: 2.436e-01
# Epoch 091, Loss: 2.0049638748168945, Neurons: 30, Grad norm: 2.436e-01
# Epoch 092, Loss: 1.9991180896759033, Neurons: 30, Grad norm: 2.387e-01
# Epoch 092, Loss: 1.9991180896759033, Neurons: 30, Grad norm: 2.387e-01
# Epoch 093, Loss: 1.9934568405151367, Neurons: 30, Grad norm: 2.335e-01
# Epoch 093, Loss: 1.9934568405151367, Neurons: 30, Grad norm: 2.335e-01
# Epoch 094, Loss: 1.98798668384552, Neurons: 30, Grad norm: 2.283e-01
# Epoch 094, Loss: 1.98798668384552, Neurons: 30, Grad norm: 2.283e-01
# Epoch 095, Loss: 1.9827122688293457, Neurons: 30, Grad norm: 2.229e-01
# Epoch 095, Loss: 1.9827122688293457, Neurons: 30, Grad norm: 2.229e-01
# Epoch 096, Loss: 1.9776384830474854, Neurons: 30, Grad norm: 2.175e-01
# Epoch 096, Loss: 1.9776384830474854, Neurons: 30, Grad norm: 2.175e-01
# Epoch 097, Loss: 1.9727674722671509, Neurons: 30, Grad norm: 2.120e-01
# Epoch 097, Loss: 1.9727674722671509, Neurons: 30, Grad norm: 2.120e-01
# Epoch 098, Loss: 1.9680991172790527, Neurons: 30, Grad norm: 2.065e-01
# Epoch 098, Loss: 1.9680991172790527, Neurons: 30, Grad norm: 2.065e-01
# Epoch 099, Loss: 1.9636310338974, Neurons: 30, Grad norm: 2.011e-01
# Epoch 099, Loss: 1.9636310338974, Neurons: 30, Grad norm: 2.011e-01
# Epoch 099, Test loss: 1.9689688682556152, Test accuracy: 0.20200000703334808
# Epoch 099, Test loss: 1.9689688682556152, Test accuracy: 0.20200000703334808
# Added neuron to hidden layer 1 with activation relu
# Added neuron to hidden layer 1 with activation relu
# network shape updated to :[11, 10, 10]
# network shape updated to :[11, 10, 10]
# Check loss updated to 1.9689688682556152
# Check loss updated to 1.9689688682556152
# Epoch 100, Loss: 1.982696533203125, Neurons: 31, Grad norm: 2.842e-01
# Epoch 100, Loss: 1.982696533203125, Neurons: 31, Grad norm: 2.842e-01
# Epoch 101, Loss: 1.9815319776535034, Neurons: 31, Grad norm: 2.809e-01
# Epoch 101, Loss: 1.9815319776535034, Neurons: 31, Grad norm: 2.809e-01
# Epoch 102, Loss: 1.98032546043396, Neurons: 31, Grad norm: 2.778e-01
# Epoch 102, Loss: 1.98032546043396, Neurons: 31, Grad norm: 2.778e-01
# Epoch 103, Loss: 1.9790804386138916, Neurons: 31, Grad norm: 2.744e-01
# Epoch 103, Loss: 1.9790804386138916, Neurons: 31, Grad norm: 2.744e-01
# Epoch 104, Loss: 1.9777977466583252, Neurons: 31, Grad norm: 2.709e-01
# Epoch 104, Loss: 1.9777977466583252, Neurons: 31, Grad norm: 2.709e-01
# Epoch 105, Loss: 1.9764810800552368, Neurons: 31, Grad norm: 2.671e-01
# Epoch 105, Loss: 1.9764810800552368, Neurons: 31, Grad norm: 2.671e-01
# Epoch 106, Loss: 1.9751331806182861, Neurons: 31, Grad norm: 2.635e-01
# Epoch 106, Loss: 1.9751331806182861, Neurons: 31, Grad norm: 2.635e-01
# Epoch 107, Loss: 1.9737571477890015, Neurons: 31, Grad norm: 2.597e-01
# Epoch 107, Loss: 1.9737571477890015, Neurons: 31, Grad norm: 2.597e-01
# Epoch 108, Loss: 1.9723562002182007, Neurons: 31, Grad norm: 2.562e-01
# Epoch 108, Loss: 1.9723562002182007, Neurons: 31, Grad norm: 2.562e-01
# Epoch 109, Loss: 1.9709322452545166, Neurons: 31, Grad norm: 2.528e-01
# Epoch 109, Loss: 1.9709322452545166, Neurons: 31, Grad norm: 2.528e-01
# Epoch 110, Loss: 1.9694863557815552, Neurons: 31, Grad norm: 2.492e-01
# Epoch 110, Loss: 1.9694863557815552, Neurons: 31, Grad norm: 2.492e-01
# Epoch 111, Loss: 1.9680216312408447, Neurons: 31, Grad norm: 2.459e-01
# Epoch 111, Loss: 1.9680216312408447, Neurons: 31, Grad norm: 2.459e-01
# Epoch 112, Loss: 1.9665396213531494, Neurons: 31, Grad norm: 2.424e-01
# Epoch 112, Loss: 1.9665396213531494, Neurons: 31, Grad norm: 2.424e-01
# Epoch 113, Loss: 1.965043306350708, Neurons: 31, Grad norm: 2.389e-01
# Epoch 113, Loss: 1.965043306350708, Neurons: 31, Grad norm: 2.389e-01
# Epoch 114, Loss: 1.9635355472564697, Neurons: 31, Grad norm: 2.354e-01
# Epoch 149, Loss: 1.9154986143112183, Neurons: 31, Grad norm: 1.475e-01
# Epoch 149, Test loss: 1.9272657632827759, Test accuracy: 0.19550001621246338
# Epoch 149, Test loss: 1.9272657632827759, Test accuracy: 0.19550001621246338
# Added neuron to hidden layer 1 with activation sin
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[12, 10, 10]
# network shape updated to :[12, 10, 10]
# Check loss updated to 1.9272657632827759
# Check loss updated to 1.9272657632827759
# Epoch 150, Loss: 1.9295862913131714, Neurons: 32, Grad norm: 1.641e-01
# Epoch 150, Loss: 1.9295862913131714, Neurons: 32, Grad norm: 1.641e-01
# Epoch 151, Loss: 1.9288021326065063, Neurons: 32, Grad norm: 1.628e-01
# Epoch 151, Loss: 1.9288021326065063, Neurons: 32, Grad norm: 1.628e-01
# Epoch 152, Loss: 1.9279932975769043, Neurons: 32, Grad norm: 1.615e-01
# Epoch 152, Loss: 1.9279932975769043, Neurons: 32, Grad norm: 1.615e-01
# Epoch 153, Loss: 1.9271605014801025, Neurons: 32, Grad norm: 1.603e-01
# Epoch 153, Loss: 1.9271605014801025, Neurons: 32, Grad norm: 1.603e-01
# Epoch 154, Loss: 1.9263063669204712, Neurons: 32, Grad norm: 1.588e-01
# Epoch 154, Loss: 1.9263063669204712, Neurons: 32, Grad norm: 1.588e-01
# Epoch 155, Loss: 1.9254326820373535, Neurons: 32, Grad norm: 1.575e-01
# Epoch 155, Loss: 1.9254326820373535, Neurons: 32, Grad norm: 1.575e-01
# Epoch 156, Loss: 1.9245408773422241, Neurons: 32, Grad norm: 1.562e-01
# Epoch 156, Loss: 1.9245408773422241, Neurons: 32, Grad norm: 1.562e-01
# Epoch 157, Loss: 1.9236332178115845, Neurons: 32, Grad norm: 1.551e-01
# Epoch 157, Loss: 1.9236332178115845, Neurons: 32, Grad norm: 1.551e-01
# Epoch 158, Loss: 1.9227102994918823, Neurons: 32, Grad norm: 1.538e-01
# Epoch 158, Loss: 1.9227102994918823, Neurons: 32, Grad norm: 1.538e-01
# Epoch 159, Loss: 1.9217729568481445, Neurons: 32, Grad norm: 1.525e-01
# Epoch 159, Loss: 1.9217729568481445, Neurons: 32, Grad norm: 1.525e-01
# Epoch 160, Loss: 1.9208227396011353, Neurons: 32, Grad norm: 1.515e-01
# Epoch 160, Loss: 1.9208227396011353, Neurons: 32, Grad norm: 1.515e-01
# Epoch 161, Loss: 1.9198600053787231, Neurons: 32, Grad norm: 1.502e-01
# Epoch 161, Loss: 1.9198600053787231, Neurons: 32, Grad norm: 1.502e-01
# Epoch 162, Loss: 1.9188857078552246, Neurons: 32, Grad norm: 1.491e-01
# Epoch 162, Loss: 1.9188857078552246, Neurons: 32, Grad norm: 1.491e-01
# Epoch 163, Loss: 1.9179009199142456, Neurons: 32, Grad norm: 1.482e-01
# Epoch 163, Loss: 1.9179009199142456, Neurons: 32, Grad norm: 1.482e-01
# Epoch 164, Loss: 1.9169056415557861, Neurons: 32, Grad norm: 1.471e-01
# Epoch 164, Loss: 1.9169056415557861, Neurons: 32, Grad norm: 1.471e-01
# Epoch 182, Loss: 1.8980332612991333, Neurons: 32, Grad norm: 1.291e-01
# Epoch 183, Loss: 1.8969751596450806, Neurons: 32, Grad norm: 1.282e-01
# Epoch 183, Loss: 1.8969751596450806, Neurons: 32, Grad norm: 1.282e-01
# Epoch 184, Loss: 1.8959193229675293, Neurons: 32, Grad norm: 1.274e-01
# Epoch 184, Loss: 1.8959193229675293, Neurons: 32, Grad norm: 1.274e-01
# Epoch 185, Loss: 1.8948643207550049, Neurons: 32, Grad norm: 1.264e-01
# Epoch 185, Loss: 1.8948643207550049, Neurons: 32, Grad norm: 1.264e-01
# Epoch 186, Loss: 1.8938124179840088, Neurons: 32, Grad norm: 1.257e-01
# Epoch 186, Loss: 1.8938124179840088, Neurons: 32, Grad norm: 1.257e-01
# Epoch 187, Loss: 1.8927638530731201, Neurons: 32, Grad norm: 1.248e-01
# Epoch 187, Loss: 1.8927638530731201, Neurons: 32, Grad norm: 1.248e-01
# Epoch 188, Loss: 1.8917170763015747, Neurons: 32, Grad norm: 1.240e-01
# Epoch 188, Loss: 1.8917170763015747, Neurons: 32, Grad norm: 1.240e-01
# Epoch 189, Loss: 1.8906745910644531, Neurons: 32, Grad norm: 1.230e-01
# Epoch 189, Loss: 1.8906745910644531, Neurons: 32, Grad norm: 1.230e-01
# Epoch 190, Loss: 1.889638066291809, Neurons: 32, Grad norm: 1.220e-01
# Epoch 190, Loss: 1.889638066291809, Neurons: 32, Grad norm: 1.220e-01
# Epoch 191, Loss: 1.888607144355774, Neurons: 32, Grad norm: 1.212e-01
# Epoch 191, Loss: 1.888607144355774, Neurons: 32, Grad norm: 1.212e-01
# Epoch 192, Loss: 1.8875831365585327, Neurons: 32, Grad norm: 1.203e-01
# Epoch 192, Loss: 1.8875831365585327, Neurons: 32, Grad norm: 1.203e-01
# Epoch 193, Loss: 1.8865658044815063, Neurons: 32, Grad norm: 1.195e-01
# Epoch 193, Loss: 1.8865658044815063, Neurons: 32, Grad norm: 1.195e-01
# Epoch 194, Loss: 1.8855555057525635, Neurons: 32, Grad norm: 1.186e-01
# Epoch 194, Loss: 1.8855555057525635, Neurons: 32, Grad norm: 1.186e-01
# Epoch 195, Loss: 1.8845500946044922, Neurons: 32, Grad norm: 1.179e-01
# Epoch 195, Loss: 1.8845500946044922, Neurons: 32, Grad norm: 1.179e-01
# Epoch 196, Loss: 1.8835489749908447, Neurons: 32, Grad norm: 1.170e-01
# Epoch 196, Loss: 1.8835489749908447, Neurons: 32, Grad norm: 1.170e-01
# Epoch 197, Loss: 1.8825550079345703, Neurons: 32, Grad norm: 1.162e-01
# Epoch 197, Loss: 1.8825550079345703, Neurons: 32, Grad norm: 1.162e-01
# Epoch 198, Loss: 1.8815665245056152, Neurons: 32, Grad norm: 1.153e-01
# Epoch 198, Loss: 1.8815665245056152, Neurons: 32, Grad norm: 1.153e-01
# Epoch 199, Loss: 1.8805861473083496, Neurons: 32, Grad norm: 1.146e-01
# Epoch 199, Loss: 1.8805861473083496, Neurons: 32, Grad norm: 1.146e-01
# Epoch 199, Test loss: 1.8941010236740112, Test accuracy: 0.21150000393390656
# Epoch 199, Test loss: 1.8941010236740112, Test accuracy: 0.21150000393390656
# Epoch 200, Loss: 1.879611849784851, Neurons: 32, Grad norm: 1.139e-01
# Epoch 200, Loss: 1.879611849784851, Neurons: 32, Grad norm: 1.139e-01
# Epoch 201, Loss: 1.8786424398422241, Neurons: 32, Grad norm: 1.132e-01
# Epoch 201, Loss: 1.8786424398422241, Neurons: 32, Grad norm: 1.132e-01
# Epoch 202, Loss: 1.8776758909225464, Neurons: 32, Grad norm: 1.126e-01
# Epoch 202, Loss: 1.8776758909225464, Neurons: 32, Grad norm: 1.126e-01
# Epoch 203, Loss: 1.8767119646072388, Neurons: 32, Grad norm: 1.119e-01
# Epoch 203, Loss: 1.8767119646072388, Neurons: 32, Grad norm: 1.119e-01
# Epoch 204, Loss: 1.875752568244934, Neurons: 32, Grad norm: 1.112e-01
# Epoch 204, Loss: 1.875752568244934, Neurons: 32, Grad norm: 1.112e-01
# Epoch 205, Loss: 1.8747972249984741, Neurons: 32, Grad norm: 1.106e-01
# Epoch 205, Loss: 1.8747972249984741, Neurons: 32, Grad norm: 1.106e-01
# Epoch 206, Loss: 1.8738477230072021, Neurons: 32, Grad norm: 1.100e-01
# Epoch 206, Loss: 1.8738477230072021, Neurons: 32, Grad norm: 1.100e-01
# Epoch 207, Loss: 1.8729017972946167, Neurons: 32, Grad norm: 1.095e-01
# Epoch 207, Loss: 1.8729017972946167, Neurons: 32, Grad norm: 1.095e-01
# Epoch 208, Loss: 1.8719574213027954, Neurons: 32, Grad norm: 1.089e-01
# Epoch 208, Loss: 1.8719574213027954, Neurons: 32, Grad norm: 1.089e-01
# Epoch 209, Loss: 1.871015191078186, Neurons: 32, Grad norm: 1.084e-01
# Epoch 209, Loss: 1.871015191078186, Neurons: 32, Grad norm: 1.084e-01
# Epoch 210, Loss: 1.8700751066207886, Neurons: 32, Grad norm: 1.078e-01
# Epoch 210, Loss: 1.8700751066207886, Neurons: 32, Grad norm: 1.078e-01
# Epoch 211, Loss: 1.8691377639770508, Neurons: 32, Grad norm: 1.073e-01
# Epoch 211, Loss: 1.8691377639770508, Neurons: 32, Grad norm: 1.073e-01
# Epoch 212, Loss: 1.8682012557983398, Neurons: 32, Grad norm: 1.068e-01
# Epoch 212, Loss: 1.8682012557983398, Neurons: 32, Grad norm: 1.068e-01
# Epoch 213, Loss: 1.8672666549682617, Neurons: 32, Grad norm: 1.064e-01
# Epoch 213, Loss: 1.8672666549682617, Neurons: 32, Grad norm: 1.064e-01
# Epoch 214, Loss: 1.8663333654403687, Neurons: 32, Grad norm: 1.059e-01
# Epoch 214, Loss: 1.8663333654403687, Neurons: 32, Grad norm: 1.059e-01
# Epoch 215, Loss: 1.8654024600982666, Neurons: 32, Grad norm: 1.054e-01
# Epoch 215, Loss: 1.8654024600982666, Neurons: 32, Grad norm: 1.054e-01
# Epoch 216, Loss: 1.8644741773605347, Neurons: 32, Grad norm: 1.050e-01
# Epoch 216, Loss: 1.8644741773605347, Neurons: 32, Grad norm: 1.050e-01
# Epoch 2901, Loss: 1.2316079139709473, Neurons: 47, Grad norm: 2.643e+00
# Epoch 2902, Loss: 1.2175365686416626, Neurons: 47, Grad norm: 2.557e+00
# Epoch 2902, Loss: 1.2175365686416626, Neurons: 47, Grad norm: 2.557e+00
# Epoch 2903, Loss: 1.2033623456954956, Neurons: 47, Grad norm: 2.466e+00
# Epoch 2903, Loss: 1.2033623456954956, Neurons: 47, Grad norm: 2.466e+00
# Epoch 2904, Loss: 1.1891794204711914, Neurons: 47, Grad norm: 2.374e+00
# Epoch 2904, Loss: 1.1891794204711914, Neurons: 47, Grad norm: 2.374e+00
# Epoch 2905, Loss: 1.1750727891921997, Neurons: 47, Grad norm: 2.278e+00
# Epoch 2905, Loss: 1.1750727891921997, Neurons: 47, Grad norm: 2.278e+00
# Epoch 2906, Loss: 1.16111159324646, Neurons: 47, Grad norm: 2.178e+00
# Epoch 2906, Loss: 1.16111159324646, Neurons: 47, Grad norm: 2.178e+00
# Epoch 2907, Loss: 1.1473883390426636, Neurons: 47, Grad norm: 2.079e+00
# Epoch 2907, Loss: 1.1473883390426636, Neurons: 47, Grad norm: 2.079e+00
# Epoch 2908, Loss: 1.1339939832687378, Neurons: 47, Grad norm: 1.979e+00
# Epoch 2908, Loss: 1.1339939832687378, Neurons: 47, Grad norm: 1.979e+00
# Epoch 2909, Loss: 1.1209734678268433, Neurons: 47, Grad norm: 1.877e+00
# Epoch 2909, Loss: 1.1209734678268433, Neurons: 47, Grad norm: 1.877e+00
# Epoch 2910, Loss: 1.1083934307098389, Neurons: 47, Grad norm: 1.778e+00
# Epoch 2910, Loss: 1.1083934307098389, Neurons: 47, Grad norm: 1.778e+00
# Epoch 2911, Loss: 1.0962973833084106, Neurons: 47, Grad norm: 1.677e+00
# Epoch 2911, Loss: 1.0962973833084106, Neurons: 47, Grad norm: 1.677e+00
# Epoch 2912, Loss: 1.08473539352417, Neurons: 47, Grad norm: 1.578e+00
# Epoch 2912, Loss: 1.08473539352417, Neurons: 47, Grad norm: 1.578e+00
# Epoch 2913, Loss: 1.0737451314926147, Neurons: 47, Grad norm: 1.481e+00
# Epoch 2913, Loss: 1.0737451314926147, Neurons: 47, Grad norm: 1.481e+00
# Epoch 2914, Loss: 1.0633450746536255, Neurons: 47, Grad norm: 1.389e+00
# Epoch 2914, Loss: 1.0633450746536255, Neurons: 47, Grad norm: 1.389e+00
# Epoch 2915, Loss: 1.0535476207733154, Neurons: 47, Grad norm: 1.302e+00
# Epoch 2915, Loss: 1.0535476207733154, Neurons: 47, Grad norm: 1.302e+00
# Epoch 2916, Loss: 1.0443531274795532, Neurons: 47, Grad norm: 1.217e+00
# Epoch 2916, Loss: 1.0443531274795532, Neurons: 47, Grad norm: 1.217e+00
# Epoch 2917, Loss: 1.035751461982727, Neurons: 47, Grad norm: 1.138e+00
# Epoch 2917, Loss: 1.035751461982727, Neurons: 47, Grad norm: 1.138e+00
# Epoch 2918, Loss: 1.0277397632598877, Neurons: 47, Grad norm: 1.064e+00
# Epoch 2985, Loss: 0.9564208984375, Neurons: 46, Grad norm: 1.473e-01
# Epoch 2986, Loss: 0.955800473690033, Neurons: 46, Grad norm: 1.430e-01
# Epoch 2986, Loss: 0.955800473690033, Neurons: 46, Grad norm: 1.430e-01
# Epoch 2987, Loss: 0.9552079439163208, Neurons: 46, Grad norm: 1.382e-01
# Epoch 2987, Loss: 0.9552079439163208, Neurons: 46, Grad norm: 1.382e-01
# Epoch 2988, Loss: 0.9546402096748352, Neurons: 46, Grad norm: 1.339e-01
# Epoch 2988, Loss: 0.9546402096748352, Neurons: 46, Grad norm: 1.339e-01
# Epoch 2989, Loss: 0.9540959000587463, Neurons: 46, Grad norm: 1.307e-01
# Epoch 2989, Loss: 0.9540959000587463, Neurons: 46, Grad norm: 1.307e-01
# Epoch 2990, Loss: 0.9535714387893677, Neurons: 46, Grad norm: 1.272e-01
# Epoch 2990, Loss: 0.9535714387893677, Neurons: 46, Grad norm: 1.272e-01
# Epoch 2991, Loss: 0.9530655145645142, Neurons: 46, Grad norm: 1.239e-01
# Epoch 2991, Loss: 0.9530655145645142, Neurons: 46, Grad norm: 1.239e-01
# Epoch 2992, Loss: 0.9525771141052246, Neurons: 46, Grad norm: 1.209e-01
# Epoch 2992, Loss: 0.9525771141052246, Neurons: 46, Grad norm: 1.209e-01
# Epoch 2993, Loss: 0.9521050453186035, Neurons: 46, Grad norm: 1.179e-01
# Epoch 2993, Loss: 0.9521050453186035, Neurons: 46, Grad norm: 1.179e-01
# Epoch 2994, Loss: 0.9516493082046509, Neurons: 46, Grad norm: 1.150e-01
# Epoch 2994, Loss: 0.9516493082046509, Neurons: 46, Grad norm: 1.150e-01
# Epoch 2995, Loss: 0.9512101411819458, Neurons: 46, Grad norm: 1.126e-01
# Epoch 2995, Loss: 0.9512101411819458, Neurons: 46, Grad norm: 1.126e-01
# Epoch 2996, Loss: 0.9507856965065002, Neurons: 46, Grad norm: 1.098e-01
# Epoch 2996, Loss: 0.9507856965065002, Neurons: 46, Grad norm: 1.098e-01
# Epoch 2997, Loss: 0.9503754377365112, Neurons: 46, Grad norm: 1.074e-01
# Epoch 2997, Loss: 0.9503754377365112, Neurons: 46, Grad norm: 1.074e-01
# Epoch 2998, Loss: 0.949979305267334, Neurons: 46, Grad norm: 1.050e-01
# Epoch 2998, Loss: 0.949979305267334, Neurons: 46, Grad norm: 1.050e-01
# Epoch 2999, Loss: 0.9495965838432312, Neurons: 46, Grad norm: 1.027e-01
# Epoch 2999, Loss: 0.9495965838432312, Neurons: 46, Grad norm: 1.027e-01

# %%
np.savetxt(f"{out_folder}/neurons.txt", node_history)
np.savetxt(f"{out_folder}/train_loss.txt", train_loss_history)
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/test_accuracy.txt", accuracy_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)

# %% [markdown]
# ### evaluation

# %%
update_history
# Out:
# [(99,
#   30,
#   Array(1.963631, dtype=float32),
#   Array(1.9689689, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (149,
#   31,
#   Array(1.9154986, dtype=float32),
#   Array(1.9272658, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (249,
#   32,
#   Array(1.8332821, dtype=float32),
#   Array(1.8475194, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (549,
#   33,
#   Array(1.5335847, dtype=float32),
#   Array(1.558668, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (599,
#   34,
#   Array(1.4981599, dtype=float32),
#   Array(1.5274124, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (649,
#   35,
#   Array(1.4666294, dtype=float32),
#   Array(1.4989073, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (699,
#   36,
#   Array(1.4383123, dtype=float32),
#   Array(1.4731992, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (799,
#   37,
#   Array(1.3913918, dtype=float32),
#   Array(1.4278122, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (849,
#   38,
#   Array(1.3608563, dtype=float32),
#   Array(1.3966365, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (999,
#   39,
#   Array(1.2441727, dtype=float32),
#   Array(1.2870446, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1099,
#   40,
#   Array(1.1965772, dtype=float32),
#   Array(1.242565, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1249,
#   41,
#   Array(1.1355691, dtype=float32),
#   Array(1.1950254, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1399,
#   42,
#   Array(1.0940112, dtype=float32),
#   Array(1.1622925, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (1499,
#   43,
#   Array(1.0811266, dtype=float32),
#   Array(1.1525558, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1649,
#   44,
#   Array(1.035113, dtype=float32),
#   Array(1.125979, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1699,
#   45,
#   Array(1.0332559, dtype=float32),
#   Array(1.1276784, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (1849,
#   44,
#   Array(1.0157125, dtype=float32),
#   Array(1.1175698, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1899,
#   45,
#   Array(1.0212686, dtype=float32),
#   Array(1.1265111, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (1999,
#   44,
#   Array(1.0078785, dtype=float32),
#   Array(1.1120888, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (2199,
#   45,
#   Array(0.9708802, dtype=float32),
#   Array(1.0813936, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2249,
#   46,
#   Array(0.9876942, dtype=float32),
#   Array(1.1029402, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (2399,
#   45,
#   Array(0.96582735, dtype=float32),
#   Array(1.0789158, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (2699,
#   46,
#   Array(0.92103314, dtype=float32),
#   Array(1.0441556, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (2799,
#   47,
#   Array(0.9109821, dtype=float32),
#   Array(1.0339991, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (2899,
#   48,
#   Array(1.0437281, dtype=float32),
#   Array(1.1536334, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (2949,
#   47,
#   Array(0.9330176, dtype=float32),
#   Array(1.0582184, dtype=float32),
#   'removed',
#   Array(0, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)
accuracy_epochs, test_accuracy = zip(*accuracy_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")

# %%
plt.plot(accuracy_epochs, test_accuracy, "*")
plt.xlabel("Epochs")
plt.ylabel("Test Accuracy")
# Out:
# Text(0, 0.5, 'Test Accuracy')

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)
