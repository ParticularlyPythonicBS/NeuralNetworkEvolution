# %% [markdown]
# # Deterministic growth strategy for 1d mnist classification with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "32_hetero_1dmnist_bare_probabilistic_additive.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="32_hetero_1dmnist_bare_probabilistic_additive.ipynb"
# env: WANDB_SILENT=True

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

from mnist1d.data import make_dataset, get_dataset_args, get_templates

import os
import sys
import time
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
# mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %%
def plot_1dmnist(xs, t, labels=None, ratio=2.6, dark_mode=False, zoom=1):
    rows, cols = 1, 10
    fig = plt.figure(figsize=[cols*1.5,rows*1.5*ratio], dpi=60)
    for r in range(rows):
        for c in range(cols):
            ix = r*cols + c
            x, t = xs[ix], t
            ax = plt.subplot(rows,cols,ix+1)

            if dark_mode:
                plt.plot(x, t, 'wo', linewidth=6)
                ax.set_facecolor('k')
            else:
                plt.plot(x, t, 'k-', linewidth=2)
            if labels is not None:
                plt.title("label=" + str(labels[ix]), fontsize=22)

            plt.xlim(-zoom,zoom) ; plt.ylim(-zoom,zoom)
            plt.gca().invert_yaxis() ; plt.xticks([], []), plt.yticks([], [])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.tight_layout() ; plt.show()
    return fig

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 40
hidden_sizes = [5, 5] 
min_neurons = 10
output_size = 10
max_neurons = 64 + output_size
initial_activation_list = [jax.nn.relu, jax.nn.tanh, sin]
activation_list = [jax.nn.relu, jax.nn.tanh, sin]
optimizer = optax.adabelief
bias = False
num_epochs = 3000
intervene_every = 50
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"Hetero_{act_string}_1dmnist_deterministic_addition_{optimizer.__name__}_no_bias_min_{min_neurons}_max{max_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: Hetero_relu_tanh_sin_1dmnist_deterministic_addition_adabelief_no_bias_min_10_max74_5_5_3000_50_0.0001_0
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
data_config = get_dataset_args()

# %%
data_config.num_samples = n_samples
data_config.shuffle_seq = True

# %%
data = make_dataset(data_config)

# %%
x_train, y_train = data["x"], data["y"]
x_test, y_test = data["x_test"], data["y_test"]
template = data["t"]

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape, template.shape
# Out:
# ((16000, 40), (16000,), (4000, 40), (4000,), (40,))

# %%
plt.hist(y_train)
# Out:
# (array([1613., 1598., 1597., 1614., 1571., 1589., 1597., 1602., 1600.,
#         1619.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_1dmnist(x, t, labels=y, ratio=1.33, dark_mode=False)
plt.savefig(f"{fig_folder}/mnist1d_templates.pdf", bbox_inches='tight')
plt.savefig(f"{fig_folder}/mnist1d_templates.svg", bbox_inches='tight', format='svg')
# Out:
# Templates for the MNIST-1D dataset:

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@jax.jit
def cross_entropy(y, pred_y):
    # y are the true targets, and should be integers 0-9.
    # pred_y are the log-softmax'd predictions.
    pred_y = jnp.take_along_axis(pred_y, jnp.expand_dims(y, 1), axis=1)
    return -jnp.mean(pred_y)

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred_y = jax.nn.log_softmax(jax.vmap(mlp)(x))
    loss = cross_entropy(y, pred_y)
    return loss

# %%
@eqx.filter_jit()
def accuracy(mlp, x, y):
    logits = jax.vmap(mlp)(x)
    return jnp.mean(jnp.argmax(logits, axis=-1) == y)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0], accuracy(mlp, x, y)

# %%
@eqx.filter_jit()
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 20

# %%
# logits = jax.nn.log_softmax(jax.vmap(mlp)(x_train))
# logits.shape
# one_hot_labels = jax.nn.one_hot(y_train, 10)
# one_hot_labels.shape
# plt.plot(optax.softmax_cross_entropy(logits=logits, labels=one_hot_labels))

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
plt.savefig(f"{fig_folder}/initial_graph.pdf")
plt.savefig(f"{fig_folder}/initial_graph.svg", format='svg', bbox_inches='tight')
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.pdf")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
accuracy_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity
check_accuracy = 0 # initialize check accuracy to 0

# %%
# def p_continue(test_loss, n_neurons, min_neurons):
#     """
#     Unnormalized Probability of continuing with the current network
#     """
#     return 1 / (test_loss + 1)

def p_add(test_loss, n_neurons, min_neurons):
    """
    Unnormalized Probability of trying to add a neuron
    """
    # test_loss = test_loss/(test_loss + 1)
    return test_loss / (test_loss + n_neurons / min_neurons)

# def p_remove(test_loss, n_neurons, min_neurons):
#     """
#     Unnormalized Probability of trying to remove a neuron
#     """
#     return test_loss / (test_loss + min_neurons / n_neurons)

# def p_norm(test_loss, n_neurons, min_neurons):
#     """
#     Norm to get probability to 1
#     """
#     return p_continue(test_loss, n_neurons, min_neurons) + p_add(test_loss, n_neurons, min_neurons) + p_remove(test_loss, n_neurons, min_neurons)

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss, test_accuracy = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}, Test accuracy: {test_accuracy}")
        wandb.log({"test_loss": test_loss.item(), "test_accuracy": test_accuracy})
        test_loss_history.append((epoch,test_loss))
        accuracy_history.append((epoch, test_accuracy))


        # Neuron Addition criteria
        if n_neurons< max_neurons:

            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(act_key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0] # randomly select a layer to add neuron to
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            update_history.append((epoch, n_neurons, train_loss, test_loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 2.3025851249694824, Neurons: 20, Grad norm: 6.280e-02
# Epoch 001, Loss: 2.302487373352051, Neurons: 20, Grad norm: 6.367e-02
# Epoch 002, Loss: 2.302381992340088, Neurons: 20, Grad norm: 6.470e-02
# Epoch 003, Loss: 2.3022677898406982, Neurons: 20, Grad norm: 6.583e-02
# Epoch 004, Loss: 2.3021440505981445, Neurons: 20, Grad norm: 6.704e-02
# Epoch 005, Loss: 2.3020105361938477, Neurons: 20, Grad norm: 6.835e-02
# Epoch 006, Loss: 2.301866292953491, Neurons: 20, Grad norm: 6.975e-02
# Epoch 007, Loss: 2.3017101287841797, Neurons: 20, Grad norm: 7.124e-02
# Epoch 008, Loss: 2.301542043685913, Neurons: 20, Grad norm: 7.281e-02
# Epoch 009, Loss: 2.3013598918914795, Neurons: 20, Grad norm: 7.447e-02
# Epoch 010, Loss: 2.301163673400879, Neurons: 20, Grad norm: 7.623e-02
# Epoch 011, Loss: 2.300952196121216, Neurons: 20, Grad norm: 7.808e-02
# Epoch 012, Loss: 2.3007237911224365, Neurons: 20, Grad norm: 8.002e-02
# Epoch 013, Loss: 2.300477981567383, Neurons: 20, Grad norm: 8.205e-02
# Epoch 014, Loss: 2.300213098526001, Neurons: 20, Grad norm: 8.418e-02
# Epoch 015, Loss: 2.2999277114868164, Neurons: 20, Grad norm: 8.641e-02
# Epoch 016, Loss: 2.2996206283569336, Neurons: 20, Grad norm: 8.872e-02
# Epoch 017, Loss: 2.299290418624878, Neurons: 20, Grad norm: 9.113e-02
# Epoch 018, Loss: 2.2989354133605957, Neurons: 20, Grad norm: 9.363e-02
# Epoch 019, Loss: 2.2985544204711914, Neurons: 20, Grad norm: 9.622e-02
# Epoch 020, Loss: 2.298144578933716, Neurons: 20, Grad norm: 9.890e-02
# Epoch 021, Loss: 2.29770565032959, Neurons: 20, Grad norm: 1.017e-01
# Epoch 022, Loss: 2.2972350120544434, Neurons: 20, Grad norm: 1.045e-01
# Epoch 023, Loss: 2.2967305183410645, Neurons: 20, Grad norm: 1.075e-01
# Epoch 024, Loss: 2.2961912155151367, Neurons: 20, Grad norm: 1.105e-01
# Epoch 025, Loss: 2.29561448097229, Neurons: 20, Grad norm: 1.136e-01
# Epoch 026, Loss: 2.2949981689453125, Neurons: 20, Grad norm: 1.167e-01
# Epoch 027, Loss: 2.2943408489227295, Neurons: 20, Grad norm: 1.199e-01
# Epoch 028, Loss: 2.2936394214630127, Neurons: 20, Grad norm: 1.232e-01
# Epoch 029, Loss: 2.2928929328918457, Neurons: 20, Grad norm: 1.266e-01
# Epoch 030, Loss: 2.2920982837677, Neurons: 20, Grad norm: 1.300e-01
# Epoch 031, Loss: 2.2912535667419434, Neurons: 20, Grad norm: 1.335e-01
# Epoch 032, Loss: 2.2903571128845215, Neurons: 20, Grad norm: 1.370e-01
# Epoch 033, Loss: 2.2894062995910645, Neurons: 20, Grad norm: 1.405e-01
# Epoch 034, Loss: 2.2883992195129395, Neurons: 20, Grad norm: 1.441e-01
# Epoch 035, Loss: 2.2873339653015137, Neurons: 20, Grad norm: 1.477e-01
# Epoch 036, Loss: 2.2862086296081543, Neurons: 20, Grad norm: 1.513e-01
# Epoch 037, Loss: 2.2850210666656494, Neurons: 20, Grad norm: 1.549e-01
# Epoch 038, Loss: 2.283769369125366, Neurons: 20, Grad norm: 1.585e-01
# Epoch 039, Loss: 2.28245210647583, Neurons: 20, Grad norm: 1.622e-01
# Epoch 040, Loss: 2.281067132949829, Neurons: 20, Grad norm: 1.658e-01
# Epoch 041, Loss: 2.2796132564544678, Neurons: 20, Grad norm: 1.693e-01
# Epoch 042, Loss: 2.2780890464782715, Neurons: 20, Grad norm: 1.729e-01
# Epoch 043, Loss: 2.276493787765503, Neurons: 20, Grad norm: 1.764e-01
# Epoch 044, Loss: 2.27482533454895, Neurons: 20, Grad norm: 1.799e-01
# Epoch 045, Loss: 2.2730846405029297, Neurons: 20, Grad norm: 1.833e-01
# Epoch 046, Loss: 2.2712690830230713, Neurons: 20, Grad norm: 1.867e-01
# Epoch 047, Loss: 2.269378185272217, Neurons: 20, Grad norm: 1.900e-01
# Epoch 048, Loss: 2.267411708831787, Neurons: 20, Grad norm: 1.933e-01
# Epoch 049, Loss: 2.265369176864624, Neurons: 20, Grad norm: 1.965e-01
# Epoch 049, Test loss: 2.2636728286743164, Test accuracy: 0.17000000178813934
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[5, 6, 10]
# Epoch 050, Loss: 2.2632505893707275, Neurons: 21, Grad norm: 2.020e-01
# Epoch 051, Loss: 2.2627482414245605, Neurons: 21, Grad norm: 2.028e-01
# Epoch 052, Loss: 2.2622179985046387, Neurons: 21, Grad norm: 2.036e-01
# Epoch 053, Loss: 2.2616589069366455, Neurons: 21, Grad norm: 2.045e-01
# Epoch 054, Loss: 2.261070728302002, Neurons: 21, Grad norm: 2.053e-01
# Epoch 055, Loss: 2.2604525089263916, Neurons: 21, Grad norm: 2.062e-01
# Epoch 056, Loss: 2.2598037719726562, Neurons: 21, Grad norm: 2.072e-01
# Epoch 057, Loss: 2.259124517440796, Neurons: 21, Grad norm: 2.081e-01
# Epoch 058, Loss: 2.258413791656494, Neurons: 21, Grad norm: 2.091e-01
# Epoch 059, Loss: 2.2576711177825928, Neurons: 21, Grad norm: 2.101e-01
# Epoch 060, Loss: 2.2568957805633545, Neurons: 21, Grad norm: 2.112e-01
# Epoch 061, Loss: 2.2560875415802, Neurons: 21, Grad norm: 2.122e-01
# Epoch 062, Loss: 2.255246162414551, Neurons: 21, Grad norm: 2.133e-01
# Epoch 063, Loss: 2.254371404647827, Neurons: 21, Grad norm: 2.144e-01
# Epoch 064, Loss: 2.253462553024292, Neurons: 21, Grad norm: 2.155e-01
# Epoch 065, Loss: 2.2525196075439453, Neurons: 21, Grad norm: 2.166e-01
# Epoch 066, Loss: 2.2515413761138916, Neurons: 21, Grad norm: 2.178e-01
# Epoch 271, Loss: 2.0136353969573975, Neurons: 25, Grad norm: 3.837e-01
# Epoch 272, Loss: 2.0115108489990234, Neurons: 25, Grad norm: 3.740e-01
# Epoch 273, Loss: 2.0094094276428223, Neurons: 25, Grad norm: 3.648e-01
# Epoch 274, Loss: 2.0073320865631104, Neurons: 25, Grad norm: 3.558e-01
# Epoch 275, Loss: 2.0052804946899414, Neurons: 25, Grad norm: 3.476e-01
# Epoch 276, Loss: 2.0032548904418945, Neurons: 25, Grad norm: 3.387e-01
# Epoch 277, Loss: 2.0012590885162354, Neurons: 25, Grad norm: 3.305e-01
# Epoch 278, Loss: 1.9992952346801758, Neurons: 25, Grad norm: 3.224e-01
# Epoch 279, Loss: 1.9973644018173218, Neurons: 25, Grad norm: 3.149e-01
# Epoch 280, Loss: 1.9954675436019897, Neurons: 25, Grad norm: 3.077e-01
# Epoch 281, Loss: 1.993605375289917, Neurons: 25, Grad norm: 3.006e-01
# Epoch 282, Loss: 1.9917793273925781, Neurons: 25, Grad norm: 2.938e-01
# Epoch 283, Loss: 1.9899905920028687, Neurons: 25, Grad norm: 2.878e-01
# Epoch 284, Loss: 1.98823881149292, Neurons: 25, Grad norm: 2.818e-01
# Epoch 285, Loss: 1.9865227937698364, Neurons: 25, Grad norm: 2.765e-01
# Epoch 286, Loss: 1.9848424196243286, Neurons: 25, Grad norm: 2.715e-01
# Epoch 287, Loss: 1.9831944704055786, Neurons: 25, Grad norm: 2.666e-01
# Epoch 288, Loss: 1.9815787076950073, Neurons: 25, Grad norm: 2.622e-01
# Epoch 289, Loss: 1.9799933433532715, Neurons: 25, Grad norm: 2.581e-01
# Epoch 290, Loss: 1.9784362316131592, Neurons: 25, Grad norm: 2.542e-01
# Epoch 291, Loss: 1.9769043922424316, Neurons: 25, Grad norm: 2.501e-01
# Epoch 292, Loss: 1.9753968715667725, Neurons: 25, Grad norm: 2.464e-01
# Epoch 293, Loss: 1.9739115238189697, Neurons: 25, Grad norm: 2.427e-01
# Epoch 294, Loss: 1.972446084022522, Neurons: 25, Grad norm: 2.392e-01
# Epoch 295, Loss: 1.971000075340271, Neurons: 25, Grad norm: 2.354e-01
# Epoch 296, Loss: 1.9695723056793213, Neurons: 25, Grad norm: 2.321e-01
# Epoch 297, Loss: 1.968161940574646, Neurons: 25, Grad norm: 2.290e-01
# Epoch 298, Loss: 1.9667664766311646, Neurons: 25, Grad norm: 2.257e-01
# Epoch 299, Loss: 1.965384840965271, Neurons: 25, Grad norm: 2.226e-01
# Epoch 299, Test loss: 1.972145676612854, Test accuracy: 0.20400001108646393
# Added neuron to hidden layer 1 with activation tanh
# network shape updated to :[9, 7, 10]
# Epoch 300, Loss: 1.9705325365066528, Neurons: 26, Grad norm: 4.200e-01
# Epoch 301, Loss: 1.9691509008407593, Neurons: 26, Grad norm: 3.964e-01
# Epoch 302, Loss: 1.9677859544754028, Neurons: 26, Grad norm: 3.729e-01
# Epoch 303, Loss: 1.9664478302001953, Neurons: 26, Grad norm: 3.514e-01
# Epoch 339, Loss: 1.9297266006469727, Neurons: 26, Grad norm: 1.484e-01
# Epoch 340, Loss: 1.928805947303772, Neurons: 26, Grad norm: 1.470e-01
# Epoch 341, Loss: 1.9278898239135742, Neurons: 26, Grad norm: 1.458e-01
# Epoch 342, Loss: 1.9269777536392212, Neurons: 26, Grad norm: 1.445e-01
# Epoch 343, Loss: 1.9260694980621338, Neurons: 26, Grad norm: 1.433e-01
# Epoch 344, Loss: 1.9251656532287598, Neurons: 26, Grad norm: 1.421e-01
# Epoch 345, Loss: 1.924265742301941, Neurons: 26, Grad norm: 1.409e-01
# Epoch 346, Loss: 1.9233697652816772, Neurons: 26, Grad norm: 1.397e-01
# Epoch 347, Loss: 1.9224780797958374, Neurons: 26, Grad norm: 1.385e-01
# Epoch 348, Loss: 1.9215906858444214, Neurons: 26, Grad norm: 1.372e-01
# Epoch 349, Loss: 1.920707106590271, Neurons: 26, Grad norm: 1.362e-01
# Epoch 349, Test loss: 1.9304723739624023, Test accuracy: 0.2045000046491623
# Added neuron to hidden layer 1 with activation tanh
# network shape updated to :[10, 7, 10]
# Epoch 350, Loss: 2.159944534301758, Neurons: 27, Grad norm: 2.230e+00
# Epoch 351, Loss: 2.152946710586548, Neurons: 27, Grad norm: 2.190e+00
# Epoch 352, Loss: 2.1457600593566895, Neurons: 27, Grad norm: 2.147e+00
# Epoch 353, Loss: 2.1384072303771973, Neurons: 27, Grad norm: 2.101e+00
# Epoch 354, Loss: 2.130922794342041, Neurons: 27, Grad norm: 2.055e+00
# Epoch 355, Loss: 2.1233208179473877, Neurons: 27, Grad norm: 2.006e+00
# Epoch 356, Loss: 2.115633964538574, Neurons: 27, Grad norm: 1.951e+00
# Epoch 357, Loss: 2.1078999042510986, Neurons: 27, Grad norm: 1.895e+00
# Epoch 358, Loss: 2.100158452987671, Neurons: 27, Grad norm: 1.834e+00
# Epoch 359, Loss: 2.0924441814422607, Neurons: 27, Grad norm: 1.774e+00
# Epoch 360, Loss: 2.084794044494629, Neurons: 27, Grad norm: 1.712e+00
# Epoch 361, Loss: 2.077242851257324, Neurons: 27, Grad norm: 1.648e+00
# Epoch 362, Loss: 2.0698177814483643, Neurons: 27, Grad norm: 1.586e+00
# Epoch 363, Loss: 2.062551498413086, Neurons: 27, Grad norm: 1.524e+00
# Epoch 364, Loss: 2.0554614067077637, Neurons: 27, Grad norm: 1.464e+00
# Epoch 365, Loss: 2.048560619354248, Neurons: 27, Grad norm: 1.405e+00
# Epoch 366, Loss: 2.0418591499328613, Neurons: 27, Grad norm: 1.348e+00
# Epoch 367, Loss: 2.0353636741638184, Neurons: 27, Grad norm: 1.291e+00
# Epoch 368, Loss: 2.0290894508361816, Neurons: 27, Grad norm: 1.238e+00
# Epoch 369, Loss: 2.023036003112793, Neurons: 27, Grad norm: 1.185e+00
# Epoch 370, Loss: 2.0172054767608643, Neurons: 27, Grad norm: 1.135e+00
# Epoch 371, Loss: 2.011606216430664, Neurons: 27, Grad norm: 1.088e+00
# Epoch 405, Loss: 1.9303534030914307, Neurons: 28, Grad norm: 3.905e-01
# Epoch 406, Loss: 1.9286566972732544, Neurons: 28, Grad norm: 3.626e-01
# Epoch 407, Loss: 1.9270557165145874, Neurons: 28, Grad norm: 3.379e-01
# Epoch 408, Loss: 1.925540804862976, Neurons: 28, Grad norm: 3.175e-01
# Epoch 409, Loss: 1.924103856086731, Neurons: 28, Grad norm: 2.998e-01
# Epoch 410, Loss: 1.9227313995361328, Neurons: 28, Grad norm: 2.847e-01
# Epoch 411, Loss: 1.9214110374450684, Neurons: 28, Grad norm: 2.721e-01
# Epoch 412, Loss: 1.9201349020004272, Neurons: 28, Grad norm: 2.612e-01
# Epoch 413, Loss: 1.9188936948776245, Neurons: 28, Grad norm: 2.516e-01
# Epoch 414, Loss: 1.917682409286499, Neurons: 28, Grad norm: 2.430e-01
# Epoch 415, Loss: 1.9164950847625732, Neurons: 28, Grad norm: 2.351e-01
# Epoch 416, Loss: 1.9153308868408203, Neurons: 28, Grad norm: 2.278e-01
# Epoch 417, Loss: 1.914188265800476, Neurons: 28, Grad norm: 2.215e-01
# Epoch 418, Loss: 1.9130678176879883, Neurons: 28, Grad norm: 2.159e-01
# Epoch 419, Loss: 1.9119678735733032, Neurons: 28, Grad norm: 2.106e-01
# Epoch 420, Loss: 1.910887360572815, Neurons: 28, Grad norm: 2.058e-01
# Epoch 421, Loss: 1.9098255634307861, Neurons: 28, Grad norm: 2.015e-01
# Epoch 422, Loss: 1.9087796211242676, Neurons: 28, Grad norm: 1.975e-01
# Epoch 423, Loss: 1.907747745513916, Neurons: 28, Grad norm: 1.933e-01
# Epoch 424, Loss: 1.906730055809021, Neurons: 28, Grad norm: 1.899e-01
# Epoch 425, Loss: 1.9057241678237915, Neurons: 28, Grad norm: 1.863e-01
# Epoch 426, Loss: 1.904728651046753, Neurons: 28, Grad norm: 1.831e-01
# Epoch 427, Loss: 1.9037402868270874, Neurons: 28, Grad norm: 1.797e-01
# Epoch 428, Loss: 1.9027581214904785, Neurons: 28, Grad norm: 1.765e-01
# Epoch 429, Loss: 1.9017815589904785, Neurons: 28, Grad norm: 1.730e-01
# Epoch 430, Loss: 1.9008091688156128, Neurons: 28, Grad norm: 1.698e-01
# Epoch 431, Loss: 1.899841070175171, Neurons: 28, Grad norm: 1.667e-01
# Epoch 432, Loss: 1.898876428604126, Neurons: 28, Grad norm: 1.636e-01
# Epoch 433, Loss: 1.8979147672653198, Neurons: 28, Grad norm: 1.602e-01
# Epoch 434, Loss: 1.8969577550888062, Neurons: 28, Grad norm: 1.574e-01
# Epoch 435, Loss: 1.8960058689117432, Neurons: 28, Grad norm: 1.549e-01
# Epoch 436, Loss: 1.8950577974319458, Neurons: 28, Grad norm: 1.523e-01
# Epoch 437, Loss: 1.89411461353302, Neurons: 28, Grad norm: 1.502e-01
# Epoch 438, Loss: 1.8931758403778076, Neurons: 28, Grad norm: 1.483e-01
# Epoch 439, Loss: 1.8922407627105713, Neurons: 28, Grad norm: 1.466e-01
# Epoch 506, Loss: 1.8380438089370728, Neurons: 30, Grad norm: 1.108e-01
# Epoch 507, Loss: 1.8375601768493652, Neurons: 30, Grad norm: 1.108e-01
# Epoch 508, Loss: 1.8370589017868042, Neurons: 30, Grad norm: 1.108e-01
# Epoch 509, Loss: 1.836539626121521, Neurons: 30, Grad norm: 1.109e-01
# Epoch 510, Loss: 1.8360017538070679, Neurons: 30, Grad norm: 1.109e-01
# Epoch 511, Loss: 1.8354465961456299, Neurons: 30, Grad norm: 1.109e-01
# Epoch 512, Loss: 1.834874153137207, Neurons: 30, Grad norm: 1.109e-01
# Epoch 513, Loss: 1.8342832326889038, Neurons: 30, Grad norm: 1.108e-01
# Epoch 514, Loss: 1.8336753845214844, Neurons: 30, Grad norm: 1.109e-01
# Epoch 515, Loss: 1.8330501317977905, Neurons: 30, Grad norm: 1.109e-01
# Epoch 516, Loss: 1.8324071168899536, Neurons: 30, Grad norm: 1.109e-01
# Epoch 517, Loss: 1.8317468166351318, Neurons: 30, Grad norm: 1.110e-01
# Epoch 518, Loss: 1.8310701847076416, Neurons: 30, Grad norm: 1.110e-01
# Epoch 519, Loss: 1.830376386642456, Neurons: 30, Grad norm: 1.111e-01
# Epoch 520, Loss: 1.8296661376953125, Neurons: 30, Grad norm: 1.111e-01
# Epoch 521, Loss: 1.8289390802383423, Neurons: 30, Grad norm: 1.112e-01
# Epoch 522, Loss: 1.8281959295272827, Neurons: 30, Grad norm: 1.112e-01
# Epoch 523, Loss: 1.827436089515686, Neurons: 30, Grad norm: 1.113e-01
# Epoch 524, Loss: 1.8266606330871582, Neurons: 30, Grad norm: 1.112e-01
# Epoch 525, Loss: 1.8258694410324097, Neurons: 30, Grad norm: 1.112e-01
# Epoch 526, Loss: 1.82506263256073, Neurons: 30, Grad norm: 1.112e-01
# Epoch 527, Loss: 1.8242393732070923, Neurons: 30, Grad norm: 1.113e-01
# Epoch 528, Loss: 1.8233997821807861, Neurons: 30, Grad norm: 1.113e-01
# Epoch 529, Loss: 1.8225445747375488, Neurons: 30, Grad norm: 1.113e-01
# Epoch 530, Loss: 1.8216743469238281, Neurons: 30, Grad norm: 1.114e-01
# Epoch 531, Loss: 1.8207881450653076, Neurons: 30, Grad norm: 1.113e-01
# Epoch 532, Loss: 1.8198859691619873, Neurons: 30, Grad norm: 1.113e-01
# Epoch 533, Loss: 1.8189693689346313, Neurons: 30, Grad norm: 1.114e-01
# Epoch 534, Loss: 1.8180354833602905, Neurons: 30, Grad norm: 1.115e-01
# Epoch 535, Loss: 1.8170838356018066, Neurons: 30, Grad norm: 1.116e-01
# Epoch 536, Loss: 1.816115379333496, Neurons: 30, Grad norm: 1.116e-01
# Epoch 537, Loss: 1.8151284456253052, Neurons: 30, Grad norm: 1.117e-01
# Epoch 538, Loss: 1.8141242265701294, Neurons: 30, Grad norm: 1.118e-01
# Epoch 539, Loss: 1.8131030797958374, Neurons: 30, Grad norm: 1.118e-01
# Epoch 540, Loss: 1.8120650053024292, Neurons: 30, Grad norm: 1.118e-01
# Epoch 2974, Loss: 0.6874895095825195, Neurons: 74, Grad norm: 3.743e-02
# Epoch 2975, Loss: 0.6868227124214172, Neurons: 74, Grad norm: 3.801e-02
# Epoch 2976, Loss: 0.6861593127250671, Neurons: 74, Grad norm: 3.686e-02
# Epoch 2977, Loss: 0.6854986548423767, Neurons: 74, Grad norm: 3.648e-02
# Epoch 2978, Loss: 0.6848419308662415, Neurons: 74, Grad norm: 3.583e-02
# Epoch 2979, Loss: 0.6841875314712524, Neurons: 74, Grad norm: 3.647e-02
# Epoch 2980, Loss: 0.6835350394248962, Neurons: 74, Grad norm: 3.683e-02
# Epoch 2981, Loss: 0.6828835010528564, Neurons: 74, Grad norm: 3.682e-02
# Epoch 2982, Loss: 0.6822322607040405, Neurons: 74, Grad norm: 3.612e-02
# Epoch 2983, Loss: 0.6815829277038574, Neurons: 74, Grad norm: 3.951e-02
# Epoch 2984, Loss: 0.6809345483779907, Neurons: 74, Grad norm: 3.810e-02
# Epoch 2985, Loss: 0.6802884340286255, Neurons: 74, Grad norm: 3.667e-02
# Epoch 2986, Loss: 0.6796444654464722, Neurons: 74, Grad norm: 3.595e-02
# Epoch 2987, Loss: 0.6790025234222412, Neurons: 74, Grad norm: 3.756e-02
# Epoch 2988, Loss: 0.6783642768859863, Neurons: 74, Grad norm: 3.710e-02
# Epoch 2989, Loss: 0.6777263879776001, Neurons: 74, Grad norm: 3.600e-02
# Epoch 2990, Loss: 0.6770898103713989, Neurons: 74, Grad norm: 3.655e-02
# Epoch 2991, Loss: 0.6764519214630127, Neurons: 74, Grad norm: 3.625e-02
# Epoch 2992, Loss: 0.6758151650428772, Neurons: 74, Grad norm: 3.643e-02
# Epoch 2993, Loss: 0.6751812100410461, Neurons: 74, Grad norm: 3.659e-02
# Epoch 2994, Loss: 0.6745479106903076, Neurons: 74, Grad norm: 3.658e-02
# Epoch 2995, Loss: 0.6739165186882019, Neurons: 74, Grad norm: 3.566e-02
# Epoch 2996, Loss: 0.6732879877090454, Neurons: 74, Grad norm: 3.782e-02
# Epoch 2997, Loss: 0.672661542892456, Neurons: 74, Grad norm: 3.632e-02
# Epoch 2998, Loss: 0.6720384955406189, Neurons: 74, Grad norm: 3.613e-02
# Epoch 2999, Loss: 0.671417772769928, Neurons: 74, Grad norm: 3.548e-02

# %%
np.savetxt(f"{out_folder}/neurons.txt", node_history)
np.savetxt(f"{out_folder}/train_loss.txt", train_loss_history)
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/test_accuracy.txt", accuracy_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)

# %%
# save the update history
with open(f"{out_folder}/update_history.txt", "w") as f:
    for item in update_history:
        f.write(f"{item}\n")

# %% [markdown]
# ### evaluation

# %%
y_pred = jax.nn.softmax(jax.vmap(mlp)(x_test))
y_pred = np.argmax(y_pred, axis=-1)

confusion_matrix = np.zeros((10,10))
for true, pred in zip(y_test, y_pred):
    confusion_matrix[true, pred] += 1

np.savetxt(f"{out_folder}/confusion_matrix.txt", confusion_matrix)
fig, ax = plt.subplots(figsize=[10,10])
cax = ax.matshow(confusion_matrix, cmap='gray')
fig.colorbar(cax, label="Number of predictions")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion matrix")
plt.savefig(f"{fig_folder}/confusion_matrix.png")
plt.savefig(f"{fig_folder}/confusion_matrix.pdf")
plt.savefig(f"{fig_folder}/confusion_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"confusion matrix": wandb.Image(plt, caption="confusion matrix")})

# %%
update_history
# Out:
# [(49,
#   20,
#   Array(2.2653692, dtype=float32),
#   Array(2.2636728, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (99,
#   21,
#   Array(2.1967576, dtype=float32),
#   Array(2.1954365, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (149,
#   22,
#   Array(2.1121726, dtype=float32),
#   Array(2.112353, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (199,
#   23,
#   Array(2.044226, dtype=float32),
#   Array(2.0470169, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (249,
#   24,
#   Array(1.9864401, dtype=float32),
#   Array(1.9918399, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (299,
#   25,
#   Array(1.9653848, dtype=float32),
#   Array(1.9721457, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (349,
#   26,
#   Array(1.9207071, dtype=float32),
#   Array(1.9304724, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (399,
#   27,
#   Array(1.9290076, dtype=float32),
#   Array(1.9378287, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (449,
#   28,
#   Array(1.88302, dtype=float32),
#   Array(1.8956536, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (499,
#   29,
#   Array(1.8417022, dtype=float32),
#   Array(1.8531241, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (549,
#   30,
#   Array(1.8019503, dtype=float32),
#   Array(1.8121351, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (599,
#   31,
#   Array(1.7629193, dtype=float32),
#   Array(1.7725899, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (649,
#   32,
#   Array(1.7248789, dtype=float32),
#   Array(1.7359078, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (699,
#   33,
#   Array(1.6880653, dtype=float32),
#   Array(1.699913, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (749,
#   34,
#   Array(1.6673576, dtype=float32),
#   Array(1.6792611, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (799,
#   35,
#   Array(1.6345549, dtype=float32),
#   Array(1.6472815, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (849,
#   36,
#   Array(1.6084483, dtype=float32),
#   Array(1.6231236, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (899,
#   37,
#   Array(1.5845405, dtype=float32),
#   Array(1.6017919, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (949,
#   38,
#   Array(1.5610561, dtype=float32),
#   Array(1.5816315, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (999,
#   39,
#   Array(1.5432315, dtype=float32),
#   Array(1.5664066, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1049,
#   40,
#   Array(1.5169302, dtype=float32),
#   Array(1.545519, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1099,
#   41,
#   Array(1.4928715, dtype=float32),
#   Array(1.5269374, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1149,
#   42,
#   Array(1.469379, dtype=float32),
#   Array(1.5074404, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1199,
#   43,
#   Array(1.4460346, dtype=float32),
#   Array(1.4866717, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1249,
#   44,
#   Array(1.4206165, dtype=float32),
#   Array(1.4638275, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1299,
#   45,
#   Array(1.3944881, dtype=float32),
#   Array(1.4419669, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1349,
#   46,
#   Array(1.3671157, dtype=float32),
#   Array(1.4191053, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1399,
#   47,
#   Array(1.3506477, dtype=float32),
#   Array(1.4066086, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (1449,
#   48,
#   Array(1.3327081, dtype=float32),
#   Array(1.3894771, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (1499,
#   49,
#   Array(1.3184146, dtype=float32),
#   Array(1.377093, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1549,
#   50,
#   Array(1.287261, dtype=float32),
#   Array(1.3494004, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1599,
#   51,
#   Array(1.2581054, dtype=float32),
#   Array(1.3242985, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1649,
#   52,
#   Array(1.2278925, dtype=float32),
#   Array(1.2967603, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (1699,
#   53,
#   Array(1.2161555, dtype=float32),
#   Array(1.2872398, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (1749,
#   54,
#   Array(1.1937855, dtype=float32),
#   Array(1.2660874, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1799,
#   55,
#   Array(1.1648995, dtype=float32),
#   Array(1.2409099, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1849,
#   56,
#   Array(1.1405852, dtype=float32),
#   Array(1.2178199, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (1899,
#   57,
#   Array(1.1382874, dtype=float32),
#   Array(1.2192503, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1949,
#   58,
#   Array(1.1093888, dtype=float32),
#   Array(1.1914132, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1999,
#   59,
#   Array(1.0878931, dtype=float32),
#   Array(1.1733704, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (2049,
#   60,
#   Array(1.0674541, dtype=float32),
#   Array(1.1560818, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2099,
#   61,
#   Array(1.0480884, dtype=float32),
#   Array(1.1409682, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2149,
#   62,
#   Array(1.0372033, dtype=float32),
#   Array(1.1326871, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (2199,
#   63,
#   Array(1.0182804, dtype=float32),
#   Array(1.1168516, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2249,
#   64,
#   Array(1.0334486, dtype=float32),
#   Array(1.1310527, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (2299,
#   65,
#   Array(1.000444, dtype=float32),
#   Array(1.1010429, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2349,
#   66,
#   Array(0.98048073, dtype=float32),
#   Array(1.083299, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2399,
#   67,
#   Array(1.0135199, dtype=float32),
#   Array(1.1201847, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2449,
#   68,
#   Array(0.97011465, dtype=float32),
#   Array(1.0765668, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2499,
#   69,
#   Array(0.94958234, dtype=float32),
#   Array(1.0588413, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2549,
#   70,
#   Array(1.1106565, dtype=float32),
#   Array(1.210971, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2599,
#   71,
#   Array(0.9769114, dtype=float32),
#   Array(1.0763688, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2649,
#   72,
#   Array(0.9338781, dtype=float32),
#   Array(1.0400203, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2699,
#   73,
#   Array(0.9086286, dtype=float32),
#   Array(1.0215585, dtype=float32),
#   'relu',
#   Array(1, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.pdf")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum([mlp.input_size] + mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')


plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.savefig(f"{fig_folder}/final_weight_distribution.pdf")
plt.savefig(f"{fig_folder}/final_weight_distribution.png")
plt.savefig(f"{fig_folder}/final_weight_distribution.svg", format='svg', bbox_inches='tight')
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)
accuracy_epochs, test_accuracy = zip(*accuracy_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
plt.savefig(f"{fig_folder}/loss_curve.pdf")
plt.savefig(f"{fig_folder}/loss_curve.svg", format='svg', bbox_inches='tight')
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")
plt.savefig(f"{fig_folder}/loss_curve_loglog.pdf")
plt.savefig(f"{fig_folder}/loss_curve_loglog.svg", format='svg', bbox_inches='tight')

# %%
plt.plot(accuracy_epochs, test_accuracy, "*")
plt.xlabel("Epochs")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy")
plt.savefig(f"{fig_folder}/test_accuracy.png")
plt.savefig(f"{fig_folder}/test_accuracy.pdf")
plt.savefig(f"{fig_folder}/test_accuracy.svg", format='svg', bbox_inches='tight')

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
plt.savefig(f"{fig_folder}/final_graph.pdf")
plt.savefig(f"{fig_folder}/final_graph.svg", format='svg', bbox_inches='tight')
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/time_curve.png")
plt.savefig(f"{fig_folder}/time_curve.pdf")
plt.savefig(f"{fig_folder}/time_curve.svg", format='svg', bbox_inches='tight')
