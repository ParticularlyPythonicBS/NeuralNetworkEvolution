# %% [markdown]
# # No strategy for Polynomial prediction with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "hetero_poly_no_strat.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="hetero_poly_no_strat.ipynb"
# env: WANDB_SILENT=True

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

import os
import sys
import time
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 1
hidden_sizes = [32, 32] 
min_neurons = 64
output_size = 1
initial_activation_list = [sin, jax.nn.relu, jax.nn.tanh]
activation_list = [sin, jax.nn.relu, jax.nn.tanh]
optimizer = optax.adabelief
bias = False
num_epochs = 25000
intervene_every = 100
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"Hetero_{act_string}_poly_no_strat_{optimizer.__name__}_no_bias_min_{min_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: Hetero_sin_relu_tanh_poly_no_strat_adabelief_no_bias_min_64_32_32_25000_100_0.0001_0
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
def poly(x):
    """
    7th degree polynomial to predict
    """
    return (x - 3)*(x - 2)*(x - 1)*x*(x + 1)*(x + 2)*(x + 3)

# %%
x = jnp.linspace(-3, 3, n_samples).reshape(-1, 1)
y = poly(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.2, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha = 0.2, label=f"test:{len(x_test)}")
plt.legend()
plt.suptitle("Data")
plt.savefig(f"{fig_folder}/data.png")
plt.savefig(f"{fig_folder}/data.pdf", bbox_inches='tight')
plt.savefig(f"{fig_folder}/data.svg", bbox_inches='tight', format='svg')

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0]

# %%
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 65

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
plt.savefig(f"{fig_folder}/initial_graph.pdf")
plt.savefig(f"{fig_folder}/initial_graph.svg", format='svg', bbox_inches='tight')
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.pdf")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity
L_0 = 1 # loss normalization for probabilistic strat

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}")
        wandb.log({"test_loss": test_loss.item()})
        test_loss_history.append((epoch,test_loss))
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 1516.2186279296875, Neurons: 65, Grad norm: 8.026e+01
# Epoch 001, Loss: 1515.727783203125, Neurons: 65, Grad norm: 8.012e+01
# Epoch 002, Loss: 1515.21337890625, Neurons: 65, Grad norm: 7.999e+01
# Epoch 003, Loss: 1514.67529296875, Neurons: 65, Grad norm: 7.986e+01
# Epoch 004, Loss: 1514.1138916015625, Neurons: 65, Grad norm: 7.974e+01
# Epoch 005, Loss: 1513.5291748046875, Neurons: 65, Grad norm: 7.965e+01
# Epoch 006, Loss: 1512.9212646484375, Neurons: 65, Grad norm: 7.957e+01
# Epoch 007, Loss: 1512.2901611328125, Neurons: 65, Grad norm: 7.952e+01
# Epoch 008, Loss: 1511.6363525390625, Neurons: 65, Grad norm: 7.949e+01
# Epoch 009, Loss: 1510.9595947265625, Neurons: 65, Grad norm: 7.949e+01
# Epoch 010, Loss: 1510.2601318359375, Neurons: 65, Grad norm: 7.950e+01
# Epoch 011, Loss: 1509.537841796875, Neurons: 65, Grad norm: 7.954e+01
# Epoch 012, Loss: 1508.7928466796875, Neurons: 65, Grad norm: 7.961e+01
# Epoch 013, Loss: 1508.0252685546875, Neurons: 65, Grad norm: 7.970e+01
# Epoch 014, Loss: 1507.235107421875, Neurons: 65, Grad norm: 7.982e+01
# Epoch 015, Loss: 1506.42236328125, Neurons: 65, Grad norm: 7.997e+01
# Epoch 016, Loss: 1505.5865478515625, Neurons: 65, Grad norm: 8.038e+01
# Epoch 017, Loss: 1504.7264404296875, Neurons: 65, Grad norm: 8.110e+01
# Epoch 018, Loss: 1503.8343505859375, Neurons: 65, Grad norm: 8.130e+01
# Epoch 019, Loss: 1502.9166259765625, Neurons: 65, Grad norm: 8.154e+01
# Epoch 020, Loss: 1501.9755859375, Neurons: 65, Grad norm: 8.181e+01
# Epoch 021, Loss: 1501.011474609375, Neurons: 65, Grad norm: 8.212e+01
# Epoch 022, Loss: 1500.024169921875, Neurons: 65, Grad norm: 8.245e+01
# Epoch 023, Loss: 1499.013427734375, Neurons: 65, Grad norm: 8.282e+01
# Epoch 024, Loss: 1497.9796142578125, Neurons: 65, Grad norm: 8.323e+01
# Epoch 025, Loss: 1496.9222412109375, Neurons: 65, Grad norm: 8.367e+01
# Epoch 026, Loss: 1495.84130859375, Neurons: 65, Grad norm: 8.412e+01
# Epoch 027, Loss: 1494.73681640625, Neurons: 65, Grad norm: 8.460e+01
# Epoch 028, Loss: 1493.609375, Neurons: 65, Grad norm: 8.522e+01
# Epoch 029, Loss: 1492.457275390625, Neurons: 65, Grad norm: 8.595e+01
# Epoch 030, Loss: 1491.27783203125, Neurons: 65, Grad norm: 8.649e+01
# Epoch 031, Loss: 1490.0714111328125, Neurons: 65, Grad norm: 8.639e+01
# Epoch 032, Loss: 1488.85400390625, Neurons: 65, Grad norm: 8.704e+01
# Epoch 033, Loss: 1487.6312255859375, Neurons: 65, Grad norm: 8.776e+01
# Epoch 034, Loss: 1486.3848876953125, Neurons: 65, Grad norm: 8.850e+01
# Epoch 035, Loss: 1485.1146240234375, Neurons: 65, Grad norm: 8.928e+01
# Epoch 036, Loss: 1483.8197021484375, Neurons: 65, Grad norm: 9.008e+01
# Epoch 037, Loss: 1482.4998779296875, Neurons: 65, Grad norm: 9.091e+01
# Epoch 038, Loss: 1481.1546630859375, Neurons: 65, Grad norm: 9.177e+01
# Epoch 039, Loss: 1479.7838134765625, Neurons: 65, Grad norm: 9.265e+01
# Epoch 040, Loss: 1478.3870849609375, Neurons: 65, Grad norm: 9.351e+01
# Epoch 041, Loss: 1476.9644775390625, Neurons: 65, Grad norm: 9.430e+01
# Epoch 042, Loss: 1475.519287109375, Neurons: 65, Grad norm: 9.511e+01
# Epoch 043, Loss: 1474.0546875, Neurons: 65, Grad norm: 9.600e+01
# Epoch 044, Loss: 1472.5712890625, Neurons: 65, Grad norm: 9.696e+01
# Epoch 045, Loss: 1471.0677490234375, Neurons: 65, Grad norm: 9.796e+01
# Epoch 046, Loss: 1469.5416259765625, Neurons: 65, Grad norm: 9.899e+01
# Epoch 047, Loss: 1467.9910888671875, Neurons: 65, Grad norm: 1.000e+02
# Epoch 048, Loss: 1466.4146728515625, Neurons: 65, Grad norm: 1.011e+02
# Epoch 049, Loss: 1464.811279296875, Neurons: 65, Grad norm: 1.021e+02
# Epoch 050, Loss: 1463.18115234375, Neurons: 65, Grad norm: 1.032e+02
# Epoch 051, Loss: 1461.5238037109375, Neurons: 65, Grad norm: 1.042e+02
# Epoch 052, Loss: 1459.8394775390625, Neurons: 65, Grad norm: 1.053e+02
# Epoch 053, Loss: 1458.1285400390625, Neurons: 65, Grad norm: 1.064e+02
# Epoch 054, Loss: 1456.3914794921875, Neurons: 65, Grad norm: 1.074e+02
# Epoch 055, Loss: 1454.6282958984375, Neurons: 65, Grad norm: 1.085e+02
# Epoch 056, Loss: 1452.83935546875, Neurons: 65, Grad norm: 1.095e+02
# Epoch 057, Loss: 1451.0260009765625, Neurons: 65, Grad norm: 1.106e+02
# Epoch 058, Loss: 1449.1898193359375, Neurons: 65, Grad norm: 1.116e+02
# Epoch 059, Loss: 1447.33251953125, Neurons: 65, Grad norm: 1.126e+02
# Epoch 060, Loss: 1445.4542236328125, Neurons: 65, Grad norm: 1.136e+02
# Epoch 061, Loss: 1443.5546875, Neurons: 65, Grad norm: 1.145e+02
# Epoch 062, Loss: 1441.634521484375, Neurons: 65, Grad norm: 1.155e+02
# Epoch 063, Loss: 1439.69482421875, Neurons: 65, Grad norm: 1.164e+02
# Epoch 064, Loss: 1437.73583984375, Neurons: 65, Grad norm: 1.174e+02
# Epoch 065, Loss: 1435.7587890625, Neurons: 65, Grad norm: 1.183e+02
# Epoch 066, Loss: 1433.7640380859375, Neurons: 65, Grad norm: 1.192e+02
# Epoch 067, Loss: 1431.7525634765625, Neurons: 65, Grad norm: 1.200e+02
# Epoch 068, Loss: 1429.725341796875, Neurons: 65, Grad norm: 1.209e+02
# Epoch 069, Loss: 1427.6826171875, Neurons: 65, Grad norm: 1.217e+02
# Epoch 070, Loss: 1425.625244140625, Neurons: 65, Grad norm: 1.225e+02
# Epoch 071, Loss: 1423.5535888671875, Neurons: 65, Grad norm: 1.233e+02
# Epoch 072, Loss: 1421.4683837890625, Neurons: 65, Grad norm: 1.240e+02
# Epoch 073, Loss: 1419.3701171875, Neurons: 65, Grad norm: 1.248e+02
# Epoch 074, Loss: 1417.259033203125, Neurons: 65, Grad norm: 1.255e+02
# Epoch 075, Loss: 1415.1353759765625, Neurons: 65, Grad norm: 1.262e+02
# Epoch 076, Loss: 1412.999267578125, Neurons: 65, Grad norm: 1.269e+02
# Epoch 077, Loss: 1410.85107421875, Neurons: 65, Grad norm: 1.276e+02
# Epoch 078, Loss: 1408.6905517578125, Neurons: 65, Grad norm: 1.283e+02
# Epoch 079, Loss: 1406.51806640625, Neurons: 65, Grad norm: 1.289e+02
# Epoch 080, Loss: 1404.3328857421875, Neurons: 65, Grad norm: 1.296e+02
# Epoch 081, Loss: 1402.1353759765625, Neurons: 65, Grad norm: 1.302e+02
# Epoch 082, Loss: 1399.925048828125, Neurons: 65, Grad norm: 1.309e+02
# Epoch 083, Loss: 1397.7015380859375, Neurons: 65, Grad norm: 1.315e+02
# Epoch 084, Loss: 1395.4647216796875, Neurons: 65, Grad norm: 1.321e+02
# Epoch 085, Loss: 1393.2139892578125, Neurons: 65, Grad norm: 1.327e+02
# Epoch 086, Loss: 1390.948974609375, Neurons: 65, Grad norm: 1.333e+02
# Epoch 087, Loss: 1388.6693115234375, Neurons: 65, Grad norm: 1.339e+02
# Epoch 088, Loss: 1386.3741455078125, Neurons: 65, Grad norm: 1.344e+02
# Epoch 089, Loss: 1384.063232421875, Neurons: 65, Grad norm: 1.350e+02
# Epoch 090, Loss: 1381.735595703125, Neurons: 65, Grad norm: 1.356e+02
# Epoch 091, Loss: 1379.390869140625, Neurons: 65, Grad norm: 1.362e+02
# Epoch 092, Loss: 1377.02783203125, Neurons: 65, Grad norm: 1.367e+02
# Epoch 093, Loss: 1374.6461181640625, Neurons: 65, Grad norm: 1.373e+02
# Epoch 094, Loss: 1372.2445068359375, Neurons: 65, Grad norm: 1.379e+02
# Epoch 095, Loss: 1369.8228759765625, Neurons: 65, Grad norm: 1.385e+02
# Epoch 096, Loss: 1367.3795166015625, Neurons: 65, Grad norm: 1.390e+02
# Epoch 097, Loss: 1364.914306640625, Neurons: 65, Grad norm: 1.396e+02
# Epoch 098, Loss: 1362.42626953125, Neurons: 65, Grad norm: 1.402e+02
# Epoch 099, Loss: 1359.91455078125, Neurons: 65, Grad norm: 1.408e+02
# Epoch 099, Test loss: 1384.6123046875
# Epoch 100, Loss: 1357.378662109375, Neurons: 65, Grad norm: 1.414e+02
# Epoch 101, Loss: 1354.818115234375, Neurons: 65, Grad norm: 1.420e+02
# Epoch 102, Loss: 1352.23193359375, Neurons: 65, Grad norm: 1.426e+02
# Epoch 103, Loss: 1349.6201171875, Neurons: 65, Grad norm: 1.432e+02
# Epoch 104, Loss: 1346.9818115234375, Neurons: 65, Grad norm: 1.438e+02
# Epoch 105, Loss: 1344.3170166015625, Neurons: 65, Grad norm: 1.444e+02
# Epoch 106, Loss: 1341.625244140625, Neurons: 65, Grad norm: 1.450e+02
# Epoch 107, Loss: 1338.906005859375, Neurons: 65, Grad norm: 1.456e+02
# Epoch 108, Loss: 1336.1593017578125, Neurons: 65, Grad norm: 1.462e+02
# Epoch 109, Loss: 1333.384033203125, Neurons: 65, Grad norm: 1.468e+02
# Epoch 110, Loss: 1330.580322265625, Neurons: 65, Grad norm: 1.475e+02
# Epoch 111, Loss: 1327.747314453125, Neurons: 65, Grad norm: 1.481e+02
# Epoch 112, Loss: 1324.8848876953125, Neurons: 65, Grad norm: 1.487e+02
# Epoch 113, Loss: 1321.992431640625, Neurons: 65, Grad norm: 1.494e+02
# Epoch 114, Loss: 1319.0697021484375, Neurons: 65, Grad norm: 1.500e+02
# Epoch 115, Loss: 1316.1165771484375, Neurons: 65, Grad norm: 1.506e+02
# Epoch 116, Loss: 1313.1326904296875, Neurons: 65, Grad norm: 1.513e+02
# Epoch 117, Loss: 1310.1181640625, Neurons: 65, Grad norm: 1.519e+02
# Epoch 118, Loss: 1307.07275390625, Neurons: 65, Grad norm: 1.525e+02
# Epoch 119, Loss: 1303.996826171875, Neurons: 65, Grad norm: 1.532e+02
# Epoch 120, Loss: 1300.8897705078125, Neurons: 65, Grad norm: 1.538e+02
# Epoch 121, Loss: 1297.7518310546875, Neurons: 65, Grad norm: 1.545e+02
# Epoch 122, Loss: 1294.582763671875, Neurons: 65, Grad norm: 1.551e+02
# Epoch 123, Loss: 1291.3829345703125, Neurons: 65, Grad norm: 1.557e+02
# Epoch 124, Loss: 1288.15185546875, Neurons: 65, Grad norm: 1.564e+02
# Epoch 125, Loss: 1284.8895263671875, Neurons: 65, Grad norm: 1.570e+02
# Epoch 126, Loss: 1281.595947265625, Neurons: 65, Grad norm: 1.576e+02
# Epoch 127, Loss: 1278.2711181640625, Neurons: 65, Grad norm: 1.582e+02
# Epoch 128, Loss: 1274.9150390625, Neurons: 65, Grad norm: 1.588e+02
# Epoch 129, Loss: 1271.527587890625, Neurons: 65, Grad norm: 1.594e+02
# Epoch 130, Loss: 1268.1092529296875, Neurons: 65, Grad norm: 1.600e+02
# Epoch 131, Loss: 1264.6597900390625, Neurons: 65, Grad norm: 1.606e+02
# Epoch 132, Loss: 1261.1796875, Neurons: 65, Grad norm: 1.612e+02
# Epoch 133, Loss: 1257.6688232421875, Neurons: 65, Grad norm: 1.617e+02
# Epoch 134, Loss: 1254.1278076171875, Neurons: 65, Grad norm: 1.622e+02
# Epoch 135, Loss: 1250.556640625, Neurons: 65, Grad norm: 1.627e+02
# Epoch 136, Loss: 1246.955810546875, Neurons: 65, Grad norm: 1.632e+02
# Epoch 137, Loss: 1243.3258056640625, Neurons: 65, Grad norm: 1.637e+02
# Epoch 138, Loss: 1239.666748046875, Neurons: 65, Grad norm: 1.641e+02
# Epoch 139, Loss: 1235.979248046875, Neurons: 65, Grad norm: 1.646e+02
# Epoch 140, Loss: 1232.2637939453125, Neurons: 65, Grad norm: 1.650e+02
# Epoch 141, Loss: 1228.5211181640625, Neurons: 65, Grad norm: 1.653e+02
# Epoch 142, Loss: 1224.7515869140625, Neurons: 65, Grad norm: 1.657e+02
# Epoch 143, Loss: 1220.955810546875, Neurons: 65, Grad norm: 1.660e+02
# Epoch 144, Loss: 1217.135009765625, Neurons: 65, Grad norm: 1.662e+02
# Epoch 145, Loss: 1213.289794921875, Neurons: 65, Grad norm: 1.665e+02
# Epoch 146, Loss: 1209.4210205078125, Neurons: 65, Grad norm: 1.667e+02
# Epoch 147, Loss: 1205.530029296875, Neurons: 65, Grad norm: 1.668e+02
# Epoch 148, Loss: 1201.6175537109375, Neurons: 65, Grad norm: 1.669e+02
# Epoch 149, Loss: 1197.68505859375, Neurons: 65, Grad norm: 1.670e+02
# Epoch 150, Loss: 1193.7337646484375, Neurons: 65, Grad norm: 1.670e+02
# Epoch 151, Loss: 1189.7650146484375, Neurons: 65, Grad norm: 1.670e+02
# Epoch 152, Loss: 1185.7802734375, Neurons: 65, Grad norm: 1.669e+02
# Epoch 153, Loss: 1181.781005859375, Neurons: 65, Grad norm: 1.668e+02
# Epoch 154, Loss: 1177.769287109375, Neurons: 65, Grad norm: 1.666e+02
# Epoch 155, Loss: 1173.7464599609375, Neurons: 65, Grad norm: 1.663e+02
# Epoch 156, Loss: 1169.714599609375, Neurons: 65, Grad norm: 1.660e+02
# Epoch 157, Loss: 1165.67578125, Neurons: 65, Grad norm: 1.656e+02
# Epoch 158, Loss: 1161.63232421875, Neurons: 65, Grad norm: 1.652e+02
# Epoch 159, Loss: 1157.5860595703125, Neurons: 65, Grad norm: 1.647e+02
# Epoch 160, Loss: 1153.539794921875, Neurons: 65, Grad norm: 1.642e+02
# Epoch 161, Loss: 1149.49560546875, Neurons: 65, Grad norm: 1.635e+02
# Epoch 162, Loss: 1145.4564208984375, Neurons: 65, Grad norm: 1.629e+02
# Epoch 163, Loss: 1141.4248046875, Neurons: 65, Grad norm: 1.621e+02
# Epoch 164, Loss: 1137.4034423828125, Neurons: 65, Grad norm: 1.613e+02
# Epoch 165, Loss: 1133.395263671875, Neurons: 65, Grad norm: 1.604e+02
# Epoch 166, Loss: 1129.4031982421875, Neurons: 65, Grad norm: 1.594e+02
# Epoch 167, Loss: 1125.4300537109375, Neurons: 65, Grad norm: 1.584e+02
# Epoch 168, Loss: 1121.47900390625, Neurons: 65, Grad norm: 1.573e+02
# Epoch 169, Loss: 1117.5531005859375, Neurons: 65, Grad norm: 1.562e+02
# Epoch 170, Loss: 1113.655029296875, Neurons: 65, Grad norm: 1.550e+02
# Epoch 171, Loss: 1109.787841796875, Neurons: 65, Grad norm: 1.537e+02
# Epoch 172, Loss: 1105.9544677734375, Neurons: 65, Grad norm: 1.524e+02
# Epoch 173, Loss: 1102.157470703125, Neurons: 65, Grad norm: 1.510e+02
# Epoch 174, Loss: 1098.3995361328125, Neurons: 65, Grad norm: 1.496e+02
# Epoch 175, Loss: 1094.6834716796875, Neurons: 65, Grad norm: 1.481e+02
# Epoch 176, Loss: 1091.0111083984375, Neurons: 65, Grad norm: 1.466e+02
# Epoch 177, Loss: 1087.3848876953125, Neurons: 65, Grad norm: 1.450e+02
# Epoch 178, Loss: 1083.8067626953125, Neurons: 65, Grad norm: 1.434e+02
# Epoch 179, Loss: 1080.2783203125, Neurons: 65, Grad norm: 1.417e+02
# Epoch 180, Loss: 1076.80126953125, Neurons: 65, Grad norm: 1.400e+02
# Epoch 181, Loss: 1073.376953125, Neurons: 65, Grad norm: 1.383e+02
# Epoch 182, Loss: 1070.006591796875, Neurons: 65, Grad norm: 1.366e+02
# Epoch 183, Loss: 1066.6907958984375, Neurons: 65, Grad norm: 1.348e+02
# Epoch 184, Loss: 1063.4305419921875, Neurons: 65, Grad norm: 1.330e+02
# Epoch 185, Loss: 1060.2265625, Neurons: 65, Grad norm: 1.312e+02
# Epoch 186, Loss: 1057.0789794921875, Neurons: 65, Grad norm: 1.294e+02
# Epoch 187, Loss: 1053.9879150390625, Neurons: 65, Grad norm: 1.276e+02
# Epoch 188, Loss: 1050.953857421875, Neurons: 65, Grad norm: 1.257e+02
# Epoch 189, Loss: 1047.9766845703125, Neurons: 65, Grad norm: 1.239e+02
# Epoch 190, Loss: 1045.0560302734375, Neurons: 65, Grad norm: 1.220e+02
# Epoch 191, Loss: 1042.1917724609375, Neurons: 65, Grad norm: 1.202e+02
# Epoch 192, Loss: 1039.383544921875, Neurons: 65, Grad norm: 1.184e+02
# Epoch 193, Loss: 1036.630859375, Neurons: 65, Grad norm: 1.165e+02
# Epoch 194, Loss: 1033.9329833984375, Neurons: 65, Grad norm: 1.147e+02
# Epoch 195, Loss: 1031.2894287109375, Neurons: 65, Grad norm: 1.129e+02
# Epoch 196, Loss: 1028.699462890625, Neurons: 65, Grad norm: 1.111e+02
# Epoch 197, Loss: 1026.161865234375, Neurons: 65, Grad norm: 1.093e+02
# Epoch 198, Loss: 1023.6761474609375, Neurons: 65, Grad norm: 1.076e+02
# Epoch 199, Loss: 1021.2409057617188, Neurons: 65, Grad norm: 1.059e+02
# Epoch 199, Test loss: 1034.6383056640625
# Epoch 200, Loss: 1018.8551025390625, Neurons: 65, Grad norm: 1.042e+02
# Epoch 201, Loss: 1016.5176391601562, Neurons: 65, Grad norm: 1.025e+02
# Epoch 202, Loss: 1014.22705078125, Neurons: 65, Grad norm: 1.009e+02
# Epoch 203, Loss: 1011.9820556640625, Neurons: 65, Grad norm: 9.925e+01
# Epoch 204, Loss: 1009.7813720703125, Neurons: 65, Grad norm: 9.769e+01
# Epoch 205, Loss: 1007.6234130859375, Neurons: 65, Grad norm: 9.616e+01
# Epoch 206, Loss: 1005.5070190429688, Neurons: 65, Grad norm: 9.468e+01
# Epoch 207, Loss: 1003.4306640625, Neurons: 65, Grad norm: 9.324e+01
# Epoch 208, Loss: 1001.39306640625, Neurons: 65, Grad norm: 9.185e+01
# Epoch 209, Loss: 999.3931274414062, Neurons: 65, Grad norm: 9.050e+01
# Epoch 210, Loss: 997.4295043945312, Neurons: 65, Grad norm: 8.920e+01
# Epoch 211, Loss: 995.5014038085938, Neurons: 65, Grad norm: 8.794e+01
# Epoch 212, Loss: 993.6078491210938, Neurons: 65, Grad norm: 8.673e+01
# Epoch 213, Loss: 991.748291015625, Neurons: 65, Grad norm: 8.556e+01
# Epoch 214, Loss: 989.9217529296875, Neurons: 65, Grad norm: 8.444e+01
# Epoch 215, Loss: 988.12744140625, Neurons: 65, Grad norm: 8.336e+01
# Epoch 216, Loss: 986.364013671875, Neurons: 65, Grad norm: 8.232e+01
# Epoch 217, Loss: 984.6299438476562, Neurons: 65, Grad norm: 8.132e+01
# Epoch 218, Loss: 982.9234008789062, Neurons: 65, Grad norm: 8.035e+01
# Epoch 219, Loss: 981.2423095703125, Neurons: 65, Grad norm: 7.942e+01
# Epoch 220, Loss: 979.5846557617188, Neurons: 65, Grad norm: 7.851e+01
# Epoch 221, Loss: 977.9486694335938, Neurons: 65, Grad norm: 7.763e+01
# Epoch 222, Loss: 976.3324584960938, Neurons: 65, Grad norm: 7.678e+01
# Epoch 223, Loss: 974.7350463867188, Neurons: 65, Grad norm: 7.595e+01
# Epoch 224, Loss: 973.1551513671875, Neurons: 65, Grad norm: 7.515e+01
# Epoch 225, Loss: 971.5921630859375, Neurons: 65, Grad norm: 7.437e+01
# Epoch 226, Loss: 970.0455932617188, Neurons: 65, Grad norm: 7.361e+01
# Epoch 227, Loss: 968.515625, Neurons: 65, Grad norm: 7.288e+01
# Epoch 228, Loss: 967.002197265625, Neurons: 65, Grad norm: 7.216e+01
# Epoch 229, Loss: 965.505859375, Neurons: 65, Grad norm: 7.146e+01
# Epoch 230, Loss: 964.0274047851562, Neurons: 65, Grad norm: 7.077e+01
# Epoch 231, Loss: 962.5676879882812, Neurons: 65, Grad norm: 7.011e+01
# Epoch 232, Loss: 961.1278076171875, Neurons: 65, Grad norm: 6.945e+01
# Epoch 233, Loss: 959.7085571289062, Neurons: 65, Grad norm: 6.882e+01
# Epoch 234, Loss: 958.3109741210938, Neurons: 65, Grad norm: 6.819e+01
# Epoch 235, Loss: 956.9359130859375, Neurons: 65, Grad norm: 6.757e+01
# Epoch 236, Loss: 955.584228515625, Neurons: 65, Grad norm: 6.696e+01
# Epoch 237, Loss: 954.2567749023438, Neurons: 65, Grad norm: 6.635e+01
# Epoch 238, Loss: 952.9542846679688, Neurons: 65, Grad norm: 6.575e+01
# Epoch 239, Loss: 951.67724609375, Neurons: 65, Grad norm: 6.514e+01
# Epoch 240, Loss: 950.426025390625, Neurons: 65, Grad norm: 6.454e+01
# Epoch 241, Loss: 949.2011108398438, Neurons: 65, Grad norm: 6.393e+01
# Epoch 242, Loss: 948.00244140625, Neurons: 65, Grad norm: 6.332e+01
# Epoch 243, Loss: 946.8302001953125, Neurons: 65, Grad norm: 6.269e+01
# Epoch 244, Loss: 945.6841430664062, Neurons: 65, Grad norm: 6.206e+01
# Epoch 245, Loss: 944.5643920898438, Neurons: 65, Grad norm: 6.141e+01
# Epoch 246, Loss: 943.4705810546875, Neurons: 65, Grad norm: 6.075e+01
# Epoch 247, Loss: 942.4026489257812, Neurons: 65, Grad norm: 6.008e+01
# Epoch 248, Loss: 941.3601684570312, Neurons: 65, Grad norm: 5.938e+01
# Epoch 249, Loss: 940.3428955078125, Neurons: 65, Grad norm: 5.868e+01
# Epoch 250, Loss: 939.3502807617188, Neurons: 65, Grad norm: 5.797e+01
# Epoch 251, Loss: 938.3818969726562, Neurons: 65, Grad norm: 5.724e+01
# Epoch 252, Loss: 937.4370727539062, Neurons: 65, Grad norm: 5.650e+01
# Epoch 253, Loss: 936.5150146484375, Neurons: 65, Grad norm: 5.575e+01
# Epoch 254, Loss: 935.6152954101562, Neurons: 65, Grad norm: 5.498e+01
# Epoch 255, Loss: 934.7367553710938, Neurons: 65, Grad norm: 5.421e+01
# Epoch 256, Loss: 933.878662109375, Neurons: 65, Grad norm: 5.343e+01
# Epoch 257, Loss: 933.0404052734375, Neurons: 65, Grad norm: 5.266e+01
# Epoch 258, Loss: 932.2213134765625, Neurons: 65, Grad norm: 5.188e+01
# Epoch 259, Loss: 931.4205322265625, Neurons: 65, Grad norm: 5.111e+01
# Epoch 260, Loss: 930.6375732421875, Neurons: 65, Grad norm: 5.034e+01
# Epoch 261, Loss: 929.8716430664062, Neurons: 65, Grad norm: 4.959e+01
# Epoch 262, Loss: 929.1224365234375, Neurons: 65, Grad norm: 4.885e+01
# Epoch 263, Loss: 928.38916015625, Neurons: 65, Grad norm: 4.811e+01
# Epoch 264, Loss: 927.6715087890625, Neurons: 65, Grad norm: 4.739e+01
# Epoch 265, Loss: 926.9688110351562, Neurons: 65, Grad norm: 4.670e+01
# Epoch 266, Loss: 926.2805786132812, Neurons: 65, Grad norm: 4.602e+01
# Epoch 267, Loss: 925.6064453125, Neurons: 65, Grad norm: 4.538e+01
# Epoch 268, Loss: 924.9457397460938, Neurons: 65, Grad norm: 4.476e+01
# Epoch 269, Loss: 924.2980346679688, Neurons: 65, Grad norm: 4.416e+01
# Epoch 270, Loss: 923.662841796875, Neurons: 65, Grad norm: 4.357e+01
# Epoch 271, Loss: 923.0397338867188, Neurons: 65, Grad norm: 4.300e+01
# Epoch 272, Loss: 922.4281005859375, Neurons: 65, Grad norm: 4.246e+01
# Epoch 273, Loss: 921.8276977539062, Neurons: 65, Grad norm: 4.196e+01
# Epoch 274, Loss: 921.2379150390625, Neurons: 65, Grad norm: 4.148e+01
# Epoch 275, Loss: 920.658203125, Neurons: 65, Grad norm: 4.102e+01
# Epoch 276, Loss: 920.0883178710938, Neurons: 65, Grad norm: 4.059e+01
# Epoch 277, Loss: 919.527587890625, Neurons: 65, Grad norm: 4.017e+01
# Epoch 278, Loss: 918.9757080078125, Neurons: 65, Grad norm: 3.976e+01
# Epoch 279, Loss: 918.4321899414062, Neurons: 65, Grad norm: 3.939e+01
# Epoch 280, Loss: 917.8965454101562, Neurons: 65, Grad norm: 3.903e+01
# Epoch 281, Loss: 917.3682861328125, Neurons: 65, Grad norm: 3.870e+01
# Epoch 282, Loss: 916.84716796875, Neurons: 65, Grad norm: 3.838e+01
# Epoch 283, Loss: 916.3326416015625, Neurons: 65, Grad norm: 3.809e+01
# Epoch 284, Loss: 915.8242797851562, Neurons: 65, Grad norm: 3.781e+01
# Epoch 285, Loss: 915.3216552734375, Neurons: 65, Grad norm: 3.754e+01
# Epoch 286, Loss: 914.8245239257812, Neurons: 65, Grad norm: 3.729e+01
# Epoch 287, Loss: 914.3322143554688, Neurons: 65, Grad norm: 3.706e+01
# Epoch 288, Loss: 913.8446044921875, Neurons: 65, Grad norm: 3.685e+01
# Epoch 289, Loss: 913.3611450195312, Neurons: 65, Grad norm: 3.665e+01
# Epoch 290, Loss: 912.881591796875, Neurons: 65, Grad norm: 3.648e+01
# Epoch 291, Loss: 912.4053955078125, Neurons: 65, Grad norm: 3.632e+01
# Epoch 292, Loss: 911.9324340820312, Neurons: 65, Grad norm: 3.617e+01
# Epoch 293, Loss: 911.462158203125, Neurons: 65, Grad norm: 3.603e+01
# Epoch 294, Loss: 910.9943237304688, Neurons: 65, Grad norm: 3.593e+01
# Epoch 295, Loss: 910.528564453125, Neurons: 65, Grad norm: 3.584e+01
# Epoch 296, Loss: 910.064697265625, Neurons: 65, Grad norm: 3.577e+01
# Epoch 297, Loss: 909.6021118164062, Neurons: 65, Grad norm: 3.572e+01
# Epoch 298, Loss: 909.1406860351562, Neurons: 65, Grad norm: 3.568e+01
# Epoch 299, Loss: 908.6799926757812, Neurons: 65, Grad norm: 3.566e+01
# Epoch 299, Test loss: 919.8628540039062
# Epoch 300, Loss: 908.2199096679688, Neurons: 65, Grad norm: 3.566e+01
# Epoch 301, Loss: 907.7600708007812, Neurons: 65, Grad norm: 3.569e+01
# Epoch 302, Loss: 907.300048828125, Neurons: 65, Grad norm: 3.573e+01
# Epoch 303, Loss: 906.8396606445312, Neurons: 65, Grad norm: 3.580e+01
# Epoch 304, Loss: 906.3786010742188, Neurons: 65, Grad norm: 3.589e+01
# Epoch 305, Loss: 905.9165649414062, Neurons: 65, Grad norm: 3.599e+01
# Epoch 306, Loss: 905.4533081054688, Neurons: 65, Grad norm: 3.611e+01
# Epoch 307, Loss: 904.9884033203125, Neurons: 65, Grad norm: 3.624e+01
# Epoch 308, Loss: 904.5216674804688, Neurons: 65, Grad norm: 3.640e+01
# Epoch 309, Loss: 904.0529174804688, Neurons: 65, Grad norm: 3.658e+01
# Epoch 310, Loss: 903.581787109375, Neurons: 65, Grad norm: 3.678e+01
# Epoch 311, Loss: 903.10791015625, Neurons: 65, Grad norm: 3.699e+01
# Epoch 312, Loss: 902.6311645507812, Neurons: 65, Grad norm: 3.721e+01
# Epoch 313, Loss: 902.1511840820312, Neurons: 65, Grad norm: 3.745e+01
# Epoch 314, Loss: 901.6676635742188, Neurons: 65, Grad norm: 3.770e+01
# Epoch 315, Loss: 901.180419921875, Neurons: 65, Grad norm: 3.797e+01
# Epoch 316, Loss: 900.6891479492188, Neurons: 65, Grad norm: 3.826e+01
# Epoch 317, Loss: 900.1936645507812, Neurons: 65, Grad norm: 3.855e+01
# Epoch 318, Loss: 899.693603515625, Neurons: 65, Grad norm: 3.886e+01
# Epoch 319, Loss: 899.1886596679688, Neurons: 65, Grad norm: 3.918e+01
# Epoch 320, Loss: 898.6787719726562, Neurons: 65, Grad norm: 3.951e+01
# Epoch 321, Loss: 898.1633911132812, Neurons: 65, Grad norm: 3.985e+01
# Epoch 322, Loss: 897.6425170898438, Neurons: 65, Grad norm: 4.021e+01
# Epoch 323, Loss: 897.1157836914062, Neurons: 65, Grad norm: 4.057e+01
# Epoch 324, Loss: 896.5830078125, Neurons: 65, Grad norm: 4.094e+01
# Epoch 325, Loss: 896.0437622070312, Neurons: 65, Grad norm: 4.132e+01
# Epoch 326, Loss: 895.4979248046875, Neurons: 65, Grad norm: 4.171e+01
# Epoch 327, Loss: 894.9453125, Neurons: 65, Grad norm: 4.210e+01
# Epoch 328, Loss: 894.3854370117188, Neurons: 65, Grad norm: 4.250e+01
# Epoch 329, Loss: 893.8181762695312, Neurons: 65, Grad norm: 4.291e+01
# Epoch 330, Loss: 893.2433471679688, Neurons: 65, Grad norm: 4.332e+01
# Epoch 331, Loss: 892.66064453125, Neurons: 65, Grad norm: 4.374e+01
# Epoch 332, Loss: 892.0699462890625, Neurons: 65, Grad norm: 4.417e+01
# Epoch 333, Loss: 891.4706420898438, Neurons: 65, Grad norm: 4.460e+01
# Epoch 334, Loss: 890.86279296875, Neurons: 65, Grad norm: 4.503e+01
# Epoch 335, Loss: 890.2460327148438, Neurons: 65, Grad norm: 4.546e+01
# Epoch 336, Loss: 889.6202392578125, Neurons: 65, Grad norm: 4.590e+01
# Epoch 337, Loss: 888.9849853515625, Neurons: 65, Grad norm: 4.635e+01
# Epoch 338, Loss: 888.340087890625, Neurons: 65, Grad norm: 4.680e+01
# Epoch 339, Loss: 887.685302734375, Neurons: 65, Grad norm: 4.725e+01
# Epoch 340, Loss: 887.0203247070312, Neurons: 65, Grad norm: 4.770e+01
# Epoch 341, Loss: 886.3450317382812, Neurons: 65, Grad norm: 4.815e+01
# Epoch 342, Loss: 885.658935546875, Neurons: 65, Grad norm: 4.860e+01
# Epoch 343, Loss: 884.9619750976562, Neurons: 65, Grad norm: 4.905e+01
# Epoch 344, Loss: 884.2537841796875, Neurons: 65, Grad norm: 4.951e+01
# Epoch 345, Loss: 883.5341796875, Neurons: 65, Grad norm: 4.996e+01
# Epoch 346, Loss: 882.8027954101562, Neurons: 65, Grad norm: 5.042e+01
# Epoch 347, Loss: 882.0595703125, Neurons: 65, Grad norm: 5.087e+01
# Epoch 348, Loss: 881.3038940429688, Neurons: 65, Grad norm: 5.133e+01
# Epoch 349, Loss: 880.5357055664062, Neurons: 65, Grad norm: 5.178e+01
# Epoch 350, Loss: 879.7548828125, Neurons: 65, Grad norm: 5.223e+01
# Epoch 351, Loss: 878.9609375, Neurons: 65, Grad norm: 5.269e+01
# Epoch 352, Loss: 878.153564453125, Neurons: 65, Grad norm: 5.314e+01
# Epoch 353, Loss: 877.3326416015625, Neurons: 65, Grad norm: 5.359e+01
# Epoch 354, Loss: 876.4979248046875, Neurons: 65, Grad norm: 5.404e+01
# Epoch 355, Loss: 875.6490478515625, Neurons: 65, Grad norm: 5.449e+01
# Epoch 356, Loss: 874.78564453125, Neurons: 65, Grad norm: 5.494e+01
# Epoch 357, Loss: 873.9076538085938, Neurons: 65, Grad norm: 5.539e+01
# Epoch 358, Loss: 873.0146484375, Neurons: 65, Grad norm: 5.584e+01
# Epoch 359, Loss: 872.1065063476562, Neurons: 65, Grad norm: 5.629e+01
# Epoch 360, Loss: 871.1827392578125, Neurons: 65, Grad norm: 5.674e+01
# Epoch 361, Loss: 870.2432861328125, Neurons: 65, Grad norm: 5.720e+01
# Epoch 362, Loss: 869.2877807617188, Neurons: 65, Grad norm: 5.765e+01
# Epoch 363, Loss: 868.3160400390625, Neurons: 65, Grad norm: 5.810e+01
# Epoch 364, Loss: 867.3277587890625, Neurons: 65, Grad norm: 5.856e+01
# Epoch 365, Loss: 866.3225708007812, Neurons: 65, Grad norm: 5.902e+01
# Epoch 366, Loss: 865.3004150390625, Neurons: 65, Grad norm: 5.948e+01
# Epoch 367, Loss: 864.2608032226562, Neurons: 65, Grad norm: 5.995e+01
# Epoch 368, Loss: 863.2036743164062, Neurons: 65, Grad norm: 6.042e+01
# Epoch 369, Loss: 862.1287841796875, Neurons: 65, Grad norm: 6.089e+01
# Epoch 370, Loss: 861.0357666015625, Neurons: 65, Grad norm: 6.137e+01
# Epoch 371, Loss: 859.9244384765625, Neurons: 65, Grad norm: 6.186e+01
# Epoch 372, Loss: 858.7945556640625, Neurons: 65, Grad norm: 6.236e+01
# Epoch 373, Loss: 857.6458129882812, Neurons: 65, Grad norm: 6.286e+01
# Epoch 374, Loss: 856.4780883789062, Neurons: 65, Grad norm: 6.337e+01
# Epoch 375, Loss: 855.2911376953125, Neurons: 65, Grad norm: 6.389e+01
# Epoch 376, Loss: 854.084716796875, Neurons: 65, Grad norm: 6.442e+01
# Epoch 377, Loss: 852.8585815429688, Neurons: 65, Grad norm: 6.496e+01
# Epoch 378, Loss: 851.6124267578125, Neurons: 65, Grad norm: 6.552e+01
# Epoch 379, Loss: 850.3461303710938, Neurons: 65, Grad norm: 6.608e+01
# Epoch 380, Loss: 849.0593872070312, Neurons: 65, Grad norm: 6.667e+01
# Epoch 381, Loss: 847.7520751953125, Neurons: 65, Grad norm: 6.726e+01
# Epoch 382, Loss: 846.4239501953125, Neurons: 65, Grad norm: 6.787e+01
# Epoch 383, Loss: 845.0748901367188, Neurons: 65, Grad norm: 6.850e+01
# Epoch 384, Loss: 843.7045288085938, Neurons: 65, Grad norm: 6.915e+01
# Epoch 385, Loss: 842.3126831054688, Neurons: 65, Grad norm: 6.982e+01
# Epoch 386, Loss: 840.8992309570312, Neurons: 65, Grad norm: 7.051e+01
# Epoch 387, Loss: 839.4638061523438, Neurons: 65, Grad norm: 7.121e+01
# Epoch 388, Loss: 838.0062866210938, Neurons: 65, Grad norm: 7.195e+01
# Epoch 389, Loss: 836.5263671875, Neurons: 65, Grad norm: 7.270e+01
# Epoch 390, Loss: 835.0239868164062, Neurons: 65, Grad norm: 7.348e+01
# Epoch 391, Loss: 833.498779296875, Neurons: 65, Grad norm: 7.428e+01
# Epoch 392, Loss: 831.9508056640625, Neurons: 65, Grad norm: 7.511e+01
# Epoch 393, Loss: 830.3795166015625, Neurons: 65, Grad norm: 7.596e+01
# Epoch 394, Loss: 828.7847900390625, Neurons: 65, Grad norm: 7.684e+01
# Epoch 395, Loss: 827.16650390625, Neurons: 65, Grad norm: 7.775e+01
# Epoch 396, Loss: 825.5242919921875, Neurons: 65, Grad norm: 7.869e+01
# Epoch 397, Loss: 823.8579711914062, Neurons: 65, Grad norm: 7.966e+01
# Epoch 398, Loss: 822.1674194335938, Neurons: 65, Grad norm: 8.066e+01
# Epoch 399, Loss: 820.452392578125, Neurons: 65, Grad norm: 8.169e+01
# Epoch 399, Test loss: 828.0896606445312
# Epoch 400, Loss: 818.712646484375, Neurons: 65, Grad norm: 8.275e+01
# Epoch 401, Loss: 816.9479370117188, Neurons: 65, Grad norm: 8.384e+01
# Epoch 402, Loss: 815.157958984375, Neurons: 65, Grad norm: 8.496e+01
# Epoch 403, Loss: 813.3425903320312, Neurons: 65, Grad norm: 8.612e+01
# Epoch 404, Loss: 811.5015258789062, Neurons: 65, Grad norm: 8.730e+01
# Epoch 405, Loss: 809.6346435546875, Neurons: 65, Grad norm: 8.852e+01
# Epoch 406, Loss: 807.74169921875, Neurons: 65, Grad norm: 8.978e+01
# Epoch 407, Loss: 805.8224487304688, Neurons: 65, Grad norm: 9.106e+01
# Epoch 408, Loss: 803.8766479492188, Neurons: 65, Grad norm: 9.238e+01
# Epoch 409, Loss: 801.904296875, Neurons: 65, Grad norm: 9.372e+01
# Epoch 410, Loss: 799.90478515625, Neurons: 65, Grad norm: 9.510e+01
# Epoch 411, Loss: 797.8782958984375, Neurons: 65, Grad norm: 9.651e+01
# Epoch 412, Loss: 795.8242797851562, Neurons: 65, Grad norm: 9.795e+01
# Epoch 413, Loss: 793.7427978515625, Neurons: 65, Grad norm: 9.943e+01
# Epoch 414, Loss: 791.633544921875, Neurons: 65, Grad norm: 1.009e+02
# Epoch 415, Loss: 789.4962768554688, Neurons: 65, Grad norm: 1.025e+02
# Epoch 416, Loss: 787.3309326171875, Neurons: 65, Grad norm: 1.040e+02
# Epoch 417, Loss: 785.1373291015625, Neurons: 65, Grad norm: 1.056e+02
# Epoch 418, Loss: 782.915283203125, Neurons: 65, Grad norm: 1.072e+02
# Epoch 419, Loss: 780.6647338867188, Neurons: 65, Grad norm: 1.088e+02
# Epoch 420, Loss: 778.3854370117188, Neurons: 65, Grad norm: 1.105e+02
# Epoch 421, Loss: 776.0772705078125, Neurons: 65, Grad norm: 1.122e+02
# Epoch 422, Loss: 773.7402954101562, Neurons: 65, Grad norm: 1.139e+02
# Epoch 423, Loss: 771.374267578125, Neurons: 65, Grad norm: 1.156e+02
# Epoch 424, Loss: 768.9791870117188, Neurons: 65, Grad norm: 1.173e+02
# Epoch 425, Loss: 766.5548095703125, Neurons: 65, Grad norm: 1.191e+02
# Epoch 426, Loss: 764.10107421875, Neurons: 65, Grad norm: 1.209e+02
# Epoch 427, Loss: 761.6182861328125, Neurons: 65, Grad norm: 1.227e+02
# Epoch 428, Loss: 759.1060791015625, Neurons: 65, Grad norm: 1.245e+02
# Epoch 429, Loss: 756.5646362304688, Neurons: 65, Grad norm: 1.263e+02
# Epoch 430, Loss: 753.993896484375, Neurons: 65, Grad norm: 1.281e+02
# Epoch 431, Loss: 751.3939208984375, Neurons: 65, Grad norm: 1.299e+02
# Epoch 432, Loss: 748.7647705078125, Neurons: 65, Grad norm: 1.317e+02
# Epoch 433, Loss: 746.1063842773438, Neurons: 65, Grad norm: 1.336e+02
# Epoch 434, Loss: 743.4188842773438, Neurons: 65, Grad norm: 1.354e+02
# Epoch 435, Loss: 740.7024536132812, Neurons: 65, Grad norm: 1.372e+02
# Epoch 436, Loss: 737.95703125, Neurons: 65, Grad norm: 1.390e+02
# Epoch 437, Loss: 735.1829223632812, Neurons: 65, Grad norm: 1.408e+02
# Epoch 438, Loss: 732.3803100585938, Neurons: 65, Grad norm: 1.426e+02
# Epoch 439, Loss: 729.5491333007812, Neurons: 65, Grad norm: 1.444e+02
# Epoch 440, Loss: 726.6897583007812, Neurons: 65, Grad norm: 1.462e+02
# Epoch 441, Loss: 723.8023681640625, Neurons: 65, Grad norm: 1.479e+02
# Epoch 442, Loss: 720.8870239257812, Neurons: 65, Grad norm: 1.497e+02
# Epoch 443, Loss: 717.9440307617188, Neurons: 65, Grad norm: 1.514e+02
# Epoch 444, Loss: 714.9736938476562, Neurons: 65, Grad norm: 1.531e+02
# Epoch 445, Loss: 711.9761962890625, Neurons: 65, Grad norm: 1.547e+02
# Epoch 446, Loss: 708.951904296875, Neurons: 65, Grad norm: 1.563e+02
# Epoch 447, Loss: 705.9010620117188, Neurons: 65, Grad norm: 1.579e+02
# Epoch 448, Loss: 702.8240356445312, Neurons: 65, Grad norm: 1.595e+02
# Epoch 449, Loss: 699.7211303710938, Neurons: 65, Grad norm: 1.610e+02
# Epoch 450, Loss: 696.5927734375, Neurons: 65, Grad norm: 1.625e+02
# Epoch 451, Loss: 693.4393920898438, Neurons: 65, Grad norm: 1.639e+02
# Epoch 452, Loss: 690.2614135742188, Neurons: 65, Grad norm: 1.653e+02
# Epoch 453, Loss: 687.059326171875, Neurons: 65, Grad norm: 1.666e+02
# Epoch 454, Loss: 683.8336181640625, Neurons: 65, Grad norm: 1.678e+02
# Epoch 455, Loss: 680.5847778320312, Neurons: 65, Grad norm: 1.690e+02
# Epoch 456, Loss: 677.3135375976562, Neurons: 65, Grad norm: 1.702e+02
# Epoch 457, Loss: 674.020263671875, Neurons: 65, Grad norm: 1.713e+02
# Epoch 458, Loss: 670.705810546875, Neurons: 65, Grad norm: 1.723e+02
# Epoch 459, Loss: 667.3707885742188, Neurons: 65, Grad norm: 1.732e+02
# Epoch 460, Loss: 664.0159301757812, Neurons: 65, Grad norm: 1.741e+02
# Epoch 461, Loss: 660.6420288085938, Neurons: 65, Grad norm: 1.748e+02
# Epoch 462, Loss: 657.2500610351562, Neurons: 65, Grad norm: 1.755e+02
# Epoch 463, Loss: 653.8407592773438, Neurons: 65, Grad norm: 1.761e+02
# Epoch 464, Loss: 650.415283203125, Neurons: 65, Grad norm: 1.767e+02
# Epoch 465, Loss: 646.9744262695312, Neurons: 65, Grad norm: 1.771e+02
# Epoch 466, Loss: 643.5193481445312, Neurons: 65, Grad norm: 1.774e+02
# Epoch 467, Loss: 640.0513305664062, Neurons: 65, Grad norm: 1.776e+02
# Epoch 468, Loss: 636.5716552734375, Neurons: 65, Grad norm: 1.778e+02
# Epoch 469, Loss: 633.08154296875, Neurons: 65, Grad norm: 1.778e+02
# Epoch 470, Loss: 629.5824584960938, Neurons: 65, Grad norm: 1.777e+02
# Epoch 471, Loss: 626.0759887695312, Neurons: 65, Grad norm: 1.776e+02
# Epoch 472, Loss: 622.5635986328125, Neurons: 65, Grad norm: 1.773e+02
# Epoch 473, Loss: 619.047119140625, Neurons: 65, Grad norm: 1.768e+02
# Epoch 474, Loss: 615.5283813476562, Neurons: 65, Grad norm: 1.763e+02
# Epoch 475, Loss: 612.0092163085938, Neurons: 65, Grad norm: 1.757e+02
# Epoch 476, Loss: 608.4915771484375, Neurons: 65, Grad norm: 1.749e+02
# Epoch 477, Loss: 604.9776000976562, Neurons: 65, Grad norm: 1.740e+02
# Epoch 478, Loss: 601.469482421875, Neurons: 65, Grad norm: 1.730e+02
# Epoch 479, Loss: 597.9695434570312, Neurons: 65, Grad norm: 1.719e+02
# Epoch 480, Loss: 594.4802856445312, Neurons: 65, Grad norm: 1.707e+02
# Epoch 481, Loss: 591.0039672851562, Neurons: 65, Grad norm: 1.693e+02
# Epoch 482, Loss: 587.5433959960938, Neurons: 65, Grad norm: 1.679e+02
# Epoch 483, Loss: 584.10107421875, Neurons: 65, Grad norm: 1.664e+02
# Epoch 484, Loss: 580.6796875, Neurons: 65, Grad norm: 1.648e+02
# Epoch 485, Loss: 577.2820434570312, Neurons: 65, Grad norm: 1.632e+02
# Epoch 486, Loss: 573.91064453125, Neurons: 65, Grad norm: 1.614e+02
# Epoch 487, Loss: 570.5682983398438, Neurons: 65, Grad norm: 1.595e+02
# Epoch 488, Loss: 567.2576904296875, Neurons: 65, Grad norm: 1.576e+02
# Epoch 489, Loss: 563.9812622070312, Neurons: 65, Grad norm: 1.557e+02
# Epoch 490, Loss: 560.7415161132812, Neurons: 65, Grad norm: 1.536e+02
# Epoch 491, Loss: 557.5408325195312, Neurons: 65, Grad norm: 1.514e+02
# Epoch 492, Loss: 554.3814086914062, Neurons: 65, Grad norm: 1.492e+02
# Epoch 493, Loss: 551.2653198242188, Neurons: 65, Grad norm: 1.470e+02
# Epoch 494, Loss: 548.1945190429688, Neurons: 65, Grad norm: 1.446e+02
# Epoch 495, Loss: 545.1708984375, Neurons: 65, Grad norm: 1.424e+02
# Epoch 496, Loss: 542.1959838867188, Neurons: 65, Grad norm: 1.401e+02
# Epoch 497, Loss: 539.27099609375, Neurons: 65, Grad norm: 1.379e+02
# Epoch 498, Loss: 536.397216796875, Neurons: 65, Grad norm: 1.358e+02
# Epoch 499, Loss: 533.575439453125, Neurons: 65, Grad norm: 1.336e+02
# Epoch 499, Test loss: 533.3923950195312
# Epoch 500, Loss: 530.806396484375, Neurons: 65, Grad norm: 1.315e+02
# Epoch 501, Loss: 528.0906982421875, Neurons: 65, Grad norm: 1.293e+02
# Epoch 502, Loss: 525.4286499023438, Neurons: 65, Grad norm: 1.272e+02
# Epoch 503, Loss: 522.8203735351562, Neurons: 65, Grad norm: 1.249e+02
# Epoch 504, Loss: 520.2658081054688, Neurons: 65, Grad norm: 1.226e+02
# Epoch 505, Loss: 517.7650146484375, Neurons: 65, Grad norm: 1.204e+02
# Epoch 506, Loss: 515.3178100585938, Neurons: 65, Grad norm: 1.182e+02
# Epoch 507, Loss: 512.9237060546875, Neurons: 65, Grad norm: 1.161e+02
# Epoch 508, Loss: 510.5823059082031, Neurons: 65, Grad norm: 1.140e+02
# Epoch 509, Loss: 508.2929382324219, Neurons: 65, Grad norm: 1.120e+02
# Epoch 510, Loss: 506.0549621582031, Neurons: 65, Grad norm: 1.100e+02
# Epoch 511, Loss: 503.8677062988281, Neurons: 65, Grad norm: 1.081e+02
# Epoch 512, Loss: 501.7303161621094, Neurons: 65, Grad norm: 1.063e+02
# Epoch 513, Loss: 499.64190673828125, Neurons: 65, Grad norm: 1.044e+02
# Epoch 514, Loss: 497.6015319824219, Neurons: 65, Grad norm: 1.027e+02
# Epoch 515, Loss: 495.6084289550781, Neurons: 65, Grad norm: 1.009e+02
# Epoch 516, Loss: 493.6615295410156, Neurons: 65, Grad norm: 9.906e+01
# Epoch 517, Loss: 491.759765625, Neurons: 65, Grad norm: 9.727e+01
# Epoch 518, Loss: 489.9022521972656, Neurons: 65, Grad norm: 9.551e+01
# Epoch 519, Loss: 488.08795166015625, Neurons: 65, Grad norm: 9.383e+01
# Epoch 520, Loss: 486.3158874511719, Neurons: 65, Grad norm: 9.215e+01
# Epoch 521, Loss: 484.5849609375, Neurons: 65, Grad norm: 9.052e+01
# Epoch 522, Loss: 482.8941345214844, Neurons: 65, Grad norm: 8.897e+01
# Epoch 523, Loss: 481.2424621582031, Neurons: 65, Grad norm: 8.743e+01
# Epoch 524, Loss: 479.6287841796875, Neurons: 65, Grad norm: 8.601e+01
# Epoch 525, Loss: 478.05218505859375, Neurons: 65, Grad norm: 8.457e+01
# Epoch 526, Loss: 476.51165771484375, Neurons: 65, Grad norm: 8.316e+01
# Epoch 527, Loss: 475.0061340332031, Neurons: 65, Grad norm: 8.177e+01
# Epoch 528, Loss: 473.5347595214844, Neurons: 65, Grad norm: 8.039e+01
# Epoch 529, Loss: 472.0964660644531, Neurons: 65, Grad norm: 7.900e+01
# Epoch 530, Loss: 470.6903381347656, Neurons: 65, Grad norm: 7.764e+01
# Epoch 531, Loss: 469.3155212402344, Neurons: 65, Grad norm: 7.638e+01
# Epoch 532, Loss: 467.97100830078125, Neurons: 65, Grad norm: 7.509e+01
# Epoch 533, Loss: 466.6560363769531, Neurons: 65, Grad norm: 7.383e+01
# Epoch 534, Loss: 465.3696594238281, Neurons: 65, Grad norm: 7.264e+01
# Epoch 535, Loss: 464.11102294921875, Neurons: 65, Grad norm: 7.146e+01
# Epoch 536, Loss: 462.8793640136719, Neurons: 65, Grad norm: 7.038e+01
# Epoch 537, Loss: 461.6738586425781, Neurons: 65, Grad norm: 6.930e+01
# Epoch 538, Loss: 460.49371337890625, Neurons: 65, Grad norm: 6.823e+01
# Epoch 539, Loss: 459.33819580078125, Neurons: 65, Grad norm: 6.715e+01
# Epoch 540, Loss: 458.2065734863281, Neurons: 65, Grad norm: 6.610e+01
# Epoch 541, Loss: 457.09814453125, Neurons: 65, Grad norm: 6.510e+01
# Epoch 542, Loss: 456.01220703125, Neurons: 65, Grad norm: 6.413e+01
# Epoch 543, Loss: 454.9481201171875, Neurons: 65, Grad norm: 6.314e+01
# Epoch 544, Loss: 453.9051818847656, Neurons: 65, Grad norm: 6.222e+01
# Epoch 545, Loss: 452.8827819824219, Neurons: 65, Grad norm: 6.129e+01
# Epoch 546, Loss: 451.8803405761719, Neurons: 65, Grad norm: 6.045e+01
# Epoch 547, Loss: 450.897216796875, Neurons: 65, Grad norm: 5.963e+01
# Epoch 548, Loss: 449.9328308105469, Neurons: 65, Grad norm: 5.876e+01
# Epoch 549, Loss: 448.98663330078125, Neurons: 65, Grad norm: 5.794e+01
# Epoch 550, Loss: 448.05810546875, Neurons: 65, Grad norm: 5.714e+01
# Epoch 551, Loss: 447.1466979980469, Neurons: 65, Grad norm: 5.636e+01
# Epoch 552, Loss: 446.251953125, Neurons: 65, Grad norm: 5.556e+01
# Epoch 553, Loss: 445.373291015625, Neurons: 65, Grad norm: 5.482e+01
# Epoch 554, Loss: 444.5103454589844, Neurons: 65, Grad norm: 5.408e+01
# Epoch 555, Loss: 443.6626281738281, Neurons: 65, Grad norm: 5.339e+01
# Epoch 556, Loss: 442.8296203613281, Neurons: 65, Grad norm: 5.273e+01
# Epoch 557, Loss: 442.010986328125, Neurons: 65, Grad norm: 5.208e+01
# Epoch 558, Loss: 441.2062683105469, Neurons: 65, Grad norm: 5.145e+01
# Epoch 559, Loss: 440.41510009765625, Neurons: 65, Grad norm: 5.084e+01
# Epoch 560, Loss: 439.6370849609375, Neurons: 65, Grad norm: 5.026e+01
# Epoch 561, Loss: 438.87188720703125, Neurons: 65, Grad norm: 4.967e+01
# Epoch 562, Loss: 438.11907958984375, Neurons: 65, Grad norm: 4.908e+01
# Epoch 563, Loss: 437.3783264160156, Neurons: 65, Grad norm: 4.851e+01
# Epoch 564, Loss: 436.6493835449219, Neurons: 65, Grad norm: 4.797e+01
# Epoch 565, Loss: 435.93182373046875, Neurons: 65, Grad norm: 4.741e+01
# Epoch 566, Loss: 435.225341796875, Neurons: 65, Grad norm: 4.685e+01
# Epoch 567, Loss: 434.5296936035156, Neurons: 65, Grad norm: 4.633e+01
# Epoch 568, Loss: 433.84454345703125, Neurons: 65, Grad norm: 4.583e+01
# Epoch 569, Loss: 433.16961669921875, Neurons: 65, Grad norm: 4.537e+01
# Epoch 570, Loss: 432.504638671875, Neurons: 65, Grad norm: 4.490e+01
# Epoch 571, Loss: 431.849365234375, Neurons: 65, Grad norm: 4.447e+01
# Epoch 572, Loss: 431.2035217285156, Neurons: 65, Grad norm: 4.402e+01
# Epoch 573, Loss: 430.5668640136719, Neurons: 65, Grad norm: 4.359e+01
# Epoch 574, Loss: 429.9391784667969, Neurons: 65, Grad norm: 4.318e+01
# Epoch 575, Loss: 429.3202209472656, Neurons: 65, Grad norm: 4.276e+01
# Epoch 576, Loss: 428.70977783203125, Neurons: 65, Grad norm: 4.235e+01
# Epoch 577, Loss: 428.1075744628906, Neurons: 65, Grad norm: 4.196e+01
# Epoch 578, Loss: 427.5135192871094, Neurons: 65, Grad norm: 4.155e+01
# Epoch 579, Loss: 426.9278564453125, Neurons: 65, Grad norm: 4.113e+01
# Epoch 580, Loss: 426.3513488769531, Neurons: 65, Grad norm: 4.073e+01
# Epoch 581, Loss: 425.7841491699219, Neurons: 65, Grad norm: 4.035e+01
# Epoch 582, Loss: 425.22589111328125, Neurons: 65, Grad norm: 4.000e+01
# Epoch 583, Loss: 424.67633056640625, Neurons: 65, Grad norm: 3.966e+01
# Epoch 584, Loss: 424.13482666015625, Neurons: 65, Grad norm: 3.933e+01
# Epoch 585, Loss: 423.60089111328125, Neurons: 65, Grad norm: 3.900e+01
# Epoch 586, Loss: 423.0739440917969, Neurons: 65, Grad norm: 3.868e+01
# Epoch 587, Loss: 422.5535888671875, Neurons: 65, Grad norm: 3.836e+01
# Epoch 588, Loss: 422.0394287109375, Neurons: 65, Grad norm: 3.805e+01
# Epoch 589, Loss: 421.5311584472656, Neurons: 65, Grad norm: 3.775e+01
# Epoch 590, Loss: 421.02862548828125, Neurons: 65, Grad norm: 3.746e+01
# Epoch 591, Loss: 420.5320739746094, Neurons: 65, Grad norm: 3.717e+01
# Epoch 592, Loss: 420.0418395996094, Neurons: 65, Grad norm: 3.689e+01
# Epoch 593, Loss: 419.5577697753906, Neurons: 65, Grad norm: 3.662e+01
# Epoch 594, Loss: 419.0797119140625, Neurons: 65, Grad norm: 3.636e+01
# Epoch 595, Loss: 418.60736083984375, Neurons: 65, Grad norm: 3.610e+01
# Epoch 596, Loss: 418.1405944824219, Neurons: 65, Grad norm: 3.586e+01
# Epoch 597, Loss: 417.6791076660156, Neurons: 65, Grad norm: 3.562e+01
# Epoch 598, Loss: 417.222900390625, Neurons: 65, Grad norm: 3.539e+01
# Epoch 599, Loss: 416.7717590332031, Neurons: 65, Grad norm: 3.517e+01
# Epoch 599, Test loss: 416.1361999511719
# Epoch 600, Loss: 416.3255920410156, Neurons: 65, Grad norm: 3.495e+01
# Epoch 601, Loss: 415.8841552734375, Neurons: 65, Grad norm: 3.474e+01
# Epoch 602, Loss: 415.4473876953125, Neurons: 65, Grad norm: 3.453e+01
# Epoch 603, Loss: 415.01519775390625, Neurons: 65, Grad norm: 3.433e+01
# Epoch 604, Loss: 414.5874328613281, Neurons: 65, Grad norm: 3.413e+01
# Epoch 605, Loss: 414.1640319824219, Neurons: 65, Grad norm: 3.394e+01
# Epoch 606, Loss: 413.744873046875, Neurons: 65, Grad norm: 3.375e+01
# Epoch 607, Loss: 413.32989501953125, Neurons: 65, Grad norm: 3.357e+01
# Epoch 608, Loss: 412.91900634765625, Neurons: 65, Grad norm: 3.339e+01
# Epoch 609, Loss: 412.51214599609375, Neurons: 65, Grad norm: 3.322e+01
# Epoch 610, Loss: 412.1092529296875, Neurons: 65, Grad norm: 3.304e+01
# Epoch 611, Loss: 411.710205078125, Neurons: 65, Grad norm: 3.287e+01
# Epoch 612, Loss: 411.3150329589844, Neurons: 65, Grad norm: 3.271e+01
# Epoch 613, Loss: 410.92352294921875, Neurons: 65, Grad norm: 3.255e+01
# Epoch 614, Loss: 410.53564453125, Neurons: 65, Grad norm: 3.239e+01
# Epoch 615, Loss: 410.15142822265625, Neurons: 65, Grad norm: 3.223e+01
# Epoch 616, Loss: 409.7707214355469, Neurons: 65, Grad norm: 3.208e+01
# Epoch 617, Loss: 409.3935546875, Neurons: 65, Grad norm: 3.193e+01
# Epoch 618, Loss: 409.01983642578125, Neurons: 65, Grad norm: 3.179e+01
# Epoch 619, Loss: 408.64947509765625, Neurons: 65, Grad norm: 3.165e+01
# Epoch 620, Loss: 408.28253173828125, Neurons: 65, Grad norm: 3.151e+01
# Epoch 621, Loss: 407.91888427734375, Neurons: 65, Grad norm: 3.137e+01
# Epoch 622, Loss: 407.5585632324219, Neurons: 65, Grad norm: 3.124e+01
# Epoch 623, Loss: 407.2013854980469, Neurons: 65, Grad norm: 3.112e+01
# Epoch 624, Loss: 406.8474426269531, Neurons: 65, Grad norm: 3.100e+01
# Epoch 625, Loss: 406.4966735839844, Neurons: 65, Grad norm: 3.087e+01
# Epoch 626, Loss: 406.14898681640625, Neurons: 65, Grad norm: 3.075e+01
# Epoch 627, Loss: 405.8043212890625, Neurons: 65, Grad norm: 3.063e+01
# Epoch 628, Loss: 405.4626770019531, Neurons: 65, Grad norm: 3.050e+01
# Epoch 629, Loss: 405.1239929199219, Neurons: 65, Grad norm: 3.038e+01
# Epoch 630, Loss: 404.7882385253906, Neurons: 65, Grad norm: 3.025e+01
# Epoch 631, Loss: 404.455322265625, Neurons: 65, Grad norm: 3.013e+01
# Epoch 632, Loss: 404.1252746582031, Neurons: 65, Grad norm: 3.001e+01
# Epoch 633, Loss: 403.798095703125, Neurons: 65, Grad norm: 2.989e+01
# Epoch 634, Loss: 403.4736022949219, Neurons: 65, Grad norm: 2.978e+01
# Epoch 635, Loss: 403.15185546875, Neurons: 65, Grad norm: 2.966e+01
# Epoch 636, Loss: 402.8328552246094, Neurons: 65, Grad norm: 2.955e+01
# Epoch 637, Loss: 402.51654052734375, Neurons: 65, Grad norm: 2.943e+01
# Epoch 638, Loss: 402.202880859375, Neurons: 65, Grad norm: 2.932e+01
# Epoch 639, Loss: 401.891845703125, Neurons: 65, Grad norm: 2.921e+01
# Epoch 640, Loss: 401.5834045410156, Neurons: 65, Grad norm: 2.909e+01
# Epoch 641, Loss: 401.2774963378906, Neurons: 65, Grad norm: 2.898e+01
# Epoch 642, Loss: 400.9741516113281, Neurons: 65, Grad norm: 2.888e+01
# Epoch 643, Loss: 400.67333984375, Neurons: 65, Grad norm: 2.877e+01
# Epoch 644, Loss: 400.3749694824219, Neurons: 65, Grad norm: 2.869e+01
# Epoch 645, Loss: 400.0790100097656, Neurons: 65, Grad norm: 2.859e+01
# Epoch 646, Loss: 399.78558349609375, Neurons: 65, Grad norm: 2.848e+01
# Epoch 647, Loss: 399.4944763183594, Neurons: 65, Grad norm: 2.837e+01
# Epoch 648, Loss: 399.205810546875, Neurons: 65, Grad norm: 2.827e+01
# Epoch 649, Loss: 398.91943359375, Neurons: 65, Grad norm: 2.817e+01
# Epoch 650, Loss: 398.6354064941406, Neurons: 65, Grad norm: 2.808e+01
# Epoch 651, Loss: 398.35369873046875, Neurons: 65, Grad norm: 2.799e+01
# Epoch 652, Loss: 398.07421875, Neurons: 65, Grad norm: 2.790e+01
# Epoch 653, Loss: 397.7970275878906, Neurons: 65, Grad norm: 2.781e+01
# Epoch 654, Loss: 397.5220947265625, Neurons: 65, Grad norm: 2.773e+01
# Epoch 655, Loss: 397.24932861328125, Neurons: 65, Grad norm: 2.764e+01
# Epoch 656, Loss: 396.978759765625, Neurons: 65, Grad norm: 2.756e+01
# Epoch 657, Loss: 396.7103576660156, Neurons: 65, Grad norm: 2.748e+01
# Epoch 658, Loss: 396.44415283203125, Neurons: 65, Grad norm: 2.739e+01
# Epoch 659, Loss: 396.1800231933594, Neurons: 65, Grad norm: 2.731e+01
# Epoch 660, Loss: 395.91802978515625, Neurons: 65, Grad norm: 2.723e+01
# Epoch 661, Loss: 395.65814208984375, Neurons: 65, Grad norm: 2.714e+01
# Epoch 662, Loss: 395.4002685546875, Neurons: 65, Grad norm: 2.707e+01
# Epoch 663, Loss: 395.14453125, Neurons: 65, Grad norm: 2.697e+01
# Epoch 664, Loss: 394.8907470703125, Neurons: 65, Grad norm: 2.690e+01
# Epoch 665, Loss: 394.6389465332031, Neurons: 65, Grad norm: 2.683e+01
# Epoch 666, Loss: 394.38922119140625, Neurons: 65, Grad norm: 2.675e+01
# Epoch 667, Loss: 394.1414489746094, Neurons: 65, Grad norm: 2.668e+01
# Epoch 668, Loss: 393.8955993652344, Neurons: 65, Grad norm: 2.664e+01
# Epoch 669, Loss: 393.6517333984375, Neurons: 65, Grad norm: 2.658e+01
# Epoch 670, Loss: 393.4097595214844, Neurons: 65, Grad norm: 2.650e+01
# Epoch 671, Loss: 393.1697082519531, Neurons: 65, Grad norm: 2.641e+01
# Epoch 672, Loss: 392.9315490722656, Neurons: 65, Grad norm: 2.634e+01
# Epoch 673, Loss: 392.6952819824219, Neurons: 65, Grad norm: 2.626e+01
# Epoch 674, Loss: 392.4607849121094, Neurons: 65, Grad norm: 2.619e+01
# Epoch 675, Loss: 392.22821044921875, Neurons: 65, Grad norm: 2.612e+01
# Epoch 676, Loss: 391.9974060058594, Neurons: 65, Grad norm: 2.603e+01
# Epoch 677, Loss: 391.7684631347656, Neurons: 65, Grad norm: 2.597e+01
# Epoch 678, Loss: 391.541259765625, Neurons: 65, Grad norm: 2.591e+01
# Epoch 679, Loss: 391.3157958984375, Neurons: 65, Grad norm: 2.585e+01
# Epoch 680, Loss: 391.09210205078125, Neurons: 65, Grad norm: 2.579e+01
# Epoch 681, Loss: 390.8702087402344, Neurons: 65, Grad norm: 2.574e+01
# Epoch 682, Loss: 390.6500244140625, Neurons: 65, Grad norm: 2.567e+01
# Epoch 683, Loss: 390.4315185546875, Neurons: 65, Grad norm: 2.561e+01
# ...
# Epoch 24785, Loss: 0.06893664598464966, Neurons: 65, Grad norm: 2.124e+00
# Epoch 24786, Loss: 0.06893786787986755, Neurons: 65, Grad norm: 2.362e+00
# Epoch 24787, Loss: 0.06893882900476456, Neurons: 65, Grad norm: 2.576e+00
# Epoch 24788, Loss: 0.06893964111804962, Neurons: 65, Grad norm: 2.750e+00
# Epoch 24789, Loss: 0.06894013285636902, Neurons: 65, Grad norm: 2.927e+00
# Epoch 24790, Loss: 0.0689401924610138, Neurons: 65, Grad norm: 3.059e+00
# Epoch 24791, Loss: 0.06894010305404663, Neurons: 65, Grad norm: 3.214e+00
# Epoch 24792, Loss: 0.06894053518772125, Neurons: 65, Grad norm: 3.334e+00
# Epoch 24793, Loss: 0.06894038617610931, Neurons: 65, Grad norm: 3.477e+00
# Epoch 24794, Loss: 0.06894069910049438, Neurons: 65, Grad norm: 3.603e+00
# Epoch 24795, Loss: 0.06894110888242722, Neurons: 65, Grad norm: 3.749e+00
# Epoch 24796, Loss: 0.0689418837428093, Neurons: 65, Grad norm: 3.886e+00
# Epoch 24797, Loss: 0.06894327700138092, Neurons: 65, Grad norm: 4.065e+00
# Epoch 24798, Loss: 0.06894518435001373, Neurons: 65, Grad norm: 4.237e+00
# Epoch 24799, Loss: 0.06894785165786743, Neurons: 65, Grad norm: 4.476e+00
# Epoch 24799, Test loss: 0.06153516098856926
# Epoch 24800, Loss: 0.06895287334918976, Neurons: 65, Grad norm: 4.724e+00
# Epoch 24801, Loss: 0.06895898282527924, Neurons: 65, Grad norm: 5.042e+00
# Epoch 24802, Loss: 0.06896761059761047, Neurons: 65, Grad norm: 5.365e+00
# Epoch 24803, Loss: 0.06897814571857452, Neurons: 65, Grad norm: 5.763e+00
# Epoch 24804, Loss: 0.06899204105138779, Neurons: 65, Grad norm: 6.188e+00
# Epoch 24805, Loss: 0.06900902092456818, Neurons: 65, Grad norm: 6.699e+00
# Epoch 24806, Loss: 0.06903167814016342, Neurons: 65, Grad norm: 7.248e+00
# Epoch 24807, Loss: 0.0690588727593422, Neurons: 65, Grad norm: 7.900e+00
# Epoch 24808, Loss: 0.06909427046775818, Neurons: 65, Grad norm: 8.600e+00
# Epoch 24809, Loss: 0.06913723051548004, Neurons: 65, Grad norm: 9.436e+00
# Epoch 24810, Loss: 0.06919354945421219, Neurons: 65, Grad norm: 1.033e+01
# Epoch 24811, Loss: 0.06926118582487106, Neurons: 65, Grad norm: 1.133e+01
# Epoch 24812, Loss: 0.0693456307053566, Neurons: 65, Grad norm: 1.239e+01
# Epoch 24813, Loss: 0.06944374740123749, Neurons: 65, Grad norm: 1.355e+01
# Epoch 24814, Loss: 0.06956223398447037, Neurons: 65, Grad norm: 1.471e+01
# Epoch 24815, Loss: 0.0696931779384613, Neurons: 65, Grad norm: 1.592e+01
# Epoch 24816, Loss: 0.06984251737594604, Neurons: 65, Grad norm: 1.708e+01
# Epoch 24817, Loss: 0.06999856233596802, Neurons: 65, Grad norm: 1.814e+01
# Epoch 24818, Loss: 0.0701526552438736, Neurons: 65, Grad norm: 1.897e+01
# Epoch 24819, Loss: 0.07028039544820786, Neurons: 65, Grad norm: 1.948e+01
# Epoch 24820, Loss: 0.07036434859037399, Neurons: 65, Grad norm: 1.952e+01
# Epoch 24821, Loss: 0.07037397474050522, Neurons: 65, Grad norm: 1.899e+01
# Epoch 24822, Loss: 0.07029524445533752, Neurons: 65, Grad norm: 1.778e+01
# Epoch 24823, Loss: 0.07011430710554123, Neurons: 65, Grad norm: 1.591e+01
# Epoch 24824, Loss: 0.06985684484243393, Neurons: 65, Grad norm: 1.340e+01
# Epoch 24825, Loss: 0.0695519745349884, Neurons: 65, Grad norm: 1.040e+01
# Epoch 24826, Loss: 0.06925412267446518, Neurons: 65, Grad norm: 7.096e+00
# Epoch 24827, Loss: 0.06900889426469803, Neurons: 65, Grad norm: 3.747e+00
# Epoch 24828, Loss: 0.06885044276714325, Neurons: 65, Grad norm: 9.921e-01
# Epoch 24829, Loss: 0.06878767907619476, Neurons: 65, Grad norm: 2.789e+00
# Epoch 24830, Loss: 0.0688069611787796, Neurons: 65, Grad norm: 5.280e+00
# Epoch 24831, Loss: 0.0688825398683548, Neurons: 65, Grad norm: 7.280e+00
# Epoch 24832, Loss: 0.06898123770952225, Neurons: 65, Grad norm: 8.758e+00
# Epoch 24833, Loss: 0.0690746158361435, Neurons: 65, Grad norm: 9.632e+00
# Epoch 24834, Loss: 0.0691392570734024, Neurons: 65, Grad norm: 9.979e+00
# Epoch 24835, Loss: 0.06916453689336777, Neurons: 65, Grad norm: 9.769e+00
# Epoch 24836, Loss: 0.0691465213894844, Neurons: 65, Grad norm: 9.106e+00
# Epoch 24837, Loss: 0.06909297406673431, Neurons: 65, Grad norm: 8.024e+00
# Epoch 24838, Loss: 0.06901440769433975, Neurons: 65, Grad norm: 6.639e+00
# Epoch 24839, Loss: 0.06892798095941544, Neurons: 65, Grad norm: 5.044e+00
# Epoch 24840, Loss: 0.06884851306676865, Neurons: 65, Grad norm: 3.380e+00
# Epoch 24841, Loss: 0.06878724694252014, Neurons: 65, Grad norm: 1.720e+00
# Epoch 24842, Loss: 0.06874919682741165, Neurons: 65, Grad norm: 1.781e-01
# Epoch 24843, Loss: 0.0687333270907402, Neurons: 65, Grad norm: 1.271e+00
# Epoch 24844, Loss: 0.06873621046543121, Neurons: 65, Grad norm: 2.472e+00
# Epoch 24845, Loss: 0.06875166296958923, Neurons: 65, Grad norm: 3.482e+00
# Epoch 24846, Loss: 0.06877285242080688, Neurons: 65, Grad norm: 4.237e+00
# Epoch 24847, Loss: 0.06879370659589767, Neurons: 65, Grad norm: 4.791e+00
# Epoch 24848, Loss: 0.06881061941385269, Neurons: 65, Grad norm: 5.089e+00
# Epoch 24849, Loss: 0.06881961971521378, Neurons: 65, Grad norm: 5.177e+00
# Epoch 24850, Loss: 0.06881960481405258, Neurons: 65, Grad norm: 5.067e+00
# Epoch 24851, Loss: 0.06881186366081238, Neurons: 65, Grad norm: 4.823e+00
# Epoch 24852, Loss: 0.06879802793264389, Neurons: 65, Grad norm: 4.437e+00
# Epoch 24853, Loss: 0.06878060847520828, Neurons: 65, Grad norm: 3.981e+00
# Epoch 24854, Loss: 0.0687609538435936, Neurons: 65, Grad norm: 3.447e+00
# Epoch 24855, Loss: 0.06874176114797592, Neurons: 65, Grad norm: 2.909e+00
# Epoch 24856, Loss: 0.06872455030679703, Neurons: 65, Grad norm: 2.337e+00
# Epoch 24857, Loss: 0.06870968639850616, Neurons: 65, Grad norm: 1.811e+00
# Epoch 24858, Loss: 0.06869743764400482, Neurons: 65, Grad norm: 1.298e+00
# Epoch 24859, Loss: 0.06868851184844971, Neurons: 65, Grad norm: 9.164e-01
# Epoch 24860, Loss: 0.06868212670087814, Neurons: 65, Grad norm: 6.867e-01
# Epoch 24861, Loss: 0.06867828220129013, Neurons: 65, Grad norm: 6.958e-01
# Epoch 24862, Loss: 0.06867572665214539, Neurons: 65, Grad norm: 8.682e-01
# Epoch 24863, Loss: 0.06867454946041107, Neurons: 65, Grad norm: 1.077e+00
# Epoch 24864, Loss: 0.0686737596988678, Neurons: 65, Grad norm: 1.277e+00
# Epoch 24865, Loss: 0.0686732828617096, Neurons: 65, Grad norm: 1.459e+00
# Epoch 24866, Loss: 0.06867298483848572, Neurons: 65, Grad norm: 1.606e+00
# Epoch 24867, Loss: 0.06867242604494095, Neurons: 65, Grad norm: 1.726e+00
# Epoch 24868, Loss: 0.06867159157991409, Neurons: 65, Grad norm: 1.838e+00
# Epoch 24869, Loss: 0.06867042183876038, Neurons: 65, Grad norm: 1.897e+00
# Epoch 24870, Loss: 0.06866936385631561, Neurons: 65, Grad norm: 1.949e+00
# Epoch 24871, Loss: 0.0686677098274231, Neurons: 65, Grad norm: 2.011e+00
# Epoch 24872, Loss: 0.0686657726764679, Neurons: 65, Grad norm: 2.049e+00
# Epoch 24873, Loss: 0.06866370141506195, Neurons: 65, Grad norm: 2.058e+00
# Epoch 24874, Loss: 0.06866148114204407, Neurons: 65, Grad norm: 2.075e+00
# Epoch 24875, Loss: 0.06865932047367096, Neurons: 65, Grad norm: 2.098e+00
# Epoch 24876, Loss: 0.06865744292736053, Neurons: 65, Grad norm: 2.104e+00
# Epoch 24877, Loss: 0.06865572929382324, Neurons: 65, Grad norm: 2.131e+00
# Epoch 24878, Loss: 0.06865426898002625, Neurons: 65, Grad norm: 2.180e+00
# Epoch 24879, Loss: 0.06865275651216507, Neurons: 65, Grad norm: 2.194e+00
# Epoch 24880, Loss: 0.06865158677101135, Neurons: 65, Grad norm: 2.228e+00
# Epoch 24881, Loss: 0.06865018606185913, Neurons: 65, Grad norm: 2.293e+00
# Epoch 24882, Loss: 0.0686490535736084, Neurons: 65, Grad norm: 2.320e+00
# Epoch 24883, Loss: 0.06864773482084274, Neurons: 65, Grad norm: 2.351e+00
# Epoch 24884, Loss: 0.06864652782678604, Neurons: 65, Grad norm: 2.395e+00
# Epoch 24885, Loss: 0.06864474713802338, Neurons: 65, Grad norm: 2.408e+00
# Epoch 24886, Loss: 0.0686422735452652, Neurons: 65, Grad norm: 2.411e+00
# Epoch 24887, Loss: 0.06863916665315628, Neurons: 65, Grad norm: 2.424e+00
# Epoch 24888, Loss: 0.06863542646169662, Neurons: 65, Grad norm: 2.388e+00
# Epoch 24889, Loss: 0.0686311274766922, Neurons: 65, Grad norm: 2.356e+00
# Epoch 24890, Loss: 0.06862598657608032, Neurons: 65, Grad norm: 2.327e+00
# Epoch 24891, Loss: 0.06861990690231323, Neurons: 65, Grad norm: 2.276e+00
# Epoch 24892, Loss: 0.06861358880996704, Neurons: 65, Grad norm: 2.248e+00
# Epoch 24893, Loss: 0.06860727071762085, Neurons: 65, Grad norm: 2.271e+00
# Epoch 24894, Loss: 0.06860127300024033, Neurons: 65, Grad norm: 2.336e+00
# Epoch 24895, Loss: 0.06859662383794785, Neurons: 65, Grad norm: 2.479e+00
# Epoch 24896, Loss: 0.06859374791383743, Neurons: 65, Grad norm: 2.759e+00
# Epoch 24897, Loss: 0.06859376281499863, Neurons: 65, Grad norm: 3.163e+00
# Epoch 24898, Loss: 0.06859845668077469, Neurons: 65, Grad norm: 3.767e+00
# Epoch 24899, Loss: 0.06860968470573425, Neurons: 65, Grad norm: 4.529e+00
# Epoch 24899, Test loss: 0.06122613698244095
# Epoch 24900, Loss: 0.0686306580901146, Neurons: 65, Grad norm: 5.552e+00
# Epoch 24901, Loss: 0.06866701692342758, Neurons: 65, Grad norm: 6.782e+00
# Epoch 24902, Loss: 0.06872380524873734, Neurons: 65, Grad norm: 8.327e+00
# Epoch 24903, Loss: 0.06881240010261536, Neurons: 65, Grad norm: 1.016e+01
# Epoch 24904, Loss: 0.06894401460886002, Neurons: 65, Grad norm: 1.242e+01
# Epoch 24905, Loss: 0.06914243847131729, Neurons: 65, Grad norm: 1.508e+01
# Epoch 24906, Loss: 0.06942994147539139, Neurons: 65, Grad norm: 1.825e+01
# Epoch 24907, Loss: 0.06984487920999527, Neurons: 65, Grad norm: 2.189e+01
# Epoch 24908, Loss: 0.07042114436626434, Neurons: 65, Grad norm: 2.589e+01
# Epoch 24909, Loss: 0.07117821276187897, Neurons: 65, Grad norm: 3.000e+01
# Epoch 24910, Loss: 0.07209575176239014, Neurons: 65, Grad norm: 3.370e+01
# Epoch 24911, Loss: 0.07304327189922333, Neurons: 65, Grad norm: 3.618e+01
# Epoch 24912, Loss: 0.07375993579626083, Neurons: 65, Grad norm: 3.648e+01
# Epoch 24913, Loss: 0.07389450818300247, Neurons: 65, Grad norm: 3.373e+01
# Epoch 24914, Loss: 0.07317202538251877, Neurons: 65, Grad norm: 2.757e+01
# Epoch 24915, Loss: 0.07170137017965317, Neurons: 65, Grad norm: 1.851e+01
# Epoch 24916, Loss: 0.07002831250429153, Neurons: 65, Grad norm: 8.214e+00
# Epoch 24917, Loss: 0.06887523084878922, Neurons: 65, Grad norm: 4.913e+00
# Epoch 24918, Loss: 0.06863000988960266, Neurons: 65, Grad norm: 1.291e+01
# Epoch 24919, Loss: 0.0691511482000351, Neurons: 65, Grad norm: 1.901e+01
# Epoch 24920, Loss: 0.06992786377668381, Neurons: 65, Grad norm: 2.170e+01
# Epoch 24921, Loss: 0.07040911912918091, Neurons: 65, Grad norm: 2.072e+01
# Epoch 24922, Loss: 0.07029738277196884, Neurons: 65, Grad norm: 1.642e+01
# Epoch 24923, Loss: 0.06967996805906296, Neurons: 65, Grad norm: 9.891e+00
# Epoch 24924, Loss: 0.06896321475505829, Neurons: 65, Grad norm: 3.189e+00
# Epoch 24925, Loss: 0.06855398416519165, Neurons: 65, Grad norm: 5.884e+00
# Epoch 24926, Loss: 0.06860727071762085, Neurons: 65, Grad norm: 1.114e+01
# Epoch 24927, Loss: 0.0689609944820404, Neurons: 65, Grad norm: 1.411e+01
# Epoch 24928, Loss: 0.06929346174001694, Neurons: 65, Grad norm: 1.438e+01
# Epoch 24929, Loss: 0.06935542821884155, Neurons: 65, Grad norm: 1.204e+01
# Epoch 24930, Loss: 0.06911131739616394, Neurons: 65, Grad norm: 7.784e+00
# Epoch 24931, Loss: 0.06874416023492813, Neurons: 65, Grad norm: 2.643e+00
# Epoch 24932, Loss: 0.06849122792482376, Neurons: 65, Grad norm: 2.955e+00
# Epoch 24933, Loss: 0.06847851723432541, Neurons: 65, Grad norm: 7.046e+00
# Epoch 24934, Loss: 0.0686497837305069, Neurons: 65, Grad norm: 9.528e+00
# Epoch 24935, Loss: 0.06883406639099121, Neurons: 65, Grad norm: 1.006e+01
# Epoch 24936, Loss: 0.06888482719659805, Neurons: 65, Grad norm: 8.699e+00
# Epoch 24937, Loss: 0.06877096742391586, Neurons: 65, Grad norm: 5.894e+00
# Epoch 24938, Loss: 0.06858447939157486, Neurons: 65, Grad norm: 2.277e+00
# Epoch 24939, Loss: 0.06844832748174667, Neurons: 65, Grad norm: 1.398e+00
# Epoch 24940, Loss: 0.06843230128288269, Neurons: 65, Grad norm: 4.463e+00
# Epoch 24941, Loss: 0.06851159781217575, Neurons: 65, Grad norm: 6.428e+00
# Epoch 24942, Loss: 0.06860371679067612, Neurons: 65, Grad norm: 7.104e+00
# Epoch 24943, Loss: 0.06863652169704437, Neurons: 65, Grad norm: 6.475e+00
# Epoch 24944, Loss: 0.06859060376882553, Neurons: 65, Grad norm: 4.844e+00
# Epoch 24945, Loss: 0.06850384920835495, Neurons: 65, Grad norm: 2.595e+00
# Epoch 24946, Loss: 0.06843116879463196, Neurons: 65, Grad norm: 8.625e-01
# Epoch 24947, Loss: 0.06840788573026657, Neurons: 65, Grad norm: 2.409e+00
# Epoch 24948, Loss: 0.06843043863773346, Neurons: 65, Grad norm: 3.948e+00
# Epoch 24949, Loss: 0.06846830248832703, Neurons: 65, Grad norm: 4.754e+00
# Epoch 24950, Loss: 0.0684901773929596, Neurons: 65, Grad norm: 4.729e+00
# Epoch 24951, Loss: 0.06848111003637314, Neurons: 65, Grad norm: 4.021e+00
# Epoch 24952, Loss: 0.06845010817050934, Neurons: 65, Grad norm: 2.792e+00
# Epoch 24953, Loss: 0.06841451674699783, Neurons: 65, Grad norm: 1.472e+00
# Epoch 24954, Loss: 0.06839102506637573, Neurons: 65, Grad norm: 1.018e+00
# Epoch 24955, Loss: 0.06838545203208923, Neurons: 65, Grad norm: 1.929e+00
# Epoch 24956, Loss: 0.0683927983045578, Neurons: 65, Grad norm: 2.778e+00
# Epoch 24957, Loss: 0.0684037059545517, Neurons: 65, Grad norm: 3.203e+00
# Epoch 24958, Loss: 0.06840886175632477, Neurons: 65, Grad norm: 3.178e+00
# Epoch 24959, Loss: 0.0684041902422905, Neurons: 65, Grad norm: 2.709e+00
# Epoch 24960, Loss: 0.06839106231927872, Neurons: 65, Grad norm: 1.980e+00
# Epoch 24961, Loss: 0.0683753713965416, Neurons: 65, Grad norm: 1.078e+00
# Epoch 24962, Loss: 0.06836187094449997, Neurons: 65, Grad norm: 5.859e-01
# Epoch 24963, Loss: 0.06835492700338364, Neurons: 65, Grad norm: 1.135e+00
# Epoch 24964, Loss: 0.0683547854423523, Neurons: 65, Grad norm: 1.753e+00
# Epoch 24965, Loss: 0.0683581605553627, Neurons: 65, Grad norm: 2.153e+00
# Epoch 24966, Loss: 0.06836125254631042, Neurons: 65, Grad norm: 2.226e+00
# Epoch 24967, Loss: 0.0683598667383194, Neurons: 65, Grad norm: 2.034e+00
# Epoch 24968, Loss: 0.06835391372442245, Neurons: 65, Grad norm: 1.567e+00
# Epoch 24969, Loss: 0.06834407150745392, Neurons: 65, Grad norm: 9.622e-01
# Epoch 24970, Loss: 0.06833446025848389, Neurons: 65, Grad norm: 2.948e-01
# Epoch 24971, Loss: 0.068327896296978, Neurons: 65, Grad norm: 3.800e-01
# Epoch 24972, Loss: 0.06832463294267654, Neurons: 65, Grad norm: 9.309e-01
# Epoch 24973, Loss: 0.06832477450370789, Neurons: 65, Grad norm: 1.305e+00
# Epoch 24974, Loss: 0.06832516938447952, Neurons: 65, Grad norm: 1.497e+00
# Epoch 24975, Loss: 0.06832440942525864, Neurons: 65, Grad norm: 1.485e+00
# Epoch 24976, Loss: 0.06832098960876465, Neurons: 65, Grad norm: 1.353e+00
# Epoch 24977, Loss: 0.06831610202789307, Neurons: 65, Grad norm: 1.044e+00
# Epoch 24978, Loss: 0.06831002235412598, Neurons: 65, Grad norm: 6.795e-01
# Epoch 24979, Loss: 0.06830448657274246, Neurons: 65, Grad norm: 2.870e-01
# Epoch 24980, Loss: 0.06829993426799774, Neurons: 65, Grad norm: 2.577e-01
# Epoch 24981, Loss: 0.06829684227705002, Neurons: 65, Grad norm: 5.290e-01
# Epoch 24982, Loss: 0.06829462200403214, Neurons: 65, Grad norm: 7.594e-01
# Epoch 24983, Loss: 0.06829288601875305, Neurons: 65, Grad norm: 9.350e-01
# Epoch 24984, Loss: 0.06829065829515457, Neurons: 65, Grad norm: 9.486e-01
# Epoch 24985, Loss: 0.06828766316175461, Neurons: 65, Grad norm: 9.141e-01
# Epoch 24986, Loss: 0.06828431785106659, Neurons: 65, Grad norm: 7.862e-01
# Epoch 24987, Loss: 0.06828033179044724, Neurons: 65, Grad norm: 6.267e-01
# Epoch 24988, Loss: 0.06827639788389206, Neurons: 65, Grad norm: 4.166e-01
# Epoch 24989, Loss: 0.0682724341750145, Neurons: 65, Grad norm: 2.309e-01
# Epoch 24990, Loss: 0.06826891005039215, Neurons: 65, Grad norm: 1.757e-01
# Epoch 24991, Loss: 0.06826582551002502, Neurons: 65, Grad norm: 2.536e-01
# Epoch 24992, Loss: 0.06826259940862656, Neurons: 65, Grad norm: 4.201e-01
# Epoch 24993, Loss: 0.0682598426938057, Neurons: 65, Grad norm: 5.480e-01
# Epoch 24994, Loss: 0.0682571530342102, Neurons: 65, Grad norm: 6.792e-01
# Epoch 24995, Loss: 0.06825464218854904, Neurons: 65, Grad norm: 7.431e-01
# Epoch 24996, Loss: 0.06825218349695206, Neurons: 65, Grad norm: 7.786e-01
# Epoch 24997, Loss: 0.06824898719787598, Neurons: 65, Grad norm: 7.339e-01
# Epoch 24998, Loss: 0.06824588775634766, Neurons: 65, Grad norm: 6.610e-01
# Epoch 24999, Loss: 0.06824228167533875, Neurons: 65, Grad norm: 5.403e-01

# %%
np.savetxt(f"{out_folder}/neurons.txt", node_history)
np.savetxt(f"{out_folder}/train_loss.txt", train_loss_history)
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)

# %% [markdown]
# ### evaluation

# %%
y_pred = jax.vmap(mlp)(x_test)
test_mse = jnp.mean((y_pred - y_test) ** 2)
plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, "b.", alpha=0.2, label="True Poly Function")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label="MLP Predictions\n Test MSE: {:.4f}".format(test_mse))
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("MLP Approximation of polynomial Function")
plt.savefig(f"{fig_folder}/polynomial_approximation.png")
plt.savefig(f"{fig_folder}/polynomial_approximation.pdf")
plt.savefig(f"{fig_folder}/polynomial_approximation.svg", format='svg', bbox_inches='tight')
wandb.log({"polynomial approximation": wandb.Image(plt, caption="polynomial approximation")})

# %%
update_history
# Out:
# []

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.pdf")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum([mlp.input_size]+mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.savefig(f"{fig_folder}/final_weight_distribution.pdf")
plt.savefig(f"{fig_folder}/final_weight_distribution.png")
plt.savefig(f"{fig_folder}/final_weight_distribution.svg", format='svg', bbox_inches='tight')
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
plt.savefig(f"{fig_folder}/loss_curve.pdf")
plt.savefig(f"{fig_folder}/loss_curve.svg", format='svg', bbox_inches='tight')
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")
plt.savefig(f"{fig_folder}/loss_curve_loglog.pdf")
plt.savefig(f"{fig_folder}/loss_curve_loglog.svg", format='svg', bbox_inches='tight')

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
plt.savefig(f"{fig_folder}/final_graph.pdf")
plt.savefig(f"{fig_folder}/final_graph.svg", format='svg', bbox_inches='tight')
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/time_curve.png")
plt.savefig(f"{fig_folder}/time_curve.pdf")
plt.savefig(f"{fig_folder}/time_curve.svg", format='svg', bbox_inches='tight')
