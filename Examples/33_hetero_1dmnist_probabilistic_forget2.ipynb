# %% [markdown]
# # Probabilistic strategy for 1d mnist classification with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "33_hetero_1dmnist_probabilistic_forget2.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="30_hetero_1dmnist_probabilistic.ipynb"
# env: WANDB_SILENT=True
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

from mnist1d.data import make_dataset, get_dataset_args, get_templates

import os
import sys
import time
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
# mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %%
def plot_1dmnist(xs, t, labels=None, ratio=2.6, dark_mode=False, zoom=1):
    rows, cols = 1, 10
    fig = plt.figure(figsize=[cols*1.5,rows*1.5*ratio], dpi=60)
    for r in range(rows):
        for c in range(cols):
            ix = r*cols + c
            x, t = xs[ix], t
            ax = plt.subplot(rows,cols,ix+1)

            if dark_mode:
                plt.plot(x, t, 'wo', linewidth=6)
                ax.set_facecolor('k')
            else:
                plt.plot(x, t, 'k-', linewidth=2)
            if labels is not None:
                plt.title("label=" + str(labels[ix]), fontsize=22)

            plt.xlim(-zoom,zoom) ; plt.ylim(-zoom,zoom)
            plt.gca().invert_yaxis() ; plt.xticks([], []), plt.yticks([], [])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.tight_layout() ; plt.show()
    return fig

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 40
hidden_sizes = [5, 5] 
min_neurons = 10
output_size = 10
initial_activation_list = [jax.nn.relu, jax.nn.tanh, sin]
activation_list = [jax.nn.relu, jax.nn.tanh, sin]
optimizer = optax.adabelief
bias = False
num_epochs = 25000
intervene_every = 100
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"proto_loss_Hetero_{act_string}_1dmnist_L0_normalized_probabilistic_forget2_strat_{optimizer.__name__}_no_bias_min_{min_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: proto_loss_Hetero_relu_tanh_sin_1dmnist_L0_normalized_probabilistic_OR_strat_adabelief_no_bias_min_10_5_5_2500_100_0.0001_0
# Description: proto_loss_Hetero_relu_tanh_sin_1dmnist_L0_normalized_probabilistic_OR_strat_adabelief_no_bias_min_10_5_5_2500_100_0.0001_0
# jax backend: cpu
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
data_config = get_dataset_args()

# %%
data_config.num_samples = n_samples
data_config.shuffle_seq = True

# %%
data = make_dataset(data_config)

# %%
x_train, y_train = data["x"], data["y"]
x_test, y_test = data["x_test"], data["y_test"]
template = data["t"]

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape, template.shape
# Out:
# ((16000, 40), (16000,), (4000, 40), (4000,), (40,))

# %%
plt.hist(y_train)
# Out:
# (array([1613., 1598., 1597., 1614., 1571., 1589., 1597., 1602., 1600.,
#         1619.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_1dmnist(x, t, labels=y, ratio=1.33, dark_mode=False)
plt.savefig(f"{fig_folder}/mnist1d_templates.pdf", bbox_inches='tight')
plt.savefig(f"{fig_folder}/mnist1d_templates.svg", bbox_inches='tight', format='svg')
# Out:
# Templates for the MNIST-1D dataset:

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
# @jax.jit
# def cross_entropy(y, pred_y):
#     # y are the true targets, and should be integers 0-9.
#     # pred_y are the log-softmax'd predictions.
#     pred_y = jnp.take_along_axis(pred_y, jnp.expand_dims(y, 1), axis=1)
#     return -jnp.mean(pred_y)

@jax.jit
def cross_entropy(y, pred_y):
    # Convert y to one-hot encoding
    y_one_hot = jax.nn.one_hot(y, num_classes=10)
    # Use optax's softmax_cross_entropy
    return jnp.mean(optax.softmax_cross_entropy(pred_y, y_one_hot))

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred_y = jax.nn.log_softmax(jax.vmap(mlp)(x))
    loss = cross_entropy(y, pred_y)
    return loss

# %%
@eqx.filter_jit()
def accuracy(mlp, x, y):
    logits = jax.vmap(mlp)(x)
    return jnp.mean(jnp.argmax(logits, axis=-1) == y)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0], accuracy(mlp, x, y)

# %%
@eqx.filter_jit()
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 20
# Number of neurons at start: 20

# %%
# logits = jax.nn.log_softmax(jax.vmap(mlp)(x_train))
# logits.shape
# one_hot_labels = jax.nn.one_hot(y_train, 10)
# one_hot_labels.shape
# plt.plot(optax.softmax_cross_entropy(logits=logits, labels=one_hot_labels))

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
plt.savefig(f"{fig_folder}/initial_graph.pdf")
plt.savefig(f"{fig_folder}/initial_graph.svg", format='svg', bbox_inches='tight')
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.pdf")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
accuracy_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []
add_prob_history = []
remove_prob_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity
check_accuracy = 0 # initialize check accuracy to 0
L_0 = 1 # loss normalization for probabilistic strat

# %%
def p_continue(test_loss, n_neurons, min_neurons):
    """
    Unnormalized Probability of continuing with the current network
    """
    return 1 / (test_loss + 1)

def p_add(test_loss, n_neurons, min_neurons):
    """
    Unnormalized Probability of trying to add a neuron
    """
    return test_loss / (test_loss + n_neurons / min_neurons)

def p_remove(test_loss, n_neurons, min_neurons):
    """
    Unnormalized Probability of trying to remove a neuron
    """
    return test_loss / (test_loss + min_neurons / n_neurons)

def p_norm(test_loss, n_neurons, min_neurons):
    """
    Norm to get probability to 1
    """
    return p_continue(test_loss, n_neurons, min_neurons) + p_add(test_loss, n_neurons, min_neurons) + p_remove(test_loss, n_neurons, min_neurons)

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss, test_accuracy = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}, Test accuracy: {test_accuracy}")
        wandb.log({"test_loss": test_loss.item(), "test_accuracy": test_accuracy})
        test_loss_history.append((epoch,test_loss))
        accuracy_history.append((epoch, test_accuracy))
        # if epoch+1 == intervene_every:
        #     L_0 = test_loss
        normed_loss = test_loss / L_0
        add_prob = p_add(normed_loss, n_neurons, min_neurons)/p_norm(normed_loss, n_neurons, min_neurons)
        add_prob_history.append((epoch, add_prob))
        remove_prob = p_remove(normed_loss, n_neurons, min_neurons)/p_norm(normed_loss, n_neurons, min_neurons)
        remove_prob_history.append((epoch, remove_prob))
        continue_prob = p_continue(normed_loss, n_neurons, min_neurons)/p_norm(normed_loss, n_neurons, min_neurons)
        layers = len(mlp.get_shape()) - 1
        
        # Neuron Removal criteria
        if jax.random.uniform(prob_key, minval = 0, maxval = 1)<remove_prob:
            if ((check_loss < test_loss) # check current loss against last accepted addition
                and n_neurons>min_neurons): # neuron floor

                layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
                layer = update_history[-1][-1] # get the layer of last addition

                if len(mlp.layers[layer]) <= 1: # if only one neuron in layer, remove from another layer
                    layer_num = jax.random.randint(layer_key, (), 0, layers-1)
                    layer = jnp.where(layer_num >= layer, layer_num + 1, layer_num)
                    logging.info(f"Cannot remove neuron from layer {layer+1}, only one neuron left")
                    update_history.append((epoch, n_neurons, train_loss, test_loss, "single_node_layer", layer))
                    logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx} instead")
                    check_loss = test_loss
                    logging.info(f"Check loss updated to {check_loss} due to removal")

                neuron_idx = len(mlp.layers[layer]) -1

                mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
                opt_state = initialize_optimizer_state(mlp, opt)
                update_history.append((epoch, n_neurons, train_loss, test_loss, "removed", layer))

                logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
                wandb.log({"removed neuron": neuron_idx})
                logging.info(f"network shape updated to :{mlp.get_shape()}")
        
        # Neuron Addition criteria
        if jax.random.uniform(prob_key, minval = 0, maxval = 1)<add_prob:
            if ((len(update_history) == 0    # if no previous addition
                or check_loss > test_loss)): # if last addition was accepted

                add_key, act_key = jax.random.split(add_key)
                activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
                layers = len(mlp.get_shape()) - 1
                layer = jax.random.randint(act_key, (1,), 0, layers)[0] # randomly select a layer to add neuron to
                mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
                opt_state = initialize_optimizer_state(mlp, opt)

                update_history.append((epoch, n_neurons, train_loss, test_loss, activation.__name__, layer))
                logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
                wandb.log({"added neuron": activation.__name__})
                logging.info(f"network shape updated to :{mlp.get_shape()}")
            check_loss = test_loss
            logging.info(f"Check loss updated to {check_loss} due to addition")
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 2.3025851249694824, Neurons: 20, Grad norm: 6.280e-02
# Epoch 000, Loss: 2.3025851249694824, Neurons: 20, Grad norm: 6.280e-02
# Epoch 001, Loss: 2.302487373352051, Neurons: 20, Grad norm: 6.367e-02
# Epoch 001, Loss: 2.302487373352051, Neurons: 20, Grad norm: 6.367e-02
# Epoch 002, Loss: 2.302381992340088, Neurons: 20, Grad norm: 6.470e-02
# Epoch 002, Loss: 2.302381992340088, Neurons: 20, Grad norm: 6.470e-02
# Epoch 003, Loss: 2.3022677898406982, Neurons: 20, Grad norm: 6.583e-02
# Epoch 003, Loss: 2.3022677898406982, Neurons: 20, Grad norm: 6.583e-02
# Epoch 004, Loss: 2.3021440505981445, Neurons: 20, Grad norm: 6.704e-02
# Epoch 004, Loss: 2.3021440505981445, Neurons: 20, Grad norm: 6.704e-02
# Epoch 005, Loss: 2.3020105361938477, Neurons: 20, Grad norm: 6.835e-02
# Epoch 005, Loss: 2.3020105361938477, Neurons: 20, Grad norm: 6.835e-02
# Epoch 006, Loss: 2.301866292953491, Neurons: 20, Grad norm: 6.975e-02
# Epoch 006, Loss: 2.301866292953491, Neurons: 20, Grad norm: 6.975e-02
# Epoch 007, Loss: 2.3017101287841797, Neurons: 20, Grad norm: 7.124e-02
# Epoch 007, Loss: 2.3017101287841797, Neurons: 20, Grad norm: 7.124e-02
# Epoch 008, Loss: 2.301542043685913, Neurons: 20, Grad norm: 7.281e-02
# Epoch 008, Loss: 2.301542043685913, Neurons: 20, Grad norm: 7.281e-02
# Epoch 009, Loss: 2.3013598918914795, Neurons: 20, Grad norm: 7.447e-02
# Epoch 009, Loss: 2.3013598918914795, Neurons: 20, Grad norm: 7.447e-02
# Epoch 010, Loss: 2.301163673400879, Neurons: 20, Grad norm: 7.623e-02
# Epoch 010, Loss: 2.301163673400879, Neurons: 20, Grad norm: 7.623e-02
# Epoch 011, Loss: 2.300952196121216, Neurons: 20, Grad norm: 7.808e-02
# Epoch 011, Loss: 2.300952196121216, Neurons: 20, Grad norm: 7.808e-02
# Epoch 012, Loss: 2.3007237911224365, Neurons: 20, Grad norm: 8.002e-02
# Epoch 012, Loss: 2.3007237911224365, Neurons: 20, Grad norm: 8.002e-02
# Epoch 013, Loss: 2.300477981567383, Neurons: 20, Grad norm: 8.205e-02
# Epoch 013, Loss: 2.300477981567383, Neurons: 20, Grad norm: 8.205e-02
# Epoch 014, Loss: 2.300213098526001, Neurons: 20, Grad norm: 8.418e-02
# Epoch 014, Loss: 2.300213098526001, Neurons: 20, Grad norm: 8.418e-02
# Epoch 015, Loss: 2.2999277114868164, Neurons: 20, Grad norm: 8.641e-02
# Epoch 015, Loss: 2.2999277114868164, Neurons: 20, Grad norm: 8.641e-02
# Epoch 016, Loss: 2.2996203899383545, Neurons: 20, Grad norm: 8.872e-02
# Epoch 016, Loss: 2.2996203899383545, Neurons: 20, Grad norm: 8.872e-02
# Epoch 017, Loss: 2.299290418624878, Neurons: 20, Grad norm: 9.113e-02
# Epoch 017, Loss: 2.299290418624878, Neurons: 20, Grad norm: 9.113e-02
# Epoch 018, Loss: 2.2989354133605957, Neurons: 20, Grad norm: 9.363e-02
# Epoch 018, Loss: 2.2989354133605957, Neurons: 20, Grad norm: 9.363e-02
# Epoch 019, Loss: 2.2985544204711914, Neurons: 20, Grad norm: 9.622e-02
# Epoch 019, Loss: 2.2985544204711914, Neurons: 20, Grad norm: 9.622e-02
# Epoch 020, Loss: 2.298144817352295, Neurons: 20, Grad norm: 9.890e-02
# Epoch 020, Loss: 2.298144817352295, Neurons: 20, Grad norm: 9.890e-02
# Epoch 021, Loss: 2.29770565032959, Neurons: 20, Grad norm: 1.017e-01
# Epoch 021, Loss: 2.29770565032959, Neurons: 20, Grad norm: 1.017e-01
# Epoch 022, Loss: 2.2972350120544434, Neurons: 20, Grad norm: 1.045e-01
# Epoch 022, Loss: 2.2972350120544434, Neurons: 20, Grad norm: 1.045e-01
# Epoch 023, Loss: 2.2967305183410645, Neurons: 20, Grad norm: 1.075e-01
# Epoch 023, Loss: 2.2967305183410645, Neurons: 20, Grad norm: 1.075e-01
# Epoch 024, Loss: 2.2961912155151367, Neurons: 20, Grad norm: 1.105e-01
# Epoch 024, Loss: 2.2961912155151367, Neurons: 20, Grad norm: 1.105e-01
# Epoch 025, Loss: 2.29561448097229, Neurons: 20, Grad norm: 1.136e-01
# Epoch 025, Loss: 2.29561448097229, Neurons: 20, Grad norm: 1.136e-01
# Epoch 026, Loss: 2.2949981689453125, Neurons: 20, Grad norm: 1.167e-01
# Epoch 026, Loss: 2.2949981689453125, Neurons: 20, Grad norm: 1.167e-01
# Epoch 027, Loss: 2.2943408489227295, Neurons: 20, Grad norm: 1.199e-01
# Epoch 027, Loss: 2.2943408489227295, Neurons: 20, Grad norm: 1.199e-01
# Epoch 028, Loss: 2.2936394214630127, Neurons: 20, Grad norm: 1.232e-01
# Epoch 028, Loss: 2.2936394214630127, Neurons: 20, Grad norm: 1.232e-01
# Epoch 029, Loss: 2.2928929328918457, Neurons: 20, Grad norm: 1.266e-01
# Epoch 029, Loss: 2.2928929328918457, Neurons: 20, Grad norm: 1.266e-01
# Epoch 030, Loss: 2.2920982837677, Neurons: 20, Grad norm: 1.300e-01
# Epoch 030, Loss: 2.2920982837677, Neurons: 20, Grad norm: 1.300e-01
# Epoch 031, Loss: 2.2912535667419434, Neurons: 20, Grad norm: 1.335e-01
# Epoch 031, Loss: 2.2912535667419434, Neurons: 20, Grad norm: 1.335e-01
# Epoch 032, Loss: 2.2903571128845215, Neurons: 20, Grad norm: 1.370e-01
# Epoch 032, Loss: 2.2903571128845215, Neurons: 20, Grad norm: 1.370e-01
# Epoch 033, Loss: 2.2894062995910645, Neurons: 20, Grad norm: 1.405e-01
# Epoch 033, Loss: 2.2894062995910645, Neurons: 20, Grad norm: 1.405e-01
# Epoch 034, Loss: 2.2883994579315186, Neurons: 20, Grad norm: 1.441e-01
# Epoch 034, Loss: 2.2883994579315186, Neurons: 20, Grad norm: 1.441e-01
# Epoch 035, Loss: 2.2873342037200928, Neurons: 20, Grad norm: 1.477e-01
# Epoch 035, Loss: 2.2873342037200928, Neurons: 20, Grad norm: 1.477e-01
# Epoch 036, Loss: 2.2862086296081543, Neurons: 20, Grad norm: 1.513e-01
# Epoch 036, Loss: 2.2862086296081543, Neurons: 20, Grad norm: 1.513e-01
# Epoch 037, Loss: 2.2850210666656494, Neurons: 20, Grad norm: 1.549e-01
# Epoch 037, Loss: 2.2850210666656494, Neurons: 20, Grad norm: 1.549e-01
# Epoch 038, Loss: 2.283769369125366, Neurons: 20, Grad norm: 1.585e-01
# Epoch 038, Loss: 2.283769369125366, Neurons: 20, Grad norm: 1.585e-01
# Epoch 039, Loss: 2.28245210647583, Neurons: 20, Grad norm: 1.622e-01
# Epoch 039, Loss: 2.28245210647583, Neurons: 20, Grad norm: 1.622e-01
# Epoch 040, Loss: 2.281067132949829, Neurons: 20, Grad norm: 1.658e-01
# Epoch 040, Loss: 2.281067132949829, Neurons: 20, Grad norm: 1.658e-01
# Epoch 041, Loss: 2.2796132564544678, Neurons: 20, Grad norm: 1.693e-01
# Epoch 041, Loss: 2.2796132564544678, Neurons: 20, Grad norm: 1.693e-01
# Epoch 042, Loss: 2.2780890464782715, Neurons: 20, Grad norm: 1.729e-01
# Epoch 042, Loss: 2.2780890464782715, Neurons: 20, Grad norm: 1.729e-01
# Epoch 043, Loss: 2.276493549346924, Neurons: 20, Grad norm: 1.764e-01
# Epoch 043, Loss: 2.276493549346924, Neurons: 20, Grad norm: 1.764e-01
# Epoch 044, Loss: 2.27482533454895, Neurons: 20, Grad norm: 1.799e-01
# Epoch 044, Loss: 2.27482533454895, Neurons: 20, Grad norm: 1.799e-01
# Epoch 045, Loss: 2.2730846405029297, Neurons: 20, Grad norm: 1.833e-01
# Epoch 045, Loss: 2.2730846405029297, Neurons: 20, Grad norm: 1.833e-01
# Epoch 046, Loss: 2.2712690830230713, Neurons: 20, Grad norm: 1.867e-01
# Epoch 046, Loss: 2.2712690830230713, Neurons: 20, Grad norm: 1.867e-01
# Epoch 047, Loss: 2.269378185272217, Neurons: 20, Grad norm: 1.900e-01
# Epoch 047, Loss: 2.269378185272217, Neurons: 20, Grad norm: 1.900e-01
# Epoch 048, Loss: 2.267411708831787, Neurons: 20, Grad norm: 1.933e-01
# Epoch 048, Loss: 2.267411708831787, Neurons: 20, Grad norm: 1.933e-01
# Epoch 049, Loss: 2.265369176864624, Neurons: 20, Grad norm: 1.965e-01
# Epoch 049, Loss: 2.265369176864624, Neurons: 20, Grad norm: 1.965e-01
# Epoch 050, Loss: 2.2632505893707275, Neurons: 20, Grad norm: 1.995e-01
# Epoch 050, Loss: 2.2632505893707275, Neurons: 20, Grad norm: 1.995e-01
# Epoch 051, Loss: 2.2610552310943604, Neurons: 20, Grad norm: 2.026e-01
# Epoch 051, Loss: 2.2610552310943604, Neurons: 20, Grad norm: 2.026e-01
# Epoch 052, Loss: 2.258784294128418, Neurons: 20, Grad norm: 2.055e-01
# Epoch 052, Loss: 2.258784294128418, Neurons: 20, Grad norm: 2.055e-01
# Epoch 053, Loss: 2.2564375400543213, Neurons: 20, Grad norm: 2.083e-01
# Epoch 053, Loss: 2.2564375400543213, Neurons: 20, Grad norm: 2.083e-01
# Epoch 054, Loss: 2.2540156841278076, Neurons: 20, Grad norm: 2.110e-01
# Epoch 054, Loss: 2.2540156841278076, Neurons: 20, Grad norm: 2.110e-01
# Epoch 055, Loss: 2.2515196800231934, Neurons: 20, Grad norm: 2.136e-01
# Epoch 055, Loss: 2.2515196800231934, Neurons: 20, Grad norm: 2.136e-01
# Epoch 056, Loss: 2.248950242996216, Neurons: 20, Grad norm: 2.161e-01
# Epoch 056, Loss: 2.248950242996216, Neurons: 20, Grad norm: 2.161e-01
# Epoch 057, Loss: 2.2463090419769287, Neurons: 20, Grad norm: 2.185e-01
# Epoch 057, Loss: 2.2463090419769287, Neurons: 20, Grad norm: 2.185e-01
# Epoch 058, Loss: 2.2435965538024902, Neurons: 20, Grad norm: 2.208e-01
# Epoch 058, Loss: 2.2435965538024902, Neurons: 20, Grad norm: 2.208e-01
# Epoch 059, Loss: 2.240814208984375, Neurons: 20, Grad norm: 2.230e-01
# Epoch 059, Loss: 2.240814208984375, Neurons: 20, Grad norm: 2.230e-01
# Epoch 060, Loss: 2.2379629611968994, Neurons: 20, Grad norm: 2.251e-01
# Epoch 060, Loss: 2.2379629611968994, Neurons: 20, Grad norm: 2.251e-01
# Epoch 061, Loss: 2.235044002532959, Neurons: 20, Grad norm: 2.270e-01
# Epoch 061, Loss: 2.235044002532959, Neurons: 20, Grad norm: 2.270e-01
# Epoch 062, Loss: 2.23205828666687, Neurons: 20, Grad norm: 2.289e-01
# Epoch 062, Loss: 2.23205828666687, Neurons: 20, Grad norm: 2.289e-01
# Epoch 063, Loss: 2.2290079593658447, Neurons: 20, Grad norm: 2.306e-01
# Epoch 063, Loss: 2.2290079593658447, Neurons: 20, Grad norm: 2.306e-01
# Epoch 064, Loss: 2.225893259048462, Neurons: 20, Grad norm: 2.322e-01
# Epoch 064, Loss: 2.225893259048462, Neurons: 20, Grad norm: 2.322e-01
# Epoch 065, Loss: 2.2227165699005127, Neurons: 20, Grad norm: 2.337e-01
# Epoch 065, Loss: 2.2227165699005127, Neurons: 20, Grad norm: 2.337e-01
# Epoch 066, Loss: 2.2194793224334717, Neurons: 20, Grad norm: 2.351e-01
# Epoch 066, Loss: 2.2194793224334717, Neurons: 20, Grad norm: 2.351e-01
# Epoch 067, Loss: 2.216183662414551, Neurons: 20, Grad norm: 2.364e-01
# Epoch 067, Loss: 2.216183662414551, Neurons: 20, Grad norm: 2.364e-01
# Epoch 068, Loss: 2.21283221244812, Neurons: 20, Grad norm: 2.376e-01
# Epoch 068, Loss: 2.21283221244812, Neurons: 20, Grad norm: 2.376e-01
# Epoch 069, Loss: 2.2094268798828125, Neurons: 20, Grad norm: 2.387e-01
# Epoch 069, Loss: 2.2094268798828125, Neurons: 20, Grad norm: 2.387e-01
# Epoch 070, Loss: 2.205970048904419, Neurons: 20, Grad norm: 2.396e-01
# Epoch 070, Loss: 2.205970048904419, Neurons: 20, Grad norm: 2.396e-01
# Epoch 071, Loss: 2.202465057373047, Neurons: 20, Grad norm: 2.404e-01
# Epoch 071, Loss: 2.202465057373047, Neurons: 20, Grad norm: 2.404e-01
# Epoch 072, Loss: 2.198914051055908, Neurons: 20, Grad norm: 2.412e-01
# Epoch 072, Loss: 2.198914051055908, Neurons: 20, Grad norm: 2.412e-01
# Epoch 073, Loss: 2.1953203678131104, Neurons: 20, Grad norm: 2.418e-01
# Epoch 073, Loss: 2.1953203678131104, Neurons: 20, Grad norm: 2.418e-01
# Epoch 074, Loss: 2.1916871070861816, Neurons: 20, Grad norm: 2.423e-01
# Epoch 074, Loss: 2.1916871070861816, Neurons: 20, Grad norm: 2.423e-01
# Epoch 075, Loss: 2.1880171298980713, Neurons: 20, Grad norm: 2.426e-01
# Epoch 075, Loss: 2.1880171298980713, Neurons: 20, Grad norm: 2.426e-01
# Epoch 076, Loss: 2.1843132972717285, Neurons: 20, Grad norm: 2.429e-01
# Epoch 076, Loss: 2.1843132972717285, Neurons: 20, Grad norm: 2.429e-01
# Epoch 077, Loss: 2.18057918548584, Neurons: 20, Grad norm: 2.431e-01
# Epoch 077, Loss: 2.18057918548584, Neurons: 20, Grad norm: 2.431e-01
# Epoch 078, Loss: 2.1768178939819336, Neurons: 20, Grad norm: 2.432e-01
# Epoch 078, Loss: 2.1768178939819336, Neurons: 20, Grad norm: 2.432e-01
# Epoch 079, Loss: 2.173031806945801, Neurons: 20, Grad norm: 2.431e-01
# Epoch 079, Loss: 2.173031806945801, Neurons: 20, Grad norm: 2.431e-01
# Epoch 080, Loss: 2.1692240238189697, Neurons: 20, Grad norm: 2.430e-01
# Epoch 080, Loss: 2.1692240238189697, Neurons: 20, Grad norm: 2.430e-01
# Epoch 081, Loss: 2.1653976440429688, Neurons: 20, Grad norm: 2.428e-01
# Epoch 081, Loss: 2.1653976440429688, Neurons: 20, Grad norm: 2.428e-01
# Epoch 082, Loss: 2.161555290222168, Neurons: 20, Grad norm: 2.425e-01
# Epoch 082, Loss: 2.161555290222168, Neurons: 20, Grad norm: 2.425e-01
# Epoch 083, Loss: 2.1576998233795166, Neurons: 20, Grad norm: 2.421e-01
# Epoch 083, Loss: 2.1576998233795166, Neurons: 20, Grad norm: 2.421e-01
# Epoch 084, Loss: 2.153832197189331, Neurons: 20, Grad norm: 2.416e-01
# Epoch 084, Loss: 2.153832197189331, Neurons: 20, Grad norm: 2.416e-01
# Epoch 085, Loss: 2.149955987930298, Neurons: 20, Grad norm: 2.411e-01
# Epoch 085, Loss: 2.149955987930298, Neurons: 20, Grad norm: 2.411e-01
# Epoch 086, Loss: 2.1460723876953125, Neurons: 20, Grad norm: 2.405e-01
# Epoch 086, Loss: 2.1460723876953125, Neurons: 20, Grad norm: 2.405e-01
# Epoch 087, Loss: 2.1421847343444824, Neurons: 20, Grad norm: 2.398e-01
# Epoch 087, Loss: 2.1421847343444824, Neurons: 20, Grad norm: 2.398e-01
# Epoch 088, Loss: 2.1382932662963867, Neurons: 20, Grad norm: 2.390e-01
# Epoch 088, Loss: 2.1382932662963867, Neurons: 20, Grad norm: 2.390e-01
# Epoch 089, Loss: 2.134399890899658, Neurons: 20, Grad norm: 2.382e-01
# Epoch 089, Loss: 2.134399890899658, Neurons: 20, Grad norm: 2.382e-01
# Epoch 090, Loss: 2.1305060386657715, Neurons: 20, Grad norm: 2.373e-01
# Epoch 090, Loss: 2.1305060386657715, Neurons: 20, Grad norm: 2.373e-01
# Epoch 091, Loss: 2.1266133785247803, Neurons: 20, Grad norm: 2.364e-01
# Epoch 091, Loss: 2.1266133785247803, Neurons: 20, Grad norm: 2.364e-01
# Epoch 092, Loss: 2.1227238178253174, Neurons: 20, Grad norm: 2.354e-01
# Epoch 092, Loss: 2.1227238178253174, Neurons: 20, Grad norm: 2.354e-01
# Epoch 093, Loss: 2.118838310241699, Neurons: 20, Grad norm: 2.344e-01
# Epoch 093, Loss: 2.118838310241699, Neurons: 20, Grad norm: 2.344e-01
# Epoch 094, Loss: 2.1149582862854004, Neurons: 20, Grad norm: 2.333e-01
# Epoch 094, Loss: 2.1149582862854004, Neurons: 20, Grad norm: 2.333e-01
# Epoch 095, Loss: 2.1110851764678955, Neurons: 20, Grad norm: 2.322e-01
# Epoch 095, Loss: 2.1110851764678955, Neurons: 20, Grad norm: 2.322e-01
# Epoch 096, Loss: 2.107219934463501, Neurons: 20, Grad norm: 2.310e-01
# Epoch 096, Loss: 2.107219934463501, Neurons: 20, Grad norm: 2.310e-01
# Epoch 097, Loss: 2.103364944458008, Neurons: 20, Grad norm: 2.298e-01
# Epoch 097, Loss: 2.103364944458008, Neurons: 20, Grad norm: 2.298e-01
# Epoch 098, Loss: 2.099520683288574, Neurons: 20, Grad norm: 2.286e-01
# Epoch 098, Loss: 2.099520683288574, Neurons: 20, Grad norm: 2.286e-01
# Epoch 099, Loss: 2.095689058303833, Neurons: 20, Grad norm: 2.273e-01
# Epoch 099, Loss: 2.095689058303833, Neurons: 20, Grad norm: 2.273e-01
# Epoch 099, Test loss: 2.0952937602996826, Test accuracy: 0.18300001323223114
# Epoch 099, Test loss: 2.0952937602996826, Test accuracy: 0.18300001323223114
# Added neuron to hidden layer 1 with activation relu
# Added neuron to hidden layer 1 with activation relu
# network shape updated to :[6, 5, 10]
# network shape updated to :[6, 5, 10]
# Check loss updated to 2.0952937602996826 due to addition
# Check loss updated to 2.0952937602996826 due to addition
# Epoch 100, Loss: 2.0999934673309326, Neurons: 21, Grad norm: 2.673e-01
# Epoch 100, Loss: 2.0999934673309326, Neurons: 21, Grad norm: 2.673e-01
# Epoch 101, Loss: 2.0991251468658447, Neurons: 21, Grad norm: 2.660e-01
# Epoch 101, Loss: 2.0991251468658447, Neurons: 21, Grad norm: 2.660e-01
# Epoch 102, Loss: 2.098221778869629, Neurons: 21, Grad norm: 2.647e-01
# Epoch 102, Loss: 2.098221778869629, Neurons: 21, Grad norm: 2.647e-01
# Epoch 103, Loss: 2.0972838401794434, Neurons: 21, Grad norm: 2.634e-01
# Epoch 103, Loss: 2.0972838401794434, Neurons: 21, Grad norm: 2.634e-01
# Epoch 104, Loss: 2.0963134765625, Neurons: 21, Grad norm: 2.618e-01
# Epoch 104, Loss: 2.0963134765625, Neurons: 21, Grad norm: 2.618e-01
# Epoch 105, Loss: 2.0953121185302734, Neurons: 21, Grad norm: 2.602e-01
# Epoch 105, Loss: 2.0953121185302734, Neurons: 21, Grad norm: 2.602e-01
# Epoch 106, Loss: 2.0942821502685547, Neurons: 21, Grad norm: 2.586e-01
# Epoch 106, Loss: 2.0942821502685547, Neurons: 21, Grad norm: 2.586e-01
# Epoch 107, Loss: 2.0932252407073975, Neurons: 21, Grad norm: 2.569e-01
# Epoch 107, Loss: 2.0932252407073975, Neurons: 21, Grad norm: 2.569e-01
# Epoch 108, Loss: 2.092144250869751, Neurons: 21, Grad norm: 2.553e-01
# Epoch 108, Loss: 2.092144250869751, Neurons: 21, Grad norm: 2.553e-01
# Epoch 109, Loss: 2.0910396575927734, Neurons: 21, Grad norm: 2.537e-01
# Epoch 109, Loss: 2.0910396575927734, Neurons: 21, Grad norm: 2.537e-01
# Epoch 110, Loss: 2.0899136066436768, Neurons: 21, Grad norm: 2.519e-01
# Epoch 110, Loss: 2.0899136066436768, Neurons: 21, Grad norm: 2.519e-01
# Epoch 111, Loss: 2.088768482208252, Neurons: 21, Grad norm: 2.502e-01
# Epoch 111, Loss: 2.088768482208252, Neurons: 21, Grad norm: 2.502e-01
# Epoch 112, Loss: 2.087606191635132, Neurons: 21, Grad norm: 2.486e-01
# Epoch 112, Loss: 2.087606191635132, Neurons: 21, Grad norm: 2.486e-01
# Epoch 113, Loss: 2.0864288806915283, Neurons: 21, Grad norm: 2.467e-01
# Epoch 113, Loss: 2.0864288806915283, Neurons: 21, Grad norm: 2.467e-01
# Epoch 114, Loss: 2.0852389335632324, Neurons: 21, Grad norm: 2.451e-01
# Epoch 114, Loss: 2.0852389335632324, Neurons: 21, Grad norm: 2.451e-01
# Epoch 115, Loss: 2.0840375423431396, Neurons: 21, Grad norm: 2.431e-01
# Epoch 115, Loss: 2.0840375423431396, Neurons: 21, Grad norm: 2.431e-01
# Epoch 116, Loss: 2.082825183868408, Neurons: 21, Grad norm: 2.417e-01
# Epoch 116, Loss: 2.082825183868408, Neurons: 21, Grad norm: 2.417e-01
# Epoch 117, Loss: 2.081604480743408, Neurons: 21, Grad norm: 2.401e-01
# Epoch 117, Loss: 2.081604480743408, Neurons: 21, Grad norm: 2.401e-01
# Epoch 118, Loss: 2.0803751945495605, Neurons: 21, Grad norm: 2.385e-01
# Epoch 118, Loss: 2.0803751945495605, Neurons: 21, Grad norm: 2.385e-01
# Epoch 119, Loss: 2.0791375637054443, Neurons: 21, Grad norm: 2.372e-01
# Epoch 119, Loss: 2.0791375637054443, Neurons: 21, Grad norm: 2.372e-01
# Epoch 120, Loss: 2.077892303466797, Neurons: 21, Grad norm: 2.358e-01
# Epoch 120, Loss: 2.077892303466797, Neurons: 21, Grad norm: 2.358e-01
# Epoch 121, Loss: 2.07663893699646, Neurons: 21, Grad norm: 2.343e-01
# Epoch 121, Loss: 2.07663893699646, Neurons: 21, Grad norm: 2.343e-01
# Epoch 122, Loss: 2.0753796100616455, Neurons: 21, Grad norm: 2.330e-01
# Epoch 122, Loss: 2.0753796100616455, Neurons: 21, Grad norm: 2.330e-01
# Epoch 123, Loss: 2.074113368988037, Neurons: 21, Grad norm: 2.317e-01
# Epoch 123, Loss: 2.074113368988037, Neurons: 21, Grad norm: 2.317e-01
# Epoch 124, Loss: 2.0728399753570557, Neurons: 21, Grad norm: 2.305e-01
# Epoch 124, Loss: 2.0728399753570557, Neurons: 21, Grad norm: 2.305e-01
# Epoch 125, Loss: 2.071561098098755, Neurons: 21, Grad norm: 2.293e-01
# Epoch 125, Loss: 2.071561098098755, Neurons: 21, Grad norm: 2.293e-01
# Epoch 126, Loss: 2.0702760219573975, Neurons: 21, Grad norm: 2.282e-01
# Epoch 126, Loss: 2.0702760219573975, Neurons: 21, Grad norm: 2.282e-01
# Epoch 127, Loss: 2.068983793258667, Neurons: 21, Grad norm: 2.270e-01
# Epoch 127, Loss: 2.068983793258667, Neurons: 21, Grad norm: 2.270e-01
# Epoch 128, Loss: 2.067685604095459, Neurons: 21, Grad norm: 2.260e-01
# Epoch 128, Loss: 2.067685604095459, Neurons: 21, Grad norm: 2.260e-01
# Epoch 129, Loss: 2.0663816928863525, Neurons: 21, Grad norm: 2.250e-01
# Epoch 129, Loss: 2.0663816928863525, Neurons: 21, Grad norm: 2.250e-01
# Epoch 130, Loss: 2.0650718212127686, Neurons: 21, Grad norm: 2.240e-01
# Epoch 130, Loss: 2.0650718212127686, Neurons: 21, Grad norm: 2.240e-01
# Epoch 131, Loss: 2.0637564659118652, Neurons: 21, Grad norm: 2.230e-01
# Epoch 131, Loss: 2.0637564659118652, Neurons: 21, Grad norm: 2.230e-01
# Epoch 132, Loss: 2.062434673309326, Neurons: 21, Grad norm: 2.221e-01
# Epoch 132, Loss: 2.062434673309326, Neurons: 21, Grad norm: 2.221e-01
# Epoch 133, Loss: 2.0611069202423096, Neurons: 21, Grad norm: 2.211e-01
# Epoch 133, Loss: 2.0611069202423096, Neurons: 21, Grad norm: 2.211e-01
# Epoch 134, Loss: 2.0597732067108154, Neurons: 21, Grad norm: 2.203e-01
# Epoch 134, Loss: 2.0597732067108154, Neurons: 21, Grad norm: 2.203e-01
# Epoch 135, Loss: 2.05843448638916, Neurons: 21, Grad norm: 2.194e-01
# Epoch 135, Loss: 2.05843448638916, Neurons: 21, Grad norm: 2.194e-01
# Epoch 136, Loss: 2.057088613510132, Neurons: 21, Grad norm: 2.185e-01
# Epoch 136, Loss: 2.057088613510132, Neurons: 21, Grad norm: 2.185e-01
# Epoch 137, Loss: 2.0557374954223633, Neurons: 21, Grad norm: 2.176e-01
# Epoch 137, Loss: 2.0557374954223633, Neurons: 21, Grad norm: 2.176e-01
# Epoch 138, Loss: 2.0543808937072754, Neurons: 21, Grad norm: 2.167e-01
# Epoch 138, Loss: 2.0543808937072754, Neurons: 21, Grad norm: 2.167e-01
# Epoch 139, Loss: 2.0530200004577637, Neurons: 21, Grad norm: 2.158e-01
# Epoch 139, Loss: 2.0530200004577637, Neurons: 21, Grad norm: 2.158e-01
# Epoch 140, Loss: 2.05165433883667, Neurons: 21, Grad norm: 2.150e-01
# Epoch 140, Loss: 2.05165433883667, Neurons: 21, Grad norm: 2.150e-01
# Epoch 141, Loss: 2.0502841472625732, Neurons: 21, Grad norm: 2.142e-01
# Epoch 141, Loss: 2.0502841472625732, Neurons: 21, Grad norm: 2.142e-01
# Epoch 142, Loss: 2.04890775680542, Neurons: 21, Grad norm: 2.133e-01
# Epoch 142, Loss: 2.04890775680542, Neurons: 21, Grad norm: 2.133e-01
# Epoch 143, Loss: 2.047525405883789, Neurons: 21, Grad norm: 2.125e-01
# Epoch 143, Loss: 2.047525405883789, Neurons: 21, Grad norm: 2.125e-01
# Epoch 144, Loss: 2.046138048171997, Neurons: 21, Grad norm: 2.117e-01
# Epoch 144, Loss: 2.046138048171997, Neurons: 21, Grad norm: 2.117e-01
# Epoch 145, Loss: 2.044746160507202, Neurons: 21, Grad norm: 2.108e-01
# Epoch 145, Loss: 2.044746160507202, Neurons: 21, Grad norm: 2.108e-01
# Epoch 146, Loss: 2.043349266052246, Neurons: 21, Grad norm: 2.100e-01
# Epoch 146, Loss: 2.043349266052246, Neurons: 21, Grad norm: 2.100e-01
# Epoch 147, Loss: 2.041948080062866, Neurons: 21, Grad norm: 2.092e-01
# Epoch 147, Loss: 2.041948080062866, Neurons: 21, Grad norm: 2.092e-01
# Epoch 148, Loss: 2.0405423641204834, Neurons: 21, Grad norm: 2.084e-01
# Epoch 148, Loss: 2.0405423641204834, Neurons: 21, Grad norm: 2.084e-01
# Epoch 149, Loss: 2.039132833480835, Neurons: 21, Grad norm: 2.076e-01
# Epoch 149, Loss: 2.039132833480835, Neurons: 21, Grad norm: 2.076e-01
# Epoch 150, Loss: 2.037719488143921, Neurons: 21, Grad norm: 2.067e-01
# Epoch 150, Loss: 2.037719488143921, Neurons: 21, Grad norm: 2.067e-01
# Epoch 151, Loss: 2.0363028049468994, Neurons: 21, Grad norm: 2.059e-01
# Epoch 151, Loss: 2.0363028049468994, Neurons: 21, Grad norm: 2.059e-01
# Epoch 152, Loss: 2.034883499145508, Neurons: 21, Grad norm: 2.049e-01
# Epoch 152, Loss: 2.034883499145508, Neurons: 21, Grad norm: 2.049e-01
# Epoch 153, Loss: 2.0334620475769043, Neurons: 21, Grad norm: 2.041e-01
# Epoch 153, Loss: 2.0334620475769043, Neurons: 21, Grad norm: 2.041e-01
# Epoch 154, Loss: 2.0320382118225098, Neurons: 21, Grad norm: 2.033e-01
# Epoch 154, Loss: 2.0320382118225098, Neurons: 21, Grad norm: 2.033e-01
# Epoch 155, Loss: 2.030611991882324, Neurons: 21, Grad norm: 2.025e-01
# Epoch 155, Loss: 2.030611991882324, Neurons: 21, Grad norm: 2.025e-01
# Epoch 156, Loss: 2.0291833877563477, Neurons: 21, Grad norm: 2.017e-01
# Epoch 156, Loss: 2.0291833877563477, Neurons: 21, Grad norm: 2.017e-01
# Epoch 157, Loss: 2.027752637863159, Neurons: 21, Grad norm: 2.008e-01
# Epoch 157, Loss: 2.027752637863159, Neurons: 21, Grad norm: 2.008e-01
# Epoch 158, Loss: 2.026320695877075, Neurons: 21, Grad norm: 1.999e-01
# Epoch 158, Loss: 2.026320695877075, Neurons: 21, Grad norm: 1.999e-01
# Epoch 159, Loss: 2.024888515472412, Neurons: 21, Grad norm: 1.991e-01
# Epoch 159, Loss: 2.024888515472412, Neurons: 21, Grad norm: 1.991e-01
# Epoch 160, Loss: 2.0234553813934326, Neurons: 21, Grad norm: 1.982e-01
# Epoch 160, Loss: 2.0234553813934326, Neurons: 21, Grad norm: 1.982e-01
# Epoch 161, Loss: 2.022022247314453, Neurons: 21, Grad norm: 1.973e-01
# Epoch 161, Loss: 2.022022247314453, Neurons: 21, Grad norm: 1.973e-01
# Epoch 162, Loss: 2.0205905437469482, Neurons: 21, Grad norm: 1.965e-01
# Epoch 162, Loss: 2.0205905437469482, Neurons: 21, Grad norm: 1.965e-01
# Epoch 163, Loss: 2.019158363342285, Neurons: 21, Grad norm: 1.955e-01
# Epoch 163, Loss: 2.019158363342285, Neurons: 21, Grad norm: 1.955e-01
# Epoch 164, Loss: 2.0177268981933594, Neurons: 21, Grad norm: 1.945e-01
# Epoch 164, Loss: 2.0177268981933594, Neurons: 21, Grad norm: 1.945e-01
# Epoch 165, Loss: 2.016298294067383, Neurons: 21, Grad norm: 1.936e-01
# Epoch 165, Loss: 2.016298294067383, Neurons: 21, Grad norm: 1.936e-01
# Epoch 166, Loss: 2.0148725509643555, Neurons: 21, Grad norm: 1.927e-01
# Epoch 166, Loss: 2.0148725509643555, Neurons: 21, Grad norm: 1.927e-01
# Epoch 167, Loss: 2.013450860977173, Neurons: 21, Grad norm: 1.919e-01
# Epoch 167, Loss: 2.013450860977173, Neurons: 21, Grad norm: 1.919e-01
# Epoch 168, Loss: 2.012031078338623, Neurons: 21, Grad norm: 1.909e-01
# Epoch 168, Loss: 2.012031078338623, Neurons: 21, Grad norm: 1.909e-01
# Epoch 169, Loss: 2.0106141567230225, Neurons: 21, Grad norm: 1.900e-01
# Epoch 169, Loss: 2.0106141567230225, Neurons: 21, Grad norm: 1.900e-01
# Epoch 170, Loss: 2.0092005729675293, Neurons: 21, Grad norm: 1.891e-01
# Epoch 170, Loss: 2.0092005729675293, Neurons: 21, Grad norm: 1.891e-01
# Epoch 171, Loss: 2.0077919960021973, Neurons: 21, Grad norm: 1.881e-01
# Epoch 171, Loss: 2.0077919960021973, Neurons: 21, Grad norm: 1.881e-01
# Epoch 172, Loss: 2.006387948989868, Neurons: 21, Grad norm: 1.871e-01
# Epoch 172, Loss: 2.006387948989868, Neurons: 21, Grad norm: 1.871e-01
# Epoch 173, Loss: 2.0049898624420166, Neurons: 21, Grad norm: 1.861e-01
# Epoch 173, Loss: 2.0049898624420166, Neurons: 21, Grad norm: 1.861e-01
# Epoch 174, Loss: 2.0035996437072754, Neurons: 21, Grad norm: 1.850e-01
# Epoch 174, Loss: 2.0035996437072754, Neurons: 21, Grad norm: 1.850e-01
# Epoch 175, Loss: 2.002218008041382, Neurons: 21, Grad norm: 1.839e-01
# Epoch 175, Loss: 2.002218008041382, Neurons: 21, Grad norm: 1.839e-01
# Epoch 176, Loss: 2.0008444786071777, Neurons: 21, Grad norm: 1.828e-01
# Epoch 176, Loss: 2.0008444786071777, Neurons: 21, Grad norm: 1.828e-01
# Epoch 177, Loss: 1.9994810819625854, Neurons: 21, Grad norm: 1.817e-01
# Epoch 177, Loss: 1.9994810819625854, Neurons: 21, Grad norm: 1.817e-01
# Epoch 178, Loss: 1.998125672340393, Neurons: 21, Grad norm: 1.806e-01
# Epoch 178, Loss: 1.998125672340393, Neurons: 21, Grad norm: 1.806e-01
# Epoch 179, Loss: 1.9967806339263916, Neurons: 21, Grad norm: 1.795e-01
# Epoch 179, Loss: 1.9967806339263916, Neurons: 21, Grad norm: 1.795e-01
# Epoch 180, Loss: 1.9954458475112915, Neurons: 21, Grad norm: 1.783e-01
# Epoch 180, Loss: 1.9954458475112915, Neurons: 21, Grad norm: 1.783e-01
# Epoch 181, Loss: 1.9941215515136719, Neurons: 21, Grad norm: 1.772e-01
# Epoch 181, Loss: 1.9941215515136719, Neurons: 21, Grad norm: 1.772e-01
# Epoch 182, Loss: 1.99280846118927, Neurons: 21, Grad norm: 1.760e-01
# Epoch 182, Loss: 1.99280846118927, Neurons: 21, Grad norm: 1.760e-01
# Epoch 200, Loss: 1.9710705280303955, Neurons: 21, Grad norm: 1.546e-01
# Epoch 200, Loss: 1.9710705280303955, Neurons: 21, Grad norm: 1.546e-01
# Epoch 201, Loss: 1.9699718952178955, Neurons: 21, Grad norm: 1.534e-01
# Epoch 201, Loss: 1.9699718952178955, Neurons: 21, Grad norm: 1.534e-01
# Epoch 202, Loss: 1.9688845872879028, Neurons: 21, Grad norm: 1.523e-01
# Epoch 202, Loss: 1.9688845872879028, Neurons: 21, Grad norm: 1.523e-01
# Epoch 203, Loss: 1.9678089618682861, Neurons: 21, Grad norm: 1.511e-01
# Epoch 203, Loss: 1.9678089618682861, Neurons: 21, Grad norm: 1.511e-01
# Epoch 204, Loss: 1.96674382686615, Neurons: 21, Grad norm: 1.500e-01
# Epoch 204, Loss: 1.96674382686615, Neurons: 21, Grad norm: 1.500e-01
# Epoch 205, Loss: 1.965689778327942, Neurons: 21, Grad norm: 1.488e-01
# Epoch 205, Loss: 1.965689778327942, Neurons: 21, Grad norm: 1.488e-01
# Epoch 206, Loss: 1.9646470546722412, Neurons: 21, Grad norm: 1.477e-01
# Epoch 206, Loss: 1.9646470546722412, Neurons: 21, Grad norm: 1.477e-01
# Epoch 207, Loss: 1.9636149406433105, Neurons: 21, Grad norm: 1.465e-01
# Epoch 207, Loss: 1.9636149406433105, Neurons: 21, Grad norm: 1.465e-01
# Epoch 208, Loss: 1.9625937938690186, Neurons: 21, Grad norm: 1.453e-01
# Epoch 208, Loss: 1.9625937938690186, Neurons: 21, Grad norm: 1.453e-01
# Epoch 209, Loss: 1.9615836143493652, Neurons: 21, Grad norm: 1.442e-01
# Epoch 209, Loss: 1.9615836143493652, Neurons: 21, Grad norm: 1.442e-01
# Epoch 210, Loss: 1.960584282875061, Neurons: 21, Grad norm: 1.431e-01
# Epoch 210, Loss: 1.960584282875061, Neurons: 21, Grad norm: 1.431e-01
# Epoch 211, Loss: 1.959595799446106, Neurons: 21, Grad norm: 1.420e-01
# Epoch 211, Loss: 1.959595799446106, Neurons: 21, Grad norm: 1.420e-01
# Epoch 212, Loss: 1.958617925643921, Neurons: 21, Grad norm: 1.409e-01
# Epoch 212, Loss: 1.958617925643921, Neurons: 21, Grad norm: 1.409e-01
# Epoch 213, Loss: 1.9576503038406372, Neurons: 21, Grad norm: 1.398e-01
# Epoch 213, Loss: 1.9576503038406372, Neurons: 21, Grad norm: 1.398e-01
# Epoch 214, Loss: 1.9566932916641235, Neurons: 21, Grad norm: 1.388e-01
# Epoch 214, Loss: 1.9566932916641235, Neurons: 21, Grad norm: 1.388e-01
# Epoch 215, Loss: 1.9557461738586426, Neurons: 21, Grad norm: 1.377e-01
# Epoch 215, Loss: 1.9557461738586426, Neurons: 21, Grad norm: 1.377e-01
# Epoch 216, Loss: 1.9548089504241943, Neurons: 21, Grad norm: 1.366e-01
# Epoch 216, Loss: 1.9548089504241943, Neurons: 21, Grad norm: 1.366e-01
# Epoch 217, Loss: 1.9538819789886475, Neurons: 21, Grad norm: 1.355e-01
# Epoch 323, Loss: 1.894839882850647, Neurons: 21, Grad norm: 6.724e-02
# Epoch 323, Loss: 1.894839882850647, Neurons: 21, Grad norm: 6.724e-02
# Epoch 324, Loss: 1.8945033550262451, Neurons: 21, Grad norm: 6.692e-02
# Epoch 324, Loss: 1.8945033550262451, Neurons: 21, Grad norm: 6.692e-02
# Epoch 325, Loss: 1.8941688537597656, Neurons: 21, Grad norm: 6.659e-02
# Epoch 325, Loss: 1.8941688537597656, Neurons: 21, Grad norm: 6.659e-02
# Epoch 326, Loss: 1.893836498260498, Neurons: 21, Grad norm: 6.627e-02
# Epoch 326, Loss: 1.893836498260498, Neurons: 21, Grad norm: 6.627e-02
# Epoch 327, Loss: 1.8935060501098633, Neurons: 21, Grad norm: 6.595e-02
# Epoch 327, Loss: 1.8935060501098633, Neurons: 21, Grad norm: 6.595e-02
# Epoch 328, Loss: 1.89317786693573, Neurons: 21, Grad norm: 6.564e-02
# Epoch 328, Loss: 1.89317786693573, Neurons: 21, Grad norm: 6.564e-02
# Epoch 329, Loss: 1.89285147190094, Neurons: 21, Grad norm: 6.532e-02
# Epoch 329, Loss: 1.89285147190094, Neurons: 21, Grad norm: 6.532e-02
# Epoch 330, Loss: 1.8925272226333618, Neurons: 21, Grad norm: 6.502e-02
# Epoch 330, Loss: 1.8925272226333618, Neurons: 21, Grad norm: 6.502e-02
# Epoch 331, Loss: 1.8922048807144165, Neurons: 21, Grad norm: 6.471e-02
# Epoch 331, Loss: 1.8922048807144165, Neurons: 21, Grad norm: 6.471e-02
# Epoch 332, Loss: 1.891884446144104, Neurons: 21, Grad norm: 6.440e-02
# Epoch 332, Loss: 1.891884446144104, Neurons: 21, Grad norm: 6.440e-02
# Epoch 333, Loss: 1.8915661573410034, Neurons: 21, Grad norm: 6.411e-02
# Epoch 333, Loss: 1.8915661573410034, Neurons: 21, Grad norm: 6.411e-02
# Epoch 334, Loss: 1.891249656677246, Neurons: 21, Grad norm: 6.381e-02
# ...
# Epoch 2390, Loss: 1.383811116218567, Neurons: 25, Grad norm: 1.956e-02
# Epoch 2390, Loss: 1.383811116218567, Neurons: 25, Grad norm: 1.956e-02
# Epoch 2391, Loss: 1.3836803436279297, Neurons: 25, Grad norm: 1.976e-02
# Epoch 2391, Loss: 1.3836803436279297, Neurons: 25, Grad norm: 1.976e-02
# Epoch 2392, Loss: 1.3835495710372925, Neurons: 25, Grad norm: 1.944e-02
# Epoch 2392, Loss: 1.3835495710372925, Neurons: 25, Grad norm: 1.944e-02
# Epoch 2393, Loss: 1.3834185600280762, Neurons: 25, Grad norm: 1.954e-02
# Epoch 2393, Loss: 1.3834185600280762, Neurons: 25, Grad norm: 1.954e-02
# Epoch 2394, Loss: 1.3832876682281494, Neurons: 25, Grad norm: 1.958e-02
# Epoch 2394, Loss: 1.3832876682281494, Neurons: 25, Grad norm: 1.958e-02
# Epoch 2395, Loss: 1.3831571340560913, Neurons: 25, Grad norm: 1.950e-02
# Epoch 2395, Loss: 1.3831571340560913, Neurons: 25, Grad norm: 1.950e-02
# Epoch 2396, Loss: 1.3830270767211914, Neurons: 25, Grad norm: 1.929e-02
# Epoch 2396, Loss: 1.3830270767211914, Neurons: 25, Grad norm: 1.929e-02
# Epoch 2397, Loss: 1.3828974962234497, Neurons: 25, Grad norm: 1.890e-02
# Epoch 2397, Loss: 1.3828974962234497, Neurons: 25, Grad norm: 1.890e-02
# Epoch 2398, Loss: 1.382767677307129, Neurons: 25, Grad norm: 1.909e-02
# Epoch 2398, Loss: 1.382767677307129, Neurons: 25, Grad norm: 1.909e-02
# Epoch 2399, Loss: 1.3826380968093872, Neurons: 25, Grad norm: 1.929e-02
# Epoch 2399, Loss: 1.3826380968093872, Neurons: 25, Grad norm: 1.929e-02
# Epoch 2399, Test loss: 1.4204024076461792, Test accuracy: 0.43575000762939453
# Epoch 2399, Test loss: 1.4204024076461792, Test accuracy: 0.43575000762939453
# Epoch 2400, Loss: 1.382508635520935, Neurons: 25, Grad norm: 1.905e-02
# Epoch 2400, Loss: 1.382508635520935, Neurons: 25, Grad norm: 1.905e-02
# Epoch 2401, Loss: 1.3823792934417725, Neurons: 25, Grad norm: 1.921e-02
# Epoch 2401, Loss: 1.3823792934417725, Neurons: 25, Grad norm: 1.921e-02
# Epoch 2402, Loss: 1.382250189781189, Neurons: 25, Grad norm: 1.943e-02
# Epoch 2402, Loss: 1.382250189781189, Neurons: 25, Grad norm: 1.943e-02
# Epoch 2403, Loss: 1.3821204900741577, Neurons: 25, Grad norm: 1.934e-02
# Epoch 2403, Loss: 1.3821204900741577, Neurons: 25, Grad norm: 1.934e-02
# Epoch 2404, Loss: 1.3819905519485474, Neurons: 25, Grad norm: 1.935e-02
# Epoch 2404, Loss: 1.3819905519485474, Neurons: 25, Grad norm: 1.935e-02
# Epoch 2405, Loss: 1.3818598985671997, Neurons: 25, Grad norm: 1.915e-02
# Epoch 2405, Loss: 1.3818598985671997, Neurons: 25, Grad norm: 1.915e-02
# Epoch 2406, Loss: 1.3817287683486938, Neurons: 25, Grad norm: 1.898e-02
# Epoch 2406, Loss: 1.3817287683486938, Neurons: 25, Grad norm: 1.898e-02
# Epoch 2407, Loss: 1.3815979957580566, Neurons: 25, Grad norm: 1.946e-02
# Epoch 2407, Loss: 1.3815979957580566, Neurons: 25, Grad norm: 1.946e-02
# Epoch 2408, Loss: 1.3814668655395508, Neurons: 25, Grad norm: 1.942e-02
# Epoch 2408, Loss: 1.3814668655395508, Neurons: 25, Grad norm: 1.942e-02
# Epoch 2409, Loss: 1.3813351392745972, Neurons: 25, Grad norm: 1.971e-02
# Epoch 2409, Loss: 1.3813351392745972, Neurons: 25, Grad norm: 1.971e-02
# Epoch 2410, Loss: 1.3812026977539062, Neurons: 25, Grad norm: 1.970e-02
# Epoch 2410, Loss: 1.3812026977539062, Neurons: 25, Grad norm: 1.970e-02
# Epoch 2411, Loss: 1.3810696601867676, Neurons: 25, Grad norm: 1.976e-02
# Epoch 2411, Loss: 1.3810696601867676, Neurons: 25, Grad norm: 1.976e-02
# Epoch 2412, Loss: 1.3809373378753662, Neurons: 25, Grad norm: 1.949e-02
# Epoch 2412, Loss: 1.3809373378753662, Neurons: 25, Grad norm: 1.949e-02
# Epoch 2413, Loss: 1.3808045387268066, Neurons: 25, Grad norm: 1.932e-02
# Epoch 2413, Loss: 1.3808045387268066, Neurons: 25, Grad norm: 1.932e-02
# Epoch 2414, Loss: 1.3806716203689575, Neurons: 25, Grad norm: 1.930e-02
# Epoch 2414, Loss: 1.3806716203689575, Neurons: 25, Grad norm: 1.930e-02
# Epoch 2415, Loss: 1.3805385828018188, Neurons: 25, Grad norm: 1.953e-02
# Epoch 2415, Loss: 1.3805385828018188, Neurons: 25, Grad norm: 1.953e-02
# Epoch 2416, Loss: 1.3804054260253906, Neurons: 25, Grad norm: 1.938e-02
# Epoch 2416, Loss: 1.3804054260253906, Neurons: 25, Grad norm: 1.938e-02
# Epoch 2417, Loss: 1.3802719116210938, Neurons: 25, Grad norm: 1.960e-02
# Epoch 2417, Loss: 1.3802719116210938, Neurons: 25, Grad norm: 1.960e-02
# Epoch 2418, Loss: 1.3801379203796387, Neurons: 25, Grad norm: 1.980e-02
# Epoch 2418, Loss: 1.3801379203796387, Neurons: 25, Grad norm: 1.980e-02
# Epoch 2419, Loss: 1.3800047636032104, Neurons: 25, Grad norm: 2.014e-02
# Epoch 2419, Loss: 1.3800047636032104, Neurons: 25, Grad norm: 2.014e-02
# Epoch 2420, Loss: 1.379870057106018, Neurons: 25, Grad norm: 1.965e-02
# Epoch 2420, Loss: 1.379870057106018, Neurons: 25, Grad norm: 1.965e-02
# Epoch 2421, Loss: 1.379733681678772, Neurons: 25, Grad norm: 1.946e-02
# Epoch 2421, Loss: 1.379733681678772, Neurons: 25, Grad norm: 1.946e-02
# Epoch 2422, Loss: 1.3795980215072632, Neurons: 25, Grad norm: 2.022e-02
# Epoch 2422, Loss: 1.3795980215072632, Neurons: 25, Grad norm: 2.022e-02
# Epoch 2423, Loss: 1.379462480545044, Neurons: 25, Grad norm: 2.055e-02
# Epoch 2423, Loss: 1.379462480545044, Neurons: 25, Grad norm: 2.055e-02
# Epoch 2424, Loss: 1.379326343536377, Neurons: 25, Grad norm: 2.008e-02
# Epoch 2424, Loss: 1.379326343536377, Neurons: 25, Grad norm: 2.008e-02
# Epoch 2425, Loss: 1.379189372062683, Neurons: 25, Grad norm: 1.984e-02
# Epoch 2425, Loss: 1.379189372062683, Neurons: 25, Grad norm: 1.984e-02
# Epoch 2426, Loss: 1.3790522813796997, Neurons: 25, Grad norm: 2.011e-02
# Epoch 2426, Loss: 1.3790522813796997, Neurons: 25, Grad norm: 2.011e-02
# Epoch 2427, Loss: 1.378914713859558, Neurons: 25, Grad norm: 2.014e-02
# Epoch 2427, Loss: 1.378914713859558, Neurons: 25, Grad norm: 2.014e-02
# Epoch 2428, Loss: 1.3787761926651, Neurons: 25, Grad norm: 2.052e-02
# Epoch 2428, Loss: 1.3787761926651, Neurons: 25, Grad norm: 2.052e-02
# Epoch 2429, Loss: 1.3786370754241943, Neurons: 25, Grad norm: 2.091e-02
# Epoch 2429, Loss: 1.3786370754241943, Neurons: 25, Grad norm: 2.091e-02
# Epoch 2430, Loss: 1.3784968852996826, Neurons: 25, Grad norm: 2.070e-02
# Epoch 2430, Loss: 1.3784968852996826, Neurons: 25, Grad norm: 2.070e-02
# Epoch 2431, Loss: 1.3783570528030396, Neurons: 25, Grad norm: 2.012e-02
# Epoch 2431, Loss: 1.3783570528030396, Neurons: 25, Grad norm: 2.012e-02
# Epoch 2432, Loss: 1.3782168626785278, Neurons: 25, Grad norm: 2.012e-02
# Epoch 2432, Loss: 1.3782168626785278, Neurons: 25, Grad norm: 2.012e-02
# Epoch 2433, Loss: 1.3780783414840698, Neurons: 25, Grad norm: 2.147e-02
# Epoch 2433, Loss: 1.3780783414840698, Neurons: 25, Grad norm: 2.147e-02
# Epoch 2434, Loss: 1.3779398202896118, Neurons: 25, Grad norm: 2.120e-02
# Epoch 2434, Loss: 1.3779398202896118, Neurons: 25, Grad norm: 2.120e-02
# Epoch 2435, Loss: 1.3777999877929688, Neurons: 25, Grad norm: 2.018e-02
# Epoch 2435, Loss: 1.3777999877929688, Neurons: 25, Grad norm: 2.018e-02
# Epoch 2436, Loss: 1.3776594400405884, Neurons: 25, Grad norm: 2.035e-02
# Epoch 2436, Loss: 1.3776594400405884, Neurons: 25, Grad norm: 2.035e-02
# Epoch 2437, Loss: 1.3775193691253662, Neurons: 25, Grad norm: 2.184e-02
# Epoch 2437, Loss: 1.3775193691253662, Neurons: 25, Grad norm: 2.184e-02
# Epoch 2438, Loss: 1.3773787021636963, Neurons: 25, Grad norm: 2.156e-02
# Epoch 2438, Loss: 1.3773787021636963, Neurons: 25, Grad norm: 2.156e-02
# Epoch 2439, Loss: 1.377237319946289, Neurons: 25, Grad norm: 2.018e-02
# Epoch 2439, Loss: 1.377237319946289, Neurons: 25, Grad norm: 2.018e-02
# Epoch 2440, Loss: 1.3770955801010132, Neurons: 25, Grad norm: 2.031e-02
# Epoch 2440, Loss: 1.3770955801010132, Neurons: 25, Grad norm: 2.031e-02
# Epoch 2441, Loss: 1.3769537210464478, Neurons: 25, Grad norm: 2.086e-02
# Epoch 2441, Loss: 1.3769537210464478, Neurons: 25, Grad norm: 2.086e-02
# Epoch 2442, Loss: 1.376810908317566, Neurons: 25, Grad norm: 2.082e-02
# Epoch 2442, Loss: 1.376810908317566, Neurons: 25, Grad norm: 2.082e-02
# Epoch 2443, Loss: 1.3766670227050781, Neurons: 25, Grad norm: 1.995e-02
# Epoch 2443, Loss: 1.3766670227050781, Neurons: 25, Grad norm: 1.995e-02
# Epoch 2444, Loss: 1.3765239715576172, Neurons: 25, Grad norm: 2.059e-02
# Epoch 2444, Loss: 1.3765239715576172, Neurons: 25, Grad norm: 2.059e-02
# Epoch 2445, Loss: 1.3763809204101562, Neurons: 25, Grad norm: 2.149e-02
# Epoch 2445, Loss: 1.3763809204101562, Neurons: 25, Grad norm: 2.149e-02
# Epoch 2446, Loss: 1.3762377500534058, Neurons: 25, Grad norm: 2.170e-02
# Epoch 2446, Loss: 1.3762377500534058, Neurons: 25, Grad norm: 2.170e-02
# Epoch 2447, Loss: 1.376095175743103, Neurons: 25, Grad norm: 2.164e-02
# Epoch 2499, Loss: 1.3677607774734497, Neurons: 25, Grad norm: 2.145e-02

# %%
np.savetxt(f"{out_folder}/neurons.txt", node_history)
np.savetxt(f"{out_folder}/train_loss.txt", train_loss_history)
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/test_accuracy.txt", accuracy_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)
np.savetxt(f"{out_folder}/add_prob.txt", add_prob_history)
np.savetxt(f"{out_folder}/remove_prob.txt", remove_prob_history)

# %%
# save the update history
with open(f"{out_folder}/update_history.txt", "w") as f:
    for item in update_history:
        f.write(f"{item}\n")

# %% [markdown]
# ### evaluation

# %%
y_pred = jax.nn.softmax(jax.vmap(mlp)(x_test))
y_pred = np.argmax(y_pred, axis=-1)

confusion_matrix = np.zeros((10,10))
for true, pred in zip(y_test, y_pred):
    confusion_matrix[true, pred] += 1

np.savetxt(f"{out_folder}/confusion_matrix.txt", confusion_matrix)
fig, ax = plt.subplots(figsize=[10,10])
cax = ax.matshow(confusion_matrix, cmap='gray')
fig.colorbar(cax, label="Number of predictions")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion matrix")
plt.savefig(f"{fig_folder}/confusion_matrix.png")
plt.savefig(f"{fig_folder}/confusion_matrix.pdf")
plt.savefig(f"{fig_folder}/confusion_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"confusion matrix": wandb.Image(plt, caption="confusion matrix")})

# %%
update_history
# Out:
# [(99,
#   20,
#   Array(2.095689, dtype=float32),
#   Array(2.0952938, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (699,
#   21,
#   Array(1.7692972, dtype=float32),
#   Array(1.7892777, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (799,
#   22,
#   Array(1.7316098, dtype=float32),
#   Array(1.7520139, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1399,
#   23,
#   Array(1.4867436, dtype=float32),
#   Array(1.5133106, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (1999,
#   24,
#   Array(1.4253204, dtype=float32),
#   Array(1.4544898, dtype=float32),
#   'sin',
#   Array(1, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.pdf")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.svg", format='svg', bbox_inches='tight')
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum([mlp.input_size] + mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')


plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.savefig(f"{fig_folder}/final_weight_distribution.pdf")
plt.savefig(f"{fig_folder}/final_weight_distribution.png")
plt.savefig(f"{fig_folder}/final_weight_distribution.svg", format='svg', bbox_inches='tight')
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)
accuracy_epochs, test_accuracy = zip(*accuracy_history)
add_epochs, add_prob = zip(*add_prob_history)
remove_epochs, remove_prob = zip(*remove_prob_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
plt.savefig(f"{fig_folder}/loss_curve.pdf")
plt.savefig(f"{fig_folder}/loss_curve.svg", format='svg', bbox_inches='tight')
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")
plt.savefig(f"{fig_folder}/loss_curve_loglog.pdf")
plt.savefig(f"{fig_folder}/loss_curve_loglog.svg", format='svg', bbox_inches='tight')

# %%
plt.plot(accuracy_epochs, test_accuracy, "*")
plt.xlabel("Epochs")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy")
plt.savefig(f"{fig_folder}/test_accuracy.png")
plt.savefig(f"{fig_folder}/test_accuracy.pdf")
plt.savefig(f"{fig_folder}/test_accuracy.svg", format='svg', bbox_inches='tight')

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
plt.savefig(f"{fig_folder}/final_graph.pdf")
plt.savefig(f"{fig_folder}/final_graph.svg", format='svg', bbox_inches='tight')
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
# plot add and remove probablities with test loss and number of neurons
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(test_epochs, test_loss, "-.", color=color, label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)

ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(add_epochs, add_prob, ".", color=color, alpha = 0.6, label="Add Probability")
ax3.plot(remove_epochs, remove_prob, ".", color="orange", alpha = 0.6, label="Remove Probability")
ax3.set_ylabel('Probability', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.spines['right'].set_color(color)
ax3.set_ylim(0,1)
ax3.legend()

plt.suptitle(f"Heterogenous {act_string} Neural Network with L_0={L_0}")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_prob.png")
plt.savefig(f"{fig_folder}/loss_curve_prob.pdf")
plt.savefig(f"{fig_folder}/loss_curve_prob.svg", format='svg', bbox_inches='tight')

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/time_curve.png")
plt.savefig(f"{fig_folder}/time_curve.pdf")
plt.savefig(f"{fig_folder}/time_curve.svg", format='svg', bbox_inches='tight')
