# %% [markdown]
# # Test loss based strategy for Polynomial prediction with a homogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "18_homo_poly_test_strat.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="18_homo_poly_test_strat.ipynb"
# env: WANDB_SILENT=True
# env: XLA_PYTHON_CLIENT_MEM_FRACTION=0.3

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

import os
import sys
import logging
from tqdm.notebook import trange
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
# Normalize and shift the colormap to center 0
class MidpointNormalize(Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %% [markdown]
# ### config

# %%
input_size = 1
hidden_sizes = [10, 10] 
output_size = 1
initial_activation_list = [sin]
activation_list = [sin]
bias = False
num_epochs = 3000
intervene_every = 50
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
jax.config.update("jax_enable_x64", True)
# jax.config.update('jax_platform_name', 'cpu')
Description = f"Homo_{act_string}_poly_test_strat__no_bias_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../../figures/{Description}"
out_folder = f"../../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 4
# Description: Homo_sin_poly_test_strat__no_bias_10_10_3000_50_0.0001_0
# jax backend: gpu
# jax devices: [cuda(id=0), cuda(id=1), cuda(id=2), cuda(id=3)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
def poly(x):
    """
    7th degree polynomial to predict
    """
    return (x - 3)*(x - 2)*(x - 1)*x*(x + 1)*(x + 2)*(x + 3)

# %%
x = jnp.linspace(-3, 3, n_samples).reshape(-1, 1)
y = poly(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.2, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha = 0.2, label=f"test:{len(x_test)}")
plt.legend()
plt.suptitle("Data")
# Out:
# Text(0.5, 0.98, 'Data')

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0]

# %%
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optax.adabelief(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []

grad_norm_threshold = 1e-5

# %%
for epoch in range(num_epochs):
    train_loss, mlp, opt_state = train_step(mlp, x, y, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x, y)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold:
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    # key, add_key, sub_key = jax.random.split(key,3)

    if (epoch + 1) % intervene_every == 0 or grad_norm_val < grad_norm_threshold:
        test_loss = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}")
        wandb.log({"test_loss": test_loss.item()})
        test_loss_history.append((epoch,test_loss))
    
    

    if grad_norm_val < grad_norm_threshold/10:
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break
        
        

    # Dynamically add or remove neurons
    # if (epoch + 1) % add_node_every == 0:

    #     #add criterion
    #     if len(Update_history) == 0 or Update_history[-1][2] > loss or (Update_history[-1][3] == "removed" and Update_history[-2][3] == "removed" ):
    #         # if no previous addition or last addition was rejected, add a neuron
    #         # if last addition was accepted, add a neuron
    #         # if two removals in a row, add a neuron
    #         add_key, act_key = jax.random.split(add_key)
    #         activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
    #         layers = len(mlp.get_shape()) - 1
    #         layer = jax.random.randint(act_key, (1,), 0, layers)[0]
    #         mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
    #         opt_state = initialize_optimizer_state(mlp, opt)

    #         Update_history.append((epoch, n_neurons, loss, activation.__name__, layer))
    #         logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
    #         wandb.log({"added neuron": activation.__name__})
    #         logging.info(f"network shape updated to :{mlp.get_shape()}")
        
    #     # remove criteria
    #     elif (Update_history[-1][3] == "removed" and Update_history[-2][2] < loss) or \
    #         (Update_history[-1][3] != "removed" and Update_history[-1][2] < loss):
    #         # if last addition was removed check loss against value before that
    #         # if last addition was accepted, check loss against it
    #         # if loss doesn't improve, reject it
    #         layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
    #         layer = Update_history[-1][4]
    #         neuron_idx = len(mlp.layers[layer]) -1

    #         if len(mlp.layers[layer]) <= 1:
    #             logging.info(f"Cannot remove neuron from layer {layer+1}, only one neuron left")
    #             Update_history.append((epoch, n_neurons, loss, "single_node_layer", layer))
    #             continue

    #         mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
    #         opt_state = initialize_optimizer_state(mlp, opt)
    #         Update_history.append((epoch, n_neurons, loss, "removed", layer))

    #         logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
    #         wandb.log({"removed neuron": neuron_idx})
    #         logging.info(f"network shape updated to :{mlp.get_shape()}")
        
        
    # if loss < threshold:
    #     # if loss is below threshold, stop training
    #     logging.info(f"Threshold reached, stopping training at epoch {epoch}")
    #     wandb.log({"threshold reached": epoch})
    #     break
# Out:
# Epoch 000, Loss: 1512.7886530200146, Neurons: 21
# Epoch 001, Loss: 1512.654039728438, Neurons: 21
# Epoch 002, Loss: 1512.512562474772, Neurons: 21
# Epoch 003, Loss: 1512.3641449697488, Neurons: 21
# Epoch 004, Loss: 1512.2087303454612, Neurons: 21
# Epoch 005, Loss: 1512.0462805164916, Neurons: 21
# Epoch 006, Loss: 1511.8767750522552, Neurons: 21
# Epoch 007, Loss: 1511.7002095381208, Neurons: 21
# Epoch 008, Loss: 1511.516593435828, Neurons: 21
# Epoch 009, Loss: 1511.3259475215962, Neurons: 21
# Epoch 010, Loss: 1511.128301082428, Neurons: 21
# Epoch 011, Loss: 1510.9236891537334, Neurons: 21
# Epoch 012, Loss: 1510.7121501171432, Neurons: 21
# Epoch 013, Loss: 1510.4937238891282, Neurons: 21
# Epoch 014, Loss: 1510.2684507380598, Neurons: 21
# Epoch 015, Loss: 1510.036370572859, Neurons: 21
# Epoch 016, Loss: 1509.7975224556574, Neurons: 21
# Epoch 017, Loss: 1509.5519441263202, Neurons: 21
# Epoch 018, Loss: 1509.2996714307928, Neurons: 21
# Epoch 019, Loss: 1509.0407376457808, Neurons: 21
# Epoch 020, Loss: 1508.7751727509276, Neurons: 21
# Epoch 021, Loss: 1508.5030027152934, Neurons: 21
# Epoch 022, Loss: 1508.2242488539994, Neurons: 21
# Epoch 023, Loss: 1507.9389272901967, Neurons: 21
# Epoch 024, Loss: 1507.6470485375364, Neurons: 21
# Epoch 025, Loss: 1507.3486172034338, Neurons: 21
# Epoch 026, Loss: 1507.0436318041889, Neurons: 21
# Epoch 027, Loss: 1506.7320846784562, Neurons: 21
# Epoch 028, Loss: 1506.4139619842108, Neurons: 21
# Epoch 029, Loss: 1506.0892437649459, Neurons: 21
# Epoch 030, Loss: 1505.7579040724372, Neurons: 21
# Epoch 031, Loss: 1505.4199111353603, Neurons: 21
# Epoch 032, Loss: 1505.0752275650123, Neurons: 21
# Epoch 033, Loss: 1504.723810591122, Neurons: 21
# Epoch 034, Loss: 1504.365612322245, Neurons: 21
# Epoch 035, Loss: 1504.0005800264232, Neurons: 21
# Epoch 036, Loss: 1503.6286564287507, Neurons: 21
# Epoch 037, Loss: 1503.249780023244, Neurons: 21
# Epoch 038, Loss: 1502.8638853969985, Neurons: 21
# Epoch 039, Loss: 1502.4709035650712, Neurons: 21
# Epoch 040, Loss: 1502.0707623148967, Neurons: 21
# Epoch 041, Loss: 1501.6633865593337, Neurons: 21
# Epoch 042, Loss: 1501.2486986976705, Neurons: 21
# Epoch 043, Loss: 1500.82661898411, Neurons: 21
# Epoch 044, Loss: 1500.3970659033876, Neurons: 21
# Epoch 045, Loss: 1499.9599565533013, Neurons: 21
# Epoch 046, Loss: 1499.5152070339998, Neurons: 21
# Epoch 047, Loss: 1499.0627328439277, Neurons: 21
# Epoch 048, Loss: 1498.6024492823467, Neurons: 21
# Epoch 049, Loss: 1498.1342718583392, Neurons: 21
# Epoch 049, Test loss: 1521.8041649995128
# Epoch 050, Loss: 1497.658116706176, Neurons: 21
# Epoch 051, Loss: 1497.1739010068643, Neurons: 21
# Epoch 052, Loss: 1496.6815434155915, Neurons: 21
# Epoch 053, Loss: 1496.180964494679, Neurons: 21
# Epoch 054, Loss: 1495.6720871514708, Neurons: 21
# Epoch 055, Loss: 1495.1548370803732, Neurons: 21
# Epoch 056, Loss: 1494.629143207983, Neurons: 21
# Epoch 057, Loss: 1494.094938139873, Neurons: 21
# Epoch 058, Loss: 1493.5521586071368, Neurons: 21
# Epoch 059, Loss: 1493.0007459102208, Neurons: 21
# Epoch 060, Loss: 1492.4406463568369, Neurons: 21
# Epoch 061, Loss: 1491.8718116898901, Neurons: 21
# Epoch 062, Loss: 1491.2941995002982, Neurons: 21
# Epoch 063, Loss: 1490.7077736184035, Neurons: 21
# Epoch 064, Loss: 1490.1125044763812, Neurons: 21
# Epoch 065, Loss: 1489.5083694326868, Neurons: 21
# Epoch 066, Loss: 1488.8953530483423, Neurons: 21
# Epoch 067, Loss: 1488.2734473038734, Neurons: 21
# Epoch 068, Loss: 1487.6426517452608, Neurons: 21
# Epoch 069, Loss: 1487.002973547689, Neurons: 21
# Epoch 070, Loss: 1486.354427487536, Neurons: 21
# Epoch 071, Loss: 1485.6970358162828, Neurons: 21
# Epoch 072, Loss: 1485.0308280351162, Neurons: 21
# Epoch 073, Loss: 1484.3558405759607, Neurons: 21
# Epoch 074, Loss: 1483.672116403217, Neurons: 21
# Epoch 075, Loss: 1482.9797045598202, Neurons: 21
# Epoch 076, Loss: 1482.278659690189, Neurons: 21
# Epoch 077, Loss: 1481.5690415796446, Neurons: 21
# Epoch 078, Loss: 1480.8509147533448, Neurons: 21
# Epoch 079, Loss: 1480.1243481764545, Neurons: 21
# Epoch 080, Loss: 1479.3894150906344, Neurons: 21
# Epoch 081, Loss: 1478.6461930104954, Neurons: 21
# Epoch 082, Loss: 1477.894763888989, Neurons: 21
# Epoch 083, Loss: 1477.1352144450348, Neurons: 21
# Epoch 084, Loss: 1476.3676366324532, Neurons: 21
# Epoch 085, Loss: 1475.5921282185514, Neurons: 21
# Epoch 086, Loss: 1474.8087934345801, Neurons: 21
# Epoch 087, Loss: 1474.0177436590038, Neurons: 21
# Epoch 088, Loss: 1473.2190980972648, Neurons: 21
# Epoch 089, Loss: 1472.4129844273118, Neurons: 21
# Epoch 090, Loss: 1471.5995393871437, Neurons: 21
# Epoch 091, Loss: 1470.7789092877285, Neurons: 21
# Epoch 092, Loss: 1469.951250441027, Neurons: 21
# Epoch 093, Loss: 1469.1167294979882, Neurons: 21
# Epoch 094, Loss: 1468.2755236950586, Neurons: 21
# Epoch 095, Loss: 1467.427821010151, Neurons: 21
# Epoch 096, Loss: 1466.573820230314, Neurons: 21
# Epoch 097, Loss: 1465.7137309338382, Neurons: 21
# Epoch 098, Loss: 1464.8477733895472, Neurons: 21
# Epoch 099, Loss: 1463.9761783757117, Neurons: 21
# Epoch 099, Test loss: 1486.7270378493329
# Epoch 100, Loss: 1463.0991869206966, Neurons: 21
# Epoch 101, Loss: 1462.2170499671054, Neurons: 21
# Epoch 102, Loss: 1461.330027961003, Neurons: 21
# Epoch 103, Loss: 1460.4383903677174, Neurons: 21
# Epoch 104, Loss: 1459.542415115809, Neurons: 21
# Epoch 105, Loss: 1458.6423879709544, Neurons: 21
# Epoch 106, Loss: 1457.7386018416987, Neurons: 21
# Epoch 107, Loss: 1456.8313560192314, Neurons: 21
# Epoch 108, Loss: 1455.920955353438, Neurons: 21
# Epoch 109, Loss: 1455.007709367485, Neurons: 21
# Epoch 110, Loss: 1454.091931313026, Neurons: 21
# Epoch 111, Loss: 1453.1739371678375, Neurons: 21
# Epoch 112, Loss: 1452.2540445773013, Neurons: 21
# Epoch 113, Loss: 1451.332571740786, Neurons: 21
# Epoch 114, Loss: 1450.409836243736, Neurons: 21
# Epoch 115, Loss: 1449.4861538363393, Neurons: 21
# Epoch 116, Loss: 1448.5618371601981, Neurons: 21
# Epoch 117, Loss: 1447.6371944256032, Neurons: 21
# Epoch 118, Loss: 1446.7125280440218, Neurons: 21
# Epoch 119, Loss: 1445.7881332232305, Neurons: 21
# Epoch 120, Loss: 1444.8642965361767, Neurons: 21
# Epoch 121, Loss: 1443.941294478984, Neurons: 21
# Epoch 122, Loss: 1443.0193920381691, Neurons: 21
# Epoch 123, Loss: 1442.0988412917861, Neurons: 21
# Epoch 124, Loss: 1441.1798800732518, Neurons: 21
# Epoch 125, Loss: 1440.2627307295822, Neurons: 21
# Epoch 126, Loss: 1439.3475990070626, Neurons: 21
# Epoch 127, Loss: 1438.434673096693, Neurons: 21
# Epoch 128, Loss: 1437.5241228687946, Neurons: 21
# Epoch 129, Loss: 1436.6160993210144, Neurons: 21
# Epoch 130, Loss: 1435.7107342568934, Neurons: 21
# Epoch 131, Loss: 1434.8081402036887, Neurons: 21
# Epoch 132, Loss: 1433.9084105689838, Neurons: 21
# Epoch 133, Loss: 1433.0116200265054, Neurons: 21
# Epoch 134, Loss: 1432.1178251132853, Neurons: 21
# Epoch 135, Loss: 1431.2270650134255, Neurons: 21
# Epoch 136, Loss: 1430.3393624986745, Neurons: 21
# Epoch 137, Loss: 1429.4547249930051, Neurons: 21
# Epoch 138, Loss: 1428.5731457273432, Neurons: 21
# Epoch 139, Loss: 1427.694604951365, Neurons: 21
# Epoch 140, Loss: 1426.819071171514, Neurons: 21
# Epoch 141, Loss: 1425.9465023877617, Neurons: 21
# Epoch 142, Loss: 1425.0768473056876, Neurons: 21
# Epoch 143, Loss: 1424.2100465049082, Neurons: 21
# Epoch 144, Loss: 1423.3460335493442, Neurons: 21
# Epoch 145, Loss: 1422.4847360290482, Neurons: 21
# Epoch 146, Loss: 1421.6260765271272, Neurons: 21
# Epoch 147, Loss: 1420.7699735085548, Neurons: 21
# Epoch 148, Loss: 1419.9163421302944, Neurons: 21
# Epoch 149, Loss: 1419.065094974215, Neurons: 21
# Epoch 149, Test loss: 1441.1279931737306
# Epoch 150, Loss: 1418.216142705728, Neurons: 21
# Epoch 151, Loss: 1417.3693946620738, Neurons: 21
# Epoch 152, Loss: 1416.5247593747658, Neurons: 21
# Epoch 153, Loss: 1415.682145030969, Neurons: 21
# Epoch 154, Loss: 1414.8414598786362, Neurons: 21
# Epoch 155, Loss: 1414.0026125801135, Neurons: 21
# Epoch 156, Loss: 1413.16551251872, Neurons: 21
# Epoch 157, Loss: 1412.3300700625368, Neurons: 21
# Epoch 158, Loss: 1411.4961967893698, Neurons: 21
# Epoch 159, Loss: 1410.6638056765685, Neurons: 21
# Epoch 160, Loss: 1409.832811259119, Neurons: 21
# Epoch 161, Loss: 1409.003129759202, Neurons: 21
# Epoch 162, Loss: 1408.1746791901837, Neurons: 21
# Epoch 163, Loss: 1407.3473794378162, Neurons: 21
# Epoch 164, Loss: 1406.5211523212492, Neurons: 21
# Epoch 165, Loss: 1405.6959216362764, Neurons: 21
# Epoch 166, Loss: 1404.8716131830688, Neurons: 21
# Epoch 167, Loss: 1404.0481547804782, Neurons: 21
# Epoch 168, Loss: 1403.2254762687962, Neurons: 21
# Epoch 169, Loss: 1402.403509502675, Neurons: 21
# Epoch 170, Loss: 1401.5821883356996, Neurons: 21
# Epoch 171, Loss: 1400.7614485979213, Neurons: 21
# Epoch 172, Loss: 1399.9412280674474, Neurons: 21
# Epoch 173, Loss: 1399.1214664370127, Neurons: 21
# Epoch 174, Loss: 1398.302105276298, Neurons: 21
# Epoch 175, Loss: 1397.483087990622, Neurons: 21
# Epoch 176, Loss: 1396.6643597765349, Neurons: 21
# Epoch 177, Loss: 1395.8458675747784, Neurons: 21
# Epoch 178, Loss: 1395.0275600210146, Neurons: 21
# Epoch 179, Loss: 1394.2093873947206, Neurons: 21
# Epoch 180, Loss: 1393.3913015666267, Neurons: 21
# Epoch 181, Loss: 1392.5732559450566, Neurons: 21
# Epoch 182, Loss: 1391.7552054215125, Neurons: 21
# Epoch 183, Loss: 1390.9371063157757, Neurons: 21
# Epoch 184, Loss: 1390.1189163207205, Neurons: 21
# Epoch 185, Loss: 1389.3005944468923, Neurons: 21
# Epoch 186, Loss: 1388.4821009667173, Neurons: 21
# Epoch 187, Loss: 1387.6633973579935, Neurons: 21
# Epoch 188, Loss: 1386.8444462460475, Neurons: 21
# Epoch 189, Loss: 1386.0252113436811, Neurons: 21
# Epoch 190, Loss: 1385.2056573877778, Neurons: 21
# Epoch 191, Loss: 1384.3857500712563, Neurons: 21
# Epoch 192, Loss: 1383.5654559689856, Neurons: 21
# Epoch 193, Loss: 1382.7447424563659, Neurons: 21
# Epoch 194, Loss: 1381.9235776195933, Neurons: 21
# Epoch 195, Loss: 1381.1019301572007, Neurons: 21
# Epoch 196, Loss: 1380.2797692733218, Neurons: 21
# Epoch 197, Loss: 1379.4570645642261, Neurons: 21
# Epoch 198, Loss: 1378.6337859009598, Neurons: 21
# Epoch 199, Loss: 1377.8099033122376, Neurons: 21
# Epoch 199, Test loss: 1399.2083549616875
# Epoch 200, Loss: 1376.985386872887, Neurons: 21
# Epoch 201, Loss: 1376.160206603919, Neurons: 21
# Epoch 202, Loss: 1375.3343323904612, Neurons: 21
# Epoch 203, Loss: 1374.5077339232002, Neurons: 21
# Epoch 204, Loss: 1373.6803806675687, Neurons: 21
# Epoch 205, Loss: 1372.8522418628063, Neurons: 21
# Epoch 206, Loss: 1372.0232865504436, Neurons: 21
# Epoch 207, Loss: 1371.1934836290598, Neurons: 21
# Epoch 208, Loss: 1370.3628019297555, Neurons: 21
# Epoch 209, Loss: 1369.531210304975, Neurons: 21
# Epoch 210, Loss: 1368.6986777223558, Neurons: 21
# Epoch 211, Loss: 1367.8651733552617, Neurons: 21
# Epoch 212, Loss: 1367.030666662437, Neurons: 21
# Epoch 213, Loss: 1366.1951274506714, Neurons: 21
# Epoch 214, Loss: 1365.3585259161644, Neurons: 21
# Epoch 215, Loss: 1364.5208326621976, Neurons: 21
# Epoch 216, Loss: 1363.6820186925092, Neurons: 21
# Epoch 217, Loss: 1362.8420553812891, Neurons: 21
# Epoch 218, Loss: 1362.0009144218554, Neurons: 21
# Epoch 219, Loss: 1361.158567756842, Neurons: 21
# Epoch 220, Loss: 1360.3149874931398, Neurons: 21
# Epoch 221, Loss: 1359.4701458049283, Neurons: 21
# Epoch 222, Loss: 1358.6240148280342, Neurons: 21
# Epoch 223, Loss: 1357.7765665485417, Neurons: 21
# Epoch 224, Loss: 1356.9277726882208, Neurons: 21
# Epoch 225, Loss: 1356.0776045888933, Neurons: 21
# Epoch 226, Loss: 1355.22603309741, Neurons: 21
# Epoch 227, Loss: 1354.3730284525038, Neurons: 21
# Epoch 228, Loss: 1353.5185601743744, Neurons: 21
# Epoch 229, Loss: 1352.6625969575193, Neurons: 21
# Epoch 230, Loss: 1351.8051065670386, Neurons: 21
# Epoch 231, Loss: 1350.9460557383873, Neurons: 21
# Epoch 232, Loss: 1350.0854100803704, Neurons: 21
# Epoch 233, Loss: 1349.223133981037, Neurons: 21
# Epoch 234, Loss: 1348.3591905160442, Neurons: 21
# Epoch 235, Loss: 1347.493541359012, Neurons: 21
# Epoch 236, Loss: 1346.6261466934134, Neurons: 21
# Epoch 237, Loss: 1345.7569651255471, Neurons: 21
# Epoch 238, Loss: 1344.8859535982238, Neurons: 21
# Epoch 239, Loss: 1344.013067304868, Neurons: 21
# Epoch 240, Loss: 1343.1382596038286, Neurons: 21
# Epoch 241, Loss: 1342.261481932784, Neurons: 21
# Epoch 242, Loss: 1341.3826837232173, Neurons: 21
# Epoch 243, Loss: 1340.5018123150114, Neurons: 21
# Epoch 244, Loss: 1339.618812871264, Neurons: 21
# Epoch 245, Loss: 1338.7336282934764, Neurons: 21
# Epoch 246, Loss: 1337.8461991372678, Neurons: 21
# Epoch 247, Loss: 1336.9564635287722, Neurons: 21
# Epoch 248, Loss: 1336.0643570818434, Neurons: 21
# Epoch 249, Loss: 1335.169812816166, Neurons: 21
# Epoch 249, Test loss: 1355.8058507178137
# Epoch 250, Loss: 1334.272761076314, Neurons: 21
# Epoch 251, Loss: 1333.3731294517604, Neurons: 21
# Epoch 252, Loss: 1332.4708426977934, Neurons: 21
# Epoch 253, Loss: 1331.5658226572712, Neurons: 21
# Epoch 254, Loss: 1330.6579881831256, Neurons: 21
# Epoch 255, Loss: 1329.747255061534, Neurons: 21
# Epoch 256, Loss: 1328.8335359357072, Neurons: 21
# Epoch 257, Loss: 1327.9167402302844, Neurons: 21
# Epoch 258, Loss: 1326.9967740763982, Neurons: 21
# Epoch 259, Loss: 1326.0735402375565, Neurons: 21
# Epoch 260, Loss: 1325.146938036577, Neurons: 21
# Epoch 261, Loss: 1324.21686328392, Neurons: 21
# Epoch 262, Loss: 1323.2832082078596, Neurons: 21
# Epoch 263, Loss: 1322.345861387032, Neurons: 21
# Epoch 264, Loss: 1321.404707685987, Neurons: 21
# Epoch 265, Loss: 1320.4596281944316, Neurons: 21
# Epoch 266, Loss: 1319.5105001709223, Neurons: 21
# Epoch 267, Loss: 1318.5571969917853, Neurons: 21
# Epoch 268, Loss: 1317.5995881060694, Neurons: 21
# Epoch 269, Loss: 1316.637538997331, Neurons: 21
# Epoch 270, Loss: 1315.670911153029, Neurons: 21
# Epoch 271, Loss: 1314.699562042284, Neurons: 21
# Epoch 272, Loss: 1313.723345102698, Neurons: 21
# Epoch 273, Loss: 1312.742109736886, Neurons: 21
# Epoch 274, Loss: 1311.7557013193048, Neurons: 21
# Epoch 275, Loss: 1310.7639612138967, Neurons: 21
# Epoch 276, Loss: 1309.7667268030034, Neurons: 21
# Epoch 277, Loss: 1308.763831527931, Neurons: 21
# Epoch 278, Loss: 1307.755104941491, Neurons: 21
# Epoch 279, Loss: 1306.7403727727735, Neurons: 21
# Epoch 280, Loss: 1305.7194570043623, Neurons: 21
# Epoch 281, Loss: 1304.6921759621616, Neurons: 21
# Epoch 282, Loss: 1303.658344417955, Neurons: 21
# Epoch 283, Loss: 1302.6177737048165, Neurons: 21
# Epoch 284, Loss: 1301.5702718454659, Neurons: 21
# Epoch 285, Loss: 1300.515643693681, Neurons: 21
# Epoch 286, Loss: 1299.4536910888814, Neurons: 21
# Epoch 287, Loss: 1298.3842130240405, Neurons: 21
# Epoch 288, Loss: 1297.3070058271126, Neurons: 21
# Epoch 289, Loss: 1296.2218633562127, Neurons: 21
# Epoch 290, Loss: 1295.1285772088345, Neurons: 21
# Epoch 291, Loss: 1294.0269369454477, Neurons: 21
# Epoch 292, Loss: 1292.916730327851, Neurons: 21
# Epoch 293, Loss: 1291.7977435727234, Neurons: 21
# Epoch 294, Loss: 1290.6697616208323, Neurons: 21
# Epoch 295, Loss: 1289.5325684223983, Neurons: 21
# Epoch 296, Loss: 1288.3859472391412, Neurons: 21
# Epoch 297, Loss: 1287.2296809635543, Neurons: 21
# Epoch 298, Loss: 1286.0635524559846, Neurons: 21
# Epoch 299, Loss: 1284.8873449001228, Neurons: 21
# Epoch 299, Test loss: 1304.483315392297
# Epoch 300, Loss: 1283.700842177563, Neurons: 21
# Epoch 301, Loss: 1282.5038292621505, Neurons: 21
# Epoch 302, Loss: 1281.296092634926, Neurons: 21
# Epoch 303, Loss: 1280.0774207205739, Neurons: 21
# Epoch 304, Loss: 1278.8476043464195, Neurons: 21
# Epoch 305, Loss: 1277.6064372251594, Neurons: 21
# Epoch 306, Loss: 1276.3537164626687, Neurons: 21
# Epoch 307, Loss: 1275.0892430923805, Neurons: 21
# Epoch 308, Loss: 1273.812822637891, Neurons: 21
# Epoch 309, Loss: 1272.5242657055564, Neurons: 21
# Epoch 310, Loss: 1271.2233886089332, Neurons: 21
# Epoch 311, Loss: 1269.9100140269381, Neurons: 21
# Epoch 312, Loss: 1268.5839716975313, Neurons: 21
# Epoch 313, Loss: 1267.2450991485769, Neurons: 21
# Epoch 314, Loss: 1265.8932424672196, Neurons: 21
# Epoch 315, Loss: 1264.5282571086802, Neurons: 21
# Epoch 316, Loss: 1263.150008744721, Neurons: 21
# Epoch 317, Loss: 1261.7583741512065, Neurons: 21
# Epoch 318, Loss: 1260.3532421330844, Neurons: 21
# Epoch 319, Loss: 1258.934514483804, Neurons: 21
# Epoch 320, Loss: 1257.5021069745696, Neurons: 21
# Epoch 321, Loss: 1256.0559503669817, Neurons: 21
# Epoch 322, Loss: 1254.5959914404725, Neurons: 21
# Epoch 323, Loss: 1253.1221940236146, Neurons: 21
# Epoch 324, Loss: 1251.6345400158607, Neurons: 21
# Epoch 325, Loss: 1250.1330303837053, Neurons: 21
# Epoch 326, Loss: 1248.6176861127722, Neurons: 21
# Epoch 327, Loss: 1247.088549095091, Neurons: 21
# Epoch 328, Loss: 1245.5456829291193, Neurons: 21
# Epoch 329, Loss: 1243.989173609116, Neurons: 21
# Epoch 330, Loss: 1242.419130080606, Neurons: 21
# Epoch 331, Loss: 1240.835684640187, Neurons: 21
# Epoch 332, Loss: 1239.238993161017, Neurons: 21
# Epoch 333, Loss: 1237.6292351301413, Neurons: 21
# Epoch 334, Loss: 1236.0066134902602, Neurons: 21
# Epoch 335, Loss: 1234.371354286389, Neurons: 21
# Epoch 336, Loss: 1232.7237061265018, Neurons: 21
# Epoch 337, Loss: 1231.063939474016, Neurons: 21
# Epoch 338, Loss: 1229.3923457978938, Neurons: 21
# Epoch 339, Loss: 1227.7092366123122, Neurons: 21
# Epoch 340, Loss: 1226.014942441474, Neurons: 21
# Epoch 341, Loss: 1224.309811745696, Neurons: 21
# Epoch 342, Loss: 1222.594209842264, Neurons: 21
# Epoch 343, Loss: 1220.8685178490182, Neurons: 21
# Epoch 344, Loss: 1219.133131670873, Neurons: 21
# Epoch 345, Loss: 1217.3884610404086, Neurons: 21
# Epoch 346, Loss: 1215.6349286142968, Neurons: 21
# Epoch 347, Loss: 1213.872969118566, Neurons: 21
# Epoch 348, Loss: 1212.1030285283514, Neurons: 21
# Epoch 349, Loss: 1210.3255632623195, Neurons: 21
# Epoch 349, Test loss: 1228.3857999367008
# Epoch 350, Loss: 1208.5410393687368, Neurons: 21
# Epoch 351, Loss: 1206.749931679214, Neurons: 21
# Epoch 352, Loss: 1204.9527229074433, Neurons: 21
# Epoch 353, Loss: 1203.1499026734518, Neurons: 21
# Epoch 354, Loss: 1201.3419664386813, Neurons: 21
# Epoch 355, Loss: 1199.52941434309, Neurons: 21
# Epoch 356, Loss: 1197.7127499419464, Neurons: 21
# Epoch 357, Loss: 1195.8924788465329, Neurons: 21
# Epoch 358, Loss: 1194.0691072791126, Neurons: 21
# Epoch 359, Loss: 1192.2431405578034, Neurons: 21
# Epoch 360, Loss: 1190.4150815310602, Neurons: 21
# Epoch 361, Loss: 1188.585428984106, Neurons: 21
# Epoch 362, Loss: 1186.754676040679, Neurons: 21
# Epoch 363, Loss: 1184.923308582965, Neurons: 21
# Epoch 364, Loss: 1183.0918037107242, Neurons: 21
# Epoch 365, Loss: 1181.2606282577, Neurons: 21
# Epoch 366, Loss: 1179.4302373798746, Neurons: 21
# Epoch 367, Loss: 1177.60107322641, Neurons: 21
# Epoch 368, Loss: 1175.7735637007002, Neurons: 21
# Epoch 369, Loss: 1173.9481213161434, Neurons: 21
# Epoch 370, Loss: 1172.1251421493353, Neurons: 21
# Epoch 371, Loss: 1170.3050048924297, Neurons: 21
# Epoch 372, Loss: 1168.4880700063482, Neurons: 21
# Epoch 373, Loss: 1166.6746789771407, Neurons: 21
# Epoch 374, Loss: 1164.8651536787715, Neurons: 21
# Epoch 375, Loss: 1163.0597958465619, Neurons: 21
# Epoch 376, Loss: 1161.2588866661615, Neurons: 21
# Epoch 377, Loss: 1159.462686482937, Neurons: 21
# Epoch 378, Loss: 1157.6714346359984, Neurons: 21
# Epoch 379, Loss: 1155.8853494197213, Neurons: 21
# Epoch 380, Loss: 1154.104628173692, Neurons: 21
# Epoch 381, Loss: 1152.329447499746, Neurons: 21
# Epoch 382, Loss: 1150.5599636023642, Neurons: 21
# Epoch 383, Loss: 1148.7963127463922, Neurons: 21
# Epoch 384, Loss: 1147.038611823959, Neurons: 21
# Epoch 385, Loss: 1145.2869590207213, Neurons: 21
# Epoch 386, Loss: 1143.541434570198, Neurons: 21
# Epoch 387, Loss: 1141.8021015839872, Neurons: 21
# Epoch 388, Loss: 1140.0690069451541, Neurons: 21
# Epoch 389, Loss: 1138.3421822519572, Neurons: 21
# Epoch 390, Loss: 1136.6216447994057, Neurons: 21
# Epoch 391, Loss: 1134.907398586798, Neurons: 21
# Epoch 392, Loss: 1133.1994353403413, Neurons: 21
# Epoch 393, Loss: 1131.4977355410554, Neurons: 21
# Epoch 394, Loss: 1129.802269449336, Neurons: 21
# Epoch 395, Loss: 1128.112998118662, Neurons: 21
# Epoch 396, Loss: 1126.4298743919467, Neurons: 21
# Epoch 397, Loss: 1124.7528438748893, Neurons: 21
# Epoch 398, Loss: 1123.0818458814326, Neurons: 21
# Epoch 399, Loss: 1121.416814347038, Neurons: 21
# Epoch 399, Test loss: 1138.5492561042568
# Epoch 400, Loss: 1119.7576787060596, Neurons: 21
# Epoch 401, Loss: 1118.1043647299916, Neurons: 21
# Epoch 402, Loss: 1116.456795323825, Neurons: 21
# Epoch 403, Loss: 1114.8148912781892, Neurons: 21
# Epoch 404, Loss: 1113.1785719753384, Neurons: 21
# Epoch 405, Loss: 1111.5477560474078, Neurons: 21
# Epoch 406, Loss: 1109.9223619856687, Neurons: 21
# Epoch 407, Loss: 1108.3023086998028, Neurons: 21
# Epoch 408, Loss: 1106.687516026447, Neurons: 21
# Epoch 409, Loss: 1105.07790518647, Neurons: 21
# Epoch 410, Loss: 1103.4733991906141, Neurons: 21
# Epoch 411, Loss: 1101.873923193263, Neurons: 21
# Epoch 412, Loss: 1100.2794047941893, Neurons: 21
# Epoch 413, Loss: 1098.6897742882213, Neurons: 21
# Epoch 414, Loss: 1097.1049648628195, Neurons: 21
# Epoch 415, Loss: 1095.524912743646, Neurons: 21
# Epoch 416, Loss: 1093.9495572883336, Neurons: 21
# Epoch 417, Loss: 1092.3788410288435, Neurons: 21
# Epoch 418, Loss: 1090.8127096630649, Neurons: 21
# Epoch 419, Loss: 1089.251111996666, Neurons: 21
# Epoch 420, Loss: 1087.69399983661, Neurons: 21
# Epoch 421, Loss: 1086.1413278382563, Neurons: 21
# Epoch 422, Loss: 1084.5930533084988, Neurons: 21
# Epoch 423, Loss: 1083.0491359679572, Neurons: 21
# Epoch 424, Loss: 1081.509537675817, Neurons: 21
# Epoch 425, Loss: 1079.9742221214713, Neurons: 21
# Epoch 426, Loss: 1078.4431544876543, Neurons: 21
# Epoch 427, Loss: 1076.9163010902382, Neurons: 21
# Epoch 428, Loss: 1075.393629000284, Neurons: 21
# Epoch 429, Loss: 1073.8751056542962, Neurons: 21
# Epoch 430, Loss: 1072.3606984588828, Neurons: 21
# Epoch 431, Loss: 1070.8503743961978, Neurons: 21
# Epoch 432, Loss: 1069.3440996366055, Neurons: 21
# Epoch 433, Loss: 1067.8418391649536, Neurons: 21
# Epoch 434, Loss: 1066.3435564266615, Neurons: 21
# Epoch 435, Loss: 1064.849212999519, Neurons: 21
# Epoch 436, Loss: 1063.3587682966302, Neurons: 21
# Epoch 437, Loss: 1061.872179305333, Neurons: 21
# Epoch 438, Loss: 1060.3894003661856, Neurons: 21
# Epoch 439, Loss: 1058.9103829952396, Neurons: 21
# Epoch 440, Loss: 1057.4350757518507, Neurons: 21
# Epoch 441, Loss: 1055.963424153242, Neurons: 21
# Epoch 442, Loss: 1054.4953706359681, Neurons: 21
# Epoch 443, Loss: 1053.0308545633773, Neurons: 21
# Epoch 444, Loss: 1051.56981227717, Neurons: 21
# Epoch 445, Loss: 1050.112177190254, Neurons: 21
# Epoch 446, Loss: 1048.6578799173237, Neurons: 21
# Epoch 447, Loss: 1047.2068484389742, Neurons: 21
# Epoch 448, Loss: 1045.7590082947067, Neurons: 21
# Epoch 449, Loss: 1044.3142827999027, Neurons: 21
# Epoch 449, Test loss: 1060.654102461462
# Epoch 450, Loss: 1042.8725932817285, Neurons: 21
# Epoch 451, Loss: 1041.4338593289804, Neurons: 21
# Epoch 452, Loss: 1039.9979990510483, Neurons: 21
# Epoch 453, Loss: 1038.564929341464, Neurons: 21
# Epoch 454, Loss: 1037.1345661418825, Neurons: 21
# Epoch 455, Loss: 1035.706824702777, Neurons: 21
# Epoch 456, Loss: 1034.2816198376063, Neurons: 21
# Epoch 457, Loss: 1032.8588661677134, Neurons: 21
# Epoch 458, Loss: 1031.4384783557025, Neurons: 21
# Epoch 459, Loss: 1030.0203713255344, Neurons: 21
# Epoch 460, Loss: 1028.6044604680253, Neurons: 21
# Epoch 461, Loss: 1027.1906618308567, Neurons: 21
# Epoch 462, Loss: 1025.7788922925786, Neurons: 21
# Epoch 463, Loss: 1024.3690697204247, Neurons: 21
# Epoch 464, Loss: 1022.9611131120355, Neurons: 21
# Epoch 465, Loss: 1021.5549427214213, Neurons: 21
# Epoch 466, Loss: 1020.1504801696949, Neurons: 21
# Epoch 467, Loss: 1018.7476485412443, Neurons: 21
# Epoch 468, Loss: 1017.346372466131, Neurons: 21
# Epoch 469, Loss: 1015.9465781895772, Neurons: 21
# Epoch 470, Loss: 1014.5481936294499, Neurons: 21
# Epoch 471, Loss: 1013.1511484226716, Neurons: 21
# Epoch 472, Loss: 1011.7553739615001, Neurons: 21
# Epoch 473, Loss: 1010.3608034205929, Neurons: 21
# Epoch 474, Loss: 1008.9673717757581, Neurons: 21
# Epoch 475, Loss: 1007.5750158152556, Neurons: 21
# Epoch 476, Loss: 1006.1836741444707, Neurons: 21
# Epoch 477, Loss: 1004.7932871847365, Neurons: 21
# Epoch 478, Loss: 1003.4037971670375, Neurons: 21
# Epoch 479, Loss: 1002.015148121268, Neurons: 21
# Epoch 480, Loss: 1000.6272858616805, Neurons: 21
# Epoch 481, Loss: 999.2401579690949, Neurons: 21
# Epoch 482, Loss: 997.8537137703981, Neurons: 21
# Epoch 483, Loss: 996.467904315814, Neurons: 21
# Epoch 484, Loss: 995.0826823543716, Neurons: 21
# Epoch 485, Loss: 993.6980023079625, Neurons: 21
# Epoch 486, Loss: 992.3138202443298, Neurons: 21
# Epoch 487, Loss: 990.9300938492958, Neurons: 21
# Epoch 488, Loss: 989.5467823985026, Neurons: 21
# Epoch 489, Loss: 988.1638467288998, Neurons: 21
# Epoch 490, Loss: 986.7812492101967, Neurons: 21
# Epoch 491, Loss: 985.3989537164584, Neurons: 21
# Epoch 492, Loss: 984.0169255980135, Neurons: 21
# Epoch 493, Loss: 982.6351316538133, Neurons: 21
# Epoch 494, Loss: 981.2535401043717, Neurons: 21
# Epoch 495, Loss: 979.8721205653902, Neurons: 21
# Epoch 496, Loss: 978.4908440221735, Neurons: 21
# Epoch 497, Loss: 977.109682804908, Neurons: 21
# Epoch 498, Loss: 975.7286105648883, Neurons: 21
# Epoch 499, Loss: 974.3476022517426, Neurons: 21
# Epoch 499, Test loss: 989.7047300836617
# Epoch 500, Loss: 972.9666340917207, Neurons: 21
# Epoch 501, Loss: 971.5856835670817, Neurons: 21
# Epoch 502, Loss: 970.2047293966272, Neurons: 21
# Epoch 503, Loss: 968.8237515174062, Neurons: 21
# Epoch 504, Loss: 967.4427310676188, Neurons: 21
# Epoch 505, Loss: 966.0616503707465, Neurons: 21
# Epoch 506, Loss: 964.6804929209151, Neurons: 21
# Epoch 507, Loss: 963.2992433695138, Neurons: 21
# Epoch 508, Loss: 961.917887513077, Neurons: 21
# Epoch 509, Loss: 960.536412282433, Neurons: 21
# Epoch 510, Loss: 959.154805733131, Neurons: 21
# Epoch 511, Loss: 957.7730570371407, Neurons: 21
# Epoch 512, Loss: 956.3911564758279, Neurons: 21
# Epoch 513, Loss: 955.0090954342008, Neurons: 21
# Epoch 514, Loss: 953.6268663964225, Neurons: 21
# Epoch 515, Loss: 952.2444629425709, Neurons: 21
# Epoch 516, Loss: 950.8618797466435, Neurons: 21
# Epoch 517, Loss: 949.4791125757795, Neurons: 21
# Epoch 518, Loss: 948.0961582906833, Neurons: 21
# Epoch 519, Loss: 946.7130148472183, Neurons: 21
# Epoch 520, Loss: 945.32968129914, Neurons: 21
# Epoch 521, Loss: 943.9461578019362, Neurons: 21
# Epoch 522, Loss: 942.5624456177261, Neurons: 21
# Epoch 523, Loss: 941.1785471211718, Neurons: 21
# Epoch 524, Loss: 939.7944658063515, Neurons: 21
# Epoch 525, Loss: 938.4102062945295, Neurons: 21
# Epoch 526, Loss: 937.025774342759, Neurons: 21
# Epoch 527, Loss: 935.6411768532413, Neurons: 21
# Epoch 528, Loss: 934.2564218833581, Neurons: 21
# Epoch 529, Loss: 932.8715186562933, Neurons: 21
# Epoch 530, Loss: 931.4864775721364, Neurons: 21
# Epoch 531, Loss: 930.1013102193695, Neurons: 21
# Epoch 532, Loss: 928.7160293866151, Neurons: 21
# Epoch 533, Loss: 927.3306490745224, Neurons: 21
# Epoch 534, Loss: 925.9451845076525, Neurons: 21
# Epoch 535, Loss: 924.5596521462156, Neurons: 21
# Epoch 536, Loss: 923.1740696975061, Neurons: 21
# Epoch 537, Loss: 921.7884561268537, Neurons: 21
# Epoch 538, Loss: 920.4028316679218, Neurons: 21
# Epoch 539, Loss: 919.0172178321441, Neurons: 21
# Epoch 540, Loss: 917.6316374171004, Neurons: 21
# Epoch 541, Loss: 916.2461145136051, Neurons: 21
# Epoch 542, Loss: 914.8606745112751, Neurons: 21
# Epoch 543, Loss: 913.4753441023287, Neurons: 21
# Epoch 544, Loss: 912.0901512833569, Neurons: 21
# Epoch 545, Loss: 910.7051253547963, Neurons: 21
# Epoch 546, Loss: 909.320296917819, Neurons: 21
# Epoch 547, Loss: 907.9356978683479, Neurons: 21
# Epoch 548, Loss: 906.5513613879053, Neurons: 21
# Epoch 549, Loss: 905.1673219309802, Neurons: 21
# Epoch 549, Test loss: 919.4017994934239
# Epoch 550, Loss: 903.7836152086154, Neurons: 21
# Epoch 551, Loss: 902.4002781679031, Neurons: 21
# Epoch 552, Loss: 901.0173489670881, Neurons: 21
# Epoch 553, Loss: 899.6348669459802, Neurons: 21
# Epoch 554, Loss: 898.2528725913941, Neurons: 21
# Epoch 555, Loss: 896.8714074973451, Neurons: 21
# Epoch 556, Loss: 895.4905143197617, Neurons: 21
# Epoch 557, Loss: 894.110236725491, Neurons: 21
# Epoch 558, Loss: 892.730619335416, Neurons: 21
# Epoch 559, Loss: 891.3517076615398, Neurons: 21
# Epoch 560, Loss: 889.97354803794, Neurons: 21
# Epoch 561, Loss: 888.5961875455462, Neurons: 21
# Epoch 562, Loss: 887.2196739307583, Neurons: 21
# Epoch 563, Loss: 885.8440555179798, Neurons: 21
# Epoch 564, Loss: 884.469381116217, Neurons: 21
# Epoch 565, Loss: 883.0956999199692, Neurons: 21
# Epoch 566, Loss: 881.723061404705, Neurons: 21
# Epoch 567, Loss: 880.3515152173081, Neurons: 21
# Epoch 568, Loss: 878.9811110619482, Neurons: 21
# Epoch 569, Loss: 877.6118985819182, Neurons: 21
# Epoch 570, Loss: 876.243927238046, Neurons: 21
# Epoch 571, Loss: 874.8772461843655, Neurons: 21
# Epoch 572, Loss: 873.5119041417909, Neurons: 21
# Epoch 573, Loss: 872.1479492705968, Neurons: 21
# Epoch 574, Loss: 870.7854290425431, Neurons: 21
# Epoch 575, Loss: 869.4243901135259, Neurons: 21
# Epoch 576, Loss: 868.0648781976424, Neurons: 21
# Epoch 577, Loss: 866.706937943579, Neurons: 21
# Epoch 578, Loss: 865.3506128141992, Neurons: 21
# Epoch 579, Loss: 863.9959449702121, Neurons: 21
# Epoch 580, Loss: 862.642975158739, Neurons: 21
# Epoch 581, Loss: 861.2917426075619, Neurons: 21
# Epoch 582, Loss: 859.9422849257675, Neurons: 21
# Epoch 583, Loss: 858.594638011429, Neurons: 21
# Epoch 584, Loss: 857.2488359668863, Neurons: 21
# Epoch 585, Loss: 855.9049110220973, Neurons: 21
# Epoch 586, Loss: 854.5628934664392, Neurons: 21
# Epoch 587, Loss: 853.2228115892462, Neurons: 21
# Epoch 588, Loss: 851.8846916292713, Neurons: 21
# Epoch 589, Loss: 850.5485577331631, Neurons: 21
# Epoch 590, Loss: 849.2144319229702, Neurons: 21
# Epoch 591, Loss: 847.8823340725802, Neurons: 21
# Epoch 592, Loss: 846.5522818929345, Neurons: 21
# Epoch 593, Loss: 845.2242909257823, Neurons: 21
# Epoch 594, Loss: 843.8983745456655, Neurons: 21
# Epoch 595, Loss: 842.5745439697777, Neurons: 21
# Epoch 596, Loss: 841.2528082752835, Neurons: 21
# Epoch 597, Loss: 839.9331744236441, Neurons: 21
# Epoch 598, Loss: 838.6156472914631, Neurons: 21
# Epoch 599, Loss: 837.300229707343, Neurons: 21
# Epoch 599, Test loss: 850.4640635039325
# Epoch 600, Loss: 835.9869224942182, Neurons: 21
# Epoch 601, Loss: 834.6757245166256, Neurons: 21
# Epoch 602, Loss: 833.3666327323629, Neurons: 21
# Epoch 603, Loss: 832.0596422479889, Neurons: 21
# Epoch 604, Loss: 830.7547463776206, Neurons: 21
# Epoch 605, Loss: 829.4519367044919, Neurons: 21
# Epoch 606, Loss: 828.1512031447543, Neurons: 21
# Epoch 607, Loss: 826.8525340130049, Neurons: 21
# Epoch 608, Loss: 825.5559160890542, Neurons: 21
# Epoch 609, Loss: 824.2613346854608, Neurons: 21
# Epoch 610, Loss: 822.9687737153786, Neurons: 21
# Epoch 611, Loss: 821.6782157602875, Neurons: 21
# Epoch 612, Loss: 820.3896421372025, Neurons: 21
# Epoch 613, Loss: 819.1030329649743, Neurons: 21
# Epoch 614, Loss: 817.8183672293284, Neurons: 21
# Epoch 615, Loss: 816.5356228463091, Neurons: 21
# Epoch 616, Loss: 815.2547767238236, Neurons: 21
# Epoch 617, Loss: 813.9758048210092, Neurons: 21
# Epoch 618, Loss: 812.6986822051748, Neurons: 21
# Epoch 619, Loss: 811.4233831060913, Neurons: 21
# Epoch 620, Loss: 810.1498809674408, Neurons: 21
# Epoch 621, Loss: 808.8781484952528, Neurons: 21
# Epoch 622, Loss: 807.6081577031899, Neurons: 21
# Epoch 623, Loss: 806.3398799545681, Neurons: 21
# Epoch 624, Loss: 805.0732860010199, Neurons: 21
# Epoch 625, Loss: 803.8083460177394, Neurons: 21
# Epoch 626, Loss: 802.5450296352583, Neurons: 21
# Epoch 627, Loss: 801.2833059677383, Neurons: 21
# Epoch 628, Loss: 800.023143637769, Neurons: 21
# Epoch 629, Loss: 798.764510797687, Neurons: 21
# Epoch 630, Loss: 797.5073751474433, Neurons: 21
# Epoch 631, Loss: 796.2517039490605, Neurons: 21
# Epoch 632, Loss: 794.9974640377293, Neurons: 21
# Epoch 633, Loss: 793.7446218296077, Neurons: 21
# Epoch 634, Loss: 792.4931433263913, Neurons: 21
# Epoch 635, Loss: 791.2429941167256, Neurons: 21
# Epoch 636, Loss: 789.9941393745447, Neurons: 21
# Epoch 637, Loss: 788.7465438544147, Neurons: 21
# Epoch 638, Loss: 787.5001718839663, Neurons: 21
# Epoch 639, Loss: 786.254987353506, Neurons: 21
# Epoch 640, Loss: 785.0109537028874, Neurons: 21
# Epoch 641, Loss: 783.7680339057357, Neurons: 21
# Epoch 642, Loss: 782.5261904511083, Neurons: 21
# Epoch 643, Loss: 781.285385322683, Neurons: 21
# Epoch 644, Loss: 780.045579975563, Neurons: 21
# Epoch 645, Loss: 778.8067353107859, Neurons: 21
# Epoch 646, Loss: 777.5688116476327, Neurons: 21
# Epoch 647, Loss: 776.3317686938299, Neurons: 21
# Epoch 648, Loss: 775.0955655137395, Neurons: 21
# Epoch 649, Loss: 773.860160494645, Neurons: 21
# Epoch 649, Test loss: 786.0045716962211
# Epoch 650, Loss: 772.6255113112326, Neurons: 21
# Epoch 651, Loss: 771.391574888384, Neurons: 21
# Epoch 652, Loss: 770.1583073623998, Neurons: 21
# Epoch 653, Loss: 768.9256640407743, Neurons: 21
# Epoch 654, Loss: 767.6935993606618, Neurons: 21
# Epoch 655, Loss: 766.4620668461685, Neurons: 21
# Epoch 656, Loss: 765.2310190646278, Neurons: 21
# Epoch 657, Loss: 764.0004075820124, Neurons: 21
# Epoch 658, Loss: 762.7701829176551, Neurons: 21
# Epoch 659, Loss: 761.5402944984529, Neurons: 21
# Epoch 660, Loss: 760.3106906127434, Neurons: 21
# Epoch 661, Loss: 759.0813183640424, Neurons: 21
# Epoch 662, Loss: 757.8521236248486, Neurons: 21
# Epoch 663, Loss: 756.6230509907181, Neurons: 21
# Epoch 664, Loss: 755.3940437348235, Neurons: 21
# Epoch 665, Loss: 754.1650437632102, Neurons: 21
# Epoch 666, Loss: 752.9359915709676, Neurons: 21
# Epoch 667, Loss: 751.7068261995344, Neurons: 21
# Epoch 668, Loss: 750.4774851953488, Neurons: 21
# Epoch 669, Loss: 749.2479045700603, Neurons: 21
# Epoch 670, Loss: 748.0180187625064, Neurons: 21
# Epoch 671, Loss: 746.7877606026584, Neurons: 21
# Epoch 672, Loss: 745.557061277728, Neurons: 21
# Epoch 673, Loss: 744.3258503006213, Neurons: 21
# Epoch 674, Loss: 743.0940554809248, Neurons: 21
# Epoch 675, Loss: 741.8616028985955, Neurons: 21
# Epoch 676, Loss: 740.6284168805284, Neurons: 21
# Epoch 677, Loss: 739.3944199801805, Neurons: 21
# Epoch 678, Loss: 738.1595329604296, Neurons: 21
# Epoch 679, Loss: 736.9236747798706, Neurons: 21
# Epoch 680, Loss: 735.6867625827595, Neurons: 21
# Epoch 681, Loss: 734.4487116928675, Neurons: 21
# Epoch 682, Loss: 733.2094356115297, Neurons: 21
# Epoch 683, Loss: 731.9688460202443, Neurons: 21
# Epoch 684, Loss: 730.7268527882368, Neurons: 21
# Epoch 685, Loss: 729.4833639854866, Neurons: 21
# Epoch 686, Loss: 728.2382859018082, Neurons: 21
# Epoch 687, Loss: 726.9915230726824, Neurons: 21
# Epoch 688, Loss: 725.7429783126463, Neurons: 21
# Epoch 689, Loss: 724.4925527571797, Neurons: 21
# Epoch 690, Loss: 723.2401459141464, Neurons: 21
# Epoch 691, Loss: 721.9856557259823, Neurons: 21
# Epoch 692, Loss: 720.7289786439504, Neurons: 21
# Epoch 693, Loss: 719.4700097158968, Neurons: 21
# Epoch 694, Loss: 718.2086426890496, Neurons: 21
# Epoch 695, Loss: 716.9447701294897, Neurons: 21
# Epoch 696, Loss: 715.6782835599754, Neurons: 21
# Epoch 697, Loss: 714.4090736178341, Neurons: 21
# Epoch 698, Loss: 713.1370302346147, Neurons: 21
# Epoch 699, Loss: 711.8620428391297, Neurons: 21
# Epoch 699, Test loss: 722.8906637080125
# Epoch 700, Loss: 710.5840005853973, Neurons: 21
# Epoch 701, Loss: 709.3027926068085, Neurons: 21
# Epoch 702, Loss: 708.0183082975881, Neurons: 21
# Epoch 703, Loss: 706.7304376223, Neurons: 21
# Epoch 704, Loss: 705.4390714537342, Neurons: 21
# Epoch 705, Loss: 704.1441019390369, Neurons: 21
# Epoch 706, Loss: 702.8454228934024, Neurons: 21
# Epoch 707, Loss: 701.5429302200203, Neurons: 21
# Epoch 708, Loss: 700.2365223543303, Neurons: 21
# Epoch 709, Loss: 698.9261007299568, Neurons: 21
# Epoch 710, Loss: 697.6115702630279, Neurons: 21
# Epoch 711, Loss: 696.2928398509841, Neurons: 21
# Epoch 712, Loss: 694.9698228814653, Neurons: 21
# Epoch 713, Loss: 693.6424377465163, Neurons: 21
# Epoch 714, Loss: 692.3106083572117, Neurons: 21
# Epoch 715, Loss: 690.9742646539297, Neurons: 21
# Epoch 716, Loss: 689.6333431079483, Neurons: 21
# Epoch 717, Loss: 688.2877872108296, Neurons: 21
# Epoch 718, Loss: 686.9375479492107, Neurons: 21
# Epoch 719, Loss: 685.5825842641054, Neurons: 21
# Epoch 720, Loss: 684.2228634955887, Neurons: 21
# Epoch 721, Loss: 682.858361815705, Neurons: 21
# Epoch 722, Loss: 681.4890646544617, Neurons: 21
# Epoch 723, Loss: 680.1149671257135, Neurons: 21
# Epoch 724, Loss: 678.7360744614177, Neurons: 21
# Epoch 725, Loss: 677.3524024639976, Neurons: 21
# Epoch 726, Loss: 675.9639779872136, Neurons: 21
# Epoch 727, Loss: 674.5708394559009, Neurons: 21
# Epoch 728, Loss: 673.1730374341121, Neurons: 21
# Epoch 729, Loss: 671.7706352495696, Neurons: 21
# Epoch 730, Loss: 670.3637096799085, Neurons: 21
# Epoch 731, Loss: 668.9523517030665, Neurons: 21
# Epoch 732, Loss: 667.5366673104247, Neurons: 21
# Epoch 733, Loss: 666.1167783770602, Neurons: 21
# Epoch 734, Loss: 664.6928235788506, Neurons: 21
# Epoch 735, Loss: 663.2649593412683, Neurons: 21
# Epoch 736, Loss: 661.8333607996315, Neurons: 21
# Epoch 737, Loss: 660.3982227454026, Neurons: 21
# Epoch 738, Loss: 658.9597605279495, Neurons: 21
# Epoch 739, Loss: 657.5182108761221, Neurons: 21
# Epoch 740, Loss: 656.0738325992347, Neurons: 21
# Epoch 741, Loss: 654.6269071228313, Neurons: 21
# Epoch 742, Loss: 653.1777388113586, Neurons: 21
# Epoch 743, Loss: 651.7266550280327, Neurons: 21
# Epoch 744, Loss: 650.274005882413, Neurons: 21
# Epoch 745, Loss: 648.8201636191022, Neurons: 21
# Epoch 746, Loss: 647.3655216072409, Neurons: 21
# Epoch 747, Loss: 645.9104929005308, Neurons: 21
# Epoch 748, Loss: 644.455508351601, Neurons: 21
# Epoch 749, Loss: 643.0010142824186, Neurons: 21
# Epoch 749, Test loss: 652.7099825465574
# Epoch 750, Loss: 641.5474697333628, Neurons: 21
# Epoch 751, Loss: 640.0953433362054, Neurons: 21
# Epoch 752, Loss: 638.6451098787147, Neurons: 21
# Epoch 753, Loss: 637.1972466487093, Neurons: 21
# Epoch 754, Loss: 635.7522296608503, Neurons: 21
# Epoch 755, Loss: 634.3105298782314, Neurons: 21
# Epoch 756, Loss: 632.8726095414838, Neurons: 21
# Epoch 757, Loss: 631.4389187100986, Neurons: 21
# Epoch 758, Loss: 630.0098921045548, Neurons: 21
# Epoch 759, Loss: 628.5859463152462, Neurons: 21
# Epoch 760, Loss: 627.1674774177475, Neurons: 21
# Epoch 761, Loss: 625.7548590068384, Neurons: 21
# Epoch 762, Loss: 624.3484406372803, Neurons: 21
# Epoch 763, Loss: 622.948546640446, Neurons: 21
# Epoch 764, Loss: 621.5554752744598, Neurons: 21
# Epoch 765, Loss: 620.1694981619668, Neurons: 21
# Epoch 766, Loss: 618.7908599730501, Neurons: 21
# Epoch 767, Loss: 617.4197783189604, Neurons: 21
# Epoch 768, Loss: 616.056443832393, Neurons: 21
# Epoch 769, Loss: 614.7010204192994, Neurons: 21
# Epoch 770, Loss: 613.3536456736526, Neurons: 21
# Epoch 771, Loss: 612.014431449261, Neurons: 21
# Epoch 772, Loss: 610.6834645818402, Neurons: 21
# Epoch 773, Loss: 609.3608077511295, Neurons: 21
# Epoch 774, Loss: 608.0465004682715, Neurons: 21
# Epoch 775, Loss: 606.7405601693237, Neurons: 21
# Epoch 776, Loss: 605.4429833926844, Neurons: 21
# Epoch 777, Loss: 604.1537470169579, Neurons: 21
# Epoch 778, Loss: 602.8728095364904, Neurons: 21
# Epoch 779, Loss: 601.600112354229, Neurons: 21
# Epoch 780, Loss: 600.335581075214, Neurons: 21
# Epoch 781, Loss: 599.0791267882493, Neurons: 21
# Epoch 782, Loss: 597.8306473274708, Neurons: 21
# Epoch 783, Loss: 596.5900285090659, Neurons: 21
# Epoch 784, Loss: 595.3571453408628, Neurons: 21
# Epoch 785, Loss: 594.1318632037688, Neurons: 21
# Epoch 786, Loss: 592.9140390041252, Neurons: 21
# Epoch 787, Loss: 591.703522295259, Neurons: 21
# Epoch 788, Loss: 590.5001563652664, Neurons: 21
# Epoch 789, Loss: 589.3037792867846, Neurons: 21
# Epoch 790, Loss: 588.1142249236051, Neurons: 21
# Epoch 791, Loss: 586.9313238887063, Neurons: 21
# Epoch 792, Loss: 585.7549044487022, Neurons: 21
# Epoch 793, Loss: 584.5847933707839, Neurons: 21
# Epoch 794, Loss: 583.420816709728, Neurons: 21
# Epoch 795, Loss: 582.2628005342012, Neurons: 21
# Epoch 796, Loss: 581.1105715931161, Neurons: 21
# Epoch 797, Loss: 579.963957923947, Neurons: 21
# Epoch 798, Loss: 578.8227894055665, Neurons: 21
# Epoch 799, Loss: 577.6868982582863, Neurons: 21
# Epoch 799, Test loss: 586.5378022903623
# Epoch 800, Loss: 576.5561194934833, Neurons: 21
# Epoch 801, Loss: 575.4302913146315, Neurons: 21
# Epoch 802, Loss: 574.3092554709403, Neurons: 21
# Epoch 803, Loss: 573.1928575643151, Neurons: 21
# Epoch 804, Loss: 572.0809473101406, Neurons: 21
# Epoch 805, Loss: 570.9733787524723, Neurons: 21
# Epoch 806, Loss: 569.870010434605, Neurons: 21
# Epoch 807, Loss: 568.7707055265724, Neurons: 21
# Epoch 808, Loss: 567.6753319118046, Neurons: 21
# Epoch 809, Loss: 566.5837622358245, Neurons: 21
# Epoch 810, Loss: 565.4958739203992, Neurons: 21
# Epoch 811, Loss: 564.4115491469217, Neurons: 21
# Epoch 812, Loss: 563.3306748129601, Neurons: 21
# Epoch 813, Loss: 562.2531424658785, Neurons: 21
# Epoch 814, Loss: 561.1788482172508, Neurons: 21
# Epoch 815, Loss: 560.1076926414622, Neurons: 21
# Epoch 816, Loss: 559.0395806615242, Neurons: 21
# Epoch 817, Loss: 557.9744214246949, Neurons: 21
# Epoch 818, Loss: 556.9121281700994, Neurons: 21
# Epoch 819, Loss: 555.8526180901516, Neurons: 21
# Epoch 820, Loss: 554.7958121872737, Neurons: 21
# Epoch 821, Loss: 553.7416351271411, Neurons: 21
# Epoch 822, Loss: 552.6900150895043, Neurons: 21
# Epoch 823, Loss: 551.6408836175157, Neurons: 21
# Epoch 824, Loss: 550.5941754664261, Neurons: 21
# Epoch 825, Loss: 549.549828452482, Neurons: 21
# Epoch 826, Loss: 548.5077833028365, Neurons: 21
# Epoch 827, Loss: 547.4679835072714, Neurons: 21
# Epoch 828, Loss: 546.4303751724758, Neurons: 21
# Epoch 829, Loss: 545.3949068795716, Neurons: 21
# Epoch 830, Loss: 544.3615295454675, Neurons: 21
# Epoch 831, Loss: 543.3301962885095, Neurons: 21
# Epoch 832, Loss: 542.300862298764, Neurons: 21
# Epoch 833, Loss: 541.2734847131427, Neurons: 21
# Epoch 834, Loss: 540.2480224954535, Neurons: 21
# Epoch 835, Loss: 539.2244363213736, Neurons: 21
# Epoch 836, Loss: 538.2026884682592, Neurons: 21
# Epoch 837, Loss: 537.1827427096596, Neurons: 21
# Epoch 838, Loss: 536.1645642143721, Neurons: 21
# Epoch 839, Loss: 535.1481194498576, Neurons: 21
# Epoch 840, Loss: 534.1333760898364, Neurons: 21
# Epoch 841, Loss: 533.1203029258825, Neurons: 21
# Epoch 842, Loss: 532.108869782847, Neurons: 21
# Epoch 843, Loss: 531.0990474379402, Neurons: 21
# Epoch 844, Loss: 530.0908075433165, Neurons: 21
# Epoch 845, Loss: 529.0841225520073, Neurons: 21
# Epoch 846, Loss: 528.0789656470507, Neurons: 21
# Epoch 847, Loss: 527.0753106736696, Neurons: 21
# Epoch 848, Loss: 526.0731320743492, Neurons: 21
# Epoch 849, Loss: 525.0724048266666, Neurons: 21
# Epoch 849, Test loss: 533.0749457117685
# Epoch 850, Loss: 524.0731043837224, Neurons: 21
# Epoch 851, Loss: 523.0752066170285, Neurons: 21
# Epoch 852, Loss: 522.0786877617076, Neurons: 21
# Epoch 853, Loss: 521.0835243638612, Neurons: 21
# Epoch 854, Loss: 520.0896932299734, Neurons: 21
# Epoch 855, Loss: 519.0971713782168, Neurons: 21
# Epoch 856, Loss: 518.1059359915392, Neurons: 21
# Epoch 857, Loss: 517.1159643724147, Neurons: 21
# Epoch 858, Loss: 516.1272338991462, Neurons: 21
# Epoch 859, Loss: 515.1397219836206, Neurons: 21
# Epoch 860, Loss: 514.1534060304183, Neurons: 21
# Epoch 861, Loss: 513.1682633971882, Neurons: 21
# Epoch 862, Loss: 512.1842713562032, Neurons: 21
# Epoch 863, Loss: 511.2014070570166, Neurons: 21
# Epoch 864, Loss: 510.2196474901413, Neurons: 21
# Epoch 865, Loss: 509.23896945167894, Neurons: 21
# Epoch 866, Loss: 508.2593495088222, Neurons: 21
# Epoch 867, Loss: 507.28076396616086, Neurons: 21
# Epoch 868, Loss: 506.303188832723, Neurons: 21
# Epoch 869, Loss: 505.3265997896865, Neurons: 21
# Epoch 870, Loss: 504.35097215870417, Neurons: 21
# Epoch 871, Loss: 503.37628087079656, Neurons: 21
# Epoch 872, Loss: 502.4025004357737, Neurons: 21
# Epoch 873, Loss: 501.42960491216314, Neurons: 21
# Epoch 874, Loss: 500.4575678776307, Neurons: 21
# Epoch 875, Loss: 499.4863623998953, Neurons: 21
# Epoch 876, Loss: 498.51596100815044, Neurons: 21
# Epoch 877, Loss: 497.5463356650138, Neurons: 21
# Epoch 878, Loss: 496.5774577390449, Neurons: 21
# Epoch 879, Loss: 495.6092979778711, Neurons: 21
# Epoch 880, Loss: 494.6418264819833, Neurons: 21
# Epoch 881, Loss: 493.67501267926696, Neurons: 21
# Epoch 882, Loss: 492.7088253003474, Neurons: 21
# Epoch 883, Loss: 491.7432323548384, Neurons: 21
# Epoch 884, Loss: 490.77820110859614, Neurons: 21
# Epoch 885, Loss: 489.81369806208966, Neurons: 21
# Epoch 886, Loss: 488.84968893001604, Neurons: 21
# Epoch 887, Loss: 487.8861386222929, Neurons: 21
# Epoch 888, Loss: 486.92301122658665, Neurons: 21
# Epoch 889, Loss: 485.96026999253354, Neurons: 21
# Epoch 890, Loss: 484.99787731783607, Neurons: 21
# Epoch 891, Loss: 484.0357947364186, Neurons: 21
# Epoch 892, Loss: 483.0739829088427, Neurons: 21
# Epoch 893, Loss: 482.1124016151868, Neurons: 21
# Epoch 894, Loss: 481.1510097506069, Neurons: 21
# Epoch 895, Loss: 480.1897653237939, Neurons: 21
# Epoch 896, Loss: 479.22862545855753, Neurons: 21
# Epoch 897, Loss: 478.26754639875816, Neurons: 21
# Epoch 898, Loss: 477.30648351681987, Neurons: 21
# Epoch 899, Loss: 476.34539132604823, Neurons: 21
# Epoch 899, Test loss: 483.4942389328353
# Epoch 900, Loss: 475.3842234969743, Neurons: 21
# Epoch 901, Loss: 474.4229328779382, Neurons: 21
# Epoch 902, Loss: 473.4614715201121, Neurons: 21
# Epoch 903, Loss: 472.4997907071408, Neurons: 21
# Epoch 904, Loss: 471.53784098956345, Neurons: 21
# Epoch 905, Loss: 470.57557222414215, Neurons: 21
# Epoch 906, Loss: 469.6129336181965, Neurons: 21
# Epoch 907, Loss: 468.6498737789976, Neurons: 21
# Epoch 908, Loss: 467.68634076823054, Neurons: 21
# Epoch 909, Loss: 466.7222821614849, Neurons: 21
# Epoch 910, Loss: 465.75764511266726, Neurons: 21
# Epoch 911, Loss: 464.7923764231786, Neurons: 21
# Epoch 912, Loss: 463.8264226156243, Neurons: 21
# Epoch 913, Loss: 462.8597300117642, Neurons: 21
# Epoch 914, Loss: 461.89224481433706, Neurons: 21
# Epoch 915, Loss: 460.9239131923268, Neurons: 21
# Epoch 916, Loss: 459.9546813691702, Neurons: 21
# Epoch 917, Loss: 458.9844957133422, Neurons: 21
# Epoch 918, Loss: 458.0133028306951, Neurons: 21
# Epoch 919, Loss: 457.0410496578768, Neurons: 21
# Epoch 920, Loss: 456.0676835561143, Neurons: 21
# Epoch 921, Loss: 455.0931524046127, Neurons: 21
# Epoch 922, Loss: 454.1174046928134, Neurons: 21
# Epoch 923, Loss: 453.14038961074243, Neurons: 21
# Epoch 924, Loss: 452.16205713670627, Neurons: 21
# Epoch 925, Loss: 451.1823581216142, Neurons: 21
# Epoch 926, Loss: 450.2012443692608, Neurons: 21
# Epoch 927, Loss: 449.2186687119609, Neurons: 21
# Epoch 928, Loss: 448.23458508100885, Neurons: 21
# Epoch 929, Loss: 447.2489485715219, Neurons: 21
# Epoch 930, Loss: 446.2617155013273, Neurons: 21
# Epoch 931, Loss: 445.27284346365076, Neurons: 21
# Epoch 932, Loss: 444.28229137347773, Neurons: 21
# Epoch 933, Loss: 443.29001950755327, Neurons: 21
# Epoch 934, Loss: 442.2959895380882, Neurons: 21
# Epoch 935, Loss: 441.30016456033087, Neurons: 21
# Epoch 936, Loss: 440.3025091142339, Neurons: 21
# Epoch 937, Loss: 439.30298920051627, Neurons: 21
# Epoch 938, Loss: 438.301572291467, Neurons: 21
# Epoch 939, Loss: 437.2982273368651, Neurons: 21
# Epoch 940, Loss: 436.2929247654127, Neurons: 21
# Epoch 941, Loss: 435.2856364820669, Neurons: 21
# Epoch 942, Loss: 434.27633586165126, Neurons: 21
# Epoch 943, Loss: 433.2649977390854, Neurons: 21
# Epoch 944, Loss: 432.25159839654043, Neurons: 21
# Epoch 945, Loss: 431.23611554777403, Neurons: 21
# Epoch 946, Loss: 430.2185283198437, Neurons: 21
# Epoch 947, Loss: 429.1988172323465, Neurons: 21
# Epoch 948, Loss: 428.17696417427084, Neurons: 21
# Epoch 949, Loss: 427.15295237850233, Neurons: 21
# Epoch 949, Test loss: 433.3575511583614
# Epoch 950, Loss: 426.12676639398336, Neurons: 21
# Epoch 951, Loss: 425.0983920554899, Neurons: 21
# Epoch 952, Loss: 424.06781645098425, Neurons: 21
# Epoch 953, Loss: 423.0350278864952, Neurons: 21
# Epoch 954, Loss: 422.0000158485076, Neurons: 21
# Epoch 955, Loss: 420.9627709638823, Neurons: 21
# Epoch 956, Loss: 419.9232849574054, Neurons: 21
# Epoch 957, Loss: 418.88155060715144, Neurons: 21
# Epoch 958, Loss: 417.8375616979832, Neurons: 21
# Epoch 959, Loss: 416.7913129736472, Neurons: 21
# Epoch 960, Loss: 415.74280008812224, Neurons: 21
# Epoch 961, Loss: 414.692019557076, Neurons: 21
# Epoch 962, Loss: 413.6389687105376, Neurons: 21
# Epoch 963, Loss: 412.5836456481568, Neurons: 21
# Epoch 964, Loss: 411.52604919872556, Neurons: 21
# Epoch 965, Loss: 410.46617888596245, Neurons: 21
# Epoch 966, Loss: 409.4040349029127, Neurons: 21
# Epoch 967, Loss: 408.3396180976918, Neurons: 21
# Epoch 968, Loss: 407.2729299736902, Neurons: 21
# Epoch 969, Loss: 406.20397270775766, Neurons: 21
# Epoch 970, Loss: 405.1327491902874, Neurons: 21
# Epoch 971, Loss: 404.0592630915049, Neurons: 21
# Epoch 972, Loss: 402.9835189586309, Neurons: 21
# Epoch 973, Loss: 401.9055223488983, Neurons: 21
# Epoch 974, Loss: 400.8252800036491, Neurons: 21
# Epoch 975, Loss: 399.7428000688938, Neurons: 21
# ...
# Epoch 2681, Loss: 6.850945775393714, Neurons: 21
# Epoch 2682, Loss: 6.832668398419, Neurons: 21
# Epoch 2683, Loss: 6.815775412698748, Neurons: 21
# Epoch 2684, Loss: 6.799831366260861, Neurons: 21
# Epoch 2685, Loss: 6.782845890614765, Neurons: 21
# Epoch 2686, Loss: 6.765252041679333, Neurons: 21
# Epoch 2687, Loss: 6.748837348705621, Neurons: 21
# Epoch 2688, Loss: 6.732707534459126, Neurons: 21
# Epoch 2689, Loss: 6.715621559896933, Neurons: 21
# Epoch 2690, Loss: 6.6988369435406, Neurons: 21
# Epoch 2691, Loss: 6.682827320093018, Neurons: 21
# Epoch 2692, Loss: 6.666306090664273, Neurons: 21
# Epoch 2693, Loss: 6.6495562385132905, Neurons: 21
# Epoch 2694, Loss: 6.633480597292731, Neurons: 21
# Epoch 2695, Loss: 6.617320380877242, Neurons: 21
# Epoch 2696, Loss: 6.60078851075584, Neurons: 21
# Epoch 2697, Loss: 6.584681975167018, Neurons: 21
# Epoch 2698, Loss: 6.568730629791462, Neurons: 21
# Epoch 2699, Loss: 6.552455909804148, Neurons: 21
# Epoch 2699, Test loss: 6.396694940464397
# Epoch 2700, Loss: 6.536390235961395, Neurons: 21
# Epoch 2701, Loss: 6.520570250840206, Neurons: 21
# Epoch 2702, Loss: 6.5045359769721225, Neurons: 21
# Epoch 2703, Loss: 6.488567172242522, Neurons: 21
# Epoch 2704, Loss: 6.472847875123733, Neurons: 21
# Epoch 2705, Loss: 6.45702372940817, Neurons: 21
# Epoch 2706, Loss: 6.441186717298199, Neurons: 21
# Epoch 2707, Loss: 6.425561452571099, Neurons: 21
# Epoch 2708, Loss: 6.409918366804238, Neurons: 21
# Epoch 2709, Loss: 6.394231610179146, Neurons: 21
# Epoch 2710, Loss: 6.378704825258091, Neurons: 21
# Epoch 2711, Loss: 6.363219521338151, Neurons: 21
# Epoch 2712, Loss: 6.347690467650276, Neurons: 21
# Epoch 2713, Loss: 6.332270934169869, Neurons: 21
# Epoch 2714, Loss: 6.316926349004238, Neurons: 21
# Epoch 2715, Loss: 6.301555233062419, Neurons: 21
# Epoch 2716, Loss: 6.286252643211333, Neurons: 21
# Epoch 2717, Loss: 6.271037530972432, Neurons: 21
# Epoch 2718, Loss: 6.255820138940176, Neurons: 21
# Epoch 2719, Loss: 6.24064309856987, Neurons: 21
# Epoch 2720, Loss: 6.225551140145141, Neurons: 21
# Epoch 2721, Loss: 6.210480828556606, Neurons: 21
# Epoch 2722, Loss: 6.195435820939577, Neurons: 21
# Epoch 2723, Loss: 6.180464775524918, Neurons: 21
# Epoch 2724, Loss: 6.16553415566347, Neurons: 21
# Epoch 2725, Loss: 6.150624907944225, Neurons: 21
# Epoch 2726, Loss: 6.135775428721706, Neurons: 21
# Epoch 2727, Loss: 6.120977672845762, Neurons: 21
# Epoch 2728, Loss: 6.10620507007307, Neurons: 21
# Epoch 2729, Loss: 6.091479478602145, Neurons: 21
# Epoch 2730, Loss: 6.076809337458864, Neurons: 21
# Epoch 2731, Loss: 6.062171816320269, Neurons: 21
# Epoch 2732, Loss: 6.047572790785338, Neurons: 21
# Epoch 2733, Loss: 6.033027118387725, Neurons: 21
# Epoch 2734, Loss: 6.018521529685453, Neurons: 21
# Epoch 2735, Loss: 6.004051003323673, Neurons: 21
# Epoch 2736, Loss: 5.989628679859194, Neurons: 21
# Epoch 2737, Loss: 5.975251347123082, Neurons: 21
# Epoch 2738, Loss: 5.960909807053744, Neurons: 21
# Epoch 2739, Loss: 5.946611133647106, Neurons: 21
# Epoch 2740, Loss: 5.932358889760323, Neurons: 21
# Epoch 2741, Loss: 5.918145308109948, Neurons: 21
# Epoch 2742, Loss: 5.903971081133532, Neurons: 21
# Epoch 2743, Loss: 5.889841891726009, Neurons: 21
# Epoch 2744, Loss: 5.875754197714455, Neurons: 21
# Epoch 2745, Loss: 5.861704819932066, Neurons: 21
# Epoch 2746, Loss: 5.847697844513116, Neurons: 21
# Epoch 2747, Loss: 5.833733718452979, Neurons: 21
# Epoch 2748, Loss: 5.819808693281363, Neurons: 21
# Epoch 2749, Loss: 5.805923812583646, Neurons: 21
# Epoch 2749, Test loss: 5.654725025259562
# Epoch 2750, Loss: 5.792081397161138, Neurons: 21
# Epoch 2751, Loss: 5.778279382191475, Neurons: 21
# Epoch 2752, Loss: 5.764516512434656, Neurons: 21
# Epoch 2753, Loss: 5.7507947149175775, Neurons: 21
# Epoch 2754, Loss: 5.737114000525948, Neurons: 21
# Epoch 2755, Loss: 5.723472573097219, Neurons: 21
# Epoch 2756, Loss: 5.709870867910458, Neurons: 21
# Epoch 2757, Loss: 5.696309943020062, Neurons: 21
# Epoch 2758, Loss: 5.682788825203212, Neurons: 21
# Epoch 2759, Loss: 5.66930677408705, Neurons: 21
# Epoch 2760, Loss: 5.655864607966557, Neurons: 21
# Epoch 2761, Loss: 5.6424624125600085, Neurons: 21
# Epoch 2762, Loss: 5.629099273336247, Neurons: 21
# Epoch 2763, Loss: 5.615775194842418, Neurons: 21
# Epoch 2764, Loss: 5.602490683491006, Neurons: 21
# Epoch 2765, Loss: 5.589245361278557, Neurons: 21
# Epoch 2766, Loss: 5.57603871272721, Neurons: 21
# Epoch 2767, Loss: 5.562870967209856, Neurons: 21
# Epoch 2768, Loss: 5.549742262072752, Neurons: 21
# Epoch 2769, Loss: 5.536652157508665, Neurons: 21
# Epoch 2770, Loss: 5.523600440498736, Neurons: 21
# Epoch 2771, Loss: 5.510587309422537, Neurons: 21
# Epoch 2772, Loss: 5.497612672109388, Neurons: 21
# Epoch 2773, Loss: 5.484676179582786, Neurons: 21
# Epoch 2774, Loss: 5.471777778287427, Neurons: 21
# Epoch 2775, Loss: 5.4589175492585476, Neurons: 21
# Epoch 2776, Loss: 5.446095313849915, Neurons: 21
# Epoch 2777, Loss: 5.433310837892973, Neurons: 21
# Epoch 2778, Loss: 5.420564103162645, Neurons: 21
# Epoch 2779, Loss: 5.407855101668463, Neurons: 21
# Epoch 2780, Loss: 5.395183647168398, Neurons: 21
# Epoch 2781, Loss: 5.38254957553563, Neurons: 21
# Epoch 2782, Loss: 5.369952865976297, Neurons: 21
# Epoch 2783, Loss: 5.357393454337067, Neurons: 21
# Epoch 2784, Loss: 5.344871170946485, Neurons: 21
# Epoch 2785, Loss: 5.332385895854435, Neurons: 21
# Epoch 2786, Loss: 5.319937584445275, Neurons: 21
# Epoch 2787, Loss: 5.307526148114675, Neurons: 21
# Epoch 2788, Loss: 5.295151441055228, Neurons: 21
# Epoch 2789, Loss: 5.28281335739123, Neurons: 21
# Epoch 2790, Loss: 5.270511837174691, Neurons: 21
# Epoch 2791, Loss: 5.258246782270845, Neurons: 21
# Epoch 2792, Loss: 5.2460180620814265, Neurons: 21
# Epoch 2793, Loss: 5.233825579904036, Neurons: 21
# Epoch 2794, Loss: 5.221669261057144, Neurons: 21
# Epoch 2795, Loss: 5.2095490059767995, Neurons: 21
# Epoch 2796, Loss: 5.1974646975544925, Neurons: 21
# Epoch 2797, Loss: 5.185416238221055, Neurons: 21
# Epoch 2798, Loss: 5.173403546993851, Neurons: 21
# Epoch 2799, Loss: 5.16142652546985, Neurons: 21
# Epoch 2799, Test loss: 5.014891313227194
# Epoch 2800, Loss: 5.149485063045951, Neurons: 21
# Epoch 2801, Loss: 5.137579064024183, Neurons: 21
# Epoch 2802, Loss: 5.125708441295155, Neurons: 21
# Epoch 2803, Loss: 5.113873098464349, Neurons: 21
# Epoch 2804, Loss: 5.102072931398066, Neurons: 21
# Epoch 2805, Loss: 5.090307842627058, Neurons: 21
# Epoch 2806, Loss: 5.078577743301353, Neurons: 21
# Epoch 2807, Loss: 5.066882538655071, Neurons: 21
# Epoch 2808, Loss: 5.055222127667418, Neurons: 21
# Epoch 2809, Loss: 5.043596414173542, Neurons: 21
# Epoch 2810, Loss: 5.032005306590452, Neurons: 21
# Epoch 2811, Loss: 5.020448711787649, Neurons: 21
# Epoch 2812, Loss: 5.008926532310409, Neurons: 21
# Epoch 2813, Loss: 4.997438671515154, Neurons: 21
# Epoch 2814, Loss: 4.985985037637097, Neurons: 21
# Epoch 2815, Loss: 4.974565538160975, Neurons: 21
# Epoch 2816, Loss: 4.9631800777357915, Neurons: 21
# Epoch 2817, Loss: 4.951828561355858, Neurons: 21
# Epoch 2818, Loss: 4.9405108959999, Neurons: 21
# Epoch 2819, Loss: 4.929226990112386, Neurons: 21
# Epoch 2820, Loss: 4.917976750354131, Neurons: 21
# Epoch 2821, Loss: 4.906760082421355, Neurons: 21
# Epoch 2822, Loss: 4.895576893896574, Neurons: 21
# Epoch 2823, Loss: 4.884427093112926, Neurons: 21
# Epoch 2824, Loss: 4.87331058820304, Neurons: 21
# Epoch 2825, Loss: 4.862227286531838, Neurons: 21
# Epoch 2826, Loss: 4.851177095618725, Neurons: 21
# Epoch 2827, Loss: 4.840159924484717, Neurons: 21
# Epoch 2828, Loss: 4.8291756820772225, Neurons: 21
# Epoch 2829, Loss: 4.818224276950583, Neurons: 21
# Epoch 2830, Loss: 4.807305617763945, Neurons: 21
# Epoch 2831, Loss: 4.796419613529205, Neurons: 21
# Epoch 2832, Loss: 4.7855661741275215, Neurons: 21
# Epoch 2833, Loss: 4.7747452092180085, Neurons: 21
# Epoch 2834, Loss: 4.763956628274437, Neurons: 21
# Epoch 2835, Loss: 4.753200341210536, Neurons: 21
# Epoch 2836, Loss: 4.742476258194295, Neurons: 21
# Epoch 2837, Loss: 4.731784289889372, Neurons: 21
# Epoch 2838, Loss: 4.721124346850605, Neurons: 21
# Epoch 2839, Loss: 4.710496339618247, Neurons: 21
# Epoch 2840, Loss: 4.699900179209256, Neurons: 21
# Epoch 2841, Loss: 4.689335776803175, Neurons: 21
# Epoch 2842, Loss: 4.678803043916512, Neurons: 21
# Epoch 2843, Loss: 4.66830189208313, Neurons: 21
# Epoch 2844, Loss: 4.65783223290812, Neurons: 21
# Epoch 2845, Loss: 4.647393978417543, Neurons: 21
# Epoch 2846, Loss: 4.6369870407631435, Neurons: 21
# Epoch 2847, Loss: 4.626611332377586, Neurons: 21
# Epoch 2848, Loss: 4.61626676578857, Neurons: 21
# Epoch 2849, Loss: 4.6059532536351835, Neurons: 21
# Epoch 2849, Test loss: 4.464405971418519
# Epoch 2850, Loss: 4.595670708913221, Neurons: 21
# Epoch 2851, Loss: 4.585419044739333, Neurons: 21
# Epoch 2852, Loss: 4.5751981744934715, Neurons: 21
# Epoch 2853, Loss: 4.565008011687871, Neurons: 21
# Epoch 2854, Loss: 4.554848469969838, Neurons: 21
# Epoch 2855, Loss: 4.544719463290586, Neurons: 21
# Epoch 2856, Loss: 4.534620905728679, Neurons: 21
# Epoch 2857, Loss: 4.524552711620316, Neurons: 21
# Epoch 2858, Loss: 4.514514795448819, Neurons: 21
# Epoch 2859, Loss: 4.504507071852153, Neurons: 21
# Epoch 2860, Loss: 4.4945294557310165, Neurons: 21
# Epoch 2861, Loss: 4.484581862122452, Neurons: 21
# Epoch 2862, Loss: 4.47466420631706, Neurons: 21
# Epoch 2863, Loss: 4.464776403757317, Neurons: 21
# Epoch 2864, Loss: 4.454918370059223, Neurons: 21
# Epoch 2865, Loss: 4.445090021068756, Neurons: 21
# Epoch 2866, Loss: 4.4352912727779135, Neurons: 21
# Epoch 2867, Loss: 4.425522041425014, Neurons: 21
# Epoch 2868, Loss: 4.415782243401629, Neurons: 21
# Epoch 2869, Loss: 4.406071795290618, Neurons: 21
# Epoch 2870, Loss: 4.396390613878692, Neurons: 21
# Epoch 2871, Loss: 4.386738616109791, Neurons: 21
# Epoch 2872, Loss: 4.377115719161742, Neurons: 21
# Epoch 2873, Loss: 4.367521840367163, Neurons: 21
# Epoch 2874, Loss: 4.357956897263914, Neurons: 21
# Epoch 2875, Loss: 4.348420807573991, Neurons: 21
# Epoch 2876, Loss: 4.3389134891901024, Neurons: 21
# Epoch 2877, Loss: 4.3294348602215456, Neurons: 21
# Epoch 2878, Loss: 4.319984838936407, Neurons: 21
# Epoch 2879, Loss: 4.310563343814526, Neurons: 21
# Epoch 2880, Loss: 4.301170293507056, Neurons: 21
# Epoch 2881, Loss: 4.291805606850371, Neurons: 21
# Epoch 2882, Loss: 4.282469202878217, Neurons: 21
# Epoch 2883, Loss: 4.273161000791044, Neurons: 21
# Epoch 2884, Loss: 4.2638809199976535, Neurons: 21
# Epoch 2885, Loss: 4.254628880072821, Neurons: 21
# Epoch 2886, Loss: 4.245404800787674, Neurons: 21
# Epoch 2887, Loss: 4.236208602094157, Neurons: 21
# Epoch 2888, Loss: 4.227040204122283, Neurons: 21
# Epoch 2889, Loss: 4.217899527198606, Neurons: 21
# Epoch 2890, Loss: 4.208786491817903, Neurons: 21
# Epoch 2891, Loss: 4.199701018673858, Neurons: 21
# Epoch 2892, Loss: 4.190643028631342, Neurons: 21
# Epoch 2893, Loss: 4.181612442743988, Neurons: 21
# Epoch 2894, Loss: 4.172609182247623, Neurons: 21
# Epoch 2895, Loss: 4.163633168554557, Neurons: 21
# Epoch 2896, Loss: 4.154684323268671, Neurons: 21
# Epoch 2897, Loss: 4.145762568164353, Neurons: 21
# Epoch 2898, Loss: 4.136867825208257, Neurons: 21
# Epoch 2899, Loss: 4.12800001653966, Neurons: 21
# Epoch 2899, Test loss: 3.9915919702417377
# Epoch 2900, Loss: 4.119159064483253, Neurons: 21
# Epoch 2901, Loss: 4.1103448915434235, Neurons: 21
# Epoch 2902, Loss: 4.101557420401672, Neurons: 21
# Epoch 2903, Loss: 4.092796573925462, Neurons: 21
# Epoch 2904, Loss: 4.084062275154404, Neurons: 21
# Epoch 2905, Loss: 4.0753544473153465, Neurons: 21
# Epoch 2906, Loss: 4.066673013807379, Neurons: 21
# Epoch 2907, Loss: 4.05801789821337, Neurons: 21
# Epoch 2908, Loss: 4.049389024292168, Neurons: 21
# Epoch 2909, Loss: 4.040786315980879, Neurons: 21
# Epoch 2910, Loss: 4.032209697396825, Neurons: 21
# Epoch 2911, Loss: 4.023659092831056, Neurons: 21
# Epoch 2912, Loss: 4.01513442675712, Neurons: 21
# Epoch 2913, Loss: 4.006635623820423, Neurons: 21
# Epoch 2914, Loss: 3.9981626088482227, Neurons: 21
# Epoch 2915, Loss: 3.9897153068403335, Neurons: 21
# Epoch 2916, Loss: 3.981293642975633, Neurons: 21
# Epoch 2917, Loss: 3.9728975426077446, Neurons: 21
# Epoch 2918, Loss: 3.9645269312659512, Neurons: 21
# Epoch 2919, Loss: 3.9561817346564365, Neurons: 21
# Epoch 2920, Loss: 3.9478618786581983, Neurons: 21
# Epoch 2921, Loss: 3.9395672893282674, Neurons: 21
# Epoch 2922, Loss: 3.9312978928949547, Neurons: 21
# Epoch 2923, Loss: 3.923053615764385, Neurons: 21
# Epoch 2924, Loss: 3.914834384513689, Neurons: 21
# Epoch 2925, Loss: 3.9066401258964705, Neurons: 21
# Epoch 2926, Loss: 3.8984707668379133, Neurons: 21
# Epoch 2927, Loss: 3.890326234437785, Neurons: 21
# Epoch 2928, Loss: 3.882206455968316, Neurons: 21
# Epoch 2929, Loss: 3.8741113588743903, Neurons: 21
# Epoch 2930, Loss: 3.866040870774071, Neurons: 21
# Epoch 2931, Loss: 3.8579949194564116, Neurons: 21
# Epoch 2932, Loss: 3.849973432884009, Neurons: 21
# Epoch 2933, Loss: 3.8419763391892383, Neurons: 21
# Epoch 2934, Loss: 3.834003566677921, Neurons: 21
# Epoch 2935, Loss: 3.826055043824857, Neurons: 21
# Epoch 2936, Loss: 3.8181306992778064, Neurons: 21
# Epoch 2937, Loss: 3.8102304618530436, Neurons: 21
# Epoch 2938, Loss: 3.802354260539076, Neurons: 21
# Epoch 2939, Loss: 3.794502024492655, Neurons: 21
# Epoch 2940, Loss: 3.786673683041888, Neurons: 21
# Epoch 2941, Loss: 3.7788691656829165, Neurons: 21
# Epoch 2942, Loss: 3.7710884020823654, Neurons: 21
# Epoch 2943, Loss: 3.763331322074684, Neurons: 21
# Epoch 2944, Loss: 3.7555978556639413, Neurons: 21
# Epoch 2945, Loss: 3.747887933021776, Neurons: 21
# Epoch 2946, Loss: 3.740201484488651, Neurons: 21
# Epoch 2947, Loss: 3.7325384405722524, Neurons: 21
# Epoch 2948, Loss: 3.7248987319484095, Neurons: 21
# Epoch 2949, Loss: 3.71728228945975, Neurons: 21
# Epoch 2949, Test loss: 3.5860632984582446
# Epoch 2950, Loss: 3.709689044116399, Neurons: 21
# Epoch 2951, Loss: 3.7021189270948063, Neurons: 21
# Epoch 2952, Loss: 3.694571869738348, Neurons: 21
# Epoch 2953, Loss: 3.6870478035561844, Neurons: 21
# Epoch 2954, Loss: 3.679546660223899, Neurons: 21
# Epoch 2955, Loss: 3.672068371582243, Neurons: 21
# Epoch 2956, Loss: 3.664612869637959, Neurons: 21
# Epoch 2957, Loss: 3.657180086562275, Neurons: 21
# Epoch 2958, Loss: 3.6497699546920566, Neurons: 21
# Epoch 2959, Loss: 3.642382406527881, Neurons: 21
# Epoch 2960, Loss: 3.6350173747357273, Neurons: 21
# Epoch 2961, Loss: 3.6276747921443384, Neurons: 21
# Epoch 2962, Loss: 3.6203545917478728, Neurons: 21
# Epoch 2963, Loss: 3.61305670670201, Neurons: 21
# Epoch 2964, Loss: 3.6057810703282103, Neurons: 21
# Epoch 2965, Loss: 3.598527616107751, Neurons: 21
# Epoch 2966, Loss: 3.5912962776886883, Neurons: 21
# Epoch 2967, Loss: 3.5840869888763645, Neurons: 21
# Epoch 2968, Loss: 3.576899683645058, Neurons: 21
# Epoch 2969, Loss: 3.569734296122297, Neurons: 21
# Epoch 2970, Loss: 3.5625907606088267, Neurons: 21
# Epoch 2971, Loss: 3.555469011551922, Neurons: 21
# Epoch 2972, Loss: 3.5483689835804624, Neurons: 21
# Epoch 2973, Loss: 3.541290611458293, Neurons: 21
# Epoch 2974, Loss: 3.534233830147544, Neurons: 21
# Epoch 2975, Loss: 3.5271985747254107, Neurons: 21
# Epoch 2976, Loss: 3.5201847805021753, Neurons: 21
# Epoch 2977, Loss: 3.513192382871038, Neurons: 21
# Epoch 2978, Loss: 3.506221317537543, Neurons: 21
# Epoch 2979, Loss: 3.4992715202515057, Neurons: 21
# Epoch 2980, Loss: 3.4923429272821784, Neurons: 21
# Epoch 2981, Loss: 3.4854354749725784, Neurons: 21
# Epoch 2982, Loss: 3.478549100830808, Neurons: 21
# Epoch 2983, Loss: 3.4716837429916794, Neurons: 21
# Epoch 2984, Loss: 3.4648393431573643, Neurons: 21
# Epoch 2985, Loss: 3.4580158471730313, Neurons: 21
# Epoch 2986, Loss: 3.451213214738548, Neurons: 21
# Epoch 2987, Loss: 3.444431428932467, Neurons: 21
# Epoch 2988, Loss: 3.4376705352151906, Neurons: 21
# Epoch 2989, Loss: 3.4309307046712596, Neurons: 21
# Epoch 2990, Loss: 3.4242124147156066, Neurons: 21
# Epoch 2991, Loss: 3.417516815173097, Neurons: 21
# Epoch 2992, Loss: 3.410846635344738, Neurons: 21
# Epoch 2993, Loss: 3.4042082139987464, Neurons: 21
# Epoch 2994, Loss: 3.397616025370265, Neurons: 21
# Epoch 2995, Loss: 3.391102752126892, Neurons: 21
# Epoch 2996, Loss: 3.3847350371331153, Neurons: 21
# Epoch 2997, Loss: 3.378631553162984, Neurons: 21
# Epoch 2998, Loss: 3.372875807388164, Neurons: 21
# Epoch 2999, Loss: 3.3672205599881155, Neurons: 21
# Epoch 2999, Test loss: 3.2422752350497617

# %%
np.savetxt(f"{out_folder}/neurons.txt", node_history)
np.savetxt(f"{out_folder}/train_loss.txt", train_loss_history)
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)

# %% [markdown]
# ### evaluation

# %%
y_pred.shape
y_test.shape
# Out:
# (4000, 1)

# %%
plt.plot(x_test, y_pred, "r.", alpha=0.2, label="true")
plt.plot(x_test, y_test, "b.", alpha=0.2, label="true")

# %%
y_pred = jax.vmap(mlp)(x_test)
test_mse = jnp.mean((y_pred - y_test) ** 2)
plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, "b.", alpha=0.2, label="True Poly Function")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label="MLP Predictions\n Test MSE: {:.4f}".format(test_mse))
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("MLP Approximation of polynomial Function")
plt.savefig(f"{fig_folder}/polynomial_approximation.png")
wandb.log({"polynomial approximation": wandb.Image(plt, caption="polynomial approximation")})

# %%
update_history
# Out:
# []

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '-', color=color)
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

plt.suptitle("Homogenous Neural Network with no strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()
