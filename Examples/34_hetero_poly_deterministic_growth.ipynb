# %% [markdown]
# # Deterministic growth strategy for Polynomial prediction with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "27_hetero_poly_probabilistic_bare.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="27_hetero_poly_probabilistic_bare.ipynb"
# env: WANDB_SILENT=True

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

import os
import sys
import time
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 1
hidden_sizes = [5, 5] 
min_neurons = 10
max_neurons = 64
output_size = 1
initial_activation_list = [sin, jax.nn.relu, jax.nn.tanh]
activation_list = [sin, jax.nn.relu, jax.nn.tanh]
optimizer = optax.adabelief
bias = False
num_epochs = 25000
intervene_every = 100
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"Hetero_{act_string}_poly_deterministic_addition_{optimizer.__name__}_no_bias_min_{min_neurons}_max_{max_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: Hetero_sin_relu_tanh_poly_deterministic_addition_adabelief_no_bias_min_10_max_64_5_5_25000_100_0.0001_0
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
def poly(x):
    """
    7th degree polynomial to predict
    """
    return (x - 3)*(x - 2)*(x - 1)*x*(x + 1)*(x + 2)*(x + 3)

# %%
x = jnp.linspace(-3, 3, n_samples).reshape(-1, 1)
y = poly(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.2, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha = 0.2, label=f"test:{len(x_test)}")
plt.legend()
plt.suptitle("Data")
# Out:
# Text(0.5, 0.98, 'Data')

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0]

# %%
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 11

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []
det_neuron_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity
X_0 = 1000

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}")
        wandb.log({"test_loss": test_loss.item()})
        test_loss_history.append((epoch,test_loss))

        # Neuron Addition criteria
        if n_neurons< max_neurons:

            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(act_key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0] # randomly select a layer to add neuron to
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            update_history.append((epoch, n_neurons, train_loss, test_loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 1508.8876953125, Neurons: 11, Grad norm: 4.791e+01
# Epoch 001, Loss: 1508.81396484375, Neurons: 11, Grad norm: 4.791e+01
# Epoch 002, Loss: 1508.736572265625, Neurons: 11, Grad norm: 4.790e+01
# Epoch 003, Loss: 1508.6552734375, Neurons: 11, Grad norm: 4.790e+01
# Epoch 004, Loss: 1508.5703125, Neurons: 11, Grad norm: 4.789e+01
# Epoch 076, Loss: 1494.001708984375, Neurons: 11, Grad norm: 5.163e+01
# Epoch 077, Loss: 1493.68603515625, Neurons: 11, Grad norm: 5.177e+01
# Epoch 078, Loss: 1493.36669921875, Neurons: 11, Grad norm: 5.190e+01
# Epoch 079, Loss: 1493.0438232421875, Neurons: 11, Grad norm: 5.204e+01
# Epoch 080, Loss: 1492.717041015625, Neurons: 11, Grad norm: 5.218e+01
# Epoch 081, Loss: 1492.3868408203125, Neurons: 11, Grad norm: 5.232e+01
# Epoch 082, Loss: 1492.0528564453125, Neurons: 11, Grad norm: 5.247e+01
# Epoch 083, Loss: 1491.715087890625, Neurons: 11, Grad norm: 5.261e+01
# Epoch 084, Loss: 1491.37353515625, Neurons: 11, Grad norm: 5.275e+01
# Epoch 085, Loss: 1491.0283203125, Neurons: 11, Grad norm: 5.290e+01
# Epoch 086, Loss: 1490.6793212890625, Neurons: 11, Grad norm: 5.305e+01
# Epoch 087, Loss: 1490.3265380859375, Neurons: 11, Grad norm: 5.319e+01
# Epoch 088, Loss: 1489.9698486328125, Neurons: 11, Grad norm: 5.334e+01
# Epoch 089, Loss: 1489.6092529296875, Neurons: 11, Grad norm: 5.349e+01
# Epoch 090, Loss: 1489.2447509765625, Neurons: 11, Grad norm: 5.364e+01
# Epoch 091, Loss: 1488.8763427734375, Neurons: 11, Grad norm: 5.379e+01
# Epoch 092, Loss: 1488.504150390625, Neurons: 11, Grad norm: 5.394e+01
# Epoch 093, Loss: 1488.1280517578125, Neurons: 11, Grad norm: 5.409e+01
# Epoch 094, Loss: 1487.748046875, Neurons: 11, Grad norm: 5.424e+01
# Epoch 095, Loss: 1487.364013671875, Neurons: 11, Grad norm: 5.439e+01
# Epoch 096, Loss: 1486.976318359375, Neurons: 11, Grad norm: 5.454e+01
# Epoch 097, Loss: 1486.5845947265625, Neurons: 11, Grad norm: 5.469e+01
# Epoch 098, Loss: 1486.1888427734375, Neurons: 11, Grad norm: 5.484e+01
# Epoch 099, Loss: 1485.7891845703125, Neurons: 11, Grad norm: 5.499e+01
# Epoch 099, Test loss: 1515.2196044921875
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[6, 5, 1]
# Epoch 100, Loss: 1483.5963134765625, Neurons: 12, Grad norm: 5.586e+01
# Epoch 101, Loss: 1483.5137939453125, Neurons: 12, Grad norm: 5.585e+01
# Epoch 102, Loss: 1483.427490234375, Neurons: 12, Grad norm: 5.585e+01
# Epoch 103, Loss: 1483.33642578125, Neurons: 12, Grad norm: 5.584e+01
# Epoch 104, Loss: 1483.2415771484375, Neurons: 12, Grad norm: 5.584e+01
# Epoch 105, Loss: 1483.142333984375, Neurons: 12, Grad norm: 5.583e+01
# Epoch 106, Loss: 1483.038818359375, Neurons: 12, Grad norm: 5.583e+01
# Epoch 107, Loss: 1482.93115234375, Neurons: 12, Grad norm: 5.582e+01
# Epoch 108, Loss: 1482.8193359375, Neurons: 12, Grad norm: 5.581e+01
# Epoch 109, Loss: 1482.703369140625, Neurons: 12, Grad norm: 5.581e+01
# Epoch 110, Loss: 1482.583251953125, Neurons: 12, Grad norm: 5.580e+01
# Epoch 111, Loss: 1482.4591064453125, Neurons: 12, Grad norm: 5.579e+01
# Epoch 112, Loss: 1482.330810546875, Neurons: 12, Grad norm: 5.578e+01
# Epoch 113, Loss: 1482.1986083984375, Neurons: 12, Grad norm: 5.578e+01
# Epoch 114, Loss: 1482.0626220703125, Neurons: 12, Grad norm: 5.577e+01
# Epoch 115, Loss: 1481.9227294921875, Neurons: 12, Grad norm: 5.576e+01
# Epoch 116, Loss: 1481.779052734375, Neurons: 12, Grad norm: 5.575e+01
# Epoch 117, Loss: 1481.6319580078125, Neurons: 12, Grad norm: 5.574e+01
# Epoch 118, Loss: 1481.481201171875, Neurons: 12, Grad norm: 5.573e+01
# Epoch 119, Loss: 1481.3267822265625, Neurons: 12, Grad norm: 5.573e+01
# Epoch 120, Loss: 1481.1693115234375, Neurons: 12, Grad norm: 5.572e+01
# Epoch 121, Loss: 1481.00830078125, Neurons: 12, Grad norm: 5.571e+01
# Epoch 122, Loss: 1480.8441162109375, Neurons: 12, Grad norm: 5.570e+01
# Epoch 123, Loss: 1480.6768798828125, Neurons: 12, Grad norm: 5.570e+01
# Epoch 124, Loss: 1480.50634765625, Neurons: 12, Grad norm: 5.569e+01
# Epoch 125, Loss: 1480.3331298828125, Neurons: 12, Grad norm: 5.569e+01
# Epoch 126, Loss: 1480.1566162109375, Neurons: 12, Grad norm: 5.568e+01
# Epoch 127, Loss: 1479.9775390625, Neurons: 12, Grad norm: 5.568e+01
# Epoch 128, Loss: 1479.7955322265625, Neurons: 12, Grad norm: 5.567e+01
# Epoch 129, Loss: 1479.6107177734375, Neurons: 12, Grad norm: 5.567e+01
# Epoch 130, Loss: 1479.4232177734375, Neurons: 12, Grad norm: 5.567e+01
# Epoch 131, Loss: 1479.2332763671875, Neurons: 12, Grad norm: 5.567e+01
# Epoch 132, Loss: 1479.0406494140625, Neurons: 12, Grad norm: 5.567e+01
# Epoch 133, Loss: 1478.8455810546875, Neurons: 12, Grad norm: 5.567e+01
# Epoch 134, Loss: 1478.64794921875, Neurons: 12, Grad norm: 5.567e+01
# Epoch 135, Loss: 1478.447998046875, Neurons: 12, Grad norm: 5.568e+01
# Epoch 136, Loss: 1478.24560546875, Neurons: 12, Grad norm: 5.569e+01
# Epoch 137, Loss: 1478.040771484375, Neurons: 12, Grad norm: 5.569e+01
# Epoch 138, Loss: 1477.8338623046875, Neurons: 12, Grad norm: 5.570e+01
# Epoch 139, Loss: 1477.624267578125, Neurons: 12, Grad norm: 5.572e+01
# Epoch 140, Loss: 1477.41259765625, Neurons: 12, Grad norm: 5.573e+01
# Epoch 141, Loss: 1477.19873046875, Neurons: 12, Grad norm: 5.574e+01
# Epoch 142, Loss: 1476.982421875, Neurons: 12, Grad norm: 5.576e+01
# Epoch 143, Loss: 1476.7640380859375, Neurons: 12, Grad norm: 5.578e+01
# Epoch 144, Loss: 1476.54345703125, Neurons: 12, Grad norm: 5.580e+01
# Epoch 145, Loss: 1476.320556640625, Neurons: 12, Grad norm: 5.582e+01
# Epoch 146, Loss: 1476.0955810546875, Neurons: 12, Grad norm: 5.585e+01
# Epoch 147, Loss: 1475.8682861328125, Neurons: 12, Grad norm: 5.587e+01
# Epoch 148, Loss: 1475.638916015625, Neurons: 12, Grad norm: 5.590e+01
# Epoch 149, Loss: 1475.4073486328125, Neurons: 12, Grad norm: 5.593e+01
# Epoch 150, Loss: 1475.17333984375, Neurons: 12, Grad norm: 5.596e+01
# Epoch 151, Loss: 1474.9373779296875, Neurons: 12, Grad norm: 5.600e+01
# Epoch 152, Loss: 1474.6990966796875, Neurons: 12, Grad norm: 5.603e+01
# Epoch 153, Loss: 1474.4586181640625, Neurons: 12, Grad norm: 5.607e+01
# Epoch 154, Loss: 1474.2158203125, Neurons: 12, Grad norm: 5.611e+01
# Epoch 155, Loss: 1473.9708251953125, Neurons: 12, Grad norm: 5.616e+01
# Epoch 156, Loss: 1473.7237548828125, Neurons: 12, Grad norm: 5.620e+01
# Epoch 157, Loss: 1473.47412109375, Neurons: 12, Grad norm: 5.625e+01
# Epoch 158, Loss: 1473.2222900390625, Neurons: 12, Grad norm: 5.630e+01
# Epoch 159, Loss: 1472.968017578125, Neurons: 12, Grad norm: 5.635e+01
# Epoch 160, Loss: 1472.711669921875, Neurons: 12, Grad norm: 5.640e+01
# Epoch 161, Loss: 1472.452880859375, Neurons: 12, Grad norm: 5.646e+01
# Epoch 162, Loss: 1472.191650390625, Neurons: 12, Grad norm: 5.652e+01
# Epoch 163, Loss: 1471.9281005859375, Neurons: 12, Grad norm: 5.658e+01
# Epoch 164, Loss: 1471.662109375, Neurons: 12, Grad norm: 5.664e+01
# Epoch 165, Loss: 1471.3935546875, Neurons: 12, Grad norm: 5.670e+01
# Epoch 166, Loss: 1471.12255859375, Neurons: 12, Grad norm: 5.677e+01
# Epoch 167, Loss: 1470.84912109375, Neurons: 12, Grad norm: 5.683e+01
# Epoch 168, Loss: 1470.5731201171875, Neurons: 12, Grad norm: 5.690e+01
# Epoch 169, Loss: 1470.2945556640625, Neurons: 12, Grad norm: 5.696e+01
# Epoch 170, Loss: 1470.0135498046875, Neurons: 12, Grad norm: 5.702e+01
# Epoch 171, Loss: 1469.7301025390625, Neurons: 12, Grad norm: 5.708e+01
# Epoch 172, Loss: 1469.4442138671875, Neurons: 12, Grad norm: 5.714e+01
# Epoch 173, Loss: 1469.1556396484375, Neurons: 12, Grad norm: 5.721e+01
# Epoch 174, Loss: 1468.8648681640625, Neurons: 12, Grad norm: 5.728e+01
# Epoch 175, Loss: 1468.5712890625, Neurons: 12, Grad norm: 5.736e+01
# Epoch 176, Loss: 1468.2752685546875, Neurons: 12, Grad norm: 5.744e+01
# Epoch 177, Loss: 1467.976806640625, Neurons: 12, Grad norm: 5.752e+01
# Epoch 178, Loss: 1467.67529296875, Neurons: 12, Grad norm: 5.760e+01
# Epoch 179, Loss: 1467.371337890625, Neurons: 12, Grad norm: 5.769e+01
# Epoch 180, Loss: 1467.064697265625, Neurons: 12, Grad norm: 5.779e+01
# Epoch 181, Loss: 1466.755126953125, Neurons: 12, Grad norm: 5.789e+01
# Epoch 182, Loss: 1466.4425048828125, Neurons: 12, Grad norm: 5.799e+01
# Epoch 183, Loss: 1466.1270751953125, Neurons: 12, Grad norm: 5.810e+01
# Epoch 184, Loss: 1465.8087158203125, Neurons: 12, Grad norm: 5.822e+01
# Epoch 185, Loss: 1465.4871826171875, Neurons: 12, Grad norm: 5.834e+01
# Epoch 186, Loss: 1465.16259765625, Neurons: 12, Grad norm: 5.847e+01
# Epoch 187, Loss: 1464.8345947265625, Neurons: 12, Grad norm: 5.860e+01
# Epoch 188, Loss: 1464.5030517578125, Neurons: 12, Grad norm: 5.874e+01
# Epoch 189, Loss: 1464.168212890625, Neurons: 12, Grad norm: 5.890e+01
# Epoch 190, Loss: 1463.829833984375, Neurons: 12, Grad norm: 5.906e+01
# Epoch 191, Loss: 1463.487548828125, Neurons: 12, Grad norm: 5.922e+01
# Epoch 192, Loss: 1463.1416015625, Neurons: 12, Grad norm: 5.940e+01
# Epoch 193, Loss: 1462.79150390625, Neurons: 12, Grad norm: 5.959e+01
# Epoch 194, Loss: 1462.4373779296875, Neurons: 12, Grad norm: 5.978e+01
# Epoch 195, Loss: 1462.0787353515625, Neurons: 12, Grad norm: 5.999e+01
# Epoch 196, Loss: 1461.7156982421875, Neurons: 12, Grad norm: 6.021e+01
# Epoch 197, Loss: 1461.347900390625, Neurons: 12, Grad norm: 6.043e+01
# Epoch 198, Loss: 1460.9754638671875, Neurons: 12, Grad norm: 6.066e+01
# Epoch 199, Loss: 1460.59814453125, Neurons: 12, Grad norm: 6.090e+01
# Epoch 199, Test loss: 1489.533447265625
# Added neuron to hidden layer 2 with activation tanh
# network shape updated to :[6, 6, 1]
# Epoch 200, Loss: 1470.806884765625, Neurons: 13, Grad norm: 6.789e+01
# Epoch 201, Loss: 1470.702880859375, Neurons: 13, Grad norm: 6.793e+01
# Epoch 202, Loss: 1470.5931396484375, Neurons: 13, Grad norm: 6.797e+01
# Epoch 203, Loss: 1470.47802734375, Neurons: 13, Grad norm: 6.802e+01
# Epoch 204, Loss: 1470.357421875, Neurons: 13, Grad norm: 6.807e+01
# Epoch 205, Loss: 1470.2314453125, Neurons: 13, Grad norm: 6.812e+01
# Epoch 206, Loss: 1470.099609375, Neurons: 13, Grad norm: 6.817e+01
# Epoch 207, Loss: 1469.9622802734375, Neurons: 13, Grad norm: 6.822e+01
# Epoch 208, Loss: 1469.819091796875, Neurons: 13, Grad norm: 6.827e+01
# Epoch 209, Loss: 1469.6702880859375, Neurons: 13, Grad norm: 6.833e+01
# Epoch 210, Loss: 1469.51611328125, Neurons: 13, Grad norm: 6.838e+01
# Epoch 211, Loss: 1469.3560791015625, Neurons: 13, Grad norm: 6.844e+01
# Epoch 212, Loss: 1469.1904296875, Neurons: 13, Grad norm: 6.849e+01
# Epoch 213, Loss: 1469.019287109375, Neurons: 13, Grad norm: 6.855e+01
# Epoch 214, Loss: 1468.8427734375, Neurons: 13, Grad norm: 6.860e+01
# Epoch 215, Loss: 1468.6607666015625, Neurons: 13, Grad norm: 6.865e+01
# Epoch 216, Loss: 1468.4732666015625, Neurons: 13, Grad norm: 6.869e+01
# Epoch 394, Loss: 1410.5909423828125, Neurons: 14, Grad norm: 8.025e+01
# Epoch 395, Loss: 1410.0819091796875, Neurons: 14, Grad norm: 8.030e+01
# Epoch 396, Loss: 1409.56982421875, Neurons: 14, Grad norm: 8.035e+01
# Epoch 397, Loss: 1409.054443359375, Neurons: 14, Grad norm: 8.039e+01
# Epoch 398, Loss: 1408.5360107421875, Neurons: 14, Grad norm: 8.043e+01
# Epoch 399, Loss: 1408.0147705078125, Neurons: 14, Grad norm: 8.047e+01
# Epoch 399, Test loss: 1435.5736083984375
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[8, 6, 1]
# Epoch 400, Loss: 1405.2838134765625, Neurons: 15, Grad norm: 8.707e+01
# Epoch 401, Loss: 1405.154296875, Neurons: 15, Grad norm: 8.695e+01
# Epoch 402, Loss: 1405.018310546875, Neurons: 15, Grad norm: 8.681e+01
# Epoch 403, Loss: 1404.8758544921875, Neurons: 15, Grad norm: 8.668e+01
# Epoch 404, Loss: 1404.72705078125, Neurons: 15, Grad norm: 8.654e+01
# Epoch 405, Loss: 1404.57177734375, Neurons: 15, Grad norm: 8.639e+01
# Epoch 406, Loss: 1404.4102783203125, Neurons: 15, Grad norm: 8.624e+01
# Epoch 407, Loss: 1404.2425537109375, Neurons: 15, Grad norm: 8.609e+01
# Epoch 408, Loss: 1404.068359375, Neurons: 15, Grad norm: 8.594e+01
# Epoch 409, Loss: 1403.8880615234375, Neurons: 15, Grad norm: 8.578e+01
# Epoch 410, Loss: 1403.7017822265625, Neurons: 15, Grad norm: 8.562e+01
# Epoch 411, Loss: 1403.509765625, Neurons: 15, Grad norm: 8.545e+01
# Epoch 412, Loss: 1403.311767578125, Neurons: 15, Grad norm: 8.529e+01
# Epoch 413, Loss: 1403.1082763671875, Neurons: 15, Grad norm: 8.512e+01
# Epoch 414, Loss: 1402.8992919921875, Neurons: 15, Grad norm: 8.496e+01
# Epoch 415, Loss: 1402.68505859375, Neurons: 15, Grad norm: 8.479e+01
# Epoch 416, Loss: 1402.4654541015625, Neurons: 15, Grad norm: 8.463e+01
# Epoch 417, Loss: 1402.2410888671875, Neurons: 15, Grad norm: 8.447e+01
# Epoch 418, Loss: 1402.0118408203125, Neurons: 15, Grad norm: 8.431e+01
# Epoch 419, Loss: 1401.77783203125, Neurons: 15, Grad norm: 8.415e+01
# Epoch 420, Loss: 1401.539306640625, Neurons: 15, Grad norm: 8.399e+01
# Epoch 421, Loss: 1401.2965087890625, Neurons: 15, Grad norm: 8.384e+01
# Epoch 422, Loss: 1401.0496826171875, Neurons: 15, Grad norm: 8.369e+01
# Epoch 423, Loss: 1400.798583984375, Neurons: 15, Grad norm: 8.354e+01
# Epoch 424, Loss: 1400.543701171875, Neurons: 15, Grad norm: 8.340e+01
# Epoch 425, Loss: 1400.2847900390625, Neurons: 15, Grad norm: 8.326e+01
# Epoch 426, Loss: 1400.0225830078125, Neurons: 15, Grad norm: 8.313e+01
# Epoch 427, Loss: 1399.756591796875, Neurons: 15, Grad norm: 8.300e+01
# Epoch 428, Loss: 1399.487060546875, Neurons: 15, Grad norm: 8.288e+01
# Epoch 499, Test loss: 1400.239013671875
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[8, 7, 1]
# Epoch 500, Loss: 1391.7515869140625, Neurons: 16, Grad norm: 1.819e+02
# Epoch 501, Loss: 1391.5081787109375, Neurons: 16, Grad norm: 1.820e+02
# Epoch 502, Loss: 1391.2523193359375, Neurons: 16, Grad norm: 1.821e+02
# Epoch 503, Loss: 1390.9840087890625, Neurons: 16, Grad norm: 1.822e+02
# Epoch 504, Loss: 1390.703369140625, Neurons: 16, Grad norm: 1.822e+02
# Epoch 505, Loss: 1390.409912109375, Neurons: 16, Grad norm: 1.823e+02
# Epoch 506, Loss: 1390.1038818359375, Neurons: 16, Grad norm: 1.824e+02
# Epoch 507, Loss: 1389.78515625, Neurons: 16, Grad norm: 1.825e+02
# Epoch 508, Loss: 1389.4541015625, Neurons: 16, Grad norm: 1.825e+02
# Epoch 509, Loss: 1389.1102294921875, Neurons: 16, Grad norm: 1.826e+02
# Epoch 510, Loss: 1388.75390625, Neurons: 16, Grad norm: 1.827e+02
# Epoch 511, Loss: 1388.385498046875, Neurons: 16, Grad norm: 1.828e+02
# Epoch 512, Loss: 1388.0047607421875, Neurons: 16, Grad norm: 1.829e+02
# Epoch 513, Loss: 1387.612060546875, Neurons: 16, Grad norm: 1.829e+02
# Epoch 514, Loss: 1387.20751953125, Neurons: 16, Grad norm: 1.830e+02
# Epoch 515, Loss: 1386.791259765625, Neurons: 16, Grad norm: 1.831e+02
# Epoch 516, Loss: 1386.363525390625, Neurons: 16, Grad norm: 1.832e+02
# Epoch 517, Loss: 1385.924560546875, Neurons: 16, Grad norm: 1.833e+02
# Epoch 518, Loss: 1385.474609375, Neurons: 16, Grad norm: 1.834e+02
# Epoch 519, Loss: 1385.0133056640625, Neurons: 16, Grad norm: 1.834e+02
# Epoch 520, Loss: 1384.541748046875, Neurons: 16, Grad norm: 1.835e+02
# Epoch 521, Loss: 1384.0594482421875, Neurons: 16, Grad norm: 1.836e+02
# Epoch 522, Loss: 1383.5667724609375, Neurons: 16, Grad norm: 1.837e+02
# Epoch 523, Loss: 1383.0640869140625, Neurons: 16, Grad norm: 1.838e+02
# Epoch 524, Loss: 1382.5513916015625, Neurons: 16, Grad norm: 1.838e+02
# Epoch 525, Loss: 1382.029052734375, Neurons: 16, Grad norm: 1.839e+02
# Epoch 526, Loss: 1381.4969482421875, Neurons: 16, Grad norm: 1.840e+02
# Epoch 527, Loss: 1380.95556640625, Neurons: 16, Grad norm: 1.840e+02
# Epoch 528, Loss: 1380.404541015625, Neurons: 16, Grad norm: 1.841e+02
# Epoch 529, Loss: 1379.8448486328125, Neurons: 16, Grad norm: 1.842e+02
# Epoch 530, Loss: 1379.2760009765625, Neurons: 16, Grad norm: 1.842e+02
# Epoch 531, Loss: 1378.6981201171875, Neurons: 16, Grad norm: 1.843e+02
# Epoch 532, Loss: 1378.11181640625, Neurons: 16, Grad norm: 1.843e+02
# Epoch 533, Loss: 1377.516845703125, Neurons: 16, Grad norm: 1.844e+02
# Epoch 534, Loss: 1376.91357421875, Neurons: 16, Grad norm: 1.844e+02
# Epoch 535, Loss: 1376.3021240234375, Neurons: 16, Grad norm: 1.844e+02
# Epoch 536, Loss: 1375.682373046875, Neurons: 16, Grad norm: 1.844e+02
# Epoch 537, Loss: 1375.0546875, Neurons: 16, Grad norm: 1.845e+02
# Epoch 538, Loss: 1374.4190673828125, Neurons: 16, Grad norm: 1.845e+02
# Epoch 539, Loss: 1373.7760009765625, Neurons: 16, Grad norm: 1.845e+02
# Epoch 540, Loss: 1373.1251220703125, Neurons: 16, Grad norm: 1.845e+02
# Epoch 541, Loss: 1372.466552734375, Neurons: 16, Grad norm: 1.844e+02
# Epoch 542, Loss: 1371.80078125, Neurons: 16, Grad norm: 1.844e+02
# Epoch 543, Loss: 1371.1278076171875, Neurons: 16, Grad norm: 1.844e+02
# Epoch 544, Loss: 1370.4476318359375, Neurons: 16, Grad norm: 1.843e+02
# Epoch 545, Loss: 1369.7606201171875, Neurons: 16, Grad norm: 1.843e+02
# Epoch 546, Loss: 1369.06640625, Neurons: 16, Grad norm: 1.842e+02
# Epoch 547, Loss: 1368.3656005859375, Neurons: 16, Grad norm: 1.842e+02
# Epoch 548, Loss: 1367.6580810546875, Neurons: 16, Grad norm: 1.841e+02
# Epoch 549, Loss: 1366.9439697265625, Neurons: 16, Grad norm: 1.840e+02
# Epoch 550, Loss: 1366.2235107421875, Neurons: 16, Grad norm: 1.839e+02
# Epoch 551, Loss: 1365.496826171875, Neurons: 16, Grad norm: 1.838e+02
# Epoch 552, Loss: 1364.763671875, Neurons: 16, Grad norm: 1.836e+02
# Epoch 553, Loss: 1364.0245361328125, Neurons: 16, Grad norm: 1.835e+02
# Epoch 554, Loss: 1363.279541015625, Neurons: 16, Grad norm: 1.834e+02
# Epoch 555, Loss: 1362.528564453125, Neurons: 16, Grad norm: 1.832e+02
# Epoch 556, Loss: 1361.7718505859375, Neurons: 16, Grad norm: 1.830e+02
# Epoch 557, Loss: 1361.009521484375, Neurons: 16, Grad norm: 1.828e+02
# Epoch 558, Loss: 1360.24169921875, Neurons: 16, Grad norm: 1.826e+02
# Epoch 559, Loss: 1359.4683837890625, Neurons: 16, Grad norm: 1.824e+02
# Epoch 560, Loss: 1358.6900634765625, Neurons: 16, Grad norm: 1.822e+02
# Epoch 561, Loss: 1357.9063720703125, Neurons: 16, Grad norm: 1.819e+02
# Epoch 562, Loss: 1357.1177978515625, Neurons: 16, Grad norm: 1.817e+02
# Epoch 563, Loss: 1356.32421875, Neurons: 16, Grad norm: 1.814e+02
# Epoch 564, Loss: 1355.526123046875, Neurons: 16, Grad norm: 1.811e+02
# Epoch 565, Loss: 1354.7232666015625, Neurons: 16, Grad norm: 1.808e+02
# Epoch 566, Loss: 1353.9158935546875, Neurons: 16, Grad norm: 1.804e+02
# Epoch 567, Loss: 1353.1043701171875, Neurons: 16, Grad norm: 1.801e+02
# Epoch 568, Loss: 1352.28857421875, Neurons: 16, Grad norm: 1.797e+02
# Epoch 569, Loss: 1351.4688720703125, Neurons: 16, Grad norm: 1.794e+02
# Epoch 570, Loss: 1350.64501953125, Neurons: 16, Grad norm: 1.790e+02
# Epoch 571, Loss: 1349.8177490234375, Neurons: 16, Grad norm: 1.786e+02
# Epoch 572, Loss: 1348.98681640625, Neurons: 16, Grad norm: 1.781e+02
# Epoch 573, Loss: 1348.15234375, Neurons: 16, Grad norm: 1.777e+02
# Epoch 574, Loss: 1347.314697265625, Neurons: 16, Grad norm: 1.772e+02
# Epoch 575, Loss: 1346.47412109375, Neurons: 16, Grad norm: 1.767e+02
# Epoch 576, Loss: 1345.6304931640625, Neurons: 16, Grad norm: 1.762e+02
# Epoch 577, Loss: 1344.7840576171875, Neurons: 16, Grad norm: 1.757e+02
# Epoch 578, Loss: 1343.93505859375, Neurons: 16, Grad norm: 1.752e+02
# Epoch 579, Loss: 1343.0838623046875, Neurons: 16, Grad norm: 1.746e+02
# Epoch 580, Loss: 1342.230224609375, Neurons: 16, Grad norm: 1.740e+02
# Epoch 581, Loss: 1341.37451171875, Neurons: 16, Grad norm: 1.734e+02
# Epoch 582, Loss: 1340.51708984375, Neurons: 16, Grad norm: 1.728e+02
# Epoch 583, Loss: 1339.6580810546875, Neurons: 16, Grad norm: 1.722e+02
# Epoch 584, Loss: 1338.79736328125, Neurons: 16, Grad norm: 1.715e+02
# Epoch 585, Loss: 1337.935302734375, Neurons: 16, Grad norm: 1.709e+02
# Epoch 586, Loss: 1337.072265625, Neurons: 16, Grad norm: 1.702e+02
# Epoch 587, Loss: 1336.2083740234375, Neurons: 16, Grad norm: 1.695e+02
# Epoch 588, Loss: 1335.343505859375, Neurons: 16, Grad norm: 1.687e+02
# Epoch 589, Loss: 1334.478271484375, Neurons: 16, Grad norm: 1.680e+02
# Epoch 590, Loss: 1333.612548828125, Neurons: 16, Grad norm: 1.672e+02
# Epoch 591, Loss: 1332.746826171875, Neurons: 16, Grad norm: 1.665e+02
# Epoch 592, Loss: 1331.8809814453125, Neurons: 16, Grad norm: 1.657e+02
# Epoch 593, Loss: 1331.015380859375, Neurons: 16, Grad norm: 1.649e+02
# Epoch 594, Loss: 1330.1502685546875, Neurons: 16, Grad norm: 1.640e+02
# Epoch 595, Loss: 1329.2857666015625, Neurons: 16, Grad norm: 1.632e+02
# Epoch 596, Loss: 1328.4217529296875, Neurons: 16, Grad norm: 1.623e+02
# Epoch 597, Loss: 1327.55908203125, Neurons: 16, Grad norm: 1.615e+02
# Epoch 598, Loss: 1326.6973876953125, Neurons: 16, Grad norm: 1.606e+02
# Epoch 599, Loss: 1325.837158203125, Neurons: 16, Grad norm: 1.597e+02
# Epoch 599, Test loss: 1350.383544921875
# Added neuron to hidden layer 2 with activation relu
# network shape updated to :[8, 8, 1]
# Epoch 600, Loss: 1325.0531005859375, Neurons: 17, Grad norm: 1.985e+02
# Epoch 601, Loss: 1324.77880859375, Neurons: 17, Grad norm: 1.983e+02
# Epoch 602, Loss: 1324.490966796875, Neurons: 17, Grad norm: 1.980e+02
# Epoch 603, Loss: 1324.1893310546875, Neurons: 17, Grad norm: 1.977e+02
# Epoch 604, Loss: 1323.873779296875, Neurons: 17, Grad norm: 1.974e+02
# Epoch 605, Loss: 1323.54443359375, Neurons: 17, Grad norm: 1.971e+02
# Epoch 606, Loss: 1323.201171875, Neurons: 17, Grad norm: 1.957e+02
# Epoch 607, Loss: 1322.844482421875, Neurons: 17, Grad norm: 1.891e+02
# Epoch 608, Loss: 1322.4796142578125, Neurons: 17, Grad norm: 1.800e+02
# Epoch 609, Loss: 1322.114013671875, Neurons: 17, Grad norm: 1.722e+02
# Epoch 610, Loss: 1321.7523193359375, Neurons: 17, Grad norm: 1.654e+02
# Epoch 611, Loss: 1321.3963623046875, Neurons: 17, Grad norm: 1.607e+02
# Epoch 612, Loss: 1321.0462646484375, Neurons: 17, Grad norm: 1.579e+02
# Epoch 613, Loss: 1320.7000732421875, Neurons: 17, Grad norm: 1.563e+02
# Epoch 614, Loss: 1320.355224609375, Neurons: 17, Grad norm: 1.555e+02
# Epoch 615, Loss: 1320.008056640625, Neurons: 17, Grad norm: 1.551e+02
# Epoch 616, Loss: 1319.6566162109375, Neurons: 17, Grad norm: 1.550e+02
# Epoch 617, Loss: 1319.299072265625, Neurons: 17, Grad norm: 1.549e+02
# Epoch 618, Loss: 1318.9345703125, Neurons: 17, Grad norm: 1.548e+02
# Epoch 619, Loss: 1318.56201171875, Neurons: 17, Grad norm: 1.546e+02
# Epoch 620, Loss: 1318.18115234375, Neurons: 17, Grad norm: 1.544e+02
# Epoch 621, Loss: 1317.791748046875, Neurons: 17, Grad norm: 1.540e+02
# Epoch 622, Loss: 1317.3935546875, Neurons: 17, Grad norm: 1.536e+02
# Epoch 623, Loss: 1316.9871826171875, Neurons: 17, Grad norm: 1.532e+02
# Epoch 624, Loss: 1316.572509765625, Neurons: 17, Grad norm: 1.526e+02
# Epoch 625, Loss: 1316.1505126953125, Neurons: 17, Grad norm: 1.520e+02
# Epoch 626, Loss: 1315.72119140625, Neurons: 17, Grad norm: 1.513e+02
# Epoch 627, Loss: 1315.2847900390625, Neurons: 17, Grad norm: 1.506e+02
# Epoch 628, Loss: 1314.841796875, Neurons: 17, Grad norm: 1.499e+02
# Epoch 629, Loss: 1314.3929443359375, Neurons: 17, Grad norm: 1.491e+02
# Epoch 630, Loss: 1313.9384765625, Neurons: 17, Grad norm: 1.482e+02
# Epoch 631, Loss: 1313.4788818359375, Neurons: 17, Grad norm: 1.473e+02
# Epoch 632, Loss: 1313.0145263671875, Neurons: 17, Grad norm: 1.465e+02
# Epoch 633, Loss: 1312.546142578125, Neurons: 17, Grad norm: 1.456e+02
# Epoch 634, Loss: 1312.0740966796875, Neurons: 17, Grad norm: 1.448e+02
# Epoch 635, Loss: 1311.5986328125, Neurons: 17, Grad norm: 1.440e+02
# Epoch 636, Loss: 1311.120361328125, Neurons: 17, Grad norm: 1.432e+02
# Epoch 637, Loss: 1310.638916015625, Neurons: 17, Grad norm: 1.426e+02
# Epoch 638, Loss: 1310.1551513671875, Neurons: 17, Grad norm: 1.419e+02
# Epoch 639, Loss: 1309.6689453125, Neurons: 17, Grad norm: 1.413e+02
# Epoch 640, Loss: 1309.1805419921875, Neurons: 17, Grad norm: 1.408e+02
# Epoch 641, Loss: 1308.6900634765625, Neurons: 17, Grad norm: 1.402e+02
# Epoch 642, Loss: 1308.197265625, Neurons: 17, Grad norm: 1.397e+02
# Epoch 643, Loss: 1307.7025146484375, Neurons: 17, Grad norm: 1.392e+02
# Epoch 644, Loss: 1307.2060546875, Neurons: 17, Grad norm: 1.386e+02
# Epoch 645, Loss: 1306.7073974609375, Neurons: 17, Grad norm: 1.381e+02
# Epoch 646, Loss: 1306.2069091796875, Neurons: 17, Grad norm: 1.375e+02
# Epoch 647, Loss: 1305.70458984375, Neurons: 17, Grad norm: 1.368e+02
# Epoch 648, Loss: 1305.20068359375, Neurons: 17, Grad norm: 1.361e+02
# Epoch 649, Loss: 1304.695068359375, Neurons: 17, Grad norm: 1.354e+02
# Epoch 650, Loss: 1304.1881103515625, Neurons: 17, Grad norm: 1.346e+02
# Epoch 651, Loss: 1303.6796875, Neurons: 17, Grad norm: 1.337e+02
# Epoch 652, Loss: 1303.1702880859375, Neurons: 17, Grad norm: 1.328e+02
# Epoch 653, Loss: 1302.6597900390625, Neurons: 17, Grad norm: 1.319e+02
# Epoch 654, Loss: 1302.1488037109375, Neurons: 17, Grad norm: 1.310e+02
# Epoch 655, Loss: 1301.63720703125, Neurons: 17, Grad norm: 1.301e+02
# Epoch 656, Loss: 1301.1251220703125, Neurons: 17, Grad norm: 1.292e+02
# Epoch 657, Loss: 1300.61279296875, Neurons: 17, Grad norm: 1.284e+02
# Epoch 658, Loss: 1300.100341796875, Neurons: 17, Grad norm: 1.275e+02
# Epoch 659, Loss: 1299.5877685546875, Neurons: 17, Grad norm: 1.267e+02
# Epoch 660, Loss: 1299.0753173828125, Neurons: 17, Grad norm: 1.259e+02
# Epoch 661, Loss: 1298.5628662109375, Neurons: 17, Grad norm: 1.251e+02
# Epoch 662, Loss: 1298.050537109375, Neurons: 17, Grad norm: 1.243e+02
# Epoch 663, Loss: 1297.53857421875, Neurons: 17, Grad norm: 1.235e+02
# Epoch 664, Loss: 1297.0269775390625, Neurons: 17, Grad norm: 1.228e+02
# Epoch 665, Loss: 1296.515380859375, Neurons: 17, Grad norm: 1.220e+02
# Epoch 666, Loss: 1296.0042724609375, Neurons: 17, Grad norm: 1.213e+02
# Epoch 667, Loss: 1295.49365234375, Neurons: 17, Grad norm: 1.206e+02
# Epoch 668, Loss: 1294.9835205078125, Neurons: 17, Grad norm: 1.198e+02
# Epoch 669, Loss: 1294.4737548828125, Neurons: 17, Grad norm: 1.191e+02
# Epoch 670, Loss: 1293.96484375, Neurons: 17, Grad norm: 1.184e+02
# Epoch 671, Loss: 1293.456298828125, Neurons: 17, Grad norm: 1.177e+02
# Epoch 672, Loss: 1292.9486083984375, Neurons: 17, Grad norm: 1.170e+02
# Epoch 673, Loss: 1292.44140625, Neurons: 17, Grad norm: 1.163e+02
# ...
# Epoch 24790, Loss: 0.0021631475538015366, Neurons: 64, Grad norm: 5.555e+00
# Epoch 24791, Loss: 0.002224031137302518, Neurons: 64, Grad norm: 6.796e+00
# Epoch 24792, Loss: 0.002315276302397251, Neurons: 64, Grad norm: 8.299e+00
# Epoch 24793, Loss: 0.0024489518254995346, Neurons: 64, Grad norm: 1.005e+01
# Epoch 24794, Loss: 0.0026402552612125874, Neurons: 64, Grad norm: 1.208e+01
# Epoch 24795, Loss: 0.0029005049727857113, Neurons: 64, Grad norm: 1.446e+01
# Epoch 24796, Loss: 0.0032822422217577696, Neurons: 64, Grad norm: 1.671e+01
# Epoch 24797, Loss: 0.003691037418320775, Neurons: 64, Grad norm: 1.825e+01
# Epoch 24798, Loss: 0.00401275884360075, Neurons: 64, Grad norm: 1.845e+01
# Epoch 24799, Loss: 0.0040574143640697, Neurons: 64, Grad norm: 1.676e+01
# Epoch 24799, Test loss: 0.003429177450016141
# Epoch 24800, Loss: 0.0037068368401378393, Neurons: 64, Grad norm: 1.298e+01
# Epoch 24801, Loss: 0.0030338247306644917, Neurons: 64, Grad norm: 7.460e+00
# Epoch 24802, Loss: 0.002370106987655163, Neurons: 64, Grad norm: 1.216e+00
# Epoch 24803, Loss: 0.0020514382049441338, Neurons: 64, Grad norm: 4.599e+00
# Epoch 24804, Loss: 0.0021689520217478275, Neurons: 64, Grad norm: 9.036e+00
# Epoch 24805, Loss: 0.002526775933802128, Neurons: 64, Grad norm: 1.140e+01
# Epoch 24806, Loss: 0.002811276586726308, Neurons: 64, Grad norm: 1.136e+01
# Epoch 24807, Loss: 0.002807511482387781, Neurons: 64, Grad norm: 9.080e+00
# Epoch 24808, Loss: 0.0025272504426538944, Neurons: 64, Grad norm: 5.107e+00
# Epoch 24809, Loss: 0.0021950528025627136, Neurons: 64, Grad norm: 4.575e-01
# Epoch 24810, Loss: 0.0020451017189770937, Neurons: 64, Grad norm: 3.898e+00
# Epoch 24811, Loss: 0.0021345578134059906, Neurons: 64, Grad norm: 6.893e+00
# Epoch 24812, Loss: 0.002327108755707741, Neurons: 64, Grad norm: 8.127e+00
# Epoch 24813, Loss: 0.002433373127132654, Neurons: 64, Grad norm: 7.443e+00
# Epoch 24814, Loss: 0.002367633394896984, Neurons: 64, Grad norm: 5.142e+00
# Epoch 24815, Loss: 0.002196196699514985, Neurons: 64, Grad norm: 1.916e+00
# Epoch 24816, Loss: 0.002063518622890115, Neurons: 64, Grad norm: 1.433e+00
# Epoch 24817, Loss: 0.0020568505860865116, Neurons: 64, Grad norm: 4.114e+00
# Epoch 24818, Loss: 0.002145822625607252, Neurons: 64, Grad norm: 5.593e+00
# Epoch 24819, Loss: 0.002229442121461034, Neurons: 64, Grad norm: 5.653e+00
# Epoch 24820, Loss: 0.00223052897490561, Neurons: 64, Grad norm: 4.420e+00
# Epoch 24821, Loss: 0.002154888119548559, Neurons: 64, Grad norm: 2.313e+00
# Epoch 24822, Loss: 0.0020705421920865774, Neurons: 64, Grad norm: 1.917e-01
# Epoch 24823, Loss: 0.0020413484890013933, Neurons: 64, Grad norm: 2.278e+00
# Epoch 24824, Loss: 0.0020743426866829395, Neurons: 64, Grad norm: 3.697e+00
# Epoch 24825, Loss: 0.0021250739227980375, Neurons: 64, Grad norm: 4.130e+00
# Epoch 24826, Loss: 0.0021436375100165606, Neurons: 64, Grad norm: 3.589e+00
# Epoch 24827, Loss: 0.0021159988828003407, Neurons: 64, Grad norm: 2.272e+00
# Epoch 24828, Loss: 0.002068920759484172, Neurons: 64, Grad norm: 5.926e-01
# Epoch 24829, Loss: 0.002040283754467964, Neurons: 64, Grad norm: 1.062e+00
# Epoch 24830, Loss: 0.0020463925320655107, Neurons: 64, Grad norm: 2.303e+00
# Epoch 24831, Loss: 0.002072815550491214, Neurons: 64, Grad norm: 2.920e+00
# Epoch 24832, Loss: 0.0020919600501656532, Neurons: 64, Grad norm: 2.820e+00
# Epoch 24833, Loss: 0.002087601227685809, Neurons: 64, Grad norm: 2.116e+00
# Epoch 24834, Loss: 0.00206523179076612, Neurons: 64, Grad norm: 1.018e+00
# Epoch 24835, Loss: 0.002043615560978651, Neurons: 64, Grad norm: 1.877e-01
# Epoch 24836, Loss: 0.0020375146996229887, Neurons: 64, Grad norm: 1.238e+00
# Epoch 24837, Loss: 0.0020470907911658287, Neurons: 64, Grad norm: 1.909e+00
# Epoch 24838, Loss: 0.0020605684258043766, Neurons: 64, Grad norm: 2.118e+00
# Epoch 24839, Loss: 0.0020656499546021223, Neurons: 64, Grad norm: 1.851e+00
# Epoch 24840, Loss: 0.0020588890183717012, Neurons: 64, Grad norm: 1.225e+00
# Epoch 24841, Loss: 0.002046452136710286, Neurons: 64, Grad norm: 3.970e-01
# Epoch 24842, Loss: 0.0020377214532345533, Neurons: 64, Grad norm: 4.259e-01
# Epoch 24843, Loss: 0.0020375556778162718, Neurons: 64, Grad norm: 1.089e+00
# Epoch 24844, Loss: 0.002043643966317177, Neurons: 64, Grad norm: 1.461e+00
# Epoch 24845, Loss: 0.002049613045528531, Neurons: 64, Grad norm: 1.504e+00
# Epoch 24846, Loss: 0.0020504652056843042, Neurons: 64, Grad norm: 1.239e+00
# Epoch 24847, Loss: 0.0020460214000195265, Neurons: 64, Grad norm: 7.632e-01
# Epoch 24848, Loss: 0.0020398893393576145, Neurons: 64, Grad norm: 1.741e-01
# Epoch 24849, Loss: 0.002036262536421418, Neurons: 64, Grad norm: 3.943e-01
# Epoch 24850, Loss: 0.002036726800724864, Neurons: 64, Grad norm: 8.332e-01
# Epoch 24851, Loss: 0.0020397785119712353, Neurons: 64, Grad norm: 1.062e+00
# Epoch 24852, Loss: 0.002042454434558749, Neurons: 64, Grad norm: 1.080e+00
# Epoch 24853, Loss: 0.0020426001865416765, Neurons: 64, Grad norm: 8.865e-01
# Epoch 24854, Loss: 0.0020402937661856413, Neurons: 64, Grad norm: 5.526e-01
# Epoch 24855, Loss: 0.0020372483413666487, Neurons: 64, Grad norm: 1.462e-01
# Epoch 24856, Loss: 0.002035408280789852, Neurons: 64, Grad norm: 2.443e-01
# Epoch 24857, Loss: 0.0020354536827653646, Neurons: 64, Grad norm: 5.600e-01
# Epoch 24858, Loss: 0.002036838326603174, Neurons: 64, Grad norm: 7.355e-01
# Epoch 24859, Loss: 0.002038132632151246, Neurons: 64, Grad norm: 7.735e-01
# Epoch 24860, Loss: 0.002038352657109499, Neurons: 64, Grad norm: 6.659e-01
# Epoch 24861, Loss: 0.0020373768638819456, Neurons: 64, Grad norm: 4.593e-01
# Epoch 24862, Loss: 0.002035880461335182, Neurons: 64, Grad norm: 1.842e-01
# Epoch 24863, Loss: 0.0020347137469798326, Neurons: 64, Grad norm: 8.533e-02
# Epoch 24864, Loss: 0.002034449251368642, Neurons: 64, Grad norm: 3.216e-01
# Epoch 24865, Loss: 0.0020349109545350075, Neurons: 64, Grad norm: 4.777e-01
# Epoch 24866, Loss: 0.002035579876974225, Neurons: 64, Grad norm: 5.490e-01
# Epoch 24867, Loss: 0.0020358816254884005, Neurons: 64, Grad norm: 5.156e-01
# Epoch 24868, Loss: 0.002035623649135232, Neurons: 64, Grad norm: 4.126e-01
# Epoch 24869, Loss: 0.002034879755228758, Neurons: 64, Grad norm: 2.493e-01
# Epoch 24870, Loss: 0.0020341994240880013, Neurons: 64, Grad norm: 6.731e-02
# Epoch 24871, Loss: 0.0020337477326393127, Neurons: 64, Grad norm: 1.157e-01
# Epoch 24872, Loss: 0.0020336839370429516, Neurons: 64, Grad norm: 2.527e-01
# Epoch 24873, Loss: 0.002033921889960766, Neurons: 64, Grad norm: 3.435e-01
# Epoch 24874, Loss: 0.002034118864685297, Neurons: 64, Grad norm: 3.668e-01
# Epoch 24875, Loss: 0.0020341197960078716, Neurons: 64, Grad norm: 3.412e-01
# Epoch 24876, Loss: 0.0020338944159448147, Neurons: 64, Grad norm: 2.615e-01
# Epoch 24877, Loss: 0.002033529570326209, Neurons: 64, Grad norm: 1.604e-01
# Epoch 24878, Loss: 0.002033127937465906, Neurons: 64, Grad norm: 3.938e-02
# Epoch 24879, Loss: 0.0020329272374510765, Neurons: 64, Grad norm: 6.631e-02
# Epoch 24880, Loss: 0.002032865071669221, Neurons: 64, Grad norm: 1.566e-01
# Epoch 24881, Loss: 0.002032865071669221, Neurons: 64, Grad norm: 2.091e-01
# Epoch 24882, Loss: 0.002032894641160965, Neurons: 64, Grad norm: 2.321e-01
# Epoch 24883, Loss: 0.002032836200669408, Neurons: 64, Grad norm: 2.130e-01
# Epoch 24884, Loss: 0.0020327025558799505, Neurons: 64, Grad norm: 1.737e-01
# Epoch 24885, Loss: 0.0020324760116636753, Neurons: 64, Grad norm: 1.058e-01
# Epoch 24886, Loss: 0.0020322834607213736, Neurons: 64, Grad norm: 3.610e-02
# Epoch 24887, Loss: 0.002032122341915965, Neurons: 64, Grad norm: 3.954e-02
# Epoch 24888, Loss: 0.0020320231560617685, Neurons: 64, Grad norm: 9.524e-02
# Epoch 24889, Loss: 0.0020319640170782804, Neurons: 64, Grad norm: 1.446e-01
# Epoch 24890, Loss: 0.002031920710578561, Neurons: 64, Grad norm: 1.659e-01
# Epoch 24891, Loss: 0.002031860873103142, Neurons: 64, Grad norm: 1.730e-01
# Epoch 24892, Loss: 0.002031776588410139, Neurons: 64, Grad norm: 1.498e-01
# Epoch 24893, Loss: 0.0020316559821367264, Neurons: 64, Grad norm: 1.192e-01
# Epoch 24894, Loss: 0.002031491370871663, Neurons: 64, Grad norm: 7.220e-02
# Epoch 24895, Loss: 0.0020313484128564596, Neurons: 64, Grad norm: 3.025e-02
# Epoch 24896, Loss: 0.0020312066189944744, Neurons: 64, Grad norm: 2.002e-02
# Epoch 24897, Loss: 0.002031090669333935, Neurons: 64, Grad norm: 5.475e-02
# Epoch 24898, Loss: 0.0020310215186327696, Neurons: 64, Grad norm: 8.558e-02
# Epoch 24899, Loss: 0.0020309481769800186, Neurons: 64, Grad norm: 9.527e-02
# Epoch 24899, Test loss: 0.0019782017916440964
# Epoch 24900, Loss: 0.0020308527164161205, Neurons: 64, Grad norm: 1.036e-01
# Epoch 24901, Loss: 0.002030767500400543, Neurons: 64, Grad norm: 9.457e-02
# Epoch 24902, Loss: 0.0020306401420384645, Neurons: 64, Grad norm: 8.362e-02
# Epoch 24903, Loss: 0.002030533505603671, Neurons: 64, Grad norm: 5.572e-02
# Epoch 24904, Loss: 0.002030435251072049, Neurons: 64, Grad norm: 3.065e-02
# Epoch 24905, Loss: 0.002030313480645418, Neurons: 64, Grad norm: 8.757e-03
# Epoch 24906, Loss: 0.0020302135962992907, Neurons: 64, Grad norm: 3.683e-02
# Epoch 24907, Loss: 0.00203010905534029, Neurons: 64, Grad norm: 6.774e-02
# Epoch 24908, Loss: 0.0020300301257520914, Neurons: 64, Grad norm: 8.073e-02
# Epoch 24909, Loss: 0.002029942814260721, Neurons: 64, Grad norm: 9.276e-02
# Epoch 24910, Loss: 0.0020298438612371683, Neurons: 64, Grad norm: 8.805e-02
# Epoch 24911, Loss: 0.0020297651644796133, Neurons: 64, Grad norm: 8.331e-02
# Epoch 24912, Loss: 0.00202963687479496, Neurons: 64, Grad norm: 6.234e-02
# Epoch 24913, Loss: 0.0020295116119086742, Neurons: 64, Grad norm: 4.590e-02
# Epoch 24914, Loss: 0.00202942849136889, Neurons: 64, Grad norm: 2.100e-02
# Epoch 24915, Loss: 0.002029322786256671, Neurons: 64, Grad norm: 1.023e-02
# Epoch 24916, Loss: 0.002029199618846178, Neurons: 64, Grad norm: 2.531e-02
# Epoch 24917, Loss: 0.0020291078835725784, Neurons: 64, Grad norm: 3.730e-02
# Epoch 24918, Loss: 0.002029030816629529, Neurons: 64, Grad norm: 5.686e-02
# Epoch 24919, Loss: 0.002028940012678504, Neurons: 64, Grad norm: 6.529e-02
# Epoch 24920, Loss: 0.002028832910582423, Neurons: 64, Grad norm: 8.085e-02
# Epoch 24921, Loss: 0.002028738148510456, Neurons: 64, Grad norm: 8.325e-02
# Epoch 24922, Loss: 0.002028631279245019, Neurons: 64, Grad norm: 8.845e-02
# Epoch 24923, Loss: 0.0020285521168261766, Neurons: 64, Grad norm: 8.111e-02
# Epoch 24924, Loss: 0.002028475748375058, Neurons: 64, Grad norm: 8.072e-02
# Epoch 24925, Loss: 0.0020283665508031845, Neurons: 64, Grad norm: 7.053e-02
# Epoch 24926, Loss: 0.002028316492214799, Neurons: 64, Grad norm: 6.922e-02
# Epoch 24927, Loss: 0.0020281956531107426, Neurons: 64, Grad norm: 5.815e-02
# Epoch 24928, Loss: 0.002028117887675762, Neurons: 64, Grad norm: 5.762e-02
# Epoch 24929, Loss: 0.002028085058555007, Neurons: 64, Grad norm: 5.406e-02
# Epoch 24930, Loss: 0.0020280247554183006, Neurons: 64, Grad norm: 6.205e-02
# Epoch 24931, Loss: 0.0020280166063457727, Neurons: 64, Grad norm: 6.653e-02
# Epoch 24932, Loss: 0.002028005663305521, Neurons: 64, Grad norm: 8.167e-02
# Epoch 24933, Loss: 0.002028087619692087, Neurons: 64, Grad norm: 9.429e-02
# Epoch 24934, Loss: 0.0020281875040382147, Neurons: 64, Grad norm: 1.181e-01
# Epoch 24935, Loss: 0.0020284142810851336, Neurons: 64, Grad norm: 1.398e-01
# Epoch 24936, Loss: 0.0020287486258894205, Neurons: 64, Grad norm: 1.731e-01
# Epoch 24937, Loss: 0.002029299270361662, Neurons: 64, Grad norm: 2.030e-01
# Epoch 24938, Loss: 0.002030168194323778, Neurons: 64, Grad norm: 2.475e-01
# Epoch 24939, Loss: 0.0020314007997512817, Neurons: 64, Grad norm: 2.922e-01
# Epoch 24940, Loss: 0.0020332736894488335, Neurons: 64, Grad norm: 3.538e-01
# Epoch 24941, Loss: 0.0020360341295599937, Neurons: 64, Grad norm: 4.207e-01
# Epoch 24942, Loss: 0.002040162216871977, Neurons: 64, Grad norm: 5.111e-01
# Epoch 24943, Loss: 0.0020462009124457836, Neurons: 64, Grad norm: 6.146e-01
# Epoch 24944, Loss: 0.0020550955086946487, Neurons: 64, Grad norm: 7.489e-01
# Epoch 24945, Loss: 0.0020679652225226164, Neurons: 64, Grad norm: 9.006e-01
# Epoch 24946, Loss: 0.002086345572024584, Neurons: 64, Grad norm: 1.087e+00
# Epoch 24947, Loss: 0.0021117450669407845, Neurons: 64, Grad norm: 1.290e+00
# Epoch 24948, Loss: 0.002145081991329789, Neurons: 64, Grad norm: 1.516e+00
# Epoch 24949, Loss: 0.0021851626224815845, Neurons: 64, Grad norm: 1.735e+00
# Epoch 24950, Loss: 0.0022264549043029547, Neurons: 64, Grad norm: 1.938e+00
# Epoch 24951, Loss: 0.0022582137025892735, Neurons: 64, Grad norm: 2.075e+00
# Epoch 24952, Loss: 0.0022650090977549553, Neurons: 64, Grad norm: 2.141e+00
# Epoch 24953, Loss: 0.0022361271549016237, Neurons: 64, Grad norm: 2.117e+00
# Epoch 24954, Loss: 0.0021752400789409876, Neurons: 64, Grad norm: 2.057e+00
# Epoch 24955, Loss: 0.0021061403676867485, Neurons: 64, Grad norm: 2.003e+00
# Epoch 24956, Loss: 0.0020588948391377926, Neurons: 64, Grad norm: 2.015e+00
# Epoch 24957, Loss: 0.002050392795354128, Neurons: 64, Grad norm: 2.072e+00
# Epoch 24958, Loss: 0.0020751275587826967, Neurons: 64, Grad norm: 2.154e+00
# Epoch 24959, Loss: 0.002111264271661639, Neurons: 64, Grad norm: 2.208e+00
# Epoch 24960, Loss: 0.0021349547896534204, Neurons: 64, Grad norm: 2.224e+00
# Epoch 24961, Loss: 0.002132340567186475, Neurons: 64, Grad norm: 2.197e+00
# Epoch 24962, Loss: 0.0021066495683044195, Neurons: 64, Grad norm: 2.170e+00
# Epoch 24963, Loss: 0.00207449309527874, Neurons: 64, Grad norm: 2.157e+00
# Epoch 24964, Loss: 0.0020545274019241333, Neurons: 64, Grad norm: 2.191e+00
# Epoch 24965, Loss: 0.0020547090098261833, Neurons: 64, Grad norm: 2.244e+00
# Epoch 24966, Loss: 0.0020696690771728754, Neurons: 64, Grad norm: 2.308e+00
# Epoch 24967, Loss: 0.002086028689518571, Neurons: 64, Grad norm: 2.340e+00
# Epoch 24968, Loss: 0.0020921507384628057, Neurons: 64, Grad norm: 2.354e+00
# Epoch 24969, Loss: 0.002085012849420309, Neurons: 64, Grad norm: 2.347e+00
# Epoch 24970, Loss: 0.0020707454532384872, Neurons: 64, Grad norm: 2.357e+00
# Epoch 24971, Loss: 0.0020592897199094296, Neurons: 64, Grad norm: 2.387e+00
# Epoch 24972, Loss: 0.002057589590549469, Neurons: 64, Grad norm: 2.461e+00
# Epoch 24973, Loss: 0.0020653419196605682, Neurons: 64, Grad norm: 2.557e+00
# Epoch 24974, Loss: 0.0020767466630786657, Neurons: 64, Grad norm: 2.687e+00
# Epoch 24975, Loss: 0.0020853953901678324, Neurons: 64, Grad norm: 2.833e+00
# Epoch 24976, Loss: 0.002088455716148019, Neurons: 64, Grad norm: 3.013e+00
# Epoch 24977, Loss: 0.0020877353381365538, Neurons: 64, Grad norm: 3.215e+00
# Epoch 24978, Loss: 0.0020880752708762884, Neurons: 64, Grad norm: 3.461e+00
# Epoch 24979, Loss: 0.0020937754306942225, Neurons: 64, Grad norm: 3.734e+00
# Epoch 24980, Loss: 0.0021061727311462164, Neurons: 64, Grad norm: 4.045e+00
# Epoch 24981, Loss: 0.00212326948530972, Neurons: 64, Grad norm: 4.375e+00
# Epoch 24982, Loss: 0.0021424114238470793, Neurons: 64, Grad norm: 4.740e+00
# Epoch 24983, Loss: 0.002161729848012328, Neurons: 64, Grad norm: 5.115e+00
# Epoch 24984, Loss: 0.002181476214900613, Neurons: 64, Grad norm: 5.515e+00
# Epoch 24985, Loss: 0.0022033837158232927, Neurons: 64, Grad norm: 5.923e+00
# Epoch 24986, Loss: 0.0022298169787973166, Neurons: 64, Grad norm: 6.347e+00
# Epoch 24987, Loss: 0.002260910114273429, Neurons: 64, Grad norm: 6.757e+00
# Epoch 24988, Loss: 0.0022954775486141443, Neurons: 64, Grad norm: 7.147e+00
# Epoch 24989, Loss: 0.002329409820958972, Neurons: 64, Grad norm: 7.472e+00
# Epoch 24990, Loss: 0.0023589888587594032, Neurons: 64, Grad norm: 7.714e+00
# Epoch 24991, Loss: 0.002378988778218627, Neurons: 64, Grad norm: 7.820e+00
# Epoch 24992, Loss: 0.0023868626449257135, Neurons: 64, Grad norm: 7.769e+00
# Epoch 24993, Loss: 0.002379234414547682, Neurons: 64, Grad norm: 7.517e+00
# Epoch 24994, Loss: 0.0023557364474982023, Neurons: 64, Grad norm: 7.061e+00
# Epoch 24995, Loss: 0.0023161291610449553, Neurons: 64, Grad norm: 6.389e+00
# Epoch 24996, Loss: 0.0022640388924628496, Neurons: 64, Grad norm: 5.536e+00
# Epoch 24997, Loss: 0.0022042514756321907, Neurons: 64, Grad norm: 4.524e+00
# Epoch 24998, Loss: 0.002144267549738288, Neurons: 64, Grad norm: 3.421e+00
# Epoch 24999, Loss: 0.0020914399065077305, Neurons: 64, Grad norm: 2.267e+00

# %%
np.savetxt(f"{out_folder}/neurons.txt", node_history)
np.savetxt(f"{out_folder}/train_loss.txt", train_loss_history)
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)
np.savetxt(f"{out_folder}/det_neuron_history.txt", det_neuron_history)

# %% [markdown]
# ### evaluation

# %%
y_pred = jax.vmap(mlp)(x_test)
test_mse = jnp.mean((y_pred - y_test) ** 2)
plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, "b.", alpha=0.2, label="True Poly Function")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label="MLP Predictions\n Test MSE: {:.4f}".format(test_mse))
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("MLP Approximation of polynomial Function")
plt.savefig(f"{fig_folder}/polynomial_approximation.png")
wandb.log({"polynomial approximation": wandb.Image(plt, caption="polynomial approximation")})

# %%
update_history
# Out:
# [(99,
#   11,
#   Array(1485.7892, dtype=float32),
#   Array(1515.2196, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (199,
#   12,
#   Array(1460.5981, dtype=float32),
#   Array(1489.5334, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (299,
#   13,
#   Array(1441.283, dtype=float32),
#   Array(1469.7054, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (399,
#   14,
#   Array(1408.0148, dtype=float32),
#   Array(1435.5736, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (499,
#   15,
#   Array(1373.7546, dtype=float32),
#   Array(1400.239, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (599,
#   16,
#   Array(1325.8372, dtype=float32),
#   Array(1350.3835, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (699,
#   17,
#   Array(1279.5463, dtype=float32),
#   Array(1302.9913, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (799,
#   18,
#   Array(1242.0133, dtype=float32),
#   Array(1263.7805, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (899,
#   19,
#   Array(1212.9081, dtype=float32),
#   Array(1233.2576, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (999,
#   20,
#   Array(1178.2114, dtype=float32),
#   Array(1197.2023, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1099,
#   21,
#   Array(1144.3221, dtype=float32),
#   Array(1162.1393, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1199,
#   22,
#   Array(1114.0455, dtype=float32),
#   Array(1130.1748, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1299,
#   23,
#   Array(1075.0176, dtype=float32),
#   Array(1089.8872, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1399,
#   24,
#   Array(1036.3225, dtype=float32),
#   Array(1050.3501, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1499,
#   25,
#   Array(999.50616, dtype=float32),
#   Array(1012.4929, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1599,
#   26,
#   Array(955.862, dtype=float32),
#   Array(967.40814, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1699,
#   27,
#   Array(917.2235, dtype=float32),
#   Array(927.76337, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1799,
#   28,
#   Array(883.1432, dtype=float32),
#   Array(892.7018, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1899,
#   29,
#   Array(844.7301, dtype=float32),
#   Array(853.24384, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1999,
#   30,
#   Array(805.497, dtype=float32),
#   Array(812.928, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (2099,
#   31,
#   Array(764.7201, dtype=float32),
#   Array(770.99176, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (2199,
#   32,
#   Array(731.64514, dtype=float32),
#   Array(737.15173, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (2299,
#   33,
#   Array(701.23395, dtype=float32),
#   Array(705.9632, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (2399,
#   34,
#   Array(659.0015, dtype=float32),
#   Array(662.2202, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2499,
#   35,
#   Array(620.92114, dtype=float32),
#   Array(623.14777, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2599,
#   36,
#   Array(605.2334, dtype=float32),
#   Array(606.00757, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (2699,
#   37,
#   Array(493.37994, dtype=float32),
#   Array(494.03943, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (2799,
#   38,
#   Array(369.87607, dtype=float32),
#   Array(366.32315, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2899,
#   39,
#   Array(336.52594, dtype=float32),
#   Array(332.91284, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2999,
#   40,
#   Array(299.6908, dtype=float32),
#   Array(295.48663, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3099,
#   41,
#   Array(240.26558, dtype=float32),
#   Array(235.1217, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3199,
#   42,
#   Array(206.49432, dtype=float32),
#   Array(202.02611, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (3299,
#   43,
#   Array(182.44437, dtype=float32),
#   Array(178.60033, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (3399,
#   44,
#   Array(163.44266, dtype=float32),
#   Array(159.90047, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (3499,
#   45,
#   Array(149.14954, dtype=float32),
#   Array(145.703, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (3599,
#   46,
#   Array(127.03946, dtype=float32),
#   Array(123.695724, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (3699,
#   47,
#   Array(183.75897, dtype=float32),
#   Array(184.36516, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (3799,
#   48,
#   Array(109.01303, dtype=float32),
#   Array(106.0406, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (3899,
#   49,
#   Array(103.60758, dtype=float32),
#   Array(100.89966, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (3999,
#   50,
#   Array(83.796364, dtype=float32),
#   Array(80.903206, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (4099,
#   51,
#   Array(70.04902, dtype=float32),
#   Array(67.444145, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (4199,
#   52,
#   Array(57.00281, dtype=float32),
#   Array(54.66634, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4299,
#   53,
#   Array(46.56174, dtype=float32),
#   Array(44.549168, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (4399,
#   54,
#   Array(38.539745, dtype=float32),
#   Array(36.735954, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (4499,
#   55,
#   Array(34.701084, dtype=float32),
#   Array(33.04794, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4599,
#   56,
#   Array(28.469536, dtype=float32),
#   Array(27.12621, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (4699,
#   57,
#   Array(237.25073, dtype=float32),
#   Array(238.681, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (4799,
#   58,
#   Array(98.247444, dtype=float32),
#   Array(99.01716, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (4899,
#   59,
#   Array(65.69342, dtype=float32),
#   Array(65.53148, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4999,
#   60,
#   Array(46.36664, dtype=float32),
#   Array(45.513916, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (5099,
#   61,
#   Array(33.189663, dtype=float32),
#   Array(32.086803, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (5199,
#   62,
#   Array(26.010574, dtype=float32),
#   Array(24.859522, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (5299,
#   63,
#   Array(20.961, dtype=float32),
#   Array(19.91903, dtype=float32),
#   'sin',
#   Array(1, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum([mlp.input_size] + mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)
det_epochs, det_neurons = zip(*det_neuron_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with bare probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with bare probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")

# %%
# plot add and remove probablities with test loss and number of neurons
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(test_epochs, test_loss, "-.", color=color, label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)

ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(det_epochs, det_neurons, ".", color=color, alpha = 0.6, label="neuron function")
ax3.set_ylabel('neuron function', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.spines['right'].set_color(color)
ax3.legend()

plt.suptitle(f"Heterogenous {act_string} Neural Network")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_prob.png")
plt.savefig(f"{fig_folder}/loss_curve_prob.pdf")
plt.savefig(f"{fig_folder}/loss_curve_prob.svg", format='svg', bbox_inches='tight')

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)
