# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.style as mplstyle

import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='viridis', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
def initialize_optimizer_state(mlp, optimizer):
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
input_size = 3
hidden_sizes = [2, 3] 
output_size = 1
initial_activation_list = [jax.nn.relu, jax.nn.tanh, sin]

hetero_config = MLPConfig(input_size=input_size,
                        output_size=output_size,
                        hidden_sizes=hidden_sizes,
                        initial_activation_list=initial_activation_list,
                        seed=42)

# %%
mlp = CustomMLP(hetero_config)
# Out:
# 2024-06-04 12:36:42.187373: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.4.131). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.show()

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = mlp(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
x = jnp.array([1.0, 2.0, 3.0])
y = jnp.array([1.0])

# %%
mlp = CustomMLP(hetero_config)
opt = optax.sgd(learning_rate=1e-2)
opt_state = initialize_optimizer_state(mlp, opt)

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
plt.matshow(initial_adjacency_matrix, cmap=plt.cm.viridis)

# %%
activation_list = [jax.nn.relu, sin, jax.nn.tanh]
num_epochs = 1000
add_node_every = 10
remove_node_every = 10
key = jax.random.PRNGKey(42)
Loss_history = []
Node_history = []
graph_history = []
Update_history = []
threshold = 1e-8

# %%
for epoch in range(num_epochs):
    loss, mlp, opt_state = train_step(mlp, x, y, opt_state, opt.update)
    print(f"Epoch {epoch}, Prediction: {mlp(x)}, Loss: {loss}")

    key, add_key, sub_key = jax.random.split(key,3)
    n_neurons = sum(mlp.get_shape())
    Loss_history.append(loss)
    Node_history.append(n_neurons)


    # Dynamically add or remove neurons
    if (epoch + 1) % add_node_every == 0:
        if len(Update_history) == 0 or Update_history[-1][2] > loss or Update_history[-1][3] == "removed":
            # if no previous addition or last addition was rejected, add a neuron
            # if last addition was accepted, add a neuron
            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0]
            mlp.add_neuron(layer_index=layer, activation=activation, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            Update_history.append((epoch, n_neurons, loss, activation.__name__, layer))
            print(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            print(mlp.get_shape())
        
        elif Update_history[-1][2] < loss:
            # if last addition doesn't improve loss, reject it
            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            print(f"Update history: {Update_history[-1]}")
            layer = Update_history[-1][4]
            neuron_idx = len(mlp.layers[layer]) -1

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            Update_history.append((epoch, n_neurons, loss, "removed", layer))
            print(f"Rejecting last addition,\n Removed neuron from hidden layer {layer+1} at index {neuron_idx}")
            print(mlp.get_shape())
        
        if loss < threshold:
            # if loss is below threshold, stop training
            print(f"Threshold reached, stopping training at epoch {epoch}")
            break


print("Final Prediction:", mlp(x))
# Out:
# Epoch 0, Prediction: [0.24195556], Loss: 0.6022641062736511
# Epoch 1, Prediction: [0.25976145], Loss: 0.5746313333511353
# Epoch 2, Prediction: [0.27735046], Loss: 0.5479531288146973
# Epoch 3, Prediction: [0.29471123], Loss: 0.5222223997116089
# Epoch 4, Prediction: [0.3118323], Loss: 0.49743223190307617
# Epoch 5, Prediction: [0.3287031], Loss: 0.47357475757598877
# Epoch 6, Prediction: [0.34531385], Loss: 0.4506395161151886
# Epoch 7, Prediction: [0.3616562], Loss: 0.42861396074295044
# Epoch 8, Prediction: [0.37772292], Loss: 0.4074828326702118
# Epoch 9, Prediction: [0.39350832], Loss: 0.38722875714302063
# Added neuron to hidden layer 2 with activation sin
# [2, 4, 1]
# Epoch 10, Prediction: [0.7169265], Loss: 0.08816378563642502
# Epoch 11, Prediction: [0.7298279], Loss: 0.08013059943914413
# Epoch 12, Prediction: [0.7418802], Loss: 0.0729929730296135
# Epoch 13, Prediction: [0.7531694], Loss: 0.06662584096193314
# Epoch 14, Prediction: [0.76376975], Loss: 0.06092533469200134
# Epoch 15, Prediction: [0.7737459], Loss: 0.05580473318696022
# Epoch 16, Prediction: [0.783154], Loss: 0.05119092017412186
# Epoch 17, Prediction: [0.7920431], Loss: 0.04702218249440193
# Epoch 18, Prediction: [0.80045664], Loss: 0.0432460755109787
# Epoch 19, Prediction: [0.8084326], Loss: 0.039817553013563156
# Added neuron to hidden layer 2 with activation tanh
# [2, 5, 1]
# Epoch 20, Prediction: [0.7152058], Loss: 0.09041526168584824
# Epoch 21, Prediction: [0.72993976], Loss: 0.0811077430844307
# Epoch 22, Prediction: [0.7436349], Loss: 0.07293253391981125
# Epoch 23, Prediction: [0.7563979], Loss: 0.06572307646274567
# Epoch 24, Prediction: [0.7683218], Loss: 0.05934198200702667
# Epoch 25, Prediction: [0.7794864], Loss: 0.05367478355765343
# Epoch 26, Prediction: [0.78996176], Loss: 0.048626240342855453
# Epoch 27, Prediction: [0.7998088], Loss: 0.0441160649061203
# Epoch 28, Prediction: [0.80908114], Loss: 0.040076516568660736
# Epoch 29, Prediction: [0.8178261], Loss: 0.036450013518333435
# Added neuron to hidden layer 1 with activation tanh
# [3, 5, 1]
# Epoch 30, Prediction: [0.8284065], Loss: 0.03239734098315239
# Epoch 31, Prediction: [0.83634084], Loss: 0.02944432571530342
# Epoch 32, Prediction: [0.8438452], Loss: 0.026784319430589676
# Epoch 33, Prediction: [0.8509505], Loss: 0.024384325370192528
# Epoch 34, Prediction: [0.85768455], Loss: 0.02221575938165188
# Epoch 35, Prediction: [0.86407244], Loss: 0.020253686234354973
# Epoch 36, Prediction: [0.870137], Loss: 0.018476301804184914
# Epoch 37, Prediction: [0.8758987], Loss: 0.01686440408229828
# Epoch 38, Prediction: [0.8813768], Loss: 0.015401127748191357
# Epoch 39, Prediction: [0.8865882], Loss: 0.01407146267592907
# Added neuron to hidden layer 1 with activation tanh
# [4, 5, 1]
# Epoch 40, Prediction: [1.0964447], Loss: 0.010184718295931816
# Epoch 41, Prediction: [1.0921602], Loss: 0.009301585145294666
# Epoch 42, Prediction: [1.0880584], Loss: 0.008493507280945778
# Epoch 43, Prediction: [1.0841317], Loss: 0.007754273246973753
# Epoch 44, Prediction: [1.0803734], Loss: 0.00707814609631896
# Epoch 45, Prediction: [1.0767767], Loss: 0.006459884345531464
# Epoch 46, Prediction: [1.0733348], Loss: 0.005894668400287628
# Epoch 47, Prediction: [1.0700417], Loss: 0.005377994850277901
# Epoch 48, Prediction: [1.0668912], Loss: 0.00490583386272192
# Epoch 49, Prediction: [1.0638776], Loss: 0.0044744317419826984
# Added neuron to hidden layer 1 with activation sin
# [5, 5, 1]
# Epoch 50, Prediction: [0.7208567], Loss: 0.09071212261915207
# Epoch 51, Prediction: [0.7411025], Loss: 0.07792096585035324
# Epoch 52, Prediction: [0.75973284], Loss: 0.06702790409326553
# Epoch 53, Prediction: [0.7769026], Loss: 0.05772830545902252
# Epoch 54, Prediction: [0.7927479], Loss: 0.049772441387176514
# Epoch 55, Prediction: [0.8073878], Loss: 0.042953427881002426
# Epoch 56, Prediction: [0.8209275], Loss: 0.0370994471013546
# Epoch 57, Prediction: [0.8334609], Loss: 0.032066959887742996
# Epoch 58, Prediction: [0.8450718], Loss: 0.027735263109207153
# Epoch 59, Prediction: [0.85583586], Loss: 0.02400274947285652
# Update history: (49, 10, Array(0.00447443, dtype=float32), 'sin', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 4
# [4, 5, 1]
# Epoch 60, Prediction: [1.1427351], Loss: 0.022196929901838303
# Epoch 61, Prediction: [1.1367447], Loss: 0.02037331461906433
# Epoch 62, Prediction: [1.1310041], Loss: 0.018699122592806816
# Epoch 63, Prediction: [1.1255027], Loss: 0.017162073403596878
# Epoch 64, Prediction: [1.1202306], Loss: 0.015750929713249207
# Epoch 65, Prediction: [1.1151782], Loss: 0.014455386437475681
# Epoch 66, Prediction: [1.110336], Loss: 0.013266024179756641
# Epoch 67, Prediction: [1.1056952], Loss: 0.012174021452665329
# Epoch 68, Prediction: [1.101248], Loss: 0.011171485297381878
# Epoch 69, Prediction: [1.0969857], Loss: 0.010251162573695183
# Added neuron to hidden layer 1 with activation relu
# [5, 5, 1]
# Epoch 70, Prediction: [1.092901], Loss: 0.009406225755810738
# Epoch 71, Prediction: [1.0889864], Loss: 0.008630594238638878
# Epoch 72, Prediction: [1.085235], Loss: 0.007918578572571278
# Epoch 73, Prediction: [1.0816399], Loss: 0.007265005260705948
# Epoch 74, Prediction: [1.0781947], Loss: 0.006665071006864309
# Epoch 75, Prediction: [1.0748932], Loss: 0.006114416755735874
# Epoch 76, Prediction: [1.0717297], Loss: 0.005608996842056513
# Epoch 77, Prediction: [1.0686983], Loss: 0.005145144183188677
# Epoch 78, Prediction: [1.0657934], Loss: 0.004719454795122147
# Epoch 79, Prediction: [1.0630101], Loss: 0.004328771028667688
# Added neuron to hidden layer 1 with activation tanh
# [6, 5, 1]
# Epoch 80, Prediction: [1.0828255], Loss: 0.00748335151001811
# Epoch 81, Prediction: [1.0793015], Loss: 0.006860070396214724
# Epoch 82, Prediction: [1.0759273], Loss: 0.006288724020123482
# Epoch 83, Prediction: [1.0726966], Loss: 0.005764948669821024
# Epoch 84, Prediction: [1.0696032], Loss: 0.0052847908809781075
# Epoch 85, Prediction: [1.0666413], Loss: 0.004844605922698975
# Epoch 86, Prediction: [1.0638053], Loss: 0.004441067110747099
# Epoch 87, Prediction: [1.06109], Loss: 0.004071121569722891
# Epoch 88, Prediction: [1.05849], Loss: 0.0037319872062653303
# Epoch 89, Prediction: [1.0560007], Loss: 0.003421084489673376
# Added neuron to hidden layer 2 with activation relu
# [6, 6, 1]
# Epoch 90, Prediction: [1.0536171], Loss: 0.0031360795255750418
# Epoch 91, Prediction: [1.0513347], Loss: 0.0028747955802828074
# Epoch 92, Prediction: [1.0491494], Loss: 0.002635255455970764
# Epoch 93, Prediction: [1.0470572], Loss: 0.0024156628642231226
# Epoch 94, Prediction: [1.0450537], Loss: 0.002214375650510192
# Epoch 95, Prediction: [1.0431354], Loss: 0.0020298378076404333
# Epoch 96, Prediction: [1.0412989], Loss: 0.0018606631783768535
# Epoch 97, Prediction: [1.03954], Loss: 0.0017055963398888707
# Epoch 98, Prediction: [1.0378562], Loss: 0.001563415746204555
# Epoch 99, Prediction: [1.0362442], Loss: 0.0014330934500321746
# Added neuron to hidden layer 2 with activation relu
# [6, 7, 1]
# Epoch 100, Prediction: [1.0347004], Loss: 0.0013136386405676603
# Epoch 101, Prediction: [1.0332223], Loss: 0.0012041173176839948
# Epoch 102, Prediction: [1.0318073], Loss: 0.0011037223739549518
# Epoch 103, Prediction: [1.0304524], Loss: 0.0010117045603692532
# Epoch 104, Prediction: [1.029155], Loss: 0.0009273468749597669
# Epoch 105, Prediction: [1.0279127], Loss: 0.0008500149706378579
# Epoch 106, Prediction: [1.0267236], Loss: 0.0007791208336129785
# Epoch 107, Prediction: [1.0255849], Loss: 0.0007141520618461072
# Epoch 108, Prediction: [1.0244946], Loss: 0.0006545889773406088
# Epoch 109, Prediction: [1.0234509], Loss: 0.000599987804889679
# Added neuron to hidden layer 2 with activation tanh
# [6, 8, 1]
# Epoch 110, Prediction: [1.0243752], Loss: 0.000650520552881062
# Epoch 111, Prediction: [1.0232949], Loss: 0.000594150391407311
# Epoch 112, Prediction: [1.0222623], Loss: 0.0005426535499282181
# Epoch 113, Prediction: [1.0212754], Loss: 0.0004956115735694766
# Epoch 114, Prediction: [1.0203321], Loss: 0.00045264267828315496
# Epoch 115, Prediction: [1.0194304], Loss: 0.00041339421295560896
# Epoch 116, Prediction: [1.0185686], Loss: 0.0003775403893087059
# Epoch 117, Prediction: [1.0177448], Loss: 0.000344794214470312
# Epoch 118, Prediction: [1.0169576], Loss: 0.0003148771938867867
# Epoch 119, Prediction: [1.0162051], Loss: 0.0002875615900848061
# Added neuron to hidden layer 1 with activation tanh
# [7, 8, 1]
# Epoch 120, Prediction: [1.024675], Loss: 0.20203199982643127
# Epoch 121, Prediction: [1.023498], Loss: 0.000608856207691133
# Epoch 122, Prediction: [1.0223773], Loss: 0.0005521587445400655
# Epoch 123, Prediction: [1.0213099], Loss: 0.0005007414147257805
# Epoch 124, Prediction: [1.0202932], Loss: 0.00045410983148030937
# Epoch 125, Prediction: [1.0193255], Loss: 0.00041181541746482253
# Epoch 126, Prediction: [1.0184035], Loss: 0.00037347475881688297
# Epoch 127, Prediction: [1.0175258], Loss: 0.00033868991886265576
# Epoch 128, Prediction: [1.0166898], Loss: 0.00030715338652953506
# Epoch 129, Prediction: [1.0158937], Loss: 0.0002785486576613039
# Added neuron to hidden layer 2 with activation sin
# [7, 9, 1]
# Epoch 130, Prediction: [0.6887597], Loss: 0.15180249512195587
# Epoch 131, Prediction: [0.7508909], Loss: 0.0968705341219902
# Epoch 132, Prediction: [0.8007384], Loss: 0.06205533817410469
# Epoch 133, Prediction: [0.84074223], Loss: 0.03970518708229065
# Epoch 134, Prediction: [0.87279797], Loss: 0.02536303736269474
# Epoch 135, Prediction: [0.8984478], Loss: 0.016180356964468956
# Epoch 136, Prediction: [0.91894996], Loss: 0.01031284686177969
# Epoch 137, Prediction: [0.93532556], Loss: 0.006569108925759792
# Epoch 138, Prediction: [0.9483993], Loss: 0.004182782955467701
# Epoch 139, Prediction: [0.95883346], Loss: 0.002662631683051586
# Update history: (129, 16, Array(0.00027855, dtype=float32), 'sin', Array(1, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 2 at index 8
# [7, 8, 1]
# Epoch 140, Prediction: [1.1051977], Loss: 0.012363764457404613
# Epoch 141, Prediction: [1.0993998], Loss: 0.011066549457609653
# Epoch 142, Prediction: [1.0937788], Loss: 0.009880321100354195
# Epoch 143, Prediction: [1.0883183], Loss: 0.008794472552835941
# Epoch 144, Prediction: [1.0830058], Loss: 0.0078001306392252445
# Epoch 145, Prediction: [1.0778322], Loss: 0.00688996072858572
# Epoch 146, Prediction: [1.0727932], Loss: 0.006057854741811752
# Epoch 147, Prediction: [1.0678887], Loss: 0.005298856645822525
# Epoch 148, Prediction: [1.0631222], Loss: 0.0046088807284832
# Epoch 149, Prediction: [1.058501], Loss: 0.003984406124800444
# Added neuron to hidden layer 1 with activation relu
# [8, 8, 1]
# Epoch 150, Prediction: [0.98836803], Loss: 0.00022662433912046254
# Epoch 151, Prediction: [0.99096555], Loss: 0.0001353026309516281
# Epoch 152, Prediction: [0.99295527], Loss: 8.162137237377465e-05
# Epoch 153, Prediction: [0.9944901], Loss: 4.96282555104699e-05
# Epoch 154, Prediction: [0.9956807], Loss: 3.035914050997235e-05
# Epoch 155, Prediction: [0.99660784], Loss: 1.865644117060583e-05
# Epoch 156, Prediction: [0.9973322], Loss: 1.150674870586954e-05
# Epoch 157, Prediction: [0.99789953], Loss: 7.117075256246608e-06
# Epoch 158, Prediction: [0.99834484], Loss: 4.4119642552686855e-06
# Epoch 159, Prediction: [0.99869484], Loss: 2.739559249675949e-06
# Added neuron to hidden layer 1 with activation relu
# [9, 8, 1]
# Epoch 160, Prediction: [1.0306857], Loss: 0.0013490879209712148
# Epoch 161, Prediction: [1.0253191], Loss: 0.0009416099055670202
# Epoch 162, Prediction: [1.0206572], Loss: 0.000641056802123785
# Epoch 163, Prediction: [1.0166876], Loss: 0.00042671916889958084
# Epoch 164, Prediction: [1.0133661], Loss: 0.0002784770622383803
# Epoch 165, Prediction: [1.0106289], Loss: 0.0001786527136573568
# Epoch 166, Prediction: [1.0084021], Loss: 0.00011297433957224712
# Epoch 167, Prediction: [1.0066093], Loss: 7.059543713694438e-05
# Epoch 168, Prediction: [1.0051787], Loss: 4.3683117837645113e-05
# Epoch 169, Prediction: [1.0040451], Loss: 2.6818830519914627e-05
# Update history: (159, 17, Array(2.7395592e-06, dtype=float32), 'relu', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 8
# [8, 8, 1]
# Epoch 170, Prediction: [0.97462374], Loss: 0.001130657154135406
# Epoch 171, Prediction: [0.98060995], Loss: 0.0006439546123147011
# Epoch 172, Prediction: [0.98504937], Loss: 0.0003759739047382027
# Epoch 173, Prediction: [0.9883951], Loss: 0.00022352143423631787
# Epoch 174, Prediction: [0.9909462], Loss: 0.00013467382814269513
# Epoch 175, Prediction: [0.9929093], Loss: 8.197176794055849e-05
# Epoch 176, Prediction: [0.9944302], Loss: 5.0277853006264195e-05
# Epoch 177, Prediction: [0.9956149], Loss: 3.102284608758055e-05
# Epoch 178, Prediction: [0.9965414], Loss: 1.9229222743888386e-05
# Epoch 179, Prediction: [0.9972683], Loss: 1.1962046301050577e-05
# Added neuron to hidden layer 1 with activation sin
# [9, 8, 1]
# Epoch 180, Prediction: [1.0344437], Loss: 0.0015625108499079943
# Epoch 181, Prediction: [1.0298252], Loss: 0.0011863709660246968
# Epoch 182, Prediction: [1.0256764], Loss: 0.0008895432110875845
# Epoch 183, Prediction: [1.021988], Loss: 0.0006592759746126831
# Epoch 184, Prediction: [1.0187398], Loss: 0.0004834736464545131
# Epoch 185, Prediction: [1.0159042], Loss: 0.000351180846337229
# Epoch 186, Prediction: [1.0134478], Loss: 0.00025294319493696094
# Epoch 187, Prediction: [1.0113335], Loss: 0.00018084229668602347
# Epoch 188, Prediction: [1.0095252], Loss: 0.0001284474419662729
# Epoch 189, Prediction: [1.0079861], Loss: 9.072905231732875e-05
# Update history: (179, 17, Array(1.1962046e-05, dtype=float32), 'sin', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 8
# [8, 8, 1]
# Epoch 190, Prediction: [0.9687146], Loss: 0.0017363958759233356
# Epoch 191, Prediction: [0.9761437], Loss: 0.0009787766030058265
# Epoch 192, Prediction: [0.9816047], Loss: 0.0005691222031600773
# Epoch 193, Prediction: [0.9856988], Loss: 0.00033838723902590573
# Epoch 194, Prediction: [0.9888131], Loss: 0.0002045237779384479
# Epoch 195, Prediction: [0.991208], Loss: 0.00012514667469076812
# Epoch 196, Prediction: [0.9930653], Loss: 7.729896606178954e-05
# Epoch 197, Prediction: [0.99451506], Loss: 4.809009624295868e-05
# Epoch 198, Prediction: [0.9956522], Loss: 3.0084551326581277e-05
# Epoch 199, Prediction: [0.99654776], Loss: 1.890337443910539e-05
# Added neuron to hidden layer 2 with activation sin
# [8, 9, 1]
# Epoch 200, Prediction: [1.0248859], Loss: 0.0014932355843484402
# Epoch 201, Prediction: [1.015655], Loss: 0.0006193076842464507
# Epoch 202, Prediction: [1.009694], Loss: 0.00024508030037395656
# Epoch 203, Prediction: [1.0059417], Loss: 9.397324902238324e-05
# Epoch 204, Prediction: [1.0036187], Loss: 3.530437606968917e-05
# Epoch 205, Prediction: [1.0021954], Loss: 1.3095113899908029e-05
# Epoch 206, Prediction: [1.0013283], Loss: 4.819597961613908e-06
# Epoch 207, Prediction: [1.0008026], Loss: 1.7645113530306844e-06
# Epoch 208, Prediction: [1.0004846], Loss: 6.442247695304104e-07
# Epoch 209, Prediction: [1.0002924], Loss: 2.3482336075630883e-07
# Added neuron to hidden layer 1 with activation sin
# [9, 9, 1]
# Epoch 210, Prediction: [0.8512793], Loss: 0.032675717025995255
# Epoch 211, Prediction: [0.87638694], Loss: 0.022117841988801956
# Epoch 212, Prediction: [0.8967232], Loss: 0.01528018806129694
# Epoch 213, Prediction: [0.91348004], Loss: 0.010666094720363617
# Epoch 214, Prediction: [0.9274136], Loss: 0.007485703099519014
# Epoch 215, Prediction: [0.93905705], Loss: 0.00526878796517849
# Epoch 216, Prediction: [0.9488133], Loss: 0.0037140429485589266
# Epoch 217, Prediction: [0.9570001], Loss: 0.002620076294988394
# Epoch 218, Prediction: [0.9638754], Loss: 0.001848993357270956
# Epoch 219, Prediction: [0.9696517], Loss: 0.0013049858389422297
# Update history: (209, 18, Array(2.3482336e-07, dtype=float32), 'sin', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 8
# [8, 9, 1]
# Epoch 220, Prediction: [1.1134824], Loss: 0.025586029514670372
# Epoch 221, Prediction: [1.0742686], Loss: 0.012878244742751122
# Epoch 222, Prediction: [1.045307], Loss: 0.005515821743756533
# Epoch 223, Prediction: [1.0262334], Loss: 0.0020527278538793325
# Epoch 224, Prediction: [1.0146778], Loss: 0.0006881930748932064
# Epoch 225, Prediction: [1.0080444], Loss: 0.0002154367248294875
# Epoch 226, Prediction: [1.0043572], Loss: 6.471176311606541e-05
# Epoch 227, Prediction: [1.0023446], Loss: 1.89853544725338e-05
# Epoch 228, Prediction: [1.0012572], Loss: 5.497187885339372e-06
# Epoch 229, Prediction: [1.0006727], Loss: 1.5805044313310646e-06
# Added neuron to hidden layer 1 with activation sin
# [9, 9, 1]
# Epoch 230, Prediction: [0.93032354], Loss: 0.02901453897356987
# Epoch 231, Prediction: [0.9717472], Loss: 0.0048548090271651745
# Epoch 232, Prediction: [0.9885978], Loss: 0.0007982195820659399
# Epoch 233, Prediction: [0.99540466], Loss: 0.00013000992476008832
# Epoch 234, Prediction: [0.99814856], Loss: 2.1117142750881612e-05
# Epoch 235, Prediction: [0.99925435], Loss: 3.427828232815955e-06
# Epoch 236, Prediction: [0.9996997], Loss: 5.560000317927916e-07
# Epoch 237, Prediction: [0.99987924], Loss: 9.01730032865089e-08
# Epoch 238, Prediction: [0.99995106], Loss: 1.4582738572244125e-08
# Epoch 239, Prediction: [0.99998045], Loss: 2.3946746807723684e-09
# Added neuron to hidden layer 1 with activation sin
# [10, 9, 1]
# Threshold reached, stopping training at epoch 239
# Final Prediction: [2.4161263]

# %%
Update_history
# Out:
# [(9, 6, Array(0.38722876, dtype=float32), 'sin', Array(1, dtype=int32)),
#  (19, 7, Array(0.03981755, dtype=float32), 'tanh', Array(1, dtype=int32)),
#  (29, 8, Array(0.03645001, dtype=float32), 'tanh', Array(0, dtype=int32)),
#  (39, 9, Array(0.01407146, dtype=float32), 'tanh', Array(0, dtype=int32)),
#  (49, 10, Array(0.00447443, dtype=float32), 'sin', Array(0, dtype=int32)),
#  (59, 11, Array(0.02400275, dtype=float32), 'removed', Array(0, dtype=int32)),
#  (69, 10, Array(0.01025116, dtype=float32), 'relu', Array(0, dtype=int32)),
#  (79, 11, Array(0.00432877, dtype=float32), 'tanh', Array(0, dtype=int32)),
#  (89, 12, Array(0.00342108, dtype=float32), 'relu', Array(1, dtype=int32)),
#  (99, 13, Array(0.00143309, dtype=float32), 'relu', Array(1, dtype=int32)),
#  (109, 14, Array(0.00059999, dtype=float32), 'tanh', Array(1, dtype=int32)),
#  (119, 15, Array(0.00028756, dtype=float32), 'tanh', Array(0, dtype=int32)),
#  (129, 16, Array(0.00027855, dtype=float32), 'sin', Array(1, dtype=int32)),
#  (139, 17, Array(0.00266263, dtype=float32), 'removed', Array(1, dtype=int32)),
#  (149, 16, Array(0.00398441, dtype=float32), 'relu', Array(0, dtype=int32)),
#  (159, 17, Array(2.7395592e-06, dtype=float32), 'relu', Array(0, dtype=int32)),
#  (169,
#   18,
#   Array(2.681883e-05, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (179, 17, Array(1.1962046e-05, dtype=float32), 'sin', Array(0, dtype=int32)),
#  (189,
#   18,
#   Array(9.072905e-05, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (199, 17, Array(1.8903374e-05, dtype=float32), 'sin', Array(1, dtype=int32)),
#  (209, 18, Array(2.3482336e-07, dtype=float32), 'sin', Array(0, dtype=int32)),
#  (219, 19, Array(0.00130499, dtype=float32), 'removed', Array(0, dtype=int32)),
#  (229, 18, Array(1.5805044e-06, dtype=float32), 'sin', Array(0, dtype=int32)),
#  (239, 19, Array(2.3946747e-09, dtype=float32), 'sin', Array(0, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
plt.matshow(final_adjacency_matrix, cmap=plt.cm.viridis)

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(np.arange(0,len(Loss_history)), Loss_history, ".", color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(np.arange(0,len(Node_history)), Node_history, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.suptitle("Heterogenous Neural Network with Loss strategy Node Addition and Removal")
fig.tight_layout()

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.show()
