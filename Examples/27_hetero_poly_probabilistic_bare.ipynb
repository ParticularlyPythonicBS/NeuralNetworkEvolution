# %% [markdown]
# # Bare Probabilistic strategy for Polynomial prediction with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "27_hetero_poly_probabilistic_bare.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="25_hetero_poly_probabilistic.ipynb"
# env: WANDB_SILENT=True

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

import os
import sys
import time
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 1
hidden_sizes = [5, 5] 
min_neurons = 4
output_size = 1
initial_activation_list = [sin, jax.nn.relu, jax.nn.tanh]
activation_list = [sin, jax.nn.relu, jax.nn.tanh]
optimizer = optax.adabelief
bias = False
num_epochs = 25000
intervene_every = 100
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"Hetero_{act_string}_poly_bare_probabilistic_strat_{optimizer.__name__}_no_bias_min_{min_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: Hetero_sin_relu_tanh_poly_probabilistic_strat_adabelief_no_bias_min_4_5_5_25000_100_0.0001_0
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
def poly(x):
    """
    7th degree polynomial to predict
    """
    return (x - 3)*(x - 2)*(x - 1)*x*(x + 1)*(x + 2)*(x + 3)

# %%
x = jnp.linspace(-3, 3, n_samples).reshape(-1, 1)
y = poly(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.2, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha = 0.2, label=f"test:{len(x_test)}")
plt.legend()
plt.suptitle("Data")
# Out:
# Text(0.5, 0.98, 'Data')

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0]

# %%
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 11

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity

# %%
def p_add(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to add a neuron
    """
    return test_loss / (test_loss + n_neurons / min_neurons)

def p_remove(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to remove a neuron
    """
    return test_loss / (test_loss + min_neurons / n_neurons)

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}")
        wandb.log({"test_loss": test_loss.item()})
        test_loss_history.append((epoch,test_loss))

        # Neuron Addition criteria
        if ( jax.random.uniform(prob_key, minval = 0, maxval = 1)< p_add(test_loss, n_neurons, min_neurons)): # addition probability

            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0] # randomly select a layer to add neuron to
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            update_history.append((epoch, n_neurons, train_loss, test_loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
            check_loss = test_loss
            logging.info(f"Check loss updated to {check_loss}")
        
        # Neuron Removal criteria
        elif (jax.random.uniform(prob_key, minval = 0, maxval = 1)<p_remove(test_loss, n_neurons, min_neurons)): # removal probability 

            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            layer = update_history[-1][-1] # get the layer of last addition
            neuron_idx = len(mlp.layers[layer]) -1

            if len(mlp.layers[layer]) <= 1:
                logging.info(f"Cannot remove neuron from layer {layer+1}, only one neuron left")
                update_history.append((epoch, n_neurons, train_loss, test_loss, "single_node_layer", layer))
                continue

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            update_history.append((epoch, n_neurons, train_loss, test_loss, "removed", layer))

            logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
            wandb.log({"removed neuron": neuron_idx})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 1508.8876953125, Neurons: 11, Grad norm: 4.791e+01
# Epoch 001, Loss: 1508.81396484375, Neurons: 11, Grad norm: 4.791e+01
# Epoch 002, Loss: 1508.736572265625, Neurons: 11, Grad norm: 4.790e+01
# Epoch 003, Loss: 1508.6552734375, Neurons: 11, Grad norm: 4.790e+01
# Epoch 004, Loss: 1508.5703125, Neurons: 11, Grad norm: 4.789e+01
# Epoch 005, Loss: 1508.4813232421875, Neurons: 11, Grad norm: 4.789e+01
# Epoch 006, Loss: 1508.3885498046875, Neurons: 11, Grad norm: 4.788e+01
# Epoch 007, Loss: 1508.2921142578125, Neurons: 11, Grad norm: 4.788e+01
# Epoch 008, Loss: 1508.1915283203125, Neurons: 11, Grad norm: 4.788e+01
# Epoch 009, Loss: 1508.0872802734375, Neurons: 11, Grad norm: 4.787e+01
# Epoch 010, Loss: 1507.9793701171875, Neurons: 11, Grad norm: 4.787e+01
# Epoch 011, Loss: 1507.86767578125, Neurons: 11, Grad norm: 4.786e+01
# Epoch 012, Loss: 1507.752197265625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 013, Loss: 1507.633056640625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 014, Loss: 1507.5103759765625, Neurons: 11, Grad norm: 4.785e+01
# Epoch 015, Loss: 1507.384033203125, Neurons: 11, Grad norm: 4.785e+01
# Epoch 016, Loss: 1507.254150390625, Neurons: 11, Grad norm: 4.785e+01
# Epoch 017, Loss: 1507.1209716796875, Neurons: 11, Grad norm: 4.785e+01
# Epoch 018, Loss: 1506.9842529296875, Neurons: 11, Grad norm: 4.785e+01
# Epoch 019, Loss: 1506.84423828125, Neurons: 11, Grad norm: 4.785e+01
# Epoch 020, Loss: 1506.7008056640625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 021, Loss: 1506.5543212890625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 022, Loss: 1506.404541015625, Neurons: 11, Grad norm: 4.787e+01
# Epoch 093, Loss: 1488.1280517578125, Neurons: 11, Grad norm: 5.409e+01
# Epoch 094, Loss: 1487.748046875, Neurons: 11, Grad norm: 5.424e+01
# Epoch 095, Loss: 1487.364013671875, Neurons: 11, Grad norm: 5.439e+01
# Epoch 096, Loss: 1486.976318359375, Neurons: 11, Grad norm: 5.454e+01
# Epoch 097, Loss: 1486.5845947265625, Neurons: 11, Grad norm: 5.469e+01
# Epoch 098, Loss: 1486.1888427734375, Neurons: 11, Grad norm: 5.484e+01
# Epoch 099, Loss: 1485.7891845703125, Neurons: 11, Grad norm: 5.499e+01
# Epoch 099, Test loss: 1515.2196044921875
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[6, 5, 1]
# Check loss updated to 1515.2196044921875
# Epoch 100, Loss: 1483.5963134765625, Neurons: 12, Grad norm: 5.586e+01
# Epoch 101, Loss: 1483.5137939453125, Neurons: 12, Grad norm: 5.585e+01
# Epoch 102, Loss: 1483.427490234375, Neurons: 12, Grad norm: 5.585e+01
# Epoch 103, Loss: 1483.33642578125, Neurons: 12, Grad norm: 5.584e+01
# Epoch 104, Loss: 1483.2415771484375, Neurons: 12, Grad norm: 5.584e+01
# Epoch 105, Loss: 1483.142333984375, Neurons: 12, Grad norm: 5.583e+01
# Epoch 106, Loss: 1483.038818359375, Neurons: 12, Grad norm: 5.583e+01
# Epoch 107, Loss: 1482.93115234375, Neurons: 12, Grad norm: 5.582e+01
# Epoch 108, Loss: 1482.8193359375, Neurons: 12, Grad norm: 5.581e+01
# Epoch 109, Loss: 1482.703369140625, Neurons: 12, Grad norm: 5.581e+01
# Epoch 110, Loss: 1482.583251953125, Neurons: 12, Grad norm: 5.580e+01
# Epoch 111, Loss: 1482.4591064453125, Neurons: 12, Grad norm: 5.579e+01
# Epoch 112, Loss: 1482.330810546875, Neurons: 12, Grad norm: 5.578e+01
# Epoch 113, Loss: 1482.1986083984375, Neurons: 12, Grad norm: 5.578e+01
# Epoch 114, Loss: 1482.0626220703125, Neurons: 12, Grad norm: 5.577e+01
# Epoch 115, Loss: 1481.9227294921875, Neurons: 12, Grad norm: 5.576e+01
# Epoch 116, Loss: 1481.779052734375, Neurons: 12, Grad norm: 5.575e+01
# Epoch 117, Loss: 1481.6319580078125, Neurons: 12, Grad norm: 5.574e+01
# Epoch 118, Loss: 1481.481201171875, Neurons: 12, Grad norm: 5.573e+01
# Epoch 119, Loss: 1481.3267822265625, Neurons: 12, Grad norm: 5.573e+01
# Epoch 120, Loss: 1481.1693115234375, Neurons: 12, Grad norm: 5.572e+01
# Epoch 121, Loss: 1481.00830078125, Neurons: 12, Grad norm: 5.571e+01
# Epoch 122, Loss: 1480.8441162109375, Neurons: 12, Grad norm: 5.570e+01
# Epoch 123, Loss: 1480.6768798828125, Neurons: 12, Grad norm: 5.570e+01
# Epoch 124, Loss: 1480.50634765625, Neurons: 12, Grad norm: 5.569e+01
# Epoch 125, Loss: 1480.3331298828125, Neurons: 12, Grad norm: 5.569e+01
# Epoch 126, Loss: 1480.1566162109375, Neurons: 12, Grad norm: 5.568e+01
# Epoch 127, Loss: 1479.9775390625, Neurons: 12, Grad norm: 5.568e+01
# Epoch 128, Loss: 1479.7955322265625, Neurons: 12, Grad norm: 5.567e+01
# Epoch 129, Loss: 1479.6107177734375, Neurons: 12, Grad norm: 5.567e+01
# Epoch 130, Loss: 1479.4232177734375, Neurons: 12, Grad norm: 5.567e+01
# Epoch 131, Loss: 1479.2332763671875, Neurons: 12, Grad norm: 5.567e+01
# Epoch 132, Loss: 1479.0406494140625, Neurons: 12, Grad norm: 5.567e+01
# Epoch 133, Loss: 1478.8455810546875, Neurons: 12, Grad norm: 5.567e+01
# Epoch 134, Loss: 1478.64794921875, Neurons: 12, Grad norm: 5.567e+01
# Epoch 135, Loss: 1478.447998046875, Neurons: 12, Grad norm: 5.568e+01
# Epoch 136, Loss: 1478.24560546875, Neurons: 12, Grad norm: 5.569e+01
# Epoch 137, Loss: 1478.040771484375, Neurons: 12, Grad norm: 5.569e+01
# Epoch 138, Loss: 1477.8338623046875, Neurons: 12, Grad norm: 5.570e+01
# Epoch 139, Loss: 1477.624267578125, Neurons: 12, Grad norm: 5.572e+01
# Epoch 140, Loss: 1477.41259765625, Neurons: 12, Grad norm: 5.573e+01
# Epoch 141, Loss: 1477.19873046875, Neurons: 12, Grad norm: 5.574e+01
# Epoch 142, Loss: 1476.982421875, Neurons: 12, Grad norm: 5.576e+01
# Epoch 143, Loss: 1476.7640380859375, Neurons: 12, Grad norm: 5.578e+01
# Epoch 144, Loss: 1476.54345703125, Neurons: 12, Grad norm: 5.580e+01
# Epoch 145, Loss: 1476.320556640625, Neurons: 12, Grad norm: 5.582e+01
# Epoch 146, Loss: 1476.0955810546875, Neurons: 12, Grad norm: 5.585e+01
# Epoch 147, Loss: 1475.8682861328125, Neurons: 12, Grad norm: 5.587e+01
# Epoch 148, Loss: 1475.638916015625, Neurons: 12, Grad norm: 5.590e+01
# Epoch 149, Loss: 1475.4073486328125, Neurons: 12, Grad norm: 5.593e+01
# Epoch 150, Loss: 1475.17333984375, Neurons: 12, Grad norm: 5.596e+01
# Epoch 151, Loss: 1474.9373779296875, Neurons: 12, Grad norm: 5.600e+01
# Epoch 152, Loss: 1474.6990966796875, Neurons: 12, Grad norm: 5.603e+01
# Epoch 153, Loss: 1474.4586181640625, Neurons: 12, Grad norm: 5.607e+01
# Epoch 154, Loss: 1474.2158203125, Neurons: 12, Grad norm: 5.611e+01
# Epoch 155, Loss: 1473.9708251953125, Neurons: 12, Grad norm: 5.616e+01
# Epoch 156, Loss: 1473.7237548828125, Neurons: 12, Grad norm: 5.620e+01
# Epoch 157, Loss: 1473.47412109375, Neurons: 12, Grad norm: 5.625e+01
# Epoch 158, Loss: 1473.2222900390625, Neurons: 12, Grad norm: 5.630e+01
# Epoch 159, Loss: 1472.968017578125, Neurons: 12, Grad norm: 5.635e+01
# Epoch 160, Loss: 1472.711669921875, Neurons: 12, Grad norm: 5.640e+01
# Epoch 161, Loss: 1472.452880859375, Neurons: 12, Grad norm: 5.646e+01
# Epoch 162, Loss: 1472.191650390625, Neurons: 12, Grad norm: 5.652e+01
# Epoch 163, Loss: 1471.9281005859375, Neurons: 12, Grad norm: 5.658e+01
# Epoch 164, Loss: 1471.662109375, Neurons: 12, Grad norm: 5.664e+01
# Epoch 165, Loss: 1471.3935546875, Neurons: 12, Grad norm: 5.670e+01
# Epoch 166, Loss: 1471.12255859375, Neurons: 12, Grad norm: 5.677e+01
# Epoch 167, Loss: 1470.84912109375, Neurons: 12, Grad norm: 5.683e+01
# Epoch 168, Loss: 1470.5731201171875, Neurons: 12, Grad norm: 5.690e+01
# Epoch 169, Loss: 1470.2945556640625, Neurons: 12, Grad norm: 5.696e+01
# Epoch 170, Loss: 1470.0135498046875, Neurons: 12, Grad norm: 5.702e+01
# Epoch 171, Loss: 1469.7301025390625, Neurons: 12, Grad norm: 5.708e+01
# Epoch 172, Loss: 1469.4442138671875, Neurons: 12, Grad norm: 5.714e+01
# Epoch 173, Loss: 1469.1556396484375, Neurons: 12, Grad norm: 5.721e+01
# Epoch 174, Loss: 1468.8648681640625, Neurons: 12, Grad norm: 5.728e+01
# Epoch 175, Loss: 1468.5712890625, Neurons: 12, Grad norm: 5.736e+01
# Epoch 176, Loss: 1468.2752685546875, Neurons: 12, Grad norm: 5.744e+01
# Epoch 177, Loss: 1467.976806640625, Neurons: 12, Grad norm: 5.752e+01
# Epoch 178, Loss: 1467.67529296875, Neurons: 12, Grad norm: 5.760e+01
# Epoch 179, Loss: 1467.371337890625, Neurons: 12, Grad norm: 5.769e+01
# Epoch 180, Loss: 1467.064697265625, Neurons: 12, Grad norm: 5.779e+01
# Epoch 181, Loss: 1466.755126953125, Neurons: 12, Grad norm: 5.789e+01
# Epoch 182, Loss: 1466.4425048828125, Neurons: 12, Grad norm: 5.799e+01
# Epoch 183, Loss: 1466.1270751953125, Neurons: 12, Grad norm: 5.810e+01
# Epoch 184, Loss: 1465.8087158203125, Neurons: 12, Grad norm: 5.822e+01
# Epoch 185, Loss: 1465.4871826171875, Neurons: 12, Grad norm: 5.834e+01
# Epoch 186, Loss: 1465.16259765625, Neurons: 12, Grad norm: 5.847e+01
# Epoch 187, Loss: 1464.8345947265625, Neurons: 12, Grad norm: 5.860e+01
# Epoch 188, Loss: 1464.5030517578125, Neurons: 12, Grad norm: 5.874e+01
# Epoch 189, Loss: 1464.168212890625, Neurons: 12, Grad norm: 5.890e+01
# Epoch 190, Loss: 1463.829833984375, Neurons: 12, Grad norm: 5.906e+01
# Epoch 191, Loss: 1463.487548828125, Neurons: 12, Grad norm: 5.922e+01
# Epoch 192, Loss: 1463.1416015625, Neurons: 12, Grad norm: 5.940e+01
# Epoch 193, Loss: 1462.79150390625, Neurons: 12, Grad norm: 5.959e+01
# Epoch 194, Loss: 1462.4373779296875, Neurons: 12, Grad norm: 5.978e+01
# Epoch 195, Loss: 1462.0787353515625, Neurons: 12, Grad norm: 5.999e+01
# Epoch 401, Loss: 1405.1690673828125, Neurons: 15, Grad norm: 8.659e+01
# Epoch 402, Loss: 1405.0338134765625, Neurons: 15, Grad norm: 8.646e+01
# Epoch 403, Loss: 1404.8922119140625, Neurons: 15, Grad norm: 8.633e+01
# Epoch 404, Loss: 1404.7440185546875, Neurons: 15, Grad norm: 8.619e+01
# Epoch 405, Loss: 1404.5897216796875, Neurons: 15, Grad norm: 8.604e+01
# Epoch 406, Loss: 1404.428955078125, Neurons: 15, Grad norm: 8.589e+01
# Epoch 407, Loss: 1404.261962890625, Neurons: 15, Grad norm: 8.574e+01
# Epoch 408, Loss: 1404.0888671875, Neurons: 15, Grad norm: 8.559e+01
# Epoch 409, Loss: 1403.9095458984375, Neurons: 15, Grad norm: 8.543e+01
# Epoch 410, Loss: 1403.7242431640625, Neurons: 15, Grad norm: 8.527e+01
# Epoch 411, Loss: 1403.533203125, Neurons: 15, Grad norm: 8.511e+01
# Epoch 412, Loss: 1403.3363037109375, Neurons: 15, Grad norm: 8.495e+01
# Epoch 413, Loss: 1403.134033203125, Neurons: 15, Grad norm: 8.478e+01
# Epoch 414, Loss: 1402.9261474609375, Neurons: 15, Grad norm: 8.462e+01
# Epoch 415, Loss: 1402.7130126953125, Neurons: 15, Grad norm: 8.446e+01
# Epoch 416, Loss: 1402.4951171875, Neurons: 15, Grad norm: 8.429e+01
# Epoch 417, Loss: 1402.2718505859375, Neurons: 15, Grad norm: 8.413e+01
# Epoch 418, Loss: 1402.0440673828125, Neurons: 15, Grad norm: 8.397e+01
# Epoch 419, Loss: 1401.8115234375, Neurons: 15, Grad norm: 8.382e+01
# Epoch 420, Loss: 1401.57470703125, Neurons: 15, Grad norm: 8.366e+01
# Epoch 421, Loss: 1401.3333740234375, Neurons: 15, Grad norm: 8.351e+01
# Epoch 422, Loss: 1401.0880126953125, Neurons: 15, Grad norm: 8.336e+01
# Epoch 423, Loss: 1400.8387451171875, Neurons: 15, Grad norm: 8.322e+01
# Epoch 424, Loss: 1400.5853271484375, Neurons: 15, Grad norm: 8.308e+01
# Epoch 425, Loss: 1400.3284912109375, Neurons: 15, Grad norm: 8.294e+01
# Epoch 426, Loss: 1400.06787109375, Neurons: 15, Grad norm: 8.281e+01
# Epoch 427, Loss: 1399.8037109375, Neurons: 15, Grad norm: 8.269e+01
# Epoch 428, Loss: 1399.5361328125, Neurons: 15, Grad norm: 8.256e+01
# Epoch 429, Loss: 1399.2652587890625, Neurons: 15, Grad norm: 8.245e+01
# Epoch 430, Loss: 1398.991455078125, Neurons: 15, Grad norm: 8.234e+01
# Epoch 431, Loss: 1398.71435546875, Neurons: 15, Grad norm: 8.223e+01
# Epoch 432, Loss: 1398.43408203125, Neurons: 15, Grad norm: 8.213e+01
# Epoch 433, Loss: 1398.151123046875, Neurons: 15, Grad norm: 8.203e+01
# Epoch 434, Loss: 1397.8651123046875, Neurons: 15, Grad norm: 8.194e+01
# Epoch 435, Loss: 1397.576171875, Neurons: 15, Grad norm: 8.186e+01
# Epoch 471, Loss: 1385.558349609375, Neurons: 15, Grad norm: 8.161e+01
# Epoch 472, Loss: 1385.182373046875, Neurons: 15, Grad norm: 8.166e+01
# Epoch 473, Loss: 1384.8040771484375, Neurons: 15, Grad norm: 8.172e+01
# Epoch 474, Loss: 1384.423583984375, Neurons: 15, Grad norm: 8.177e+01
# Epoch 475, Loss: 1384.04052734375, Neurons: 15, Grad norm: 8.183e+01
# Epoch 476, Loss: 1383.655517578125, Neurons: 15, Grad norm: 8.189e+01
# Epoch 477, Loss: 1383.268310546875, Neurons: 15, Grad norm: 8.196e+01
# Epoch 478, Loss: 1382.8785400390625, Neurons: 15, Grad norm: 8.202e+01
# Epoch 479, Loss: 1382.486572265625, Neurons: 15, Grad norm: 8.209e+01
# Epoch 480, Loss: 1382.09228515625, Neurons: 15, Grad norm: 8.216e+01
# Epoch 481, Loss: 1381.69580078125, Neurons: 15, Grad norm: 8.223e+01
# Epoch 482, Loss: 1381.2969970703125, Neurons: 15, Grad norm: 8.230e+01
# Epoch 483, Loss: 1380.8956298828125, Neurons: 15, Grad norm: 8.238e+01
# Epoch 484, Loss: 1380.4921875, Neurons: 15, Grad norm: 8.245e+01
# Epoch 485, Loss: 1380.0863037109375, Neurons: 15, Grad norm: 8.253e+01
# Epoch 486, Loss: 1379.6781005859375, Neurons: 15, Grad norm: 8.261e+01
# Epoch 487, Loss: 1379.267578125, Neurons: 15, Grad norm: 8.270e+01
# Epoch 488, Loss: 1378.8546142578125, Neurons: 15, Grad norm: 8.278e+01
# Epoch 489, Loss: 1378.4393310546875, Neurons: 15, Grad norm: 8.286e+01
# Epoch 490, Loss: 1378.0216064453125, Neurons: 15, Grad norm: 8.295e+01
# Epoch 491, Loss: 1377.6015625, Neurons: 15, Grad norm: 8.304e+01
# Epoch 492, Loss: 1377.1790771484375, Neurons: 15, Grad norm: 8.313e+01
# Epoch 493, Loss: 1376.7540283203125, Neurons: 15, Grad norm: 8.322e+01
# Epoch 494, Loss: 1376.3265380859375, Neurons: 15, Grad norm: 8.332e+01
# Epoch 495, Loss: 1375.8968505859375, Neurons: 15, Grad norm: 8.341e+01
# Epoch 496, Loss: 1375.464599609375, Neurons: 15, Grad norm: 8.351e+01
# Epoch 497, Loss: 1375.0296630859375, Neurons: 15, Grad norm: 8.360e+01
# Epoch 498, Loss: 1374.592529296875, Neurons: 15, Grad norm: 8.370e+01
# Epoch 499, Loss: 1374.1527099609375, Neurons: 15, Grad norm: 8.380e+01
# Epoch 499, Test loss: 1400.6693115234375
# Added neuron to hidden layer 2 with activation relu
# network shape updated to :[8, 7, 1]
# Check loss updated to 1400.6693115234375
# Epoch 500, Loss: 1383.3980712890625, Neurons: 16, Grad norm: 1.118e+02
# Epoch 501, Loss: 1383.231201171875, Neurons: 16, Grad norm: 1.117e+02
# Epoch 502, Loss: 1383.0560302734375, Neurons: 16, Grad norm: 1.117e+02
# Epoch 503, Loss: 1382.87255859375, Neurons: 16, Grad norm: 1.117e+02
# Epoch 504, Loss: 1382.6805419921875, Neurons: 16, Grad norm: 1.116e+02
# Epoch 505, Loss: 1382.4803466796875, Neurons: 16, Grad norm: 1.116e+02
# Epoch 506, Loss: 1382.271484375, Neurons: 16, Grad norm: 1.115e+02
# Epoch 507, Loss: 1382.0543212890625, Neurons: 16, Grad norm: 1.115e+02
# Epoch 508, Loss: 1381.82861328125, Neurons: 16, Grad norm: 1.114e+02
# Epoch 509, Loss: 1381.594970703125, Neurons: 16, Grad norm: 1.113e+02
# Epoch 510, Loss: 1381.35302734375, Neurons: 16, Grad norm: 1.113e+02
# Epoch 511, Loss: 1381.10302734375, Neurons: 16, Grad norm: 1.112e+02
# Epoch 512, Loss: 1380.8453369140625, Neurons: 16, Grad norm: 1.112e+02
# Epoch 513, Loss: 1380.5797119140625, Neurons: 16, Grad norm: 1.111e+02
# Epoch 514, Loss: 1380.3065185546875, Neurons: 16, Grad norm: 1.111e+02
# Epoch 515, Loss: 1380.0257568359375, Neurons: 16, Grad norm: 1.110e+02
# Epoch 516, Loss: 1379.7379150390625, Neurons: 16, Grad norm: 1.110e+02
# Epoch 517, Loss: 1379.44287109375, Neurons: 16, Grad norm: 1.109e+02
# Epoch 518, Loss: 1379.1407470703125, Neurons: 16, Grad norm: 1.109e+02
# Epoch 519, Loss: 1378.831787109375, Neurons: 16, Grad norm: 1.108e+02
# Epoch 520, Loss: 1378.516357421875, Neurons: 16, Grad norm: 1.108e+02
# Epoch 521, Loss: 1378.1943359375, Neurons: 16, Grad norm: 1.107e+02
# Epoch 522, Loss: 1377.8658447265625, Neurons: 16, Grad norm: 1.107e+02
# Epoch 523, Loss: 1377.5313720703125, Neurons: 16, Grad norm: 1.106e+02
# Epoch 524, Loss: 1377.1905517578125, Neurons: 16, Grad norm: 1.106e+02
# Epoch 525, Loss: 1376.8438720703125, Neurons: 16, Grad norm: 1.105e+02
# Epoch 526, Loss: 1376.4915771484375, Neurons: 16, Grad norm: 1.105e+02
# Epoch 527, Loss: 1376.1334228515625, Neurons: 16, Grad norm: 1.104e+02
# Epoch 528, Loss: 1375.76953125, Neurons: 16, Grad norm: 1.104e+02
# Epoch 529, Loss: 1375.4005126953125, Neurons: 16, Grad norm: 1.103e+02
# Epoch 530, Loss: 1375.026123046875, Neurons: 16, Grad norm: 1.103e+02
# Epoch 531, Loss: 1374.646484375, Neurons: 16, Grad norm: 1.102e+02
# Epoch 532, Loss: 1374.2615966796875, Neurons: 16, Grad norm: 1.102e+02
# Epoch 533, Loss: 1373.8717041015625, Neurons: 16, Grad norm: 1.102e+02
# Epoch 534, Loss: 1373.47705078125, Neurons: 16, Grad norm: 1.101e+02
# Epoch 535, Loss: 1373.077392578125, Neurons: 16, Grad norm: 1.101e+02
# Epoch 536, Loss: 1372.673095703125, Neurons: 16, Grad norm: 1.100e+02
# Epoch 537, Loss: 1372.2640380859375, Neurons: 16, Grad norm: 1.100e+02
# Epoch 538, Loss: 1371.8505859375, Neurons: 16, Grad norm: 1.100e+02
# Epoch 539, Loss: 1371.4324951171875, Neurons: 16, Grad norm: 1.099e+02
# Epoch 540, Loss: 1371.010009765625, Neurons: 16, Grad norm: 1.099e+02
# Epoch 541, Loss: 1370.5831298828125, Neurons: 16, Grad norm: 1.099e+02
# Epoch 542, Loss: 1370.152099609375, Neurons: 16, Grad norm: 1.098e+02
# Epoch 543, Loss: 1369.716796875, Neurons: 16, Grad norm: 1.098e+02
# Epoch 544, Loss: 1369.27734375, Neurons: 16, Grad norm: 1.098e+02
# Epoch 545, Loss: 1368.833984375, Neurons: 16, Grad norm: 1.097e+02
# Epoch 546, Loss: 1368.3863525390625, Neurons: 16, Grad norm: 1.097e+02
# Epoch 547, Loss: 1367.934814453125, Neurons: 16, Grad norm: 1.097e+02
# Epoch 548, Loss: 1367.4793701171875, Neurons: 16, Grad norm: 1.096e+02
# Epoch 549, Loss: 1367.02001953125, Neurons: 16, Grad norm: 1.096e+02
# Epoch 550, Loss: 1366.5567626953125, Neurons: 16, Grad norm: 1.096e+02
# Epoch 551, Loss: 1366.0899658203125, Neurons: 16, Grad norm: 1.096e+02
# Epoch 552, Loss: 1365.619140625, Neurons: 16, Grad norm: 1.095e+02
# Epoch 553, Loss: 1365.1446533203125, Neurons: 16, Grad norm: 1.095e+02
# Epoch 554, Loss: 1364.66650390625, Neurons: 16, Grad norm: 1.095e+02
# Epoch 555, Loss: 1364.184814453125, Neurons: 16, Grad norm: 1.095e+02
# Epoch 556, Loss: 1363.6993408203125, Neurons: 16, Grad norm: 1.094e+02
# Epoch 557, Loss: 1363.2103271484375, Neurons: 16, Grad norm: 1.094e+02
# Epoch 558, Loss: 1362.7176513671875, Neurons: 16, Grad norm: 1.094e+02
# Epoch 559, Loss: 1362.2215576171875, Neurons: 16, Grad norm: 1.094e+02
# Epoch 560, Loss: 1361.721923828125, Neurons: 16, Grad norm: 1.094e+02
# Epoch 561, Loss: 1361.21875, Neurons: 16, Grad norm: 1.094e+02
# Epoch 562, Loss: 1360.7119140625, Neurons: 16, Grad norm: 1.093e+02
# Epoch 563, Loss: 1360.2017822265625, Neurons: 16, Grad norm: 1.173e+02
# Epoch 564, Loss: 1359.686279296875, Neurons: 16, Grad norm: 8.900e+01
# Epoch 565, Loss: 1359.153076171875, Neurons: 16, Grad norm: 8.668e+01
# Epoch 566, Loss: 1358.8248291015625, Neurons: 16, Grad norm: 8.671e+01
# Epoch 567, Loss: 1358.4990234375, Neurons: 16, Grad norm: 8.676e+01
# Epoch 568, Loss: 1358.1734619140625, Neurons: 16, Grad norm: 8.683e+01
# Epoch 569, Loss: 1357.8472900390625, Neurons: 16, Grad norm: 8.690e+01
# Epoch 570, Loss: 1357.52001953125, Neurons: 16, Grad norm: 8.698e+01
# Epoch 571, Loss: 1357.1910400390625, Neurons: 16, Grad norm: 8.705e+01
# Epoch 572, Loss: 1356.8597412109375, Neurons: 16, Grad norm: 8.713e+01
# Epoch 573, Loss: 1356.526123046875, Neurons: 16, Grad norm: 8.721e+01
# Epoch 574, Loss: 1356.1900634765625, Neurons: 16, Grad norm: 8.730e+01
# Epoch 575, Loss: 1355.8515625, Neurons: 16, Grad norm: 8.738e+01
# Epoch 576, Loss: 1355.5107421875, Neurons: 16, Grad norm: 8.746e+01
# Epoch 577, Loss: 1355.1676025390625, Neurons: 16, Grad norm: 8.754e+01
# Epoch 578, Loss: 1354.82177734375, Neurons: 16, Grad norm: 8.763e+01
# Epoch 579, Loss: 1354.4737548828125, Neurons: 16, Grad norm: 8.771e+01
# Epoch 580, Loss: 1354.123291015625, Neurons: 16, Grad norm: 8.780e+01
# Epoch 581, Loss: 1353.7703857421875, Neurons: 16, Grad norm: 8.789e+01
# Epoch 582, Loss: 1353.4151611328125, Neurons: 16, Grad norm: 8.797e+01
# Epoch 583, Loss: 1353.057373046875, Neurons: 16, Grad norm: 8.806e+01
# Epoch 584, Loss: 1352.697021484375, Neurons: 16, Grad norm: 8.815e+01
# Epoch 585, Loss: 1352.3343505859375, Neurons: 16, Grad norm: 8.824e+01
# Epoch 586, Loss: 1351.96923828125, Neurons: 16, Grad norm: 8.833e+01
# Epoch 587, Loss: 1351.6015625, Neurons: 16, Grad norm: 8.842e+01
# Epoch 588, Loss: 1351.2313232421875, Neurons: 16, Grad norm: 8.851e+01
# Epoch 589, Loss: 1350.8587646484375, Neurons: 16, Grad norm: 8.860e+01
# Epoch 590, Loss: 1350.4837646484375, Neurons: 16, Grad norm: 8.869e+01
# Epoch 591, Loss: 1350.106201171875, Neurons: 16, Grad norm: 8.879e+01
# Epoch 592, Loss: 1349.7261962890625, Neurons: 16, Grad norm: 8.888e+01
# Epoch 593, Loss: 1349.34375, Neurons: 16, Grad norm: 8.898e+01
# Epoch 594, Loss: 1348.958740234375, Neurons: 16, Grad norm: 8.907e+01
# Epoch 595, Loss: 1348.5712890625, Neurons: 16, Grad norm: 8.917e+01
# Epoch 596, Loss: 1348.1812744140625, Neurons: 16, Grad norm: 8.926e+01
# Epoch 597, Loss: 1347.788818359375, Neurons: 16, Grad norm: 8.936e+01
# Epoch 598, Loss: 1347.3939208984375, Neurons: 16, Grad norm: 8.946e+01
# Epoch 599, Loss: 1346.99658203125, Neurons: 16, Grad norm: 8.955e+01
# Epoch 599, Test loss: 1372.5982666015625
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[8, 8, 1]
# Check loss updated to 1372.5982666015625
# Epoch 600, Loss: 1350.2607421875, Neurons: 17, Grad norm: 1.864e+02
# Epoch 601, Loss: 1350.029541015625, Neurons: 17, Grad norm: 1.864e+02
# Epoch 602, Loss: 1349.786865234375, Neurons: 17, Grad norm: 1.863e+02
# Epoch 603, Loss: 1349.5322265625, Neurons: 17, Grad norm: 1.862e+02
# Epoch 604, Loss: 1349.265869140625, Neurons: 17, Grad norm: 1.862e+02
# Epoch 605, Loss: 1348.9873046875, Neurons: 17, Grad norm: 1.861e+02
# Epoch 606, Loss: 1348.69677734375, Neurons: 17, Grad norm: 1.860e+02
# Epoch 607, Loss: 1348.39453125, Neurons: 17, Grad norm: 1.859e+02
# Epoch 608, Loss: 1348.080322265625, Neurons: 17, Grad norm: 1.858e+02
# Epoch 609, Loss: 1347.7540283203125, Neurons: 17, Grad norm: 1.857e+02
# Epoch 610, Loss: 1347.416015625, Neurons: 17, Grad norm: 1.856e+02
# Epoch 611, Loss: 1347.0665283203125, Neurons: 17, Grad norm: 1.855e+02
# Epoch 612, Loss: 1346.70556640625, Neurons: 17, Grad norm: 1.854e+02
# Epoch 613, Loss: 1346.3330078125, Neurons: 17, Grad norm: 1.852e+02
# Epoch 614, Loss: 1345.949462890625, Neurons: 17, Grad norm: 1.851e+02
# Epoch 615, Loss: 1345.5546875, Neurons: 17, Grad norm: 1.849e+02
# Epoch 616, Loss: 1345.149169921875, Neurons: 17, Grad norm: 1.848e+02
# Epoch 617, Loss: 1344.7330322265625, Neurons: 17, Grad norm: 1.847e+02
# Epoch 618, Loss: 1344.306396484375, Neurons: 17, Grad norm: 1.845e+02
# Epoch 619, Loss: 1343.8695068359375, Neurons: 17, Grad norm: 1.843e+02
# Epoch 620, Loss: 1343.4227294921875, Neurons: 17, Grad norm: 1.842e+02
# Epoch 621, Loss: 1342.9658203125, Neurons: 17, Grad norm: 1.840e+02
# Epoch 622, Loss: 1342.49951171875, Neurons: 17, Grad norm: 1.838e+02
# Epoch 623, Loss: 1342.0235595703125, Neurons: 17, Grad norm: 1.836e+02
# Epoch 624, Loss: 1341.53857421875, Neurons: 17, Grad norm: 1.835e+02
# Epoch 625, Loss: 1341.0443115234375, Neurons: 17, Grad norm: 1.833e+02
# Epoch 626, Loss: 1340.541259765625, Neurons: 17, Grad norm: 1.831e+02
# Epoch 627, Loss: 1340.029541015625, Neurons: 17, Grad norm: 1.828e+02
# Epoch 628, Loss: 1339.5093994140625, Neurons: 17, Grad norm: 1.826e+02
# Epoch 629, Loss: 1338.9808349609375, Neurons: 17, Grad norm: 1.824e+02
# Epoch 630, Loss: 1338.4443359375, Neurons: 17, Grad norm: 1.822e+02
# Epoch 631, Loss: 1337.8995361328125, Neurons: 17, Grad norm: 1.819e+02
# Epoch 632, Loss: 1337.347412109375, Neurons: 17, Grad norm: 1.817e+02
# Epoch 633, Loss: 1336.78759765625, Neurons: 17, Grad norm: 1.814e+02
# Epoch 634, Loss: 1336.2203369140625, Neurons: 17, Grad norm: 1.812e+02
# Epoch 635, Loss: 1335.6458740234375, Neurons: 17, Grad norm: 1.809e+02
# Epoch 636, Loss: 1335.0643310546875, Neurons: 17, Grad norm: 1.806e+02
# Epoch 637, Loss: 1334.475830078125, Neurons: 17, Grad norm: 1.803e+02
# Epoch 638, Loss: 1333.8807373046875, Neurons: 17, Grad norm: 1.800e+02
# Epoch 639, Loss: 1333.2789306640625, Neurons: 17, Grad norm: 1.797e+02
# Epoch 640, Loss: 1332.6707763671875, Neurons: 17, Grad norm: 1.793e+02
# Epoch 641, Loss: 1332.0565185546875, Neurons: 17, Grad norm: 1.790e+02
# Epoch 642, Loss: 1331.436279296875, Neurons: 17, Grad norm: 1.787e+02
# Epoch 643, Loss: 1330.8099365234375, Neurons: 17, Grad norm: 1.783e+02
# Epoch 644, Loss: 1330.1778564453125, Neurons: 17, Grad norm: 1.779e+02
# Epoch 645, Loss: 1329.5400390625, Neurons: 17, Grad norm: 1.775e+02
# Epoch 646, Loss: 1328.8970947265625, Neurons: 17, Grad norm: 1.772e+02
# Epoch 647, Loss: 1328.24853515625, Neurons: 17, Grad norm: 1.767e+02
# Epoch 648, Loss: 1327.5950927734375, Neurons: 17, Grad norm: 1.763e+02
# Epoch 649, Loss: 1326.9365234375, Neurons: 17, Grad norm: 1.759e+02
# Epoch 650, Loss: 1326.273193359375, Neurons: 17, Grad norm: 1.755e+02
# Epoch 651, Loss: 1325.6051025390625, Neurons: 17, Grad norm: 1.750e+02
# Epoch 652, Loss: 1324.9326171875, Neurons: 17, Grad norm: 1.746e+02
# Epoch 653, Loss: 1324.2554931640625, Neurons: 17, Grad norm: 1.741e+02
# Epoch 654, Loss: 1323.5743408203125, Neurons: 17, Grad norm: 1.736e+02
# Epoch 655, Loss: 1322.8887939453125, Neurons: 17, Grad norm: 1.731e+02
# Epoch 656, Loss: 1322.1995849609375, Neurons: 17, Grad norm: 1.726e+02
# Epoch 657, Loss: 1321.506591796875, Neurons: 17, Grad norm: 1.721e+02
# Epoch 658, Loss: 1320.8096923828125, Neurons: 17, Grad norm: 1.715e+02
# Epoch 659, Loss: 1320.1094970703125, Neurons: 17, Grad norm: 1.710e+02
# Epoch 660, Loss: 1319.40576171875, Neurons: 17, Grad norm: 1.704e+02
# Epoch 661, Loss: 1318.6990966796875, Neurons: 17, Grad norm: 1.698e+02
# Epoch 662, Loss: 1317.9888916015625, Neurons: 17, Grad norm: 1.693e+02
# Epoch 663, Loss: 1317.276123046875, Neurons: 17, Grad norm: 1.687e+02
# Epoch 664, Loss: 1316.560302734375, Neurons: 17, Grad norm: 1.680e+02
# Epoch 665, Loss: 1315.8419189453125, Neurons: 17, Grad norm: 1.674e+02
# Epoch 666, Loss: 1315.12109375, Neurons: 17, Grad norm: 1.668e+02
# Epoch 667, Loss: 1314.3975830078125, Neurons: 17, Grad norm: 1.662e+02
# Epoch 668, Loss: 1313.672119140625, Neurons: 17, Grad norm: 1.655e+02
# Epoch 669, Loss: 1312.9442138671875, Neurons: 17, Grad norm: 1.648e+02
# ...
# Epoch 24790, Loss: 0.00236719218082726, Neurons: 59, Grad norm: 8.679e-02
# Epoch 24791, Loss: 0.0023669786751270294, Neurons: 59, Grad norm: 1.436e-01
# Epoch 24792, Loss: 0.002367650158703327, Neurons: 59, Grad norm: 2.558e-01
# Epoch 24793, Loss: 0.0023681141901761293, Neurons: 59, Grad norm: 3.397e-01
# Epoch 24794, Loss: 0.0023679600562900305, Neurons: 59, Grad norm: 3.869e-01
# Epoch 24795, Loss: 0.0023676264099776745, Neurons: 59, Grad norm: 4.114e-01
# Epoch 24796, Loss: 0.0023676862474530935, Neurons: 59, Grad norm: 4.108e-01
# Epoch 24996, Loss: 0.0023401377256959677, Neurons: 59, Grad norm: 3.762e-02
# Epoch 24997, Loss: 0.0023399940691888332, Neurons: 59, Grad norm: 3.709e-02
# Epoch 24998, Loss: 0.0023398424964398146, Neurons: 59, Grad norm: 2.928e-02
# Epoch 24999, Loss: 0.0023397114127874374, Neurons: 59, Grad norm: 2.673e-02

# %%
np.savetxt(f"{out_folder}/neurons.txt", node_history)
np.savetxt(f"{out_folder}/train_loss.txt", train_loss_history)
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)

# %% [markdown]
# ### evaluation

# %%
y_pred = jax.vmap(mlp)(x_test)
test_mse = jnp.mean((y_pred - y_test) ** 2)
plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, "b.", alpha=0.2, label="True Poly Function")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label="MLP Predictions\n Test MSE: {:.4f}".format(test_mse))
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("MLP Approximation of polynomial Function")
plt.savefig(f"{fig_folder}/polynomial_approximation.png")
wandb.log({"polynomial approximation": wandb.Image(plt, caption="polynomial approximation")})

# %%
update_history
# Out:
# [(99,
#   11,
#   Array(1485.7892, dtype=float32),
#   Array(1515.2196, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (199,
#   12,
#   Array(1460.5981, dtype=float32),
#   Array(1489.5334, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (299,
#   13,
#   Array(1441.283, dtype=float32),
#   Array(1469.7054, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (399,
#   14,
#   Array(1408.0148, dtype=float32),
#   Array(1435.5736, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (499,
#   15,
#   Array(1374.1527, dtype=float32),
#   Array(1400.6693, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (599,
#   16,
#   Array(1346.9966, dtype=float32),
#   Array(1372.5983, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (699,
#   17,
#   Array(1290.7112, dtype=float32),
#   Array(1314.1008, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (799,
#   18,
#   Array(1195.1781, dtype=float32),
#   Array(1213.5228, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (899,
#   19,
#   Array(1132.9636, dtype=float32),
#   Array(1148.3599, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (999,
#   20,
#   Array(1099.0698, dtype=float32),
#   Array(1112.5642, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1099,
#   21,
#   Array(1081.0913, dtype=float32),
#   Array(1093.4761, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1199,
#   22,
#   Array(1071.4744, dtype=float32),
#   Array(1082.8589, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1299,
#   23,
#   Array(1048.2374, dtype=float32),
#   Array(1059.3453, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1399,
#   24,
#   Array(1019.1778, dtype=float32),
#   Array(1029.9102, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1499,
#   25,
#   Array(992.45654, dtype=float32),
#   Array(1002.89056, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1599,
#   26,
#   Array(956.3633, dtype=float32),
#   Array(966.2064, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1699,
#   27,
#   Array(922.65765, dtype=float32),
#   Array(931.92566, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1799,
#   28,
#   Array(889.6928, dtype=float32),
#   Array(898.39636, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1899,
#   29,
#   Array(848.0894, dtype=float32),
#   Array(856.0392, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1999,
#   30,
#   Array(808.55194, dtype=float32),
#   Array(815.75476, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2099,
#   31,
#   Array(759.8864, dtype=float32),
#   Array(766.0017, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (2199,
#   32,
#   Array(715.0011, dtype=float32),
#   Array(720.2637, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2299,
#   33,
#   Array(688.5793, dtype=float32),
#   Array(693.2763, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2399,
#   34,
#   Array(647.06555, dtype=float32),
#   Array(650.33466, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2499,
#   35,
#   Array(603.9973, dtype=float32),
#   Array(606.06537, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2599,
#   36,
#   Array(688.6002, dtype=float32),
#   Array(685.2146, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (2699,
#   35,
#   Array(576.8343, dtype=float32),
#   Array(580.48376, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2799,
#   36,
#   Array(513.32135, dtype=float32),
#   Array(514.30884, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2899,
#   37,
#   Array(471.56372, dtype=float32),
#   Array(469.82397, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (2999,
#   38,
#   Array(461.1704, dtype=float32),
#   Array(458.86765, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3099,
#   39,
#   Array(395.31946, dtype=float32),
#   Array(391.66388, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (3199,
#   40,
#   Array(338.3618, dtype=float32),
#   Array(333.71295, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3299,
#   41,
#   Array(285.45013, dtype=float32),
#   Array(280.55325, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (3399,
#   42,
#   Array(230.29898, dtype=float32),
#   Array(225.94955, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (3499,
#   43,
#   Array(201.99643, dtype=float32),
#   Array(198.17188, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (3599,
#   44,
#   Array(174.16455, dtype=float32),
#   Array(170.7558, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (3699,
#   45,
#   Array(188.4191, dtype=float32),
#   Array(186.09409, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (3799,
#   44,
#   Array(171.31534, dtype=float32),
#   Array(167.11043, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (3899,
#   45,
#   Array(162.3882, dtype=float32),
#   Array(158.35568, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3999,
#   46,
#   Array(139.25069, dtype=float32),
#   Array(136.07039, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (4099,
#   47,
#   Array(119.92677, dtype=float32),
#   Array(116.87662, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (4199,
#   48,
#   Array(101.96644, dtype=float32),
#   Array(98.85241, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (4299,
#   49,
#   Array(86.24994, dtype=float32),
#   Array(83.141426, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4399,
#   50,
#   Array(70.25674, dtype=float32),
#   Array(67.37669, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (4499,
#   51,
#   Array(63.9869, dtype=float32),
#   Array(61.29149, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4699,
#   52,
#   Array(40.365215, dtype=float32),
#   Array(38.075184, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (4799,
#   53,
#   Array(36.659462, dtype=float32),
#   Array(34.52686, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (4899,
#   54,
#   Array(33.96537, dtype=float32),
#   Array(31.958654, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4999,
#   55,
#   Array(29.710453, dtype=float32),
#   Array(27.920021, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (5099,
#   56,
#   Array(25.453815, dtype=float32),
#   Array(23.881231, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (5199,
#   57,
#   Array(22.975925, dtype=float32),
#   Array(21.533932, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (5299,
#   58,
#   Array(19.435673, dtype=float32),
#   Array(18.160757, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (5399,
#   59,
#   Array(17.29613, dtype=float32),
#   Array(16.139566, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (5499,
#   60,
#   Array(14.693065, dtype=float32),
#   Array(13.674344, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (5599,
#   61,
#   Array(14.833693, dtype=float32),
#   Array(13.8528385, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (7299,
#   60,
#   Array(1.3333479, dtype=float32),
#   Array(1.2136734, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (7399,
#   61,
#   Array(1.5112835, dtype=float32),
#   Array(1.3821527, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (7999,
#   60,
#   Array(1.0392302, dtype=float32),
#   Array(0.940407, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (8099,
#   61,
#   Array(4.8351183, dtype=float32),
#   Array(4.5764008, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (8299,
#   60,
#   Array(1.3526099, dtype=float32),
#   Array(1.2304873, dtype=float32),
#   'removed',
#   Array(0, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with bare probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with bare probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)
