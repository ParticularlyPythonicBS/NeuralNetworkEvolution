# %% [markdown]
# # Probabilistic strategy for Polynomial prediction with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "25_hetero_poly_probabilistic.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="25_hetero_poly_probabilistic.ipynb"
# env: WANDB_SILENT=True

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

import os
import sys
import time
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 1
hidden_sizes = [5, 5] 
min_neurons = 4
output_size = 1
initial_activation_list = [sin, jax.nn.relu, jax.nn.tanh]
activation_list = [sin, jax.nn.relu, jax.nn.tanh]
optimizer = optax.adabelief
bias = False
num_epochs = 25000
intervene_every = 100
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"Hetero_{act_string}_poly_probabilistic_strat_{optimizer.__name__}_no_bias_min_{min_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: Hetero_sin_relu_tanh_poly_probabilistic_strat_adabelief_no_bias_min_4_5_5_25000_100_0.0001_0
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %% [markdown]
# ### data

# %%
def poly(x):
    """
    7th degree polynomial to predict
    """
    return (x - 3)*(x - 2)*(x - 1)*x*(x + 1)*(x + 2)*(x + 3)

# %%
x = jnp.linspace(-3, 3, n_samples).reshape(-1, 1)
y = poly(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)

# %%
plt.plot(x_train, y_train, "k.", alpha=0.2, label=f"train:{len(x_train)}")
plt.plot(x_test, y_test, "r.", alpha = 0.2, label=f"test:{len(x_test)}")
plt.legend()
plt.suptitle("Data")
# Out:
# Text(0.5, 0.98, 'Data')

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0]

# %%
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 11

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity

# %%
def p_add(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to add a neuron
    """
    return test_loss / (test_loss + n_neurons / min_neurons)

def p_remove(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to remove a neuron
    """
    return test_loss / (test_loss + min_neurons / n_neurons)

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}")
        wandb.log({"test_loss": test_loss.item()})
        test_loss_history.append((epoch,test_loss))

        # Neuron Addition criteria
        if ((len(update_history) == 0    # if no previous addition
            or check_loss > test_loss) # if last addition was accepted
            and jax.random.uniform(prob_key, minval = 0, maxval = 1)< p_add(test_loss, n_neurons, min_neurons)): # addition probability

            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0] # randomly select a layer to add neuron to
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            update_history.append((epoch, n_neurons, train_loss, test_loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
            check_loss = test_loss
            logging.info(f"Check loss updated to {check_loss}")
        
        # Neuron Removal criteria
        elif ((check_loss < test_loss) # check current loss against last accepted addition
            and n_neurons>min_neurons # neuron floor
            and jax.random.uniform(prob_key, minval = 0, maxval = 1)<p_remove(test_loss, n_neurons, min_neurons)): # removal probability 

            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            layer = update_history[-1][-1] # get the layer of last addition
            neuron_idx = len(mlp.layers[layer]) -1

            if len(mlp.layers[layer]) <= 1:
                logging.info(f"Cannot remove neuron from layer {layer+1}, only one neuron left")
                update_history.append((epoch, n_neurons, train_loss, test_loss, "single_node_layer", layer))
                continue

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            update_history.append((epoch, n_neurons, train_loss, test_loss, "removed", layer))

            logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
            wandb.log({"removed neuron": neuron_idx})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 1508.8876953125, Neurons: 11, Grad norm: 4.791e+01
# Epoch 001, Loss: 1508.81396484375, Neurons: 11, Grad norm: 4.791e+01
# Epoch 002, Loss: 1508.736572265625, Neurons: 11, Grad norm: 4.790e+01
# Epoch 003, Loss: 1508.6552734375, Neurons: 11, Grad norm: 4.790e+01
# Epoch 004, Loss: 1508.5703125, Neurons: 11, Grad norm: 4.789e+01
# Epoch 005, Loss: 1508.4813232421875, Neurons: 11, Grad norm: 4.789e+01
# Epoch 006, Loss: 1508.3885498046875, Neurons: 11, Grad norm: 4.788e+01
# Epoch 007, Loss: 1508.2921142578125, Neurons: 11, Grad norm: 4.788e+01
# Epoch 008, Loss: 1508.1915283203125, Neurons: 11, Grad norm: 4.788e+01
# Epoch 009, Loss: 1508.0872802734375, Neurons: 11, Grad norm: 4.787e+01
# Epoch 010, Loss: 1507.9793701171875, Neurons: 11, Grad norm: 4.787e+01
# Epoch 011, Loss: 1507.86767578125, Neurons: 11, Grad norm: 4.786e+01
# Epoch 012, Loss: 1507.752197265625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 013, Loss: 1507.633056640625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 014, Loss: 1507.5103759765625, Neurons: 11, Grad norm: 4.785e+01
# Epoch 015, Loss: 1507.384033203125, Neurons: 11, Grad norm: 4.785e+01
# Epoch 016, Loss: 1507.254150390625, Neurons: 11, Grad norm: 4.785e+01
# Epoch 017, Loss: 1507.1209716796875, Neurons: 11, Grad norm: 4.785e+01
# Epoch 018, Loss: 1506.9842529296875, Neurons: 11, Grad norm: 4.785e+01
# Epoch 019, Loss: 1506.84423828125, Neurons: 11, Grad norm: 4.785e+01
# Epoch 020, Loss: 1506.7008056640625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 021, Loss: 1506.5543212890625, Neurons: 11, Grad norm: 4.786e+01
# Epoch 022, Loss: 1506.404541015625, Neurons: 11, Grad norm: 4.787e+01
# Epoch 023, Loss: 1506.2515869140625, Neurons: 11, Grad norm: 4.788e+01
# Epoch 059, Loss: 1498.8443603515625, Neurons: 11, Grad norm: 4.965e+01
# Epoch 060, Loss: 1498.58544921875, Neurons: 11, Grad norm: 4.975e+01
# Epoch 061, Loss: 1498.323486328125, Neurons: 11, Grad norm: 4.985e+01
# Epoch 062, Loss: 1498.0584716796875, Neurons: 11, Grad norm: 4.995e+01
# Epoch 063, Loss: 1497.7901611328125, Neurons: 11, Grad norm: 5.006e+01
# Epoch 064, Loss: 1497.518798828125, Neurons: 11, Grad norm: 5.016e+01
# Epoch 065, Loss: 1497.2440185546875, Neurons: 11, Grad norm: 5.027e+01
# Epoch 066, Loss: 1496.96630859375, Neurons: 11, Grad norm: 5.039e+01
# Epoch 067, Loss: 1496.68505859375, Neurons: 11, Grad norm: 5.050e+01
# Epoch 068, Loss: 1496.4005126953125, Neurons: 11, Grad norm: 5.062e+01
# Epoch 069, Loss: 1496.1126708984375, Neurons: 11, Grad norm: 5.074e+01
# Epoch 070, Loss: 1495.8214111328125, Neurons: 11, Grad norm: 5.086e+01
# Epoch 071, Loss: 1495.52685546875, Neurons: 11, Grad norm: 5.098e+01
# Epoch 072, Loss: 1495.2288818359375, Neurons: 11, Grad norm: 5.111e+01
# Epoch 073, Loss: 1494.9273681640625, Neurons: 11, Grad norm: 5.124e+01
# Epoch 074, Loss: 1494.622314453125, Neurons: 11, Grad norm: 5.137e+01
# Epoch 075, Loss: 1494.3138427734375, Neurons: 11, Grad norm: 5.150e+01
# Epoch 076, Loss: 1494.001708984375, Neurons: 11, Grad norm: 5.163e+01
# Epoch 077, Loss: 1493.68603515625, Neurons: 11, Grad norm: 5.177e+01
# Epoch 078, Loss: 1493.36669921875, Neurons: 11, Grad norm: 5.190e+01
# Epoch 079, Loss: 1493.0438232421875, Neurons: 11, Grad norm: 5.204e+01
# Epoch 080, Loss: 1492.717041015625, Neurons: 11, Grad norm: 5.218e+01
# Epoch 081, Loss: 1492.3868408203125, Neurons: 11, Grad norm: 5.232e+01
# Epoch 082, Loss: 1492.0528564453125, Neurons: 11, Grad norm: 5.247e+01
# Epoch 083, Loss: 1491.715087890625, Neurons: 11, Grad norm: 5.261e+01
# Epoch 084, Loss: 1491.37353515625, Neurons: 11, Grad norm: 5.275e+01
# Epoch 085, Loss: 1491.0283203125, Neurons: 11, Grad norm: 5.290e+01
# Epoch 086, Loss: 1490.6793212890625, Neurons: 11, Grad norm: 5.305e+01
# Epoch 087, Loss: 1490.3265380859375, Neurons: 11, Grad norm: 5.319e+01
# Epoch 088, Loss: 1489.9698486328125, Neurons: 11, Grad norm: 5.334e+01
# Epoch 089, Loss: 1489.6092529296875, Neurons: 11, Grad norm: 5.349e+01
# Epoch 090, Loss: 1489.2447509765625, Neurons: 11, Grad norm: 5.364e+01
# Epoch 091, Loss: 1488.8763427734375, Neurons: 11, Grad norm: 5.379e+01
# Epoch 092, Loss: 1488.504150390625, Neurons: 11, Grad norm: 5.394e+01
# Epoch 093, Loss: 1488.1280517578125, Neurons: 11, Grad norm: 5.409e+01
# Epoch 094, Loss: 1487.748046875, Neurons: 11, Grad norm: 5.424e+01
# Epoch 130, Loss: 1471.5216064453125, Neurons: 11, Grad norm: 5.963e+01
# Epoch 131, Loss: 1471.0008544921875, Neurons: 11, Grad norm: 5.986e+01
# Epoch 132, Loss: 1470.4752197265625, Neurons: 11, Grad norm: 6.011e+01
# Epoch 133, Loss: 1469.94482421875, Neurons: 11, Grad norm: 6.035e+01
# Epoch 134, Loss: 1469.4093017578125, Neurons: 11, Grad norm: 6.058e+01
# Epoch 135, Loss: 1468.868896484375, Neurons: 11, Grad norm: 6.074e+01
# Epoch 136, Loss: 1468.32373046875, Neurons: 11, Grad norm: 6.076e+01
# Epoch 137, Loss: 1467.7747802734375, Neurons: 11, Grad norm: 6.046e+01
# Epoch 138, Loss: 1467.224853515625, Neurons: 11, Grad norm: 5.898e+01
# Epoch 139, Loss: 1466.680908203125, Neurons: 11, Grad norm: 5.857e+01
# Epoch 140, Loss: 1466.160888671875, Neurons: 11, Grad norm: 5.867e+01
# Epoch 141, Loss: 1465.640625, Neurons: 11, Grad norm: 5.877e+01
# Epoch 142, Loss: 1465.1192626953125, Neurons: 11, Grad norm: 5.886e+01
# Epoch 143, Loss: 1464.5965576171875, Neurons: 11, Grad norm: 5.896e+01
# Epoch 144, Loss: 1464.072509765625, Neurons: 11, Grad norm: 5.906e+01
# Epoch 145, Loss: 1463.547119140625, Neurons: 11, Grad norm: 5.915e+01
# Epoch 146, Loss: 1463.0196533203125, Neurons: 11, Grad norm: 5.925e+01
# Epoch 147, Loss: 1462.490478515625, Neurons: 11, Grad norm: 5.934e+01
# Epoch 148, Loss: 1461.9593505859375, Neurons: 11, Grad norm: 5.944e+01
# Epoch 149, Loss: 1461.426025390625, Neurons: 11, Grad norm: 5.954e+01
# Epoch 150, Loss: 1460.8907470703125, Neurons: 11, Grad norm: 5.964e+01
# Epoch 151, Loss: 1460.353271484375, Neurons: 11, Grad norm: 5.974e+01
# Epoch 152, Loss: 1459.8135986328125, Neurons: 11, Grad norm: 5.984e+01
# Epoch 153, Loss: 1459.2716064453125, Neurons: 11, Grad norm: 5.994e+01
# Epoch 154, Loss: 1458.727294921875, Neurons: 11, Grad norm: 6.004e+01
# Epoch 155, Loss: 1458.1805419921875, Neurons: 11, Grad norm: 6.015e+01
# Epoch 156, Loss: 1457.63134765625, Neurons: 11, Grad norm: 6.026e+01
# Epoch 157, Loss: 1457.07958984375, Neurons: 11, Grad norm: 6.036e+01
# Epoch 158, Loss: 1456.5252685546875, Neurons: 11, Grad norm: 6.047e+01
# Epoch 159, Loss: 1455.9683837890625, Neurons: 11, Grad norm: 6.059e+01
# Epoch 160, Loss: 1455.4088134765625, Neurons: 11, Grad norm: 6.070e+01
# Epoch 161, Loss: 1454.8465576171875, Neurons: 11, Grad norm: 6.082e+01
# Epoch 162, Loss: 1454.2813720703125, Neurons: 11, Grad norm: 6.093e+01
# Epoch 163, Loss: 1453.71337890625, Neurons: 11, Grad norm: 6.106e+01
# Epoch 164, Loss: 1453.1424560546875, Neurons: 11, Grad norm: 6.118e+01
# Epoch 165, Loss: 1452.568603515625, Neurons: 11, Grad norm: 6.130e+01
# Epoch 307, Loss: 1310.1876220703125, Neurons: 11, Grad norm: 1.043e+02
# Epoch 308, Loss: 1308.63330078125, Neurons: 11, Grad norm: 1.046e+02
# Epoch 309, Loss: 1307.0718994140625, Neurons: 11, Grad norm: 1.049e+02
# Epoch 310, Loss: 1305.5032958984375, Neurons: 11, Grad norm: 1.051e+02
# Epoch 311, Loss: 1303.927978515625, Neurons: 11, Grad norm: 1.054e+02
# Epoch 312, Loss: 1302.3455810546875, Neurons: 11, Grad norm: 1.057e+02
# Epoch 313, Loss: 1300.756591796875, Neurons: 11, Grad norm: 1.059e+02
# Epoch 314, Loss: 1299.1607666015625, Neurons: 11, Grad norm: 1.061e+02
# Epoch 315, Loss: 1297.558837890625, Neurons: 11, Grad norm: 1.064e+02
# Epoch 316, Loss: 1295.950439453125, Neurons: 11, Grad norm: 1.066e+02
# Epoch 317, Loss: 1294.3358154296875, Neurons: 11, Grad norm: 1.068e+02
# Epoch 318, Loss: 1292.71533203125, Neurons: 11, Grad norm: 1.070e+02
# Epoch 319, Loss: 1291.0889892578125, Neurons: 11, Grad norm: 1.071e+02
# Epoch 320, Loss: 1289.4569091796875, Neurons: 11, Grad norm: 1.073e+02
# Epoch 321, Loss: 1287.8194580078125, Neurons: 11, Grad norm: 1.075e+02
# Epoch 322, Loss: 1286.1766357421875, Neurons: 11, Grad norm: 1.076e+02
# Epoch 323, Loss: 1284.5289306640625, Neurons: 11, Grad norm: 1.077e+02
# Epoch 324, Loss: 1282.8763427734375, Neurons: 11, Grad norm: 1.079e+02
# Epoch 325, Loss: 1281.21923828125, Neurons: 11, Grad norm: 1.080e+02
# Epoch 326, Loss: 1279.557861328125, Neurons: 11, Grad norm: 1.080e+02
# Epoch 327, Loss: 1277.89208984375, Neurons: 11, Grad norm: 1.081e+02
# Epoch 328, Loss: 1276.22265625, Neurons: 11, Grad norm: 1.082e+02
# Epoch 329, Loss: 1274.5498046875, Neurons: 11, Grad norm: 1.082e+02
# Epoch 330, Loss: 1272.87353515625, Neurons: 11, Grad norm: 1.082e+02
# Epoch 331, Loss: 1271.1944580078125, Neurons: 11, Grad norm: 1.082e+02
# Epoch 332, Loss: 1269.5126953125, Neurons: 11, Grad norm: 1.082e+02
# Epoch 333, Loss: 1267.82861328125, Neurons: 11, Grad norm: 1.082e+02
# Epoch 334, Loss: 1266.1427001953125, Neurons: 11, Grad norm: 1.082e+02
# Epoch 335, Loss: 1264.455078125, Neurons: 11, Grad norm: 1.081e+02
# Epoch 336, Loss: 1262.7664794921875, Neurons: 11, Grad norm: 1.080e+02
# Epoch 337, Loss: 1261.0770263671875, Neurons: 11, Grad norm: 1.079e+02
# Epoch 338, Loss: 1259.38720703125, Neurons: 11, Grad norm: 1.078e+02
# Epoch 339, Loss: 1257.697509765625, Neurons: 11, Grad norm: 1.076e+02
# Epoch 340, Loss: 1256.008544921875, Neurons: 11, Grad norm: 1.075e+02
# Epoch 341, Loss: 1254.320556640625, Neurons: 11, Grad norm: 1.073e+02
# Epoch 342, Loss: 1252.634033203125, Neurons: 11, Grad norm: 1.071e+02
# Epoch 343, Loss: 1250.9498291015625, Neurons: 11, Grad norm: 1.069e+02
# Epoch 344, Loss: 1249.2681884765625, Neurons: 11, Grad norm: 1.066e+02
# Epoch 345, Loss: 1247.58984375, Neurons: 11, Grad norm: 1.063e+02
# Epoch 346, Loss: 1245.9150390625, Neurons: 11, Grad norm: 1.060e+02
# Epoch 347, Loss: 1244.2449951171875, Neurons: 11, Grad norm: 1.057e+02
# Epoch 348, Loss: 1242.579833984375, Neurons: 11, Grad norm: 1.053e+02
# Epoch 349, Loss: 1240.9205322265625, Neurons: 11, Grad norm: 1.050e+02
# Epoch 350, Loss: 1239.267578125, Neurons: 11, Grad norm: 1.046e+02
# Epoch 351, Loss: 1237.6219482421875, Neurons: 11, Grad norm: 1.041e+02
# Epoch 352, Loss: 1235.9840087890625, Neurons: 11, Grad norm: 1.037e+02
# Epoch 353, Loss: 1234.3548583984375, Neurons: 11, Grad norm: 1.032e+02
# Epoch 354, Loss: 1232.7349853515625, Neurons: 11, Grad norm: 1.027e+02
# Epoch 355, Loss: 1231.1253662109375, Neurons: 11, Grad norm: 1.022e+02
# Epoch 356, Loss: 1229.526611328125, Neurons: 11, Grad norm: 1.016e+02
# Epoch 357, Loss: 1227.939697265625, Neurons: 11, Grad norm: 1.011e+02
# Epoch 358, Loss: 1226.365478515625, Neurons: 11, Grad norm: 1.005e+02
# Epoch 359, Loss: 1224.8046875, Neurons: 11, Grad norm: 9.983e+01
# Epoch 360, Loss: 1223.25830078125, Neurons: 11, Grad norm: 9.917e+01
# Epoch 361, Loss: 1221.72705078125, Neurons: 11, Grad norm: 9.849e+01
# Epoch 362, Loss: 1220.2117919921875, Neurons: 11, Grad norm: 9.779e+01
# Epoch 363, Loss: 1218.713623046875, Neurons: 11, Grad norm: 9.706e+01
# Epoch 364, Loss: 1217.2330322265625, Neurons: 11, Grad norm: 9.630e+01
# Epoch 365, Loss: 1215.7711181640625, Neurons: 11, Grad norm: 9.553e+01
# Epoch 366, Loss: 1214.3284912109375, Neurons: 11, Grad norm: 9.473e+01
# Epoch 367, Loss: 1212.9058837890625, Neurons: 11, Grad norm: 9.391e+01
# Epoch 368, Loss: 1211.5042724609375, Neurons: 11, Grad norm: 9.306e+01
# Epoch 369, Loss: 1210.124267578125, Neurons: 11, Grad norm: 9.220e+01
# Epoch 370, Loss: 1208.7666015625, Neurons: 11, Grad norm: 9.132e+01
# Epoch 371, Loss: 1207.4317626953125, Neurons: 11, Grad norm: 9.042e+01
# Epoch 372, Loss: 1206.12060546875, Neurons: 11, Grad norm: 8.950e+01
# Epoch 373, Loss: 1204.833251953125, Neurons: 11, Grad norm: 8.856e+01
# Epoch 374, Loss: 1203.570556640625, Neurons: 11, Grad norm: 8.761e+01
# Epoch 375, Loss: 1202.332763671875, Neurons: 11, Grad norm: 8.665e+01
# Epoch 376, Loss: 1201.120361328125, Neurons: 11, Grad norm: 8.567e+01
# Epoch 377, Loss: 1199.9334716796875, Neurons: 11, Grad norm: 8.469e+01
# Epoch 520, Loss: 1144.3363037109375, Neurons: 11, Grad norm: 2.970e+01
# Epoch 521, Loss: 1144.1165771484375, Neurons: 11, Grad norm: 2.954e+01
# Epoch 522, Loss: 1143.8988037109375, Neurons: 11, Grad norm: 2.935e+01
# Epoch 523, Loss: 1143.683349609375, Neurons: 11, Grad norm: 2.915e+01
# Epoch 524, Loss: 1143.4700927734375, Neurons: 11, Grad norm: 2.893e+01
# Epoch 525, Loss: 1143.259033203125, Neurons: 11, Grad norm: 2.869e+01
# Epoch 526, Loss: 1143.050537109375, Neurons: 11, Grad norm: 2.844e+01
# Epoch 527, Loss: 1142.8446044921875, Neurons: 11, Grad norm: 2.818e+01
# Epoch 528, Loss: 1142.64111328125, Neurons: 11, Grad norm: 2.791e+01
# Epoch 529, Loss: 1142.4403076171875, Neurons: 11, Grad norm: 2.764e+01
# Epoch 530, Loss: 1142.2420654296875, Neurons: 11, Grad norm: 2.736e+01
# Epoch 531, Loss: 1142.04638671875, Neurons: 11, Grad norm: 2.710e+01
# Epoch 532, Loss: 1141.853515625, Neurons: 11, Grad norm: 2.684e+01
# Epoch 533, Loss: 1141.663330078125, Neurons: 11, Grad norm: 2.659e+01
# Epoch 534, Loss: 1141.4755859375, Neurons: 11, Grad norm: 2.635e+01
# Epoch 535, Loss: 1141.290283203125, Neurons: 11, Grad norm: 2.613e+01
# Epoch 536, Loss: 1141.1070556640625, Neurons: 11, Grad norm: 2.592e+01
# Epoch 537, Loss: 1140.926025390625, Neurons: 11, Grad norm: 2.574e+01
# Epoch 538, Loss: 1140.746826171875, Neurons: 11, Grad norm: 2.557e+01
# Epoch 539, Loss: 1140.5693359375, Neurons: 11, Grad norm: 2.543e+01
# Epoch 540, Loss: 1140.3931884765625, Neurons: 11, Grad norm: 2.530e+01
# Epoch 541, Loss: 1140.21826171875, Neurons: 11, Grad norm: 2.520e+01
# Epoch 542, Loss: 1140.044189453125, Neurons: 11, Grad norm: 2.511e+01
# Epoch 543, Loss: 1139.8709716796875, Neurons: 11, Grad norm: 2.505e+01
# Epoch 544, Loss: 1139.697998046875, Neurons: 11, Grad norm: 2.500e+01
# Epoch 545, Loss: 1139.525390625, Neurons: 11, Grad norm: 2.497e+01
# Epoch 546, Loss: 1139.352783203125, Neurons: 11, Grad norm: 2.495e+01
# Epoch 547, Loss: 1139.179931640625, Neurons: 11, Grad norm: 2.495e+01
# Epoch 548, Loss: 1139.0067138671875, Neurons: 11, Grad norm: 2.497e+01
# Epoch 549, Loss: 1138.832763671875, Neurons: 11, Grad norm: 2.500e+01
# Epoch 550, Loss: 1138.658203125, Neurons: 11, Grad norm: 2.505e+01
# Epoch 551, Loss: 1138.4825439453125, Neurons: 11, Grad norm: 2.511e+01
# Epoch 552, Loss: 1138.3057861328125, Neurons: 11, Grad norm: 2.519e+01
# Epoch 553, Loss: 1138.1278076171875, Neurons: 11, Grad norm: 2.528e+01
# Epoch 554, Loss: 1137.9486083984375, Neurons: 11, Grad norm: 2.538e+01
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)

# %% [markdown]
# ### evaluation

# %%
y_pred = jax.vmap(mlp)(x_test)
test_mse = jnp.mean((y_pred - y_test) ** 2)
plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, "b.", alpha=0.2, label="True Poly Function")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label="MLP Predictions\n Test MSE: {:.4f}".format(test_mse))
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("MLP Approximation of polynomial Function")
plt.savefig(f"{fig_folder}/polynomial_approximation.png")
wandb.log({"polynomial approximation": wandb.Image(plt, caption="polynomial approximation")})

# %%
update_history
# Out:
# [(99,
#   11,
#   Array(1485.7893, dtype=float32),
#   Array(1515.2196, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (199,
#   12,
#   Array(1450.7047, dtype=float32),
#   Array(1479.4166, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (299,
#   13,
#   Array(1416.8864, dtype=float32),
#   Array(1444.81, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (399,
#   14,
#   Array(1381.7533, dtype=float32),
#   Array(1408.5634, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (499,
#   15,
#   Array(1347.3591, dtype=float32),
#   Array(1372.8965, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (599,
#   16,
#   Array(1302.9243, dtype=float32),
#   Array(1326.5009, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (699,
#   17,
#   Array(1260.9032, dtype=float32),
#   Array(1282.4039, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (799,
#   18,
#   Array(1225.0275, dtype=float32),
#   Array(1244.0577, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (899,
#   19,
#   Array(1190.3467, dtype=float32),
#   Array(1207.3724, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (999,
#   20,
#   Array(1163.2277, dtype=float32),
#   Array(1178.5518, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1099,
#   21,
#   Array(1133.4429, dtype=float32),
#   Array(1147.1686, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1199,
#   22,
#   Array(1098.8988, dtype=float32),
#   Array(1111.4043, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1299,
#   23,
#   Array(1061.0616, dtype=float32),
#   Array(1072.5431, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1399,
#   24,
#   Array(1019.011, dtype=float32),
#   Array(1029.6815, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1499,
#   25,
#   Array(968.75854, dtype=float32),
#   Array(978.4578, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1599,
#   26,
#   Array(947.84827, dtype=float32),
#   Array(957.7379, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1699,
#   27,
#   Array(906.5623, dtype=float32),
#   Array(914.83295, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (1799,
#   28,
#   Array(823.2787, dtype=float32),
#   Array(829.59955, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (1899,
#   29,
#   Array(766.6147, dtype=float32),
#   Array(772.3659, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (1999,
#   30,
#   Array(845.65454, dtype=float32),
#   Array(847.8163, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (2099,
#   29,
#   Array(696.7855, dtype=float32),
#   Array(701.5415, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2199,
#   30,
#   Array(664.9319, dtype=float32),
#   Array(668.5367, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2299,
#   31,
#   Array(614.1548, dtype=float32),
#   Array(617.1214, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2399,
#   32,
#   Array(574.9905, dtype=float32),
#   Array(576.95575, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2499,
#   33,
#   Array(530.9135, dtype=float32),
#   Array(532.12714, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (2599,
#   34,
#   Array(490.85352, dtype=float32),
#   Array(491.22504, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (2699,
#   35,
#   Array(450.05847, dtype=float32),
#   Array(449.6422, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (2799,
#   36,
#   Array(407.79068, dtype=float32),
#   Array(406.66537, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (2899,
#   37,
#   Array(365.76202, dtype=float32),
#   Array(363.9951, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (2999,
#   38,
#   Array(323.84213, dtype=float32),
#   Array(321.51932, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (3099,
#   39,
#   Array(282.52725, dtype=float32),
#   Array(279.61276, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (3199,
#   40,
#   Array(259.00653, dtype=float32),
#   Array(255.7978, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3299,
#   41,
#   Array(222.15067, dtype=float32),
#   Array(218.58224, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3399,
#   42,
#   Array(193.20743, dtype=float32),
#   Array(189.05939, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (3499,
#   43,
#   Array(225.01445, dtype=float32),
#   Array(220.68079, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (3599,
#   42,
#   Array(190.8811, dtype=float32),
#   Array(186.31268, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (3699,
#   43,
#   Array(201.3818, dtype=float32),
#   Array(196.1843, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (3799,
#   42,
#   Array(167.95238, dtype=float32),
#   Array(163.50941, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (3899,
#   43,
#   Array(156.34663, dtype=float32),
#   Array(151.63231, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (3999,
#   44,
#   Array(157.09413, dtype=float32),
#   Array(152.98361, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (4099,
#   43,
#   Array(145.36316, dtype=float32),
#   Array(140.64757, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (4199,
#   44,
#   Array(129.11209, dtype=float32),
#   Array(124.25107, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (4299,
#   45,
#   Array(120.355415, dtype=float32),
#   Array(115.43459, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4399,
#   46,
#   Array(110.09701, dtype=float32),
#   Array(105.20346, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (4499,
#   47,
#   Array(96.96477, dtype=float32),
#   Array(92.254585, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (4599,
#   48,
#   Array(91.06635, dtype=float32),
#   Array(86.48246, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (4699,
#   49,
#   Array(96.69173, dtype=float32),
#   Array(92.105934, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (4799,
#   48,
#   Array(86.63716, dtype=float32),
#   Array(82.43829, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (4899,
#   49,
#   Array(73.95224, dtype=float32),
#   Array(70.11596, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (4999,
#   50,
#   Array(66.13357, dtype=float32),
#   Array(62.614037, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (5099,
#   51,
#   Array(57.025814, dtype=float32),
#   Array(53.841908, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (5199,
#   52,
#   Array(49.045353, dtype=float32),
#   Array(46.217094, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (5299,
#   53,
#   Array(43.05726, dtype=float32),
#   Array(40.503284, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (5399,
#   54,
#   Array(40.393246, dtype=float32),
#   Array(37.99376, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (5499,
#   55,
#   Array(35.857464, dtype=float32),
#   Array(33.697723, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (5599,
#   56,
#   Array(34.348816, dtype=float32),
#   Array(32.28813, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (5699,
#   57,
#   Array(33.566307, dtype=float32),
#   Array(31.614283, dtype=float32),
#   'relu',
#   Array(0, dtype=int32)),
#  (5799,
#   58,
#   Array(27.902, dtype=float32),
#   Array(26.209778, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (5899,
#   59,
#   Array(46.09761, dtype=float32),
#   Array(43.623795, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (5999,
#   58,
#   Array(31.573614, dtype=float32),
#   Array(29.499516, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (6099,
#   59,
#   Array(23.660162, dtype=float32),
#   Array(22.165607, dtype=float32),
#   'relu',
#   Array(1, dtype=int32)),
#  (6199,
#   60,
#   Array(20.290989, dtype=float32),
#   Array(18.978615, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32)),
#  (6299,
#   61,
#   Array(18.87808, dtype=float32),
#   Array(17.652914, dtype=float32),
#   'tanh',
#   Array(1, dtype=int32)),
#  (6399,
#   62,
#   Array(16.921124, dtype=float32),
#   Array(15.786155, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (6499,
#   63,
#   Array(14.399222, dtype=float32),
#   Array(13.384073, dtype=float32),
#   'tanh',
#   Array(0, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Heterogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)
