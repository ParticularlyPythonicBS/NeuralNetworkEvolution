# %%
# %env "WANDB_NOTEBOOK_NAME" "07_homo_sine_loss_strat.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="07_homo_sine_loss_strat.ipynb"
# env: WANDB_SILENT=True
# env: XLA_PYTHON_CLIENT_MEM_FRACTION=0.3

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

import os
import sys
import logging
import wandb

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='viridis', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
input_size = 1
hidden_sizes = [5, 5] 
output_size = 1
initial_activation_list = [sin]
activation_list = [sin]
bias = False
num_epochs = 1000
add_node_every = 10
seed = 42
key = jax.random.PRNGKey(42)
threshold = 1e-4
n_samples = 2000
learning_rate = 0.01

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)
# Out:
# 2024-06-04 12:40:20.744411: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.4.131). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'add_node_every': add_node_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
jax.config.update('jax_platform_name', 'cpu')
Description = f"Homo_sine_loss_strat__no_bias_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{add_node_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 4
# Description: Homo_sine_loss_strat__no_bias_5_5_1000_10_0.0001_42
# jax backend: cpu
# jax devices: [cuda(id=0), cuda(id=1), cuda(id=2), cuda(id=3)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)

# %%
def initialize_optimizer_state(mlp, optimizer):
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
mlp = CustomMLP(config)

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
x = jnp.linspace(0, 2*jnp.pi, n_samples).reshape(-1, 1)
y = jnp.sin(x)

# %%
opt = optax.adabelief(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
plt.matshow(initial_adjacency_matrix, cmap=plt.cm.viridis)
plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %%
Loss_history = []
Node_history = []
graph_history = []
Update_history = []

# %%
for epoch in range(num_epochs):
    loss, mlp, opt_state = train_step(mlp, x, y, opt_state, opt.update)

    key, add_key, sub_key = jax.random.split(key,3)
    n_neurons = sum(mlp.get_shape())
    logging.info(f"Epoch {epoch :03d}, Loss: {loss.item()}, Neurons: {n_neurons}")
    wandb.log({"loss": loss.item(), "neurons": n_neurons})
    Loss_history.append(loss)
    Node_history.append(n_neurons)


    # Dynamically add or remove neurons
    if (epoch + 1) % add_node_every == 0:

        #add criterion
        if len(Update_history) == 0 or Update_history[-1][2] > loss:
            # if no previous addition or last addition was rejected, add a neuron
            # if last addition was accepted, add a neuron
            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0]
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            Update_history.append((epoch, n_neurons, loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
        
        # remove criteria
        elif (Update_history[-1][3] == "removed" and Update_history[-2][2] < loss) or \
            (Update_history[-1][3] != "removed" and Update_history[-1][2] < loss):
            # if last addition was removed check loss against value before that
            # if last addition was accepted, check loss against it
            # if loss doesn't improve, reject it
            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            layer = Update_history[-1][4]
            neuron_idx = len(mlp.layers[layer]) -1

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            Update_history.append((epoch, n_neurons, loss, "removed", layer))

            logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
            wandb.log({"removed neuron": neuron_idx})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
        
        
    if loss < threshold:
        # if loss is below threshold, stop training
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break
# Out:
# Epoch 000, Loss: 0.4347471199231706, Neurons: 11
# Epoch 001, Loss: 0.3912637448228767, Neurons: 11
# Epoch 002, Loss: 0.3500814789390414, Neurons: 11
# Epoch 003, Loss: 0.311343050997528, Neurons: 11
# Epoch 004, Loss: 0.2748875186174447, Neurons: 11
# Epoch 005, Loss: 0.24042620923134514, Neurons: 11
# Epoch 006, Loss: 0.20776862390447734, Neurons: 11
# Epoch 007, Loss: 0.1768022621857017, Neurons: 11
# Epoch 008, Loss: 0.1474786122951523, Neurons: 11
# Epoch 009, Loss: 0.11984654284420959, Neurons: 11
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[5, 6, 1]
# Epoch 010, Loss: 0.2043460031307331, Neurons: 12
# Epoch 011, Loss: 0.15548524263497535, Neurons: 12
# Epoch 012, Loss: 0.11435626427491834, Neurons: 12
# Epoch 013, Loss: 0.08295920832210181, Neurons: 12
# Epoch 014, Loss: 0.06143883747405062, Neurons: 12
# Epoch 015, Loss: 0.04778046331168285, Neurons: 12
# Epoch 016, Loss: 0.03962418815076239, Neurons: 12
# Epoch 017, Loss: 0.035083482625591744, Neurons: 12
# Epoch 018, Loss: 0.032168366074762464, Neurons: 12
# Epoch 019, Loss: 0.028793840927029465, Neurons: 12
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[6, 6, 1]
# Epoch 020, Loss: 0.3712769655179119, Neurons: 13
# Epoch 021, Loss: 0.259444170286645, Neurons: 13
# Epoch 022, Loss: 0.16821935259519075, Neurons: 13
# Epoch 023, Loss: 0.09975471464762077, Neurons: 13
# Epoch 024, Loss: 0.05397578061189284, Neurons: 13
# Epoch 025, Loss: 0.02841392607989187, Neurons: 13
# Epoch 026, Loss: 0.018590609409861462, Neurons: 13
# Epoch 027, Loss: 0.019077264722168436, Neurons: 13
# Epoch 028, Loss: 0.024737367391479196, Neurons: 13
# Epoch 029, Loss: 0.031611897196571356, Neurons: 13
# Removed neuron to hidden layer 1 at index 5
# network shape updated to :[5, 6, 1]
# Epoch 030, Loss: 0.18982034619680907, Neurons: 12
# Epoch 031, Loss: 0.13740368382379162, Neurons: 12
# Epoch 032, Loss: 0.09611993193574549, Neurons: 12
# Epoch 033, Loss: 0.06643279618311371, Neurons: 12
# Epoch 034, Loss: 0.04603352932174977, Neurons: 12
# Epoch 035, Loss: 0.03165097737188584, Neurons: 12
# Epoch 036, Loss: 0.02116554154341295, Neurons: 12
# Epoch 037, Loss: 0.014088064029826448, Neurons: 12
# Epoch 038, Loss: 0.01072182414212367, Neurons: 12
# Epoch 039, Loss: 0.010968323641298667, Neurons: 12
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[5, 7, 1]
# Epoch 040, Loss: 0.7726013157588703, Neurons: 13
# Epoch 041, Loss: 0.5777251180943599, Neurons: 13
# Epoch 940, Loss: 0.046417196322259366, Neurons: 25
# Epoch 941, Loss: 0.010528342899802545, Neurons: 25
# Epoch 942, Loss: 0.0008333728731870576, Neurons: 25
# Epoch 943, Loss: 0.006578380261312114, Neurons: 25
# Epoch 944, Loss: 0.012616540742239753, Neurons: 25
# Epoch 945, Loss: 0.013133244817944962, Neurons: 25
# Epoch 946, Loss: 0.009611474260557536, Neurons: 25
# Epoch 947, Loss: 0.005132696471591986, Neurons: 25
# Epoch 948, Loss: 0.0019270840543184396, Neurons: 25
# Epoch 949, Loss: 0.0007639087467509647, Neurons: 25
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[9, 16, 1]
# Epoch 950, Loss: 0.002659303327025579, Neurons: 26
# Epoch 951, Loss: 0.0024540070357754397, Neurons: 26
# Epoch 952, Loss: 0.004200365117030877, Neurons: 26
# Epoch 953, Loss: 0.0007721385068818598, Neurons: 26
# Epoch 954, Loss: 0.0009659546529103392, Neurons: 26
# Epoch 955, Loss: 0.0018067292723086372, Neurons: 26
# Epoch 956, Loss: 0.0016719901792516024, Neurons: 26
# Epoch 957, Loss: 0.0012632548303835736, Neurons: 26
# Epoch 958, Loss: 0.00062523863516128, Neurons: 26
# Epoch 959, Loss: 0.00026205499488469195, Neurons: 26
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[10, 16, 1]
# Epoch 960, Loss: 0.20148620407024934, Neurons: 27
# Epoch 961, Loss: 0.08553881619596518, Neurons: 27
# Epoch 962, Loss: 0.032300327398669566, Neurons: 27
# Epoch 963, Loss: 0.029330077339227514, Neurons: 27
# Epoch 964, Loss: 0.0445395503075476, Neurons: 27
# Epoch 965, Loss: 0.05252998287973988, Neurons: 27
# Epoch 966, Loss: 0.04769362707151953, Neurons: 27
# Epoch 967, Loss: 0.03617840992547211, Neurons: 27
# Epoch 968, Loss: 0.025765773473092033, Neurons: 27
# Epoch 969, Loss: 0.018928758858187004, Neurons: 27
# Removed neuron to hidden layer 1 at index 9
# network shape updated to :[9, 16, 1]
# Epoch 970, Loss: 0.0819035944858608, Neurons: 26
# Epoch 971, Loss: 0.019710129031732714, Neurons: 26
# Epoch 972, Loss: 0.0070787427714819285, Neurons: 26
# Epoch 973, Loss: 0.013294503691068996, Neurons: 26
# Epoch 974, Loss: 0.015544987310987605, Neurons: 26
# Epoch 975, Loss: 0.011785416406516681, Neurons: 26
# Epoch 976, Loss: 0.006721672859931827, Neurons: 26
# Epoch 977, Loss: 0.004401517800488107, Neurons: 26
# Epoch 978, Loss: 0.005771907661238158, Neurons: 26
# Epoch 979, Loss: 0.00878967567727916, Neurons: 26
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[10, 16, 1]
# Epoch 980, Loss: 0.011396007873304794, Neurons: 27
# Epoch 981, Loss: 0.003240690255632817, Neurons: 27
# Epoch 982, Loss: 0.0025698935777017547, Neurons: 27
# Epoch 983, Loss: 0.0044032855874956405, Neurons: 27
# Epoch 984, Loss: 0.0039040381149831574, Neurons: 27
# Epoch 985, Loss: 0.0017349616144176467, Neurons: 27
# Epoch 986, Loss: 0.0006601780023750243, Neurons: 27
# Epoch 987, Loss: 0.0008540963383831697, Neurons: 27
# Epoch 988, Loss: 0.0013253474463534372, Neurons: 27
# Epoch 989, Loss: 0.0015977481264863851, Neurons: 27
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[11, 16, 1]
# Epoch 990, Loss: 0.0024388864484328836, Neurons: 28
# Epoch 991, Loss: 0.011730656966603822, Neurons: 28
# Epoch 992, Loss: 0.0014899161776921446, Neurons: 28
# Epoch 993, Loss: 0.003526838265458235, Neurons: 28
# Epoch 994, Loss: 0.006165185185812219, Neurons: 28
# Epoch 995, Loss: 0.0031357867046565824, Neurons: 28
# Epoch 996, Loss: 0.00047755771638580347, Neurons: 28
# Epoch 997, Loss: 0.0010975548293344782, Neurons: 28
# Epoch 998, Loss: 0.0025329938520045384, Neurons: 28
# Epoch 999, Loss: 0.0024756260785969157, Neurons: 28
# Removed neuron to hidden layer 1 at index 10
# network shape updated to :[10, 16, 1]

# %%
np.savetxt(f"{out_folder}/neurons.txt", Node_history)
np.savetxt(f"{out_folder}/loss.txt", Loss_history)

# %%
x_test = jnp.linspace(0, 2* jnp.pi, 100).reshape(-1, 1)
y_test = jnp.sin(x_test)
y_pred = jax.vmap(mlp)(x_test)

plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, label="True Sine Function")
plt.plot(x_test, y_pred, label="MLP Predictions")
plt.legend()
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("MLP Approximation of Sine Function")
plt.savefig(f"{fig_folder}/sine_approximation.png")
wandb.log({"sine approximation": wandb.Image(plt, caption="sine approximation")})

# %%
Update_history
# Out:
# [(9, 11, Array(0.11984654, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (19, 12, Array(0.02879384, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (29, 13, Array(0.0316119, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (39, 12, Array(0.01096832, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (49, 13, Array(0.05086793, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (59, 12, Array(0.00473981, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (69, 13, Array(0.00147174, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (79, 14, Array(0.02107511, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (89, 13, Array(0.01419945, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (99, 14, Array(0.0023568, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (109, 15, Array(0.00773034, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (119, 14, Array(0.00380684, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (129, 15, Array(0.00235473, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (139, 16, Array(0.09484706, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (149, 15, Array(0.00568972, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (159, 16, Array(0.02839729, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (169, 15, Array(0.01494523, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (179, 16, Array(0.00438299, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (189, 17, Array(0.00603751, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (199, 16, Array(0.00031448, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (209, 17, Array(0.00280059, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (219, 16, Array(0.00064477, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (229, 17, Array(0.00278144, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (239, 16, Array(0.00034936, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (249, 17, Array(0.00253519, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (259, 16, Array(0.0006642, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (269, 17, Array(0.00127325, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (279, 16, Array(0.00068714, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (289, 17, Array(0.00069754, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (299, 16, Array(0.00108983, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (309, 15, Array(0.00055569, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (319, 16, Array(0.00101309, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (329, 15, Array(0.000568, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (339, 16, Array(0.00088487, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (349, 15, Array(0.00019594, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (359, 16, Array(0.01780101, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (369, 15, Array(0.00638791, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (379, 16, Array(0.00095301, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (389, 17, Array(0.00143173, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (399, 16, Array(0.00055406, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (409, 17, Array(0.00064716, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (419, 16, Array(0.00024969, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (429, 17, Array(0.00229677, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (439, 16, Array(0.00062482, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (449, 17, Array(0.00220814, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (459, 16, Array(0.00149587, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (469, 17, Array(0.00066758, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (479, 18, Array(0.00117317, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (489, 17, Array(0.00145637, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (499, 16, Array(0.00052239, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (509, 17, Array(0.0013909, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (519, 16, Array(0.00063206, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (529, 17, Array(0.00045326, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (539, 18, Array(0.00427574, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (549, 17, Array(0.00219872, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (559, 18, Array(0.00065445, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (569, 19, Array(0.00037292, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (579, 20, Array(0.00101009, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (589, 19, Array(0.00060692, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (599, 20, Array(0.00093936, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (609, 19, Array(0.00059074, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (619, 20, Array(0.00110617, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (629, 19, Array(0.00044634, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (639, 20, Array(0.00351976, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (649, 19, Array(0.00027496, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (659, 20, Array(0.00601526, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (669, 19, Array(0.00091786, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (679, 20, Array(0.00023427, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (689, 21, Array(0.0003906, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (699, 20, Array(0.00097379, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (709, 19, Array(0.00076069, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (719, 20, Array(0.01198035, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (729, 19, Array(0.00394711, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (739, 20, Array(0.03170893, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (749, 19, Array(0.00130473, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (759, 20, Array(0.000508, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (769, 21, Array(0.0427486, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (779, 20, Array(0.00898935, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (789, 21, Array(0.00127642, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (799, 22, Array(0.00155484, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (809, 21, Array(0.00105092, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (819, 22, Array(0.0145108, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (829, 21, Array(0.00986503, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (839, 22, Array(0.00119474, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (849, 23, Array(0.00528015, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (859, 22, Array(0.00061421, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (869, 23, Array(0.0270522, dtype=float64), 'removed', Array(1, dtype=int64)),
#  (879, 22, Array(0.02104653, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (889, 23, Array(0.00273401, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (899, 24, Array(0.00116999, dtype=float64), 'sin', Array(1, dtype=int64)),
#  (909, 25, Array(0.00087933, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (919, 26, Array(0.00461477, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (929, 25, Array(0.00157459, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (939, 26, Array(0.02222715, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (949, 25, Array(0.00076391, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (959, 26, Array(0.00026205, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (969, 27, Array(0.01892876, dtype=float64), 'removed', Array(0, dtype=int64)),
#  (979, 26, Array(0.00878968, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (989, 27, Array(0.00159775, dtype=float64), 'sin', Array(0, dtype=int64)),
#  (999, 28, Array(0.00247563, dtype=float64), 'removed', Array(0, dtype=int64))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
plt.matshow(final_adjacency_matrix, cmap=plt.cm.viridis)
plt.colorbar()
plt.title("Final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(np.arange(0,len(Loss_history)), Loss_history, ".", color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(np.arange(0,len(Node_history)), Node_history, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.suptitle("Homogenous Neural Network with Loss Strategic Node Addition and Removal")
fig.tight_layout()

plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()
