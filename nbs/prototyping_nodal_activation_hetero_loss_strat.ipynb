# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.style as mplstyle

import seaborn as sns

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='icefire', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
class Neuron(eqx.Module):
    weight: jax.Array
    bias: jax.Array
    activation: callable

    def __init__(self, in_features, activation=jax.nn.relu, key=None):
        if key is None:
            key = jax.random.PRNGKey(0)
            key, _ = jax.random.split(key)
        w_key, b_key = jax.random.split(key)
        self.weight = jax.random.normal(w_key, (in_features,))
        self.bias = jax.random.normal(b_key, ())

        self.activation = activation

    def __call__(self, x):
        return self.activation(jnp.dot(self.weight, x) + self.bias)

# %%
def identity(x):
    return x

# %%
class CustomMLP(eqx.Module):
    layers: list

    def __init__(self, input_size, hidden_sizes, output_size, key=None):
        if key is None:
            key = jax.random.PRNGKey(0)
        keys = jax.random.split(key, len(hidden_sizes) + 1)
        act_key = jax.random.split(keys[-1], 1)[0]
        activation_list = [jax.nn.relu, jax.nn.sigmoid, jax.nn.tanh]
        layers = []
        in_features = input_size

        # Create hidden layers
        for i, out_features in enumerate(hidden_sizes):
            layer = [Neuron(in_features, activation_list[jax.random.choice(act_key, jnp.arange(len(activation_list)))], key=keys[i]) for _ in range(out_features)]
            layers.append(layer)
            in_features = out_features

        # Create output layer
        output_layer = [Neuron(in_features, activation=identity, key=keys[-1]) for _ in range(output_size)]
        layers.append(output_layer)

        self.layers = layers

    def __call__(self, x):
        for layer in self.layers:
            x = jnp.array([neuron(x) for neuron in layer])
        return x[0]  # Since output layer is a single neuron

    def add_neuron(self, layer_index, activation=jax.nn.relu, key=None):
        if key is None:
            key = jax.random.PRNGKey(0)
        in_features = self.layers[layer_index][0].weight.shape[0]
        new_neuron = Neuron(in_features, activation, key)
        self.layers[layer_index].append(new_neuron)

        # Adjust the next layer's weight matrix to include the new neuron
        if layer_index + 1 < len(self.layers):
            for i, next_neuron in enumerate(self.layers[layer_index + 1]):
                new_weight = jax.random.normal(key, (1,))
                updated_weights = jnp.append(next_neuron.weight, new_weight)
                self.layers[layer_index + 1][i] = eqx.tree_at(lambda n: n.weight, next_neuron, updated_weights)

    def remove_neuron(self, layer_index, neuron_index):
        if len(self.layers[layer_index]) > 0:
            del self.layers[layer_index][neuron_index]
        
        # Adjust the next layer's weight matrix to remove the corresponding weight
        if layer_index + 1 < len(self.layers):
            for i, next_neuron in enumerate(self.layers[layer_index + 1]):
                updated_weights = jnp.delete(next_neuron.weight, neuron_index)
                self.layers[layer_index + 1][i] = eqx.tree_at(lambda n: n.weight, next_neuron, updated_weights)
    
    def get_shape(self):
        return [len(layer) for layer in self.layers]

# %%
def initialize_optimizer_state(mlp, optimizer):
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
input_size = 3
hidden_sizes = [2, 3]  # Two hidden layers with 4 and 5 neurons respectively
output_size = 1

key = jax.random.PRNGKey(42)
mlp = CustomMLP(input_size, hidden_sizes, output_size, key)
opt = optax.sgd(learning_rate=1e-2)
opt_state = initialize_optimizer_state(mlp, opt)

# %%
mlp.get_shape()
# Out:
# [2, 3, 1]

# %%
x = jnp.array([1.0, 2.0, 3.0])
y = jnp.array([1.0])

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = mlp(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
mlp = CustomMLP(input_size, hidden_sizes, output_size, key)

# %%
activation_list = [jax.nn.relu, jax.nn.sigmoid, jax.nn.tanh]
jax.random.choice(key, jnp.arange(len(activation_list)))
# Out:
# Array(2, dtype=int32)

# %%
activation_list = [jax.nn.relu, jax.nn.sigmoid, jax.nn.tanh]
num_epochs = 1000
add_node_every = 10
remove_node_every = 10
Loss_history = []
Node_history = []
Update_history = []
threshold = 1e-8

# %%
len(mlp.layers[0])
# Out:
# 2

# %% [markdown]
# If loss is greater than threshold,
#     1. add neuron, run a little.
#      if loss is worse, remove neuron.
#      if loss is better, keep neuron.
#
# If loss is less than threshold, stop.

# %%
for epoch in range(num_epochs):
    loss, mlp, opt_state = train_step(mlp, x, y, opt_state, opt.update)
    print(f"Epoch {epoch}, Prediction: {mlp(x)}, Loss: {loss}")

    key, add_key, sub_key = jax.random.split(key,3)
    n_neurons = sum(mlp.get_shape())
    Loss_history.append(loss)
    Node_history.append(n_neurons)


    # Dynamically add or remove neurons
    if (epoch + 1) % add_node_every == 0:
        if len(Update_history) == 0 or Update_history[-1][2] > loss or Update_history[-1][3] == "removed":
            # if no previous addition or last addition was rejected, add a neuron
            # if last addition was accepted, add a neuron
            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0]
            mlp.add_neuron(layer_index=layer, activation=activation, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            Update_history.append((epoch, n_neurons, loss, activation.__name__, layer))
            print(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            print(mlp.get_shape())
        
        elif Update_history[-1][2] < loss:
            # if last addition doesn't improve loss, reject it
            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            print(f"Update history: {Update_history[-1]}")
            layer = Update_history[-1][4]
            neuron_idx = len(mlp.layers[layer]) -1

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            Update_history.append((epoch, n_neurons, loss, "removed", layer))
            print(f"Rejecting last addition,\n Removed neuron from hidden layer {layer+1} at index {neuron_idx}")
            print(mlp.get_shape())
        
        if loss < threshold:
            # if loss is below threshold, stop training
            print(f"Threshold reached, stopping training at epoch {epoch}")
            break
    


print("Final Prediction:", mlp(x))
# Out:
# Epoch 0, Prediction: -0.6204530596733093, Loss: 3.089740514755249
# Epoch 299, Prediction: 1.0135419368743896, Loss: 0.0004519581561908126
# Added neuron to hidden layer 2 with activation sigmoid
# [9, 12, 1]
# Epoch 300, Prediction: 1.0077444314956665, Loss: 0.0001477830664953217
# Epoch 301, Prediction: 1.004934310913086, Loss: 5.997622065478936e-05
# Epoch 302, Prediction: 1.0031442642211914, Loss: 2.4347424186998978e-05
# Epoch 303, Prediction: 1.0020031929016113, Loss: 9.8863974926644e-06
# Epoch 304, Prediction: 1.0012766122817993, Loss: 4.012781573692337e-06
# Epoch 305, Prediction: 1.0008132457733154, Loss: 1.6297389038300025e-06
# Epoch 306, Prediction: 1.0005180835723877, Loss: 6.613686878154112e-07
# Epoch 307, Prediction: 1.0003302097320557, Loss: 2.6841058797799633e-07
# Epoch 308, Prediction: 1.0002102851867676, Loss: 1.0903846714427345e-07
# Epoch 309, Prediction: 1.0001342296600342, Loss: 4.4219859773875214e-08
# Added neuron to hidden layer 2 with activation sigmoid
# [9, 13, 1]
# Epoch 310, Prediction: 0.517905592918396, Loss: 0.6098824739456177
# Epoch 311, Prediction: 0.703726053237915, Loss: 0.23241502046585083
# Epoch 312, Prediction: 0.8187148571014404, Loss: 0.0877782478928566
# Epoch 313, Prediction: 0.889439582824707, Loss: 0.03286430239677429
# Epoch 314, Prediction: 0.9327237606048584, Loss: 0.012223605997860432
# Epoch 315, Prediction: 0.959121823310852, Loss: 0.004526092205196619
# Epoch 316, Prediction: 0.9751846194267273, Loss: 0.0016710252966731787
# Epoch 317, Prediction: 0.9849443435668945, Loss: 0.0006158031173981726
# Epoch 318, Prediction: 0.9908689260482788, Loss: 0.000226672796998173
# Epoch 319, Prediction: 0.9944630861282349, Loss: 8.337650797329843e-05
# Update history: (309, 22, Array(4.421986e-08, dtype=float32), 'sigmoid', Array(1, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 2 at index 12
# [9, 12, 1]
# Epoch 320, Prediction: 1.4624919891357422, Loss: 0.5454241633415222
# Epoch 321, Prediction: 1.2926628589630127, Loss: 0.21389883756637573
# Epoch 322, Prediction: 1.1861321926116943, Loss: 0.08565154671669006
# Epoch 323, Prediction: 1.1186894178390503, Loss: 0.034645192325115204
# Epoch 324, Prediction: 1.075792670249939, Loss: 0.014087177813053131
# Epoch 325, Prediction: 1.048439383506775, Loss: 0.005744528956711292
# Epoch 326, Prediction: 1.0309730768203735, Loss: 0.002346373861655593
# Epoch 327, Prediction: 1.0198111534118652, Loss: 0.000959331460762769
# Epoch 328, Prediction: 1.012673258781433, Loss: 0.00039248180110007524
# Epoch 329, Prediction: 1.0081086158752441, Loss: 0.00016061148198787123
# Added neuron to hidden layer 1 with activation relu
# [10, 12, 1]
# Epoch 330, Prediction: 1.0051881074905396, Loss: 6.574964936589822e-05
# Epoch 331, Prediction: 1.003319501876831, Loss: 2.691645931918174e-05
# Epoch 332, Prediction: 1.0021241903305054, Loss: 1.1019093108188827e-05
# Epoch 333, Prediction: 1.001359224319458, Loss: 4.512184659688501e-06
# Epoch 334, Prediction: 1.0008697509765625, Loss: 1.8474906937626656e-06
# Epoch 335, Prediction: 1.0005567073822021, Loss: 7.564667612314224e-07
# Epoch 336, Prediction: 1.0003561973571777, Loss: 3.09923109398369e-07
# Epoch 337, Prediction: 1.0002282857894897, Loss: 1.2687655726040248e-07
# Epoch 338, Prediction: 1.0001459121704102, Loss: 5.211440168295667e-08
# Epoch 339, Prediction: 1.0000934600830078, Loss: 2.1290361473802477e-08
# Added neuron to hidden layer 1 with activation tanh
# [11, 12, 1]
# Epoch 340, Prediction: 1.5093914270401, Loss: 0.3768213391304016
# Epoch 341, Prediction: 1.4232869148254395, Loss: 0.2594796121120453
# Epoch 342, Prediction: 1.3520824909210205, Loss: 0.17917181551456451
# Epoch 343, Prediction: 1.2930634021759033, Loss: 0.12396208196878433
# Epoch 344, Prediction: 1.2440637350082397, Loss: 0.0858861580491066
# Epoch 345, Prediction: 1.2033343315124512, Loss: 0.059567105025053024
# Epoch 346, Prediction: 1.1694493293762207, Loss: 0.04134485125541687
# Epoch 347, Prediction: 1.141241431236267, Loss: 0.028713075444102287
# Epoch 348, Prediction: 1.1177479028701782, Loss: 0.019949141889810562
# Epoch 349, Prediction: 1.0981743335723877, Loss: 0.013864568434655666
# Update history: (339, 23, Array(2.1290361e-08, dtype=float32), 'tanh', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 10
# [10, 12, 1]
# Epoch 350, Prediction: 0.6736018657684326, Loss: 0.2552965581417084
# Epoch 351, Prediction: 0.789560854434967, Loss: 0.10653574019670486
# Epoch 352, Prediction: 0.8645855188369751, Loss: 0.0442846342921257
# Epoch 353, Prediction: 0.9129961133003235, Loss: 0.018337082117795944
# Epoch 354, Prediction: 0.9441614151000977, Loss: 0.007569676265120506
# Epoch 355, Prediction: 0.9641903638839722, Loss: 0.003117947606369853
# Epoch 356, Prediction: 0.9770464897155762, Loss: 0.0012823300203308463
# Epoch 357, Prediction: 0.9852924346923828, Loss: 0.0005268636159598827
# Epoch 358, Prediction: 0.9905776977539062, Loss: 0.00021631247363984585
# Epoch 359, Prediction: 0.9939646124839783, Loss: 8.877977961674333e-05
# Added neuron to hidden layer 1 with activation tanh
# [11, 12, 1]
# Epoch 360, Prediction: 1.0111665725708008, Loss: 0.00034291084739379585
# Epoch 361, Prediction: 1.006734848022461, Loss: 0.00012469234934542328
# Epoch 362, Prediction: 1.004062533378601, Loss: 4.5358177885646e-05
# Epoch 363, Prediction: 1.0024502277374268, Loss: 1.6504178347531706e-05
# Epoch 364, Prediction: 1.0014783143997192, Loss: 6.00361590841203e-06
# Epoch 365, Prediction: 1.0008920431137085, Loss: 2.185413450206397e-06
# Epoch 366, Prediction: 1.0005381107330322, Loss: 7.957409025038942e-07
# Epoch 367, Prediction: 1.0003249645233154, Loss: 2.895631610044802e-07
# Epoch 368, Prediction: 1.0001962184906006, Loss: 1.0560194141362444e-07
# Epoch 369, Prediction: 1.0001180171966553, Loss: 3.850169605357223e-08
# Added neuron to hidden layer 2 with activation tanh
# [11, 13, 1]
# Epoch 370, Prediction: 1.8010631799697876, Loss: 1.8705233335494995
# Epoch 371, Prediction: 1.473000168800354, Loss: 0.6417022347450256
# Epoch 372, Prediction: 1.2785866260528564, Loss: 0.22372916340827942
# Epoch 373, Prediction: 1.1633996963500977, Loss: 0.07761050760746002
# Epoch 374, Prediction: 1.0955090522766113, Loss: 0.026699461042881012
# Epoch 375, Prediction: 1.0556942224502563, Loss: 0.009121978655457497
# Epoch 376, Prediction: 1.032427191734314, Loss: 0.0031018464360386133
# Epoch 377, Prediction: 1.0188627243041992, Loss: 0.0010515227913856506
# Epoch 378, Prediction: 1.0109665393829346, Loss: 0.0003558023599907756
# Epoch 379, Prediction: 1.0063741207122803, Loss: 0.00012026498734485358
# Update history: (369, 24, Array(3.8501696e-08, dtype=float32), 'tanh', Array(1, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 2 at index 12
# [11, 12, 1]
# Epoch 380, Prediction: 0.2166815847158432, Loss: 1.6776946783065796
# Epoch 381, Prediction: 0.519273042678833, Loss: 0.6135877370834351
# Epoch 382, Prediction: 0.7045024633407593, Loss: 0.23109841346740723
# Epoch 383, Prediction: 0.8186230063438416, Loss: 0.0873187929391861
# Epoch 384, Prediction: 0.888866662979126, Loss: 0.03289761394262314
# Epoch 385, Prediction: 0.9320032596588135, Loss: 0.012350618839263916
# Epoch 386, Prediction: 0.9584372043609619, Loss: 0.004623556509613991
# Epoch 387, Prediction: 0.9746115207672119, Loss: 0.0017274660058319569
# Epoch 388, Prediction: 0.9844977259635925, Loss: 0.000644574873149395
# Epoch 389, Prediction: 0.9905369281768799, Loss: 0.00024032049986999482
# Added neuron to hidden layer 2 with activation sigmoid
# [11, 13, 1]
# Epoch 390, Prediction: 1.0598995685577393, Loss: 0.009701477363705635
# Epoch 391, Prediction: 1.036466121673584, Loss: 0.00358795840293169
# Epoch 392, Prediction: 1.0222139358520508, Loss: 0.0013297779951244593
# Epoch 393, Prediction: 1.013537049293518, Loss: 0.0004934589378535748
# Epoch 394, Prediction: 1.0082508325576782, Loss: 0.00018325170094612986
# Epoch 395, Prediction: 1.0050297975540161, Loss: 6.807623867643997e-05
# Epoch 396, Prediction: 1.0030663013458252, Loss: 2.529886296542827e-05
# Epoch 397, Prediction: 1.0018696784973145, Loss: 9.402204341313336e-06
# Epoch 398, Prediction: 1.0011399984359741, Loss: 3.4956976833200315e-06
# Epoch 399, Prediction: 1.000694990158081, Loss: 1.2995964198125876e-06
# Added neuron to hidden layer 1 with activation tanh
# [12, 13, 1]
# Epoch 400, Prediction: 0.952483057975769, Loss: 0.046437833458185196
# Epoch 401, Prediction: 0.98897784948349, Loss: 0.0022578598000109196
# Epoch 402, Prediction: 0.9974173307418823, Loss: 0.00012148779933340847
# Epoch 403, Prediction: 0.9993932843208313, Loss: 6.670180482615251e-06
# Epoch 404, Prediction: 0.9998573064804077, Loss: 3.6810391179642465e-07
# Epoch 405, Prediction: 0.9999666213989258, Loss: 2.0361440533633868e-08
# Epoch 406, Prediction: 0.9999923706054688, Loss: 1.114131009671837e-09
# Epoch 407, Prediction: 0.9999977946281433, Loss: 5.820766091346741e-11
# Epoch 408, Prediction: 0.9999994039535522, Loss: 4.863665026277886e-12
# Epoch 409, Prediction: 0.9999995231628418, Loss: 3.552713678800501e-13
# Added neuron to hidden layer 1 with activation sigmoid
# [13, 13, 1]
# Epoch 410, Prediction: 1.0258746147155762, Loss: 0.006139032077044249
# Epoch 411, Prediction: 1.0084710121154785, Loss: 0.0006694956682622433
# Epoch 412, Prediction: 1.0027662515640259, Loss: 7.175804785219952e-05
# Epoch 413, Prediction: 1.0009019374847412, Loss: 7.652147360204253e-06
# Epoch 414, Prediction: 1.0002942085266113, Loss: 8.134912263813021e-07
# Epoch 415, Prediction: 1.0000954866409302, Loss: 8.655865713080857e-08
# Epoch 416, Prediction: 1.0000312328338623, Loss: 9.11769859612832e-09
# Epoch 417, Prediction: 1.0000100135803223, Loss: 9.754899110703263e-10
# Epoch 418, Prediction: 1.0000033378601074, Loss: 1.0027179087046534e-10
# Epoch 419, Prediction: 1.0000015497207642, Loss: 1.1141310096718371e-11
# Update history: (409, 26, Array(3.5527137e-13, dtype=float32), 'sigmoid', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 12
# [12, 13, 1]
# Epoch 420, Prediction: 0.9807637929916382, Loss: 0.006947093643248081
# Epoch 421, Prediction: 0.9954793453216553, Loss: 0.00037003165925852954
# Epoch 422, Prediction: 0.9989334344863892, Loss: 2.0436318663996644e-05
# Epoch 423, Prediction: 0.9997481107711792, Loss: 1.1375619806130999e-06
# Epoch 424, Prediction: 0.9999408721923828, Loss: 6.344818359593773e-08
# Epoch 425, Prediction: 0.9999855160713196, Loss: 3.496097633615136e-09
# Epoch 426, Prediction: 0.9999960064888, Loss: 2.0978419001949078e-10
# Epoch 427, Prediction: 0.9999992847442627, Loss: 1.594813170413545e-11
# Epoch 428, Prediction: 0.9999996423721313, Loss: 5.115907697472721e-13
# Epoch 429, Prediction: 0.9999997615814209, Loss: 1.2789769243681803e-13
# Added neuron to hidden layer 2 with activation tanh
# [12, 14, 1]
# Epoch 430, Prediction: 0.692632794380188, Loss: 1.6811801195144653
# Epoch 431, Prediction: 0.9124245643615723, Loss: 0.09447459876537323
# Epoch 432, Prediction: 0.9747262001037598, Loss: 0.007669456768780947
# Epoch 433, Prediction: 0.9926910400390625, Loss: 0.0006387649336829782
# Epoch 434, Prediction: 0.99788498878479, Loss: 5.34208957105875e-05
# Epoch 435, Prediction: 0.9993880987167358, Loss: 4.473272383620497e-06
# Epoch 436, Prediction: 0.9998224973678589, Loss: 3.7442316624947125e-07
# Epoch 437, Prediction: 0.999949038028717, Loss: 3.150718441702338e-08
# Epoch 438, Prediction: 0.9999852180480957, Loss: 2.597122517045136e-09
# Epoch 439, Prediction: 0.999995768070221, Loss: 2.18506102100946e-10
# Update history: (429, 26, Array(1.2789769e-13, dtype=float32), 'tanh', Array(1, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 2 at index 13
# [12, 13, 1]
# Epoch 440, Prediction: 1.3880290985107422, Loss: 1.5927032232284546
# Epoch 478, Prediction: 1.000449299812317, Loss: 1.2476689335017e-06
# Epoch 479, Prediction: 1.0001808404922485, Loss: 2.0187032134799665e-07
# Added neuron to hidden layer 2 with activation relu
# [12, 15, 1]
# Epoch 480, Prediction: 1.0000723600387573, Loss: 3.2703283636692504e-08
# Epoch 481, Prediction: 1.00002920627594, Loss: 5.235975208961463e-09
# Epoch 482, Prediction: 1.000011682510376, Loss: 8.530065542800003e-10
# Epoch 483, Prediction: 1.0000048875808716, Loss: 1.3648104868480004e-10
# Epoch 484, Prediction: 1.000002145767212, Loss: 2.3888446776254568e-11
# Epoch 485, Prediction: 1.000001072883606, Loss: 4.604316927725449e-12
# Epoch 486, Prediction: 1.0000004768371582, Loss: 1.1510792319313623e-12
# Epoch 487, Prediction: 1.000000238418579, Loss: 2.2737367544323206e-13
# Epoch 488, Prediction: 1.000000238418579, Loss: 5.684341886080802e-14
# Epoch 489, Prediction: 1.0, Loss: 5.684341886080802e-14
# Added neuron to hidden layer 1 with activation sigmoid
# [13, 15, 1]
# Epoch 490, Prediction: 1.0137827396392822, Loss: 0.0009884373284876347
# Epoch 491, Prediction: 1.006036639213562, Loss: 0.00018996391736436635
# Epoch 492, Prediction: 1.002642273902893, Loss: 3.6441011616261676e-05
# Epoch 493, Prediction: 1.0011568069458008, Loss: 6.981611477385741e-06
# Epoch 494, Prediction: 1.0005061626434326, Loss: 1.3382023098529316e-06
# Epoch 495, Prediction: 1.0002213716506958, Loss: 2.5620062160669477e-07
# Epoch 496, Prediction: 1.0000971555709839, Loss: 4.9005407731783635e-08
# Epoch 497, Prediction: 1.000042200088501, Loss: 9.439204973205051e-09
# Epoch 498, Prediction: 1.0000187158584595, Loss: 1.7808474694902543e-09
# Epoch 499, Prediction: 1.0000079870224, Loss: 3.502833578750142e-10
# Update history: (489, 28, Array(5.684342e-14, dtype=float32), 'sigmoid', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 12
# [12, 15, 1]
# Epoch 500, Prediction: 0.9870020151138306, Loss: 0.0010481469798833132
# Epoch 501, Prediction: 0.9947727918624878, Loss: 0.0001689476048341021
# Epoch 502, Prediction: 0.9978965520858765, Loss: 2.7323705580784008e-05
# Epoch 503, Prediction: 0.9991533756256104, Loss: 4.4244929995329585e-06
# Epoch 504, Prediction: 0.9996589422225952, Loss: 7.167728313106636e-07
# Epoch 505, Prediction: 0.9998629689216614, Loss: 1.1632040752829198e-07
# Epoch 506, Prediction: 0.9999446272850037, Loss: 1.8777516430645846e-08
# Epoch 507, Prediction: 0.9999775886535645, Loss: 3.066137566065663e-09
# Epoch 508, Prediction: 0.9999911189079285, Loss: 5.022684490540996e-10
# Epoch 509, Prediction: 0.9999963641166687, Loss: 7.887379638304992e-11
# Added neuron to hidden layer 1 with activation relu
# [13, 15, 1]
# Epoch 510, Prediction: 0.9999984502792358, Loss: 1.3219647598816664e-11
# Epoch 511, Prediction: 0.9999992847442627, Loss: 2.4016344468691386e-12
# Epoch 512, Prediction: 0.9999995231628418, Loss: 5.115907697472721e-13
# Epoch 513, Prediction: 0.9999996423721313, Loss: 2.2737367544323206e-13
# Epoch 514, Prediction: 0.9999997615814209, Loss: 1.2789769243681803e-13
# Epoch 515, Prediction: 0.9999998807907104, Loss: 5.684341886080802e-14
# Epoch 516, Prediction: 0.9999998807907104, Loss: 1.4210854715202004e-14
# Epoch 517, Prediction: 1.0, Loss: 1.4210854715202004e-14
# Epoch 518, Prediction: 1.0, Loss: 0.0
# Epoch 519, Prediction: 1.0, Loss: 0.0
# Added neuron to hidden layer 2 with activation sigmoid
# [13, 16, 1]
# Epoch 520, Prediction: 1.0080780982971191, Loss: 0.0004025017551612109
# Epoch 521, Prediction: 1.0032501220703125, Loss: 6.525567005155608e-05
# Epoch 522, Prediction: 1.0013066530227661, Loss: 1.0563293471932411e-05
# Epoch 523, Prediction: 1.0005249977111816, Loss: 1.7073421076929662e-06
# Epoch 524, Prediction: 1.000211238861084, Loss: 2.7562259674596135e-07
# Epoch 525, Prediction: 1.0000848770141602, Loss: 4.462185643205885e-08
# Epoch 526, Prediction: 1.000033974647522, Loss: 7.2041075327433646e-09
# Epoch 527, Prediction: 1.000013828277588, Loss: 1.1542766742422828e-09
# Epoch 528, Prediction: 1.0000054836273193, Loss: 1.9122126104775816e-10
# Epoch 529, Prediction: 1.0000025033950806, Loss: 3.007016857736744e-11
# Update history: (519, 29, Array(0., dtype=float32), 'sigmoid', Array(1, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 2 at index 15
# [13, 15, 1]
# Epoch 530, Prediction: 0.9919365644454956, Loss: 0.00040247305878438056
# Epoch 531, Prediction: 0.9967557191848755, Loss: 6.501899042632431e-05
# Epoch 532, Prediction: 0.9986938238143921, Loss: 1.0525358447921462e-05
# Epoch 533, Prediction: 0.9994744062423706, Loss: 1.706096213638375e-06
# Epoch 534, Prediction: 0.9997882843017578, Loss: 2.76248783848132e-07
# Epoch 535, Prediction: 0.9999146461486816, Loss: 4.4823536882176995e-08
# Epoch 536, Prediction: 0.9999656677246094, Loss: 7.2852799348765984e-09
# Epoch 537, Prediction: 0.9999862909317017, Loss: 1.178705133497715e-09
# Epoch 538, Prediction: 0.9999943971633911, Loss: 1.879385536085465e-10
# Epoch 539, Prediction: 0.9999973773956299, Loss: 3.1391778065881226e-11
# Added neuron to hidden layer 1 with activation relu
# [14, 15, 1]
# Epoch 540, Prediction: 1.2799822092056274, Loss: 0.5142459273338318
# Epoch 541, Prediction: 0.9658855199813843, Loss: 0.07839003950357437
# Epoch 542, Prediction: 1.0070221424102783, Loss: 0.0011637978022918105
# Epoch 543, Prediction: 0.9986350536346436, Loss: 4.931048533762805e-05
# Epoch 544, Prediction: 1.0002689361572266, Loss: 1.8630785234563518e-06
# Epoch 545, Prediction: 0.9999471306800842, Loss: 7.232665666379035e-08
# Epoch 546, Prediction: 1.0000098943710327, Loss: 2.7951649883561913e-09
# Epoch 547, Prediction: 0.9999982118606567, Loss: 9.78985781330266e-11
# Epoch 548, Prediction: 1.000000238418579, Loss: 3.197442310920451e-12
# Epoch 549, Prediction: 1.0000001192092896, Loss: 5.684341886080802e-14
# Added neuron to hidden layer 1 with activation sigmoid
# [15, 15, 1]
# Epoch 550, Prediction: 1.5313100814819336, Loss: 0.6204313635826111
# Epoch 551, Prediction: 0.7000888586044312, Loss: 0.28229039907455444
# Epoch 552, Prediction: 1.1971681118011475, Loss: 0.0899466946721077
# Epoch 553, Prediction: 0.879391074180603, Loss: 0.038875263184309006
# Epoch 554, Prediction: 1.0777513980865479, Loss: 0.014546512626111507
# Epoch 555, Prediction: 0.9513564109802246, Loss: 0.006045280024409294
# Epoch 556, Prediction: 1.0310524702072144, Loss: 0.002366198692470789
# Epoch 557, Prediction: 0.9804186820983887, Loss: 0.0009642558870837092
# Epoch 558, Prediction: 1.0124473571777344, Loss: 0.0003834280068986118
# Epoch 559, Prediction: 0.9921268224716187, Loss: 0.00015493670071009547
# Update history: (549, 30, Array(5.684342e-14, dtype=float32), 'sigmoid', Array(0, dtype=int32))
# Rejecting last addition,
#  Removed neuron from hidden layer 1 at index 14
# [14, 15, 1]
# Epoch 560, Prediction: 1.0214117765426636, Loss: 0.3280508518218994
# Epoch 561, Prediction: 0.9981505274772644, Loss: 0.0004584641719702631
# Epoch 562, Prediction: 1.000171184539795, Loss: 3.4205486372229643e-06
# Epoch 563, Prediction: 0.999984085559845, Loss: 2.930414666479919e-08
# Epoch 564, Prediction: 1.0000016689300537, Loss: 2.532694054480089e-10
# Epoch 565, Prediction: 0.9999998807907104, Loss: 2.7853275241795927e-12
# Epoch 566, Prediction: 0.9999999403953552, Loss: 1.4210854715202004e-14
# Epoch 567, Prediction: 1.0, Loss: 3.552713678800501e-15
# Epoch 568, Prediction: 1.0, Loss: 0.0
# Epoch 569, Prediction: 1.0, Loss: 0.0
# Added neuron to hidden layer 2 with activation sigmoid
# [14, 16, 1]
# Epoch 570, Prediction: 0.9995220899581909, Loss: 2.574330210336484e-05
# Epoch 571, Prediction: 1.0000460147857666, Loss: 2.2839800806195854e-07
# Epoch 572, Prediction: 0.999995231628418, Loss: 2.1173605091462377e-09
# Epoch 573, Prediction: 1.0000004768371582, Loss: 2.2737367544323206e-11
# Epoch 574, Prediction: 1.0, Loss: 2.2737367544323206e-13
# Epoch 575, Prediction: 1.0, Loss: 0.0
# Epoch 576, Prediction: 1.0, Loss: 0.0
# Epoch 577, Prediction: 1.0, Loss: 0.0
# Epoch 578, Prediction: 1.0, Loss: 0.0
# Epoch 579, Prediction: 1.0, Loss: 0.0
# Threshold reached, stopping training at epoch 579
# Final Prediction: 1.0

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(np.arange(0,len(Loss_history)), Loss_history, ".", color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(np.arange(0,len(Node_history)), Node_history, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.suptitle("Heterogenous Neural Network with Dynamic Node Addition and Removal")
fig.tight_layout()
