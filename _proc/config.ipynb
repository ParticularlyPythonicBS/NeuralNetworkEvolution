# %% [raw]
# ---
# description: Configuration files for creating and testing MLPS
# output-file: config.html
# title: Config
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(MLPConfig)
# Out:
# ---
#
# ### MLPConfig
#
# >      MLPConfig (seed:int, input_size:int, hidden_sizes:list, output_size:int,
# >                 initial_activation_list:list, bias:bool=False)
