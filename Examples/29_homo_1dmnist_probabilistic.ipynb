# %% [markdown]
# # Probabilistic strategy for 1d mnist classification with a heterogenous MLP model

# %% [markdown]
# ### env management

# %%
# %env "WANDB_NOTEBOOK_NAME" "28_homo_1dmnist_probabilistic.ipynb"
# %env WANDB_SILENT=True
# %load_ext autoreload
# %reload_ext autoreload
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=0.3
# Out:
# env: "WANDB_NOTEBOOK_NAME"="28_homo_poly_probabilistic.ipynb"
# env: WANDB_SILENT=True

# %% [markdown]
# ### imports and setup

# %%
import jax
import numpy as np
import jax.numpy as jnp
import equinox as eqx
import optax
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize
import matplotlib.style as mplstyle
import seaborn as sns

from NeuralNetworkEvolution.config import MLPConfig
from NeuralNetworkEvolution.activations import sin
from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot

from mnist1d.data import make_dataset, get_dataset_args, get_templates

import os
import sys
import time
import logging
import wandb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 20
#      17 from NeuralNetworkEvolution.activations import sin
#      18 from NeuralNetworkEvolution.mlp import CustomMLP, mlp_plot
# ---> 20 from mnist1d.data import make_dataset, get_dataset_args, get_templates, plot_signals
#      22 import os
#      23 import sys
#
# ImportError: cannot import name 'plot_signals' from 'mnist1d.data' (/home/aradhak5/projects/NeuralNetworkEvolution/env/lib/python3.12/site-packages/mnist1d/data.py)

# %%
plt.style.use('default')
sns.set_theme(context='paper', style='white', palette='vlag', font='serif',
            font_scale=2, color_codes=True, rc={'text.usetex' : True})
mplstyle.use('fast')

# %%
class MidpointNormalize(Normalize):
    """
    Normalize and shift the colormap to center 0
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        result, is_scalar = self.process_value(value)
        (vmin, vmax, midpoint) = self.vmin, self.vmax, self.midpoint
        if vmin is None or vmax is None:
            vmin, vmax = np.min(value), np.max(value)
        if midpoint is None:
            midpoint = (vmin + vmax) / 2
        result = np.ma.masked_array(np.interp(value, [vmin, midpoint, vmax], [0, 0.5, 1]))
        if is_scalar:
            result = np.atleast_1d(result)[0]
        return result

# %%
def plot_1dmnist(xs, t, labels=None, ratio=2.6, dark_mode=False, zoom=1):
    rows, cols = 1, 10
    fig = plt.figure(figsize=[cols*1.5,rows*1.5*ratio], dpi=60)
    for r in range(rows):
        for c in range(cols):
            ix = r*cols + c
            x, t = xs[ix], t
            ax = plt.subplot(rows,cols,ix+1)

            if dark_mode:
                plt.plot(x, t, 'wo', linewidth=6)
                ax.set_facecolor('k')
            else:
                plt.plot(x, t, 'k-', linewidth=2)
            if labels is not None:
                plt.title("label=" + str(labels[ix]), fontsize=22)

            plt.xlim(-zoom,zoom) ; plt.ylim(-zoom,zoom)
            plt.gca().invert_yaxis() ; plt.xticks([], []), plt.yticks([], [])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.tight_layout() ; plt.show()
    return fig

# %% [markdown]
# ### config

# %%
jax.config.update('jax_platform_name', 'cpu')

# %%
input_size = 1
hidden_sizes = [5, 5] 
min_neurons = 4
output_size = 1
initial_activation_list = [sin]
activation_list = [sin]
optimizer = optax.adabelief
bias = False
num_epochs = 25000
intervene_every = 100
seed = 0
key = jax.random.PRNGKey(seed)
threshold = 1e-4
grad_norm_threshold = 1e-3
n_samples = 20000
test_size = 0.2
learning_rate = 3e-4

act_string = "_".join([act.__name__ for act in initial_activation_list])

config = MLPConfig(input_size=input_size,
                output_size=output_size,
                hidden_sizes=hidden_sizes,
                initial_activation_list=initial_activation_list,
                seed=seed)

# %%
config.__dict__.update({'n_samples': n_samples,
                        'learning_rate': learning_rate,
                        'num_epochs': num_epochs,
                        'intervene_every': intervene_every,
                        'threshold': threshold,
                        'activation_list': activation_list})

# %%
# jax.config.update("jax_enable_x64", True)

Description = f"Homo_{act_string}_1dmnist_probabilistic_strat_{optimizer.__name__}_no_bias_min_{min_neurons}_{hidden_sizes[0]}_{hidden_sizes[1]}_{num_epochs}_{intervene_every}_{threshold}_{seed}"
fig_folder = f"../figures/{Description}"
out_folder = f"../output/{Description}"
os.makedirs(fig_folder, exist_ok=True)
os.makedirs(out_folder, exist_ok=True)

# %% [markdown]
# ### logging

# %%
print(f"# devices: {jax.local_device_count()}")

logging.basicConfig(level=logging.INFO, filename=f"{out_folder}/info.log", filemode="w")
console = logging.StreamHandler(sys.stdout)
console.setLevel(logging.INFO)
logging.getLogger("").addHandler(console)
logging.info(f"Description: {Description}")
logging.info(f"jax backend: {jax.lib.xla_bridge.get_backend().platform}")
logging.info(f"jax devices: {jax.devices()}")
# Out:
# # devices: 1
# Description: Homo_sin_1dmnist_probabilistic_strat_adabelief_no_bias_min_4_5_5_25000_100_0.0001_0
# jax backend: cpu
# jax devices: [CpuDevice(id=0)]

# %%
run = wandb.init(project="neural-network-evolution", name=Description, config=config.__dict__)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: particularlypythonicbs. Use `wandb login --relogin` to force relogin
# wandb version 0.17.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.0
# Run data is saved locally in <code>/home/aradhak5/projects/NeuralNetworkEvolution/Examples/wandb/run-20240628_104606-2ap7pqck</code>
# Syncing run <strong><a href='https://wandb.ai/particularlypythonicbs/neural-network-evolution/runs/2ap7pqck' target="_blank">Homo_sin_1dmnist_probabilistic_strat_adabelief_no_bias_min_4_5_5_25000_100_0.0001_0</a></strong> to <a href='https://wandb.ai/particularlypythonicbs/neural-network-evolution' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/particularlypythonicbs/neural-network-evolution' target="_blank">https://wandb.ai/particularlypythonicbs/neural-network-evolution</a>
#  View run at <a href='https://wandb.ai/particularlypythonicbs/neural-network-evolution/runs/2ap7pqck' target="_blank">https://wandb.ai/particularlypythonicbs/neural-network-evolution/runs/2ap7pqck</a>

# %% [markdown]
# ### data

# %%
data_config = get_dataset_args()

# %%
data_config.num_samples = n_samples
data_config.shuffle_seq = True

# %%
data = make_dataset(data_config)

# %%
x_train, y_train = data["x"], data["y"]
x_test, y_test = data["x_test"], data["y_test"]
template = data["t"]

# %%
templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_signals(x, t, labels=y, ratio=1.33, dark_mode=False)
# Out:
# Text(0.5, 0.98, 'Data')

# %% [markdown]
# ### training and eval scheme

# %%
def initialize_optimizer_state(mlp, optimizer):
    """
    Optimizer initialization that filters for float arrays in the jax pytrees
    """
    return optimizer.init(eqx.filter(mlp, eqx.is_inexact_array))

# %%
@eqx.filter_value_and_grad()
def compute_loss(mlp, x, y):
    pred = jax.vmap(mlp)(x)
    return jnp.mean((pred - y) ** 2)

# %%
@eqx.filter_jit()
def train_step(mlp, x, y, opt_state, opt_update):
    loss, grads = compute_loss(mlp, x, y)
    updates, opt_state = opt_update(grads, opt_state)
    mlp = eqx.apply_updates(mlp, updates)
    return loss, mlp, opt_state

# %%
@eqx.filter_jit()
def test_step(mlp, x, y):
    return compute_loss(mlp, x, y)[0]

# %%
def grad_norm(grads):
    return jnp.sqrt(sum(jnp.sum(jnp.square(p)) for p in jax.tree_util.tree_leaves(grads)))

# %% [markdown]
# ### initializing MLP

# %%
mlp = CustomMLP(config)
init_neurons = sum(mlp.get_shape())
logging.info(f"Number of neurons at start: {init_neurons}")
# Out:
# Number of neurons at start: 11

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.suptitle("Initial neural network")
plt.savefig(f"{fig_folder}/initial_graph.png")
wandb.log({"initial neural network": wandb.Image(plt, caption="initial neural network")})

# %%
initial_adjacency_matrix = mlp.adjacency_matrix()

# %%
max_wt = np.max(np.abs(initial_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(initial_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("Initial adjacency matrix")
plt.savefig(f"{fig_folder}/initial_adjacency_matrix.png")
wandb.log({"initial adjacency matrix": wandb.Image(plt, caption="initial adjacency matrix")})

# %% [markdown]
# ### initializing optimizer

# %%
opt = optimizer(learning_rate=learning_rate)
opt_state = initialize_optimizer_state(mlp, opt)

# %% [markdown]
# ### training

# %%
train_loss_history = []
test_loss_history = []
node_history = []
grad_norm_history = []
graph_history = []
update_history = []
time_history = []

test_loss = np.inf # initialize test loss to infinity
check_loss = np.inf # initialize check loss to infinity

# %%
def p_add(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to add a neuron
    """
    return test_loss / (test_loss + n_neurons / min_neurons)

def p_remove(test_loss, n_neurons, min_neurons):
    """
    Probability of trying to remove a neuron
    """
    return test_loss / (test_loss + min_neurons / n_neurons)

# %%
for epoch in range(num_epochs):

    start = time.time()
    train_loss, mlp, opt_state = train_step(mlp, x_train, y_train, opt_state, opt.update)
    _, grads  = compute_loss(mlp, x_train, y_train)
    grad_norm_val = grad_norm(grads)
    n_neurons = sum(mlp.get_shape())

    logging.info(f"Epoch {epoch :03d}, Loss: {train_loss.item()}, Neurons: {n_neurons}, Grad norm: {grad_norm_val :.3e}")
    wandb.log({"train_loss": train_loss.item(), "neurons": n_neurons, "grad_norm": grad_norm_val})
    train_loss_history.append((epoch, train_loss))
    grad_norm_history.append((epoch,grad_norm_val))
    node_history.append((epoch, n_neurons))

    if test_loss < threshold: # stop training if test loss is below threshold
        logging.info(f"Threshold reached, stopping training at epoch {epoch}")
        wandb.log({"threshold reached": epoch})
        break

    if grad_norm_val < grad_norm_threshold/10: # stop training if gradient norm is very low
        logging.info(f"Gradient norm below threshold, stopping training at epoch {epoch}")
        wandb.log({"grad_norm_threshold": epoch})
        break

    key, add_key, sub_key, prob_key = jax.random.split(key,4)

    if ((epoch + 1) % intervene_every == 0
        or grad_norm_val < grad_norm_threshold) and epoch!=num_epochs-1: # intervene if gradient norm is below threshold, but not at last epoch
        test_loss = test_step(mlp, x_test, y_test)
        logging.info(f"Epoch {epoch :03d}, Test loss: {test_loss.item()}")
        wandb.log({"test_loss": test_loss.item()})
        test_loss_history.append((epoch,test_loss))

        # Neuron Addition criteria
        if ((len(update_history) == 0    # if no previous addition
            or check_loss > test_loss) # if last addition was accepted
            and jax.random.uniform(prob_key, minval = 0, maxval = 1)< p_add(test_loss, n_neurons, min_neurons)): # addition probability

            add_key, act_key = jax.random.split(add_key)
            activation = activation_list[jax.random.choice(key, jnp.arange(len(activation_list)))]
            layers = len(mlp.get_shape()) - 1
            layer = jax.random.randint(act_key, (1,), 0, layers)[0] # randomly select a layer to add neuron to
            mlp.add_neuron(layer_index=layer, activation=activation, bias = bias, key=add_key)
            opt_state = initialize_optimizer_state(mlp, opt)

            update_history.append((epoch, n_neurons, train_loss, test_loss, activation.__name__, layer))
            logging.info(f"Added neuron to hidden layer {layer+1} with activation {activation.__name__}")
            wandb.log({"added neuron": activation.__name__})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
            check_loss = test_loss
            logging.info(f"Check loss updated to {check_loss}")
        
        # Neuron Removal criteria
        elif ((check_loss < test_loss) # check current loss against last accepted addition
            and n_neurons>min_neurons # neuron floor
            and jax.random.uniform(prob_key, minval = 0, maxval = 1)<p_remove(test_loss, n_neurons, min_neurons)): # removal probability 

            layer_key, neuron_key, sub_key = jax.random.split(sub_key,3)
            layer = update_history[-1][-1] # get the layer of last addition
            neuron_idx = len(mlp.layers[layer]) -1

            if len(mlp.layers[layer]) <= 1:
                logging.info(f"Cannot remove neuron from layer {layer+1}, only one neuron left")
                update_history.append((epoch, n_neurons, train_loss, test_loss, "single_node_layer", layer))
                continue

            mlp.remove_neuron(layer_index=layer, neuron_index=neuron_idx)
            opt_state = initialize_optimizer_state(mlp, opt)
            update_history.append((epoch, n_neurons, train_loss, test_loss, "removed", layer))

            logging.info(f"Removed neuron to hidden layer {layer+1} at index {neuron_idx}")
            wandb.log({"removed neuron": neuron_idx})
            logging.info(f"network shape updated to :{mlp.get_shape()}")
    
    stop = time.time()
    time_history.append((epoch, stop-start, n_neurons))
# Out:
# Epoch 000, Loss: 1509.9005126953125, Neurons: 11, Grad norm: 4.984e+01
# Epoch 001, Loss: 1509.8218994140625, Neurons: 11, Grad norm: 4.985e+01
# Epoch 002, Loss: 1509.7393798828125, Neurons: 11, Grad norm: 4.987e+01
# Epoch 003, Loss: 1509.652587890625, Neurons: 11, Grad norm: 4.988e+01
# Epoch 004, Loss: 1509.5616455078125, Neurons: 11, Grad norm: 4.990e+01
# Epoch 005, Loss: 1509.466552734375, Neurons: 11, Grad norm: 4.992e+01
# Epoch 006, Loss: 1509.367431640625, Neurons: 11, Grad norm: 4.994e+01
# Epoch 007, Loss: 1509.263916015625, Neurons: 11, Grad norm: 4.996e+01
# Epoch 008, Loss: 1509.1561279296875, Neurons: 11, Grad norm: 4.998e+01
# Epoch 009, Loss: 1509.0443115234375, Neurons: 11, Grad norm: 5.000e+01
# Epoch 010, Loss: 1508.9281005859375, Neurons: 11, Grad norm: 5.003e+01
# Epoch 011, Loss: 1508.8077392578125, Neurons: 11, Grad norm: 5.005e+01
# Epoch 012, Loss: 1508.68310546875, Neurons: 11, Grad norm: 5.008e+01
# Epoch 013, Loss: 1508.5545654296875, Neurons: 11, Grad norm: 5.010e+01
# Epoch 014, Loss: 1508.421630859375, Neurons: 11, Grad norm: 5.013e+01
# Epoch 015, Loss: 1508.28466796875, Neurons: 11, Grad norm: 5.016e+01
# Epoch 016, Loss: 1508.1436767578125, Neurons: 11, Grad norm: 5.019e+01
# Epoch 017, Loss: 1507.9986572265625, Neurons: 11, Grad norm: 5.023e+01
# Epoch 018, Loss: 1507.8497314453125, Neurons: 11, Grad norm: 5.026e+01
# Epoch 019, Loss: 1507.69677734375, Neurons: 11, Grad norm: 5.030e+01
# Epoch 020, Loss: 1507.5399169921875, Neurons: 11, Grad norm: 5.033e+01
# Epoch 021, Loss: 1507.3792724609375, Neurons: 11, Grad norm: 5.037e+01
# Epoch 022, Loss: 1507.2147216796875, Neurons: 11, Grad norm: 5.041e+01
# Epoch 023, Loss: 1507.0462646484375, Neurons: 11, Grad norm: 5.045e+01
# Epoch 024, Loss: 1506.8741455078125, Neurons: 11, Grad norm: 5.049e+01
# Epoch 025, Loss: 1506.6983642578125, Neurons: 11, Grad norm: 5.054e+01
# Epoch 026, Loss: 1506.518798828125, Neurons: 11, Grad norm: 5.058e+01
# Epoch 027, Loss: 1506.3358154296875, Neurons: 11, Grad norm: 5.063e+01
# Epoch 028, Loss: 1506.1488037109375, Neurons: 11, Grad norm: 5.068e+01
# Epoch 029, Loss: 1505.9583740234375, Neurons: 11, Grad norm: 5.073e+01
# Epoch 030, Loss: 1505.7642822265625, Neurons: 11, Grad norm: 5.078e+01
# Epoch 031, Loss: 1505.5665283203125, Neurons: 11, Grad norm: 5.084e+01
# Epoch 067, Loss: 1496.117431640625, Neurons: 11, Grad norm: 5.390e+01
# Epoch 068, Loss: 1495.7889404296875, Neurons: 11, Grad norm: 5.401e+01
# Epoch 069, Loss: 1495.45654296875, Neurons: 11, Grad norm: 5.412e+01
# Epoch 070, Loss: 1495.1207275390625, Neurons: 11, Grad norm: 5.424e+01
# Epoch 071, Loss: 1494.7811279296875, Neurons: 11, Grad norm: 5.435e+01
# Epoch 072, Loss: 1494.4376220703125, Neurons: 11, Grad norm: 5.447e+01
# Epoch 073, Loss: 1494.090576171875, Neurons: 11, Grad norm: 5.459e+01
# Epoch 074, Loss: 1493.7396240234375, Neurons: 11, Grad norm: 5.470e+01
# Epoch 075, Loss: 1493.384765625, Neurons: 11, Grad norm: 5.482e+01
# Epoch 076, Loss: 1493.0264892578125, Neurons: 11, Grad norm: 5.494e+01
# Epoch 077, Loss: 1492.664306640625, Neurons: 11, Grad norm: 5.506e+01
# Epoch 078, Loss: 1492.29833984375, Neurons: 11, Grad norm: 5.518e+01
# Epoch 079, Loss: 1491.9285888671875, Neurons: 11, Grad norm: 5.530e+01
# Epoch 080, Loss: 1491.5550537109375, Neurons: 11, Grad norm: 5.542e+01
# Epoch 081, Loss: 1491.1778564453125, Neurons: 11, Grad norm: 5.554e+01
# Epoch 082, Loss: 1490.7969970703125, Neurons: 11, Grad norm: 5.567e+01
# Epoch 083, Loss: 1490.412109375, Neurons: 11, Grad norm: 5.579e+01
# Epoch 084, Loss: 1490.0235595703125, Neurons: 11, Grad norm: 5.591e+01
# Epoch 085, Loss: 1489.63134765625, Neurons: 11, Grad norm: 5.603e+01
# Epoch 086, Loss: 1489.2353515625, Neurons: 11, Grad norm: 5.615e+01
# Epoch 087, Loss: 1488.83544921875, Neurons: 11, Grad norm: 5.627e+01
# Epoch 088, Loss: 1488.43212890625, Neurons: 11, Grad norm: 5.640e+01
# Epoch 089, Loss: 1488.0247802734375, Neurons: 11, Grad norm: 5.652e+01
# Epoch 090, Loss: 1487.6138916015625, Neurons: 11, Grad norm: 5.664e+01
# Epoch 091, Loss: 1487.1993408203125, Neurons: 11, Grad norm: 5.676e+01
# Epoch 092, Loss: 1486.7811279296875, Neurons: 11, Grad norm: 5.688e+01
# Epoch 093, Loss: 1486.3592529296875, Neurons: 11, Grad norm: 5.700e+01
# Epoch 094, Loss: 1485.9337158203125, Neurons: 11, Grad norm: 5.712e+01
# Epoch 095, Loss: 1485.5045166015625, Neurons: 11, Grad norm: 5.723e+01
# Epoch 096, Loss: 1485.07177734375, Neurons: 11, Grad norm: 5.735e+01
# Epoch 097, Loss: 1484.6356201171875, Neurons: 11, Grad norm: 5.747e+01
# Epoch 098, Loss: 1484.1956787109375, Neurons: 11, Grad norm: 5.758e+01
# Epoch 099, Loss: 1483.7523193359375, Neurons: 11, Grad norm: 5.770e+01
# Epoch 099, Test loss: 1513.2978515625
# Added neuron to hidden layer 1 with activation sin
# network shape updated to :[6, 5, 1]
# Check loss updated to 1513.2978515625
# Epoch 135, Loss: 1476.7156982421875, Neurons: 12, Grad norm: 5.959e+01
# Epoch 136, Loss: 1476.5037841796875, Neurons: 12, Grad norm: 5.963e+01
# Epoch 137, Loss: 1476.288818359375, Neurons: 12, Grad norm: 5.967e+01
# Epoch 138, Loss: 1476.07080078125, Neurons: 12, Grad norm: 5.971e+01
# Epoch 139, Loss: 1475.8502197265625, Neurons: 12, Grad norm: 5.974e+01
# Epoch 140, Loss: 1475.626708984375, Neurons: 12, Grad norm: 5.978e+01
# Epoch 141, Loss: 1475.400390625, Neurons: 12, Grad norm: 5.981e+01
# Epoch 142, Loss: 1475.1712646484375, Neurons: 12, Grad norm: 5.985e+01
# Epoch 143, Loss: 1474.939697265625, Neurons: 12, Grad norm: 5.988e+01
# Epoch 144, Loss: 1474.705322265625, Neurons: 12, Grad norm: 5.992e+01
# Epoch 145, Loss: 1474.46826171875, Neurons: 12, Grad norm: 5.995e+01
# Epoch 146, Loss: 1474.228759765625, Neurons: 12, Grad norm: 5.998e+01
# Epoch 147, Loss: 1473.986572265625, Neurons: 12, Grad norm: 6.002e+01
# Epoch 148, Loss: 1473.741943359375, Neurons: 12, Grad norm: 6.005e+01
# Epoch 149, Loss: 1473.494873046875, Neurons: 12, Grad norm: 6.008e+01
# Epoch 150, Loss: 1473.2452392578125, Neurons: 12, Grad norm: 6.011e+01
# Epoch 151, Loss: 1472.9931640625, Neurons: 12, Grad norm: 6.014e+01
# Epoch 152, Loss: 1472.7386474609375, Neurons: 12, Grad norm: 6.017e+01
# Epoch 153, Loss: 1472.4820556640625, Neurons: 12, Grad norm: 6.020e+01
# Epoch 154, Loss: 1472.2227783203125, Neurons: 12, Grad norm: 6.023e+01
# Epoch 155, Loss: 1471.96142578125, Neurons: 12, Grad norm: 6.026e+01
# Epoch 156, Loss: 1471.697509765625, Neurons: 12, Grad norm: 6.029e+01
# Epoch 157, Loss: 1471.4315185546875, Neurons: 12, Grad norm: 6.032e+01
# Epoch 158, Loss: 1471.163330078125, Neurons: 12, Grad norm: 6.034e+01
# Epoch 159, Loss: 1470.89306640625, Neurons: 12, Grad norm: 6.037e+01
# Epoch 160, Loss: 1470.62060546875, Neurons: 12, Grad norm: 6.040e+01
# Epoch 161, Loss: 1470.3458251953125, Neurons: 12, Grad norm: 6.042e+01
# Epoch 162, Loss: 1470.069091796875, Neurons: 12, Grad norm: 6.044e+01
# Epoch 163, Loss: 1469.7901611328125, Neurons: 12, Grad norm: 6.047e+01
# Epoch 164, Loss: 1469.50927734375, Neurons: 12, Grad norm: 6.049e+01
# Epoch 165, Loss: 1469.226318359375, Neurons: 12, Grad norm: 6.051e+01
# Epoch 166, Loss: 1468.94140625, Neurons: 12, Grad norm: 6.053e+01
# Epoch 167, Loss: 1468.654541015625, Neurons: 12, Grad norm: 6.055e+01
# Epoch 168, Loss: 1468.36572265625, Neurons: 12, Grad norm: 6.057e+01
# Epoch 169, Loss: 1468.074951171875, Neurons: 12, Grad norm: 6.059e+01
# Epoch 170, Loss: 1467.7823486328125, Neurons: 12, Grad norm: 6.061e+01
# Epoch 171, Loss: 1467.48779296875, Neurons: 12, Grad norm: 6.063e+01
# Epoch 172, Loss: 1467.1915283203125, Neurons: 12, Grad norm: 6.064e+01
# Epoch 173, Loss: 1466.8935546875, Neurons: 12, Grad norm: 6.066e+01
# Epoch 174, Loss: 1466.5936279296875, Neurons: 12, Grad norm: 6.067e+01
# Epoch 175, Loss: 1466.2921142578125, Neurons: 12, Grad norm: 6.068e+01
# Epoch 176, Loss: 1465.9886474609375, Neurons: 12, Grad norm: 6.069e+01
# Epoch 177, Loss: 1465.68359375, Neurons: 12, Grad norm: 6.071e+01
# Epoch 178, Loss: 1465.3770751953125, Neurons: 12, Grad norm: 6.072e+01
# Epoch 179, Loss: 1465.06884765625, Neurons: 12, Grad norm: 6.072e+01
# Epoch 180, Loss: 1464.7589111328125, Neurons: 12, Grad norm: 6.073e+01
# Epoch 181, Loss: 1464.447509765625, Neurons: 12, Grad norm: 6.074e+01
# Epoch 182, Loss: 1464.1346435546875, Neurons: 12, Grad norm: 6.075e+01
# Epoch 183, Loss: 1463.8201904296875, Neurons: 12, Grad norm: 6.075e+01
# Epoch 184, Loss: 1463.504150390625, Neurons: 12, Grad norm: 6.076e+01
# Epoch 185, Loss: 1463.186767578125, Neurons: 12, Grad norm: 6.076e+01
# Epoch 186, Loss: 1462.8680419921875, Neurons: 12, Grad norm: 6.076e+01
# Epoch 187, Loss: 1462.5478515625, Neurons: 12, Grad norm: 6.076e+01
# Epoch 188, Loss: 1462.226318359375, Neurons: 12, Grad norm: 6.076e+01
# Epoch 189, Loss: 1461.903564453125, Neurons: 12, Grad norm: 6.076e+01
# Epoch 190, Loss: 1461.5794677734375, Neurons: 12, Grad norm: 6.076e+01
# Epoch 191, Loss: 1461.2540283203125, Neurons: 12, Grad norm: 6.076e+01
# Epoch 192, Loss: 1460.927490234375, Neurons: 12, Grad norm: 6.075e+01
# Epoch 193, Loss: 1460.599609375, Neurons: 12, Grad norm: 6.075e+01
# Epoch 194, Loss: 1460.2706298828125, Neurons: 12, Grad norm: 6.074e+01
# Epoch 195, Loss: 1459.9405517578125, Neurons: 12, Grad norm: 6.073e+01
# Epoch 196, Loss: 1459.609375, Neurons: 12, Grad norm: 6.073e+01
# Epoch 197, Loss: 1459.2772216796875, Neurons: 12, Grad norm: 6.072e+01
# Epoch 198, Loss: 1458.9439697265625, Neurons: 12, Grad norm: 6.071e+01
# Epoch 199, Loss: 1458.609619140625, Neurons: 12, Grad norm: 6.070e+01
# Epoch 199, Test loss: 1487.798583984375
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[6, 6, 1]
# Check loss updated to 1487.798583984375
# Epoch 200, Loss: 1468.1707763671875, Neurons: 13, Grad norm: 6.993e+01
# Epoch 201, Loss: 1468.071044921875, Neurons: 13, Grad norm: 6.991e+01
# Epoch 202, Loss: 1467.9661865234375, Neurons: 13, Grad norm: 6.990e+01
# Epoch 306, Loss: 1439.04541015625, Neurons: 14, Grad norm: 1.252e+02
# Epoch 307, Loss: 1438.8236083984375, Neurons: 14, Grad norm: 1.245e+02
# Epoch 308, Loss: 1438.593994140625, Neurons: 14, Grad norm: 1.238e+02
# Epoch 309, Loss: 1438.3568115234375, Neurons: 14, Grad norm: 1.231e+02
# Epoch 310, Loss: 1438.112548828125, Neurons: 14, Grad norm: 1.223e+02
# Epoch 311, Loss: 1437.861083984375, Neurons: 14, Grad norm: 1.216e+02
# Epoch 312, Loss: 1437.60302734375, Neurons: 14, Grad norm: 1.207e+02
# Epoch 313, Loss: 1437.3385009765625, Neurons: 14, Grad norm: 1.199e+02
# Epoch 314, Loss: 1437.06787109375, Neurons: 14, Grad norm: 1.191e+02
# Epoch 315, Loss: 1436.791259765625, Neurons: 14, Grad norm: 1.182e+02
# Epoch 316, Loss: 1436.50927734375, Neurons: 14, Grad norm: 1.173e+02
# Epoch 317, Loss: 1436.2222900390625, Neurons: 14, Grad norm: 1.164e+02
# Epoch 318, Loss: 1435.9302978515625, Neurons: 14, Grad norm: 1.155e+02
# Epoch 319, Loss: 1435.6339111328125, Neurons: 14, Grad norm: 1.146e+02
# Epoch 320, Loss: 1435.3336181640625, Neurons: 14, Grad norm: 1.136e+02
# Epoch 321, Loss: 1435.029296875, Neurons: 14, Grad norm: 1.127e+02
# Epoch 322, Loss: 1434.7216796875, Neurons: 14, Grad norm: 1.117e+02
# Epoch 323, Loss: 1434.41064453125, Neurons: 14, Grad norm: 1.108e+02
# Epoch 324, Loss: 1434.0970458984375, Neurons: 14, Grad norm: 1.098e+02
# Epoch 325, Loss: 1433.78076171875, Neurons: 14, Grad norm: 1.088e+02
# Epoch 326, Loss: 1433.4622802734375, Neurons: 14, Grad norm: 1.079e+02
# Epoch 327, Loss: 1433.1419677734375, Neurons: 14, Grad norm: 1.069e+02
# Epoch 328, Loss: 1432.8197021484375, Neurons: 14, Grad norm: 1.059e+02
# Epoch 329, Loss: 1432.49609375, Neurons: 14, Grad norm: 1.049e+02
# Epoch 330, Loss: 1432.1710205078125, Neurons: 14, Grad norm: 1.040e+02
# Epoch 331, Loss: 1431.844970703125, Neurons: 14, Grad norm: 1.030e+02
# Epoch 332, Loss: 1431.5179443359375, Neurons: 14, Grad norm: 1.021e+02
# Epoch 333, Loss: 1431.1903076171875, Neurons: 14, Grad norm: 1.011e+02
# Epoch 334, Loss: 1430.8619384765625, Neurons: 14, Grad norm: 1.002e+02
# Epoch 335, Loss: 1430.5333251953125, Neurons: 14, Grad norm: 9.925e+01
# Epoch 336, Loss: 1430.204345703125, Neurons: 14, Grad norm: 9.834e+01
# Epoch 337, Loss: 1429.8751220703125, Neurons: 14, Grad norm: 9.745e+01
# Epoch 338, Loss: 1429.5455322265625, Neurons: 14, Grad norm: 9.656e+01
# Epoch 339, Loss: 1429.21630859375, Neurons: 14, Grad norm: 9.570e+01
# Epoch 340, Loss: 1428.8870849609375, Neurons: 14, Grad norm: 9.484e+01
# Epoch 409, Loss: 1409.6710205078125, Neurons: 15, Grad norm: 1.161e+02
# Epoch 410, Loss: 1409.443359375, Neurons: 15, Grad norm: 1.147e+02
# Epoch 411, Loss: 1409.2109375, Neurons: 15, Grad norm: 1.132e+02
# Epoch 412, Loss: 1408.9744873046875, Neurons: 15, Grad norm: 1.117e+02
# Epoch 413, Loss: 1408.734375, Neurons: 15, Grad norm: 1.101e+02
# Epoch 414, Loss: 1408.4913330078125, Neurons: 15, Grad norm: 1.086e+02
# Epoch 415, Loss: 1408.245849609375, Neurons: 15, Grad norm: 1.070e+02
# Epoch 416, Loss: 1407.998046875, Neurons: 15, Grad norm: 1.054e+02
# Epoch 417, Loss: 1407.748779296875, Neurons: 15, Grad norm: 1.038e+02
# Epoch 418, Loss: 1407.4986572265625, Neurons: 15, Grad norm: 1.023e+02
# Epoch 419, Loss: 1407.2479248046875, Neurons: 15, Grad norm: 1.007e+02
# Epoch 420, Loss: 1406.9970703125, Neurons: 15, Grad norm: 9.912e+01
# Epoch 421, Loss: 1406.746337890625, Neurons: 15, Grad norm: 9.756e+01
# Epoch 422, Loss: 1406.496337890625, Neurons: 15, Grad norm: 9.602e+01
# Epoch 423, Loss: 1406.2471923828125, Neurons: 15, Grad norm: 9.451e+01
# Epoch 424, Loss: 1405.999267578125, Neurons: 15, Grad norm: 9.302e+01
# Epoch 425, Loss: 1405.7530517578125, Neurons: 15, Grad norm: 9.157e+01
# Epoch 426, Loss: 1405.50830078125, Neurons: 15, Grad norm: 9.015e+01
# Epoch 427, Loss: 1405.265625, Neurons: 15, Grad norm: 8.877e+01
# Epoch 428, Loss: 1405.0247802734375, Neurons: 15, Grad norm: 8.742e+01
# Epoch 429, Loss: 1404.786376953125, Neurons: 15, Grad norm: 8.612e+01
# Epoch 430, Loss: 1404.5499267578125, Neurons: 15, Grad norm: 8.487e+01
# Epoch 431, Loss: 1404.31591796875, Neurons: 15, Grad norm: 8.367e+01
# Epoch 432, Loss: 1404.0841064453125, Neurons: 15, Grad norm: 8.251e+01
# Epoch 433, Loss: 1403.8546142578125, Neurons: 15, Grad norm: 8.140e+01
# Epoch 434, Loss: 1403.6270751953125, Neurons: 15, Grad norm: 8.035e+01
# Epoch 435, Loss: 1403.40185546875, Neurons: 15, Grad norm: 7.934e+01
# Epoch 436, Loss: 1403.1788330078125, Neurons: 15, Grad norm: 7.838e+01
# Epoch 437, Loss: 1402.95751953125, Neurons: 15, Grad norm: 7.748e+01
# Epoch 438, Loss: 1402.73828125, Neurons: 15, Grad norm: 7.662e+01
# Epoch 439, Loss: 1402.5208740234375, Neurons: 15, Grad norm: 7.581e+01
# Epoch 440, Loss: 1402.3050537109375, Neurons: 15, Grad norm: 7.505e+01
# Epoch 441, Loss: 1402.0908203125, Neurons: 15, Grad norm: 7.434e+01
# Epoch 442, Loss: 1401.8780517578125, Neurons: 15, Grad norm: 7.367e+01
# Epoch 443, Loss: 1401.6663818359375, Neurons: 15, Grad norm: 7.305e+01
# Epoch 479, Loss: 1394.1707763671875, Neurons: 15, Grad norm: 6.553e+01
# Epoch 480, Loss: 1393.955078125, Neurons: 15, Grad norm: 6.548e+01
# Epoch 481, Loss: 1393.738525390625, Neurons: 15, Grad norm: 6.543e+01
# Epoch 482, Loss: 1393.5213623046875, Neurons: 15, Grad norm: 6.539e+01
# Epoch 483, Loss: 1393.3038330078125, Neurons: 15, Grad norm: 6.534e+01
# Epoch 484, Loss: 1393.0853271484375, Neurons: 15, Grad norm: 6.530e+01
# Epoch 485, Loss: 1392.8662109375, Neurons: 15, Grad norm: 6.526e+01
# Epoch 486, Loss: 1392.6466064453125, Neurons: 15, Grad norm: 6.522e+01
# Epoch 487, Loss: 1392.42626953125, Neurons: 15, Grad norm: 6.518e+01
# Epoch 488, Loss: 1392.2052001953125, Neurons: 15, Grad norm: 6.514e+01
# Epoch 489, Loss: 1391.9835205078125, Neurons: 15, Grad norm: 6.511e+01
# Epoch 490, Loss: 1391.7611083984375, Neurons: 15, Grad norm: 6.507e+01
# Epoch 491, Loss: 1391.5380859375, Neurons: 15, Grad norm: 6.504e+01
# Epoch 492, Loss: 1391.3143310546875, Neurons: 15, Grad norm: 6.500e+01
# Epoch 493, Loss: 1391.08984375, Neurons: 15, Grad norm: 6.497e+01
# Epoch 494, Loss: 1390.8646240234375, Neurons: 15, Grad norm: 6.493e+01
# Epoch 495, Loss: 1390.638671875, Neurons: 15, Grad norm: 6.490e+01
# Epoch 496, Loss: 1390.4122314453125, Neurons: 15, Grad norm: 6.487e+01
# Epoch 497, Loss: 1390.184814453125, Neurons: 15, Grad norm: 6.483e+01
# Epoch 498, Loss: 1389.956787109375, Neurons: 15, Grad norm: 6.480e+01
# Epoch 499, Loss: 1389.7279052734375, Neurons: 15, Grad norm: 6.477e+01
# Epoch 499, Test loss: 1417.692626953125
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[8, 7, 1]
# Check loss updated to 1417.692626953125
# Epoch 500, Loss: 1413.62451171875, Neurons: 16, Grad norm: 1.509e+02
# Epoch 501, Loss: 1413.4244384765625, Neurons: 16, Grad norm: 1.509e+02
# Epoch 502, Loss: 1413.21484375, Neurons: 16, Grad norm: 1.509e+02
# Epoch 503, Loss: 1412.995361328125, Neurons: 16, Grad norm: 1.510e+02
# Epoch 504, Loss: 1412.76611328125, Neurons: 16, Grad norm: 1.510e+02
# Epoch 505, Loss: 1412.5269775390625, Neurons: 16, Grad norm: 1.511e+02
# Epoch 506, Loss: 1412.2783203125, Neurons: 16, Grad norm: 1.512e+02
# Epoch 507, Loss: 1412.019775390625, Neurons: 16, Grad norm: 1.512e+02
# Epoch 508, Loss: 1411.751953125, Neurons: 16, Grad norm: 1.513e+02
# Epoch 509, Loss: 1411.474609375, Neurons: 16, Grad norm: 1.513e+02
# Epoch 510, Loss: 1411.187744140625, Neurons: 16, Grad norm: 1.514e+02
# Epoch 511, Loss: 1410.8917236328125, Neurons: 16, Grad norm: 1.515e+02
# Epoch 512, Loss: 1410.5865478515625, Neurons: 16, Grad norm: 1.516e+02
# Epoch 513, Loss: 1410.2720947265625, Neurons: 16, Grad norm: 1.517e+02
# Epoch 514, Loss: 1409.94873046875, Neurons: 16, Grad norm: 1.518e+02
# Epoch 515, Loss: 1409.616455078125, Neurons: 16, Grad norm: 1.519e+02
# Epoch 516, Loss: 1409.2750244140625, Neurons: 16, Grad norm: 1.520e+02
# Epoch 517, Loss: 1408.9249267578125, Neurons: 16, Grad norm: 1.521e+02
# Epoch 518, Loss: 1408.5657958984375, Neurons: 16, Grad norm: 1.522e+02
# Epoch 519, Loss: 1408.1981201171875, Neurons: 16, Grad norm: 1.523e+02
# Epoch 520, Loss: 1407.821533203125, Neurons: 16, Grad norm: 1.524e+02
# Epoch 521, Loss: 1407.436279296875, Neurons: 16, Grad norm: 1.525e+02
# Epoch 522, Loss: 1407.0423583984375, Neurons: 16, Grad norm: 1.526e+02
# Epoch 523, Loss: 1406.6397705078125, Neurons: 16, Grad norm: 1.527e+02
# Epoch 524, Loss: 1406.228515625, Neurons: 16, Grad norm: 1.528e+02
# Epoch 525, Loss: 1405.8089599609375, Neurons: 16, Grad norm: 1.529e+02
# Epoch 526, Loss: 1405.380859375, Neurons: 16, Grad norm: 1.530e+02
# Epoch 527, Loss: 1404.9443359375, Neurons: 16, Grad norm: 1.531e+02
# Epoch 528, Loss: 1404.4993896484375, Neurons: 16, Grad norm: 1.532e+02
# Epoch 529, Loss: 1404.0462646484375, Neurons: 16, Grad norm: 1.533e+02
# Epoch 530, Loss: 1403.5848388671875, Neurons: 16, Grad norm: 1.534e+02
# Epoch 531, Loss: 1403.115478515625, Neurons: 16, Grad norm: 1.535e+02
# Epoch 532, Loss: 1402.6378173828125, Neurons: 16, Grad norm: 1.536e+02
# Epoch 533, Loss: 1402.15234375, Neurons: 16, Grad norm: 1.537e+02
# Epoch 534, Loss: 1401.6588134765625, Neurons: 16, Grad norm: 1.538e+02
# Epoch 535, Loss: 1401.1573486328125, Neurons: 16, Grad norm: 1.539e+02
# Epoch 536, Loss: 1400.6483154296875, Neurons: 16, Grad norm: 1.540e+02
# Epoch 537, Loss: 1400.1314697265625, Neurons: 16, Grad norm: 1.541e+02
# Epoch 538, Loss: 1399.60693359375, Neurons: 16, Grad norm: 1.542e+02
# Epoch 539, Loss: 1399.07470703125, Neurons: 16, Grad norm: 1.542e+02
# Epoch 540, Loss: 1398.5350341796875, Neurons: 16, Grad norm: 1.543e+02
# Epoch 541, Loss: 1397.98779296875, Neurons: 16, Grad norm: 1.544e+02
# Epoch 542, Loss: 1397.433349609375, Neurons: 16, Grad norm: 1.544e+02
# Epoch 543, Loss: 1396.8714599609375, Neurons: 16, Grad norm: 1.545e+02
# Epoch 544, Loss: 1396.3023681640625, Neurons: 16, Grad norm: 1.545e+02
# Epoch 545, Loss: 1395.72607421875, Neurons: 16, Grad norm: 1.546e+02
# Epoch 546, Loss: 1395.142578125, Neurons: 16, Grad norm: 1.546e+02
# Epoch 582, Loss: 1370.203857421875, Neurons: 16, Grad norm: 1.496e+02
# Epoch 583, Loss: 1369.4300537109375, Neurons: 16, Grad norm: 1.492e+02
# Epoch 584, Loss: 1368.654052734375, Neurons: 16, Grad norm: 1.488e+02
# Epoch 585, Loss: 1367.8756103515625, Neurons: 16, Grad norm: 1.484e+02
# Epoch 586, Loss: 1367.0950927734375, Neurons: 16, Grad norm: 1.480e+02
# Epoch 587, Loss: 1366.3126220703125, Neurons: 16, Grad norm: 1.476e+02
# Epoch 588, Loss: 1365.5283203125, Neurons: 16, Grad norm: 1.471e+02
# Epoch 589, Loss: 1364.7425537109375, Neurons: 16, Grad norm: 1.466e+02
# Epoch 590, Loss: 1363.95556640625, Neurons: 16, Grad norm: 1.462e+02
# Epoch 591, Loss: 1363.1673583984375, Neurons: 16, Grad norm: 1.457e+02
# Epoch 592, Loss: 1362.378173828125, Neurons: 16, Grad norm: 1.452e+02
# Epoch 593, Loss: 1361.5880126953125, Neurons: 16, Grad norm: 1.446e+02
# Epoch 594, Loss: 1360.7977294921875, Neurons: 16, Grad norm: 1.441e+02
# Epoch 595, Loss: 1360.0068359375, Neurons: 16, Grad norm: 1.435e+02
# Epoch 596, Loss: 1359.2156982421875, Neurons: 16, Grad norm: 1.430e+02
# Epoch 597, Loss: 1358.4248046875, Neurons: 16, Grad norm: 1.424e+02
# Epoch 598, Loss: 1357.634033203125, Neurons: 16, Grad norm: 1.418e+02
# Epoch 599, Loss: 1356.84375, Neurons: 16, Grad norm: 1.411e+02
# Epoch 599, Test loss: 1383.5521240234375
# Added neuron to hidden layer 2 with activation sin
# network shape updated to :[8, 8, 1]
# Check loss updated to 1383.5521240234375
# Epoch 600, Loss: 1363.2847900390625, Neurons: 17, Grad norm: 2.033e+02
# Epoch 601, Loss: 1362.9796142578125, Neurons: 17, Grad norm: 2.031e+02
# Epoch 602, Loss: 1362.6593017578125, Neurons: 17, Grad norm: 2.028e+02
# Epoch 603, Loss: 1362.3238525390625, Neurons: 17, Grad norm: 2.026e+02
# Epoch 604, Loss: 1361.9732666015625, Neurons: 17, Grad norm: 2.024e+02
# Epoch 605, Loss: 1361.6072998046875, Neurons: 17, Grad norm: 2.022e+02
# Epoch 606, Loss: 1361.2261962890625, Neurons: 17, Grad norm: 2.019e+02
# Epoch 607, Loss: 1360.8299560546875, Neurons: 17, Grad norm: 2.017e+02
# Epoch 608, Loss: 1360.41845703125, Neurons: 17, Grad norm: 2.015e+02
# Epoch 609, Loss: 1359.991943359375, Neurons: 17, Grad norm: 2.012e+02
# Epoch 610, Loss: 1359.55078125, Neurons: 17, Grad norm: 2.010e+02
# Epoch 611, Loss: 1359.0947265625, Neurons: 17, Grad norm: 2.007e+02
# Epoch 612, Loss: 1358.6241455078125, Neurons: 17, Grad norm: 2.005e+02
# Epoch 613, Loss: 1358.1395263671875, Neurons: 17, Grad norm: 2.002e+02
# Epoch 614, Loss: 1357.6407470703125, Neurons: 17, Grad norm: 1.999e+02
# Epoch 615, Loss: 1357.1282958984375, Neurons: 17, Grad norm: 1.997e+02
# Epoch 616, Loss: 1356.6024169921875, Neurons: 17, Grad norm: 1.994e+02
# Epoch 617, Loss: 1356.063720703125, Neurons: 17, Grad norm: 1.991e+02
# Epoch 618, Loss: 1355.5120849609375, Neurons: 17, Grad norm: 1.988e+02
# Epoch 619, Loss: 1354.9482421875, Neurons: 17, Grad norm: 1.984e+02
# Epoch 620, Loss: 1354.3721923828125, Neurons: 17, Grad norm: 1.981e+02
# Epoch 621, Loss: 1353.7845458984375, Neurons: 17, Grad norm: 1.978e+02
# Epoch 622, Loss: 1353.185546875, Neurons: 17, Grad norm: 1.974e+02
# Epoch 623, Loss: 1352.5755615234375, Neurons: 17, Grad norm: 1.971e+02
# Epoch 624, Loss: 1351.955078125, Neurons: 17, Grad norm: 1.967e+02
# Epoch 625, Loss: 1351.3243408203125, Neurons: 17, Grad norm: 1.963e+02
# Epoch 626, Loss: 1350.68359375, Neurons: 17, Grad norm: 1.959e+02
# Epoch 627, Loss: 1350.0330810546875, Neurons: 17, Grad norm: 1.955e+02
# Epoch 628, Loss: 1349.373291015625, Neurons: 17, Grad norm: 1.950e+02
# Epoch 629, Loss: 1348.7047119140625, Neurons: 17, Grad norm: 1.946e+02
# Epoch 630, Loss: 1348.0274658203125, Neurons: 17, Grad norm: 1.942e+02
# Epoch 631, Loss: 1347.341796875, Neurons: 17, Grad norm: 1.937e+02
# Epoch 632, Loss: 1346.64794921875, Neurons: 17, Grad norm: 1.933e+02
# Epoch 633, Loss: 1345.9464111328125, Neurons: 17, Grad norm: 1.928e+02
# Epoch 634, Loss: 1345.2373046875, Neurons: 17, Grad norm: 1.923e+02
# Epoch 635, Loss: 1344.5211181640625, Neurons: 17, Grad norm: 1.918e+02
# Epoch 636, Loss: 1343.7978515625, Neurons: 17, Grad norm: 1.913e+02
# Epoch 637, Loss: 1343.06787109375, Neurons: 17, Grad norm: 1.909e+02
# Epoch 638, Loss: 1342.331298828125, Neurons: 17, Grad norm: 1.904e+02
# Epoch 639, Loss: 1341.5887451171875, Neurons: 17, Grad norm: 1.899e+02
# Epoch 640, Loss: 1340.840087890625, Neurons: 17, Grad norm: 1.894e+02
# Epoch 641, Loss: 1340.085693359375, Neurons: 17, Grad norm: 1.889e+02
# Epoch 642, Loss: 1339.32568359375, Neurons: 17, Grad norm: 1.883e+02
# Epoch 643, Loss: 1338.560302734375, Neurons: 17, Grad norm: 1.878e+02
# Epoch 644, Loss: 1337.7900390625, Neurons: 17, Grad norm: 1.873e+02
# Epoch 645, Loss: 1337.0147705078125, Neurons: 17, Grad norm: 1.868e+02
# Epoch 646, Loss: 1336.23486328125, Neurons: 17, Grad norm: 1.862e+02
# Epoch 647, Loss: 1335.4501953125, Neurons: 17, Grad norm: 1.857e+02
# Epoch 648, Loss: 1334.6614990234375, Neurons: 17, Grad norm: 1.851e+02
# Epoch 649, Loss: 1333.8685302734375, Neurons: 17, Grad norm: 1.846e+02
# Epoch 650, Loss: 1333.0716552734375, Neurons: 17, Grad norm: 1.840e+02
# Epoch 651, Loss: 1332.27099609375, Neurons: 17, Grad norm: 1.834e+02
# Epoch 652, Loss: 1331.4666748046875, Neurons: 17, Grad norm: 1.828e+02
# Epoch 653, Loss: 1330.658935546875, Neurons: 17, Grad norm: 1.822e+02
# Epoch 654, Loss: 1329.847900390625, Neurons: 17, Grad norm: 1.816e+02
# Epoch 655, Loss: 1329.0338134765625, Neurons: 17, Grad norm: 1.810e+02
# Epoch 656, Loss: 1328.216796875, Neurons: 17, Grad norm: 1.804e+02
# Epoch 657, Loss: 1327.39697265625, Neurons: 17, Grad norm: 1.798e+02
# Epoch 658, Loss: 1326.5743408203125, Neurons: 17, Grad norm: 1.792e+02
# Epoch 659, Loss: 1325.749267578125, Neurons: 17, Grad norm: 1.785e+02
# Epoch 660, Loss: 1324.9219970703125, Neurons: 17, Grad norm: 1.779e+02
# Epoch 661, Loss: 1324.09228515625, Neurons: 17, Grad norm: 1.773e+02
# Epoch 662, Loss: 1323.2606201171875, Neurons: 17, Grad norm: 1.766e+02
# Epoch 663, Loss: 1322.427001953125, Neurons: 17, Grad norm: 1.760e+02
# Epoch 664, Loss: 1321.591552734375, Neurons: 17, Grad norm: 1.753e+02
# Epoch 665, Loss: 1320.7545166015625, Neurons: 17, Grad norm: 1.746e+02
# Epoch 666, Loss: 1319.9158935546875, Neurons: 17, Grad norm: 1.739e+02
# Epoch 667, Loss: 1319.0760498046875, Neurons: 17, Grad norm: 1.733e+02
# Epoch 668, Loss: 1318.23486328125, Neurons: 17, Grad norm: 1.726e+02
# Epoch 669, Loss: 1317.392333984375, Neurons: 17, Grad norm: 1.719e+02
# Epoch 670, Loss: 1316.5489501953125, Neurons: 17, Grad norm: 1.712e+02
# ...
# Epoch 24790, Loss: 0.002558081643655896, Neurons: 43, Grad norm: 5.244e-01
# Epoch 24791, Loss: 0.002558572683483362, Neurons: 43, Grad norm: 6.334e-01
# Epoch 24792, Loss: 0.0025594555772840977, Neurons: 43, Grad norm: 7.710e-01
# Epoch 24793, Loss: 0.0025608816649764776, Neurons: 43, Grad norm: 9.441e-01
# Epoch 24794, Loss: 0.0025632334873080254, Neurons: 43, Grad norm: 1.165e+00
# Epoch 24795, Loss: 0.00256706727668643, Neurons: 43, Grad norm: 1.442e+00
# Epoch 24796, Loss: 0.0025730773340910673, Neurons: 43, Grad norm: 1.788e+00
# Epoch 24797, Loss: 0.002582588465884328, Neurons: 43, Grad norm: 2.224e+00
# Epoch 24798, Loss: 0.0025975839234888554, Neurons: 43, Grad norm: 2.774e+00
# Epoch 24799, Loss: 0.0026212721131742, Neurons: 43, Grad norm: 3.465e+00
# Epoch 24799, Test loss: 0.0022136573679745197
# Epoch 24800, Loss: 0.0026586181484162807, Neurons: 43, Grad norm: 4.336e+00
# Epoch 24801, Loss: 0.002717475173994899, Neurons: 43, Grad norm: 5.419e+00
np.savetxt(f"{out_folder}/test_loss.txt", test_loss_history)
np.savetxt(f"{out_folder}/grad_norm.txt", grad_norm_history)

# %% [markdown]
# ### evaluation

# %%
y_pred = jax.vmap(mlp)(x_test)
test_mse = jnp.mean((y_pred - y_test) ** 2)
plt.figure(figsize=(10, 6))
plt.plot(x_test, y_test, "b.", alpha=0.2, label="True Poly Function")
plt.plot(x_test, y_pred, "r.", alpha=0.2, label="MLP Predictions\n Test MSE: {:.4f}".format(test_mse))
plt.legend()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("MLP Approximation of polynomial Function")
plt.savefig(f"{fig_folder}/polynomial_approximation.png")
wandb.log({"polynomial approximation": wandb.Image(plt, caption="polynomial approximation")})

# %%
update_history
# Out:
# [(99,
#   11,
#   Array(1483.7523, dtype=float32),
#   Array(1513.2979, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (199,
#   12,
#   Array(1458.6096, dtype=float32),
#   Array(1487.7986, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (299,
#   13,
#   Array(1440.2368, dtype=float32),
#   Array(1468.9943, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (399,
#   14,
#   Array(1409.1898, dtype=float32),
#   Array(1437.4255, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (499,
#   15,
#   Array(1389.7279, dtype=float32),
#   Array(1417.6926, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (599,
#   16,
#   Array(1356.8438, dtype=float32),
#   Array(1383.5521, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (699,
#   17,
#   Array(1292.1996, dtype=float32),
#   Array(1317.505, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (799,
#   18,
#   Array(1258.07, dtype=float32),
#   Array(1283.0913, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (899,
#   19,
#   Array(1202.2585, dtype=float32),
#   Array(1226.1703, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (999,
#   20,
#   Array(1147.7917, dtype=float32),
#   Array(1170.6012, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1099,
#   21,
#   Array(1083.3466, dtype=float32),
#   Array(1105.0769, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1199,
#   22,
#   Array(1014.7542, dtype=float32),
#   Array(1035.362, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1299,
#   23,
#   Array(946.6526, dtype=float32),
#   Array(966.27484, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1399,
#   24,
#   Array(896.4197, dtype=float32),
#   Array(915.1933, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (1499,
#   25,
#   Array(850.88727, dtype=float32),
#   Array(868.84875, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1599,
#   26,
#   Array(783.0848, dtype=float32),
#   Array(799.6441, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1699,
#   27,
#   Array(740.53503, dtype=float32),
#   Array(756.1444, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (1799,
#   28,
#   Array(695.5264, dtype=float32),
#   Array(710.3469, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1899,
#   29,
#   Array(632.4885, dtype=float32),
#   Array(645.7081, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (1999,
#   30,
#   Array(562.3943, dtype=float32),
#   Array(573.9258, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (2099,
#   31,
#   Array(483.70874, dtype=float32),
#   Array(493.73523, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2199,
#   32,
#   Array(443.2958, dtype=float32),
#   Array(452.69763, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2299,
#   33,
#   Array(412.91348, dtype=float32),
#   Array(421.40884, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (2399,
#   34,
#   Array(369.41144, dtype=float32),
#   Array(377.06235, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2499,
#   35,
#   Array(336.90652, dtype=float32),
#   Array(343.8479, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2599,
#   36,
#   Array(783.56616, dtype=float32),
#   Array(788.3517, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (2699,
#   35,
#   Array(386.9206, dtype=float32),
#   Array(390.5357, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (2799,
#   34,
#   Array(300.29083, dtype=float32),
#   Array(306.2267, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (2899,
#   35,
#   Array(453.6459, dtype=float32),
#   Array(458.8382, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (2999,
#   34,
#   Array(299.00198, dtype=float32),
#   Array(302.7436, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3099,
#   35,
#   Array(238.93375, dtype=float32),
#   Array(242.89433, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3199,
#   36,
#   Array(206.28265, dtype=float32),
#   Array(209.31873, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3299,
#   37,
#   Array(181.96779, dtype=float32),
#   Array(184.31439, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3399,
#   38,
#   Array(146.00447, dtype=float32),
#   Array(147.26651, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (3499,
#   39,
#   Array(131.04439, dtype=float32),
#   Array(131.884, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3599,
#   40,
#   Array(110.17236, dtype=float32),
#   Array(110.65708, dtype=float32),
#   'sin',
#   Array(0, dtype=int32)),
#  (3699,
#   41,
#   Array(305.15378, dtype=float32),
#   Array(303.83, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (3799,
#   40,
#   Array(126.9791, dtype=float32),
#   Array(125.94954, dtype=float32),
#   'removed',
#   Array(0, dtype=int32)),
#  (3899,
#   39,
#   Array(87.99904, dtype=float32),
#   Array(88.12189, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (3999,
#   40,
#   Array(68.3744, dtype=float32),
#   Array(68.20124, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4099,
#   41,
#   Array(52.758167, dtype=float32),
#   Array(52.37412, dtype=float32),
#   'sin',
#   Array(1, dtype=int32)),
#  (4199,
#   42,
#   Array(36.328136, dtype=float32),
#   Array(36.00509, dtype=float32),
#   'sin',
#   Array(1, dtype=int32))]

# %%
final_adjacency_matrix = mlp.adjacency_matrix()

# %%
np.savetxt(f"{out_folder}/final_adjacency_matrix.txt", final_adjacency_matrix)

# %%
max_wt = np.max(np.abs(final_adjacency_matrix))
norm = MidpointNormalize(vmin=-max_wt, vmax=max_wt, midpoint=0)
cmap = plt.get_cmap('coolwarm')

fig, ax = plt.subplots()
cax = ax.matshow(final_adjacency_matrix, cmap=cmap, norm=norm)
cbar = fig.colorbar(cax, ticks=[-max_wt,
                                -max_wt/2, 
                                0,
                                max_wt/2,
                                max_wt])

# plt.colorbar()
plt.title("final adjacency matrix")
plt.savefig(f"{fig_folder}/final_adjacency_matrix.png")
wandb.log({"final adjacency matrix": wandb.Image(plt, caption="final adjacency matrix")})

# %%
sub_matrices = np.split(final_adjacency_matrix, np.cumsum(mlp.get_shape())[:-1])[:-1]

fig, axs = plt.subplots(1, len(sub_matrices), figsize=(20, 5))

for i, (sub_matrix, ax) in enumerate(zip(sub_matrices, axs), start=1):
    weights = sub_matrix.flatten()
    weights = weights[weights != 0]
    ax.hist(weights, bins="auto", density=False, alpha=0.6, color='g')
    ax.set_xlabel('Weights')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Layer {i}-Layer {i+1} ')

# Display the figure with its subplots
plt.suptitle('Final Weight Distribution (excluding zero weights)')
plt.tight_layout()
plt.show()

# %%
train_epochs, train_loss = zip(*train_loss_history)
test_epochs, test_loss = zip(*test_loss_history)
grad_epochs, grad_norm_val = zip(*grad_norm_history)
node_epochs, n_neurons = zip(*node_history)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

# ax1.set_xscale("log")

plt.suptitle(f"Homogenous {act_string} Neural Network with probabilistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve.png")
wandb.log({"loss and nodes": wandb.Image(plt, caption="loss and nodes")})

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color=color)
ax1.plot(train_epochs, train_loss, "-.", color=color, label="Train Loss")
ax1.plot(test_epochs, test_loss, "*", color="darkred", label="Test Loss")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")
ax1.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(node_epochs, n_neurons, "-.", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)


ax3 = ax1.twinx()

color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third y-axis
ax3.plot(grad_epochs, grad_norm_val, '.', color=color, alpha = 0.1, label="Gradient Norm")
ax3.set_ylabel('Gradient norm', color=color)
ax3.tick_params(axis='y', labelcolor=color)
ax3.set_yscale("log")
ax3.spines['right'].set_color(color)

ax1.set_xscale("log")

plt.suptitle(f"Homogenous {act_string} Neural Network with probablistic strategic Node Addition and Removal")
fig.tight_layout()
plt.savefig(f"{fig_folder}/loss_curve_loglog.png")

# %%
G, neuron_labels, neuron_importances = mlp.visualize_graph()
fig = mlp_plot(G, neuron_labels, neuron_importances)
plt.savefig(f"{fig_folder}/final_graph.png")
wandb.log({"final neural network": wandb.Image(plt, caption="final neural network")})

# %%
wandb.finish()

# %%
import matplotlib.patches as mpatches
colors = []
epochs, times, n_neurons = zip(*time_history)

diffs = np.diff(n_neurons, prepend=n_neurons[0])

colors = ['tab:green' if diff > 0 else
            'tab:red' if diff < 0 else
            'tab:orange' if (i+1)% intervene_every*int(n_neurons[i]/init_neurons) == 0 else
            'k' for i,diff in enumerate(diffs)]

fig, ax1 = plt.subplots(figsize=(10, 6))

# color = 'tab:red'
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Time(s)')
for epoch, time, color in zip(epochs, times, colors):
    ax1.plot(epoch, time, ".", color=color, alpha=0.5)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yscale("log")

patches = [
    mpatches.Patch(color='tab:green', label='Increase in n_neurons'),
    mpatches.Patch(color='tab:red', label='Decrease in n_neurons'),
    mpatches.Patch(color='tab:orange', label='Intervening')
]

ax1.legend(handles=patches)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Number of Nodes', color=color)  # we already handled the x-label with ax1
ax2.plot(epochs, n_neurons, ".", color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.spines['right'].set_color(color)
